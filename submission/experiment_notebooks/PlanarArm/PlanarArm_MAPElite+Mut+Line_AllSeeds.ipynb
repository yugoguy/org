# %% [markdown]
# # MAP-Elite (Gaussian + Line, Boltzmann Mix) — Baseline
#
# **Method:** MAP-Elites with `PSEMut` + `PSELine` (Boltzmann Mix adaptive allocation)
# **Environments:** 4 Planar Arm settings (Det_Linear, Unc_Linear, Det_NonLinear, Unc_NonLinear)
# **Seeds:** 3 per environment
# **Task:** 1000-joint Planar Arm (CVT, 1950 bins)

# %%
# ============================================================
# Cell 1: Setup — mount Drive, clone repo, load SSLVE modules
# Run this cell once at the start of each Colab session.
# ============================================================
from google.colab import drive
drive.mount('/content/drive')

# !rm -rf org && git clone --filter=blob:none --sparse https://github.com/yugoguy/org.git
# !cd org && git sparse-checkout set dev/SSLVE && git checkout Latent-Variable-Evolution
# !pip install cma -q

import sys, os, glob
sys.path.insert(0, 'org/dev/SSLVE')
for f in sorted(glob.glob('org/dev/SSLVE/*.py')):
    # %run {f}

print('Setup complete.')
# Out:
# Mounted at /content/drive
# Cloning into 'org'...
# remote: Enumerating objects: 1726, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (191/191), done.
# remote: Total 1726 (delta 140), reused 34 (delta 34), pack-reused 1501 (from 2)
# Receiving objects: 100% (1726/1726), 484.56 KiB | 10.77 MiB/s, done.
# Resolving deltas: 100% (692/692), done.
# remote: Enumerating objects: 1, done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 1 (from 1)
# Receiving objects: 100% (1/1), 255 bytes | 255.00 KiB/s, done.
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 18 (delta 4), reused 1 (delta 1), pack-reused 7 (from 1)
# Receiving objects: 100% (18/18), 73.23 KiB | 5.23 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Branch 'Latent-Variable-Evolution' set up to track remote branch 'Latent-Variable-Evolution' from 'origin'.
# Switched to a new branch 'Latent-Variable-Evolution'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 6.7 MB/s eta 0:00:00
# Setup complete.

# %%
# ============================================================
# Cell 2: Method Hyperparameters
# ============================================================
import numpy as np
import random
import torch

# --- Architecture ---
N_JOINTS         = 1000   #@param {type:"integer"}
END_EFFECTOR_DIM = 2      #@param {type:"integer"}
N_BINS           = 1950   #@param {type:"integer"}
CENTERS          = "Precomputed_CVT_1950"  #@param ["Precomputed_CVT_1950", "CVT", "random"]
TOP_K            = 1      #@param {type:"integer"}
GREEDY_MEM       = True   #@param {type:"boolean"}

# --- Mutation sigma ---
PSE_MUT_SIGMA    = 0.05   #@param {type:"number"}

# --- Boltzmann Mix (matched to LVE for stability) ---
EMA_ALPHA        = 0.1    #@param {type:"number"}
TEMPERATURE      = 10     #@param {type:"number"}
MIN_PROPORTION   = 0.05   #@param {type:"number"}

# --- Search budget (must match other methods for fair comparison) ---
N_TOTAL          = 500   #@param {type:"integer"}
N_STEPS          = 1000   #@param {type:"integer"}

# --- Checkpoint base directory (saved to Google Drive) ---
CKPT_BASE_DIR    = '/content/drive/MyDrive/shared_ckpts/planar_arm/PlanarArm_MAPElite_GaussLine_BoltzMix/'  #@param {type:"string"}

print(f'Method: MAP-Elite (Gaussian + Line, Boltzmann Mix)')
print(f'N_JOINTS={N_JOINTS}, N_BINS={N_BINS}, TOP_K={TOP_K}')
print(f'PSE_MUT_SIGMA={PSE_MUT_SIGMA}')
print(f'EMA_ALPHA={EMA_ALPHA}, TEMPERATURE={TEMPERATURE}, MIN_PROPORTION={MIN_PROPORTION}')
print(f'N_TOTAL={N_TOTAL}, N_STEPS={N_STEPS}')
print(f'Checkpoints will be saved to: {CKPT_BASE_DIR}')
# Out:
# Method: MAP-Elite (Gaussian + Line, Boltzmann Mix)
# N_JOINTS=1000, N_BINS=1950, TOP_K=1
# PSE_MUT_SIGMA=0.05
# EMA_ALPHA=0.1, TEMPERATURE=10, MIN_PROPORTION=0.05
# N_TOTAL=500, N_STEPS=1000
# Checkpoints will be saved to: /content/drive/MyDrive/shared_ckpts/planar_arm/PlanarArm_MAPElite_GaussLine_BoltzMix/

# %%
# ============================================================
# Cell 3: Run All Experiments (4 envs x 3 seeds)
# Each run saves a checkpoint + plots immediately after finishing.
# ============================================================

ENV_CONFIGS = [
    {'name': 'Det_Linear',    'noise_sigma': 0.0,  'n_episodes': 1, 'fitness': 'angle_variance'},
    {'name': 'Unc_Linear',    'noise_sigma': 0.05, 'n_episodes': 3, 'fitness': 'angle_variance'},
    {'name': 'Det_NonLinear', 'noise_sigma': 0.0,  'n_episodes': 1, 'fitness': 'sine_dependency'},
    {'name': 'Unc_NonLinear', 'noise_sigma': 0.05, 'n_episodes': 3, 'fitness': 'sine_dependency'},
]

SEEDS = [42, 123, 456]

FITNESS_FNS = {
    'angle_variance':  lambda info: (np.mean(info['angle_variance'])  if isinstance(info['angle_variance'],  list) else info['angle_variance']),
    'sine_dependency': lambda info: (np.mean(info['sine_dependency']) if isinstance(info['sine_dependency'], list) else info['sine_dependency']),
}

all_results = []

ANGLES_PER_JOINT = END_EFFECTOR_DIM - 1
GENE_DIM = N_JOINTS * ANGLES_PER_JOINT
init_fn = lambda: np.random.uniform(-np.pi, np.pi, GENE_DIM)

for env_cfg in ENV_CONFIGS:
    env_name    = env_cfg['name']
    noise_sig   = env_cfg['noise_sigma']
    n_eps       = env_cfg['n_episodes']
    fitness_key = env_cfg['fitness']
    fitness_fn  = FITNESS_FNS[fitness_key]

    for seed in SEEDS:
        print(f'\n========== {env_name} | seed={seed} ==========')

        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)

        collector = PlanarArmCollector(
            n_joints=N_JOINTS,
            end_effector_dim=END_EFFECTOR_DIM,
            noise_sigma=noise_sig,
            n_episodes=n_eps,
        )
        bd = PlanarArmBD_CVT(n_bins=N_BINS, centers=CENTERS, bd_dim=END_EFFECTOR_DIM)
        bm = MAPElitesBM(behavior_descriptor=bd, fitness_fn=fitness_fn, top_k=TOP_K, max_fitness=100)

        sp = BoltzmannMix(
            agent_class=PlanarArmAgent,
            architecture=GENE_DIM,
            operators=[PSEMut(sigma=PSE_MUT_SIGMA, greedy_mem=GREEDY_MEM), PSELine(greedy_mem=GREEDY_MEM)],
            n_total=N_TOTAL,
            warmup_threshold=999999,
            ema_alpha=EMA_ALPHA,
            temperature=TEMPERATURE,
            min_proportion=MIN_PROPORTION,
            init_fn=init_fn,
        )

        me = MAPElite(search_phase=sp, collector=collector, behavior_matching=bm)
        me.run(n_steps=N_STEPS)

        # Save checkpoint immediately after this run
        ckpt_path = os.path.join(
            CKPT_BASE_DIR,
            f'MAPElite_GaussLine_BoltzMix_{env_name}_seed{seed}/'
        )
        save_checkpoint(ckpt_path, bm, me.history, sp=sp)
        print(f'Checkpoint saved: {ckpt_path}')

        # Save plots into checkpoint folder
        me.plot_history(save_path=ckpt_path + 'plot_history.png')
        sp.plot_allocation(save_path=ckpt_path + 'plot_allocation.png')
        print(f'Plots saved to: {ckpt_path}')

        # Force Drive sync after each run
        from google.colab import drive
        drive.flush_and_unmount()
        drive.mount('/content/drive')
        print('Drive re-synced.')

        # Print results
        f_min, f_mean, f_max = bm.fitness_stats()
        qd  = bm.qd_score()
        cov = bm.coverage()
        print(f'QD-score: {qd:.4f} | Coverage: {cov:.4f} | Best fitness: {f_min:.6f}')

        all_results.append({
            'env': env_name, 'seed': seed,
            'qd_score': qd, 'coverage': cov,
        })

print('\n====== All runs complete ======')
# Out:
# Streaming output truncated to the last 5000 lines.
# QD-score: 43683.3456
#
# --- MAP-Elite Step 168/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 438, Bins: 438, Coverage: 0.2246, Fitness min/mean/max: 0.25/0.27/0.33
# QD-score: 43683.5178
#
# --- MAP-Elite Step 169/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 439, Bins: 439, Coverage: 0.2251, Fitness min/mean/max: 0.25/0.27/0.33
# QD-score: 43783.3634
#
# --- MAP-Elite Step 170/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 439, Bins: 439, Coverage: 0.2251, Fitness min/mean/max: 0.25/0.27/0.33
# QD-score: 43783.5571
#
# --- MAP-Elite Step 171/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 439, Bins: 439, Coverage: 0.2251, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43783.6958
#
# --- MAP-Elite Step 172/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 439, Bins: 439, Coverage: 0.2251, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43783.9234
#
# --- MAP-Elite Step 173/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 439, Bins: 439, Coverage: 0.2251, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43784.0402
#
# --- MAP-Elite Step 174/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 439, Bins: 439, Coverage: 0.2251, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43784.1705
#
# --- MAP-Elite Step 175/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 439, Bins: 439, Coverage: 0.2251, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43784.3088
#
# --- MAP-Elite Step 176/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 439, Bins: 439, Coverage: 0.2251, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43784.4700
#
# --- MAP-Elite Step 177/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 439, Bins: 439, Coverage: 0.2251, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43784.5931
#
# --- MAP-Elite Step 178/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 439, Bins: 439, Coverage: 0.2251, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43784.8023
#
# --- MAP-Elite Step 179/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 440, Bins: 440, Coverage: 0.2256, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43884.7439
#
# --- MAP-Elite Step 180/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 440, Bins: 440, Coverage: 0.2256, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43884.9054
#
# --- MAP-Elite Step 181/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 440, Bins: 440, Coverage: 0.2256, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43885.0651
#
# --- MAP-Elite Step 182/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 440, Bins: 440, Coverage: 0.2256, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43885.2152
#
# --- MAP-Elite Step 183/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 440, Bins: 440, Coverage: 0.2256, Fitness min/mean/max: 0.25/0.26/0.33
# QD-score: 43885.4294
#
# --- MAP-Elite Step 184/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 441, Bins: 441, Coverage: 0.2262, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 43985.3030
#
# --- MAP-Elite Step 185/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 441, Bins: 441, Coverage: 0.2262, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 43985.5620
#
# --- MAP-Elite Step 186/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 441, Bins: 441, Coverage: 0.2262, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 43985.7757
#
# --- MAP-Elite Step 187/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 441, Bins: 441, Coverage: 0.2262, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 43986.0327
#
# --- MAP-Elite Step 188/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 441, Bins: 441, Coverage: 0.2262, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 43986.2379
#
# --- MAP-Elite Step 189/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 441, Bins: 441, Coverage: 0.2262, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 43986.4588
#
# --- MAP-Elite Step 190/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 441, Bins: 441, Coverage: 0.2262, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 43986.6689
#
# --- MAP-Elite Step 191/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 441, Bins: 441, Coverage: 0.2262, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 43986.9454
#
# --- MAP-Elite Step 192/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 441, Bins: 441, Coverage: 0.2262, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 43987.1833
#
# --- MAP-Elite Step 193/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 442, Bins: 442, Coverage: 0.2267, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 44087.1222
#
# --- MAP-Elite Step 194/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 443, Bins: 443, Coverage: 0.2272, Fitness min/mean/max: 0.24/0.26/0.33
# QD-score: 44186.9920
#
# --- MAP-Elite Step 195/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 443, Bins: 443, Coverage: 0.2272, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44187.2201
#
# --- MAP-Elite Step 196/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 443, Bins: 443, Coverage: 0.2272, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44187.4278
#
# --- MAP-Elite Step 197/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 443, Bins: 443, Coverage: 0.2272, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44187.6334
#
# --- MAP-Elite Step 198/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 443, Bins: 443, Coverage: 0.2272, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44187.8515
#
# --- MAP-Elite Step 199/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 444, Bins: 444, Coverage: 0.2277, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44287.6866
#
# --- MAP-Elite Step 200/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 444, Bins: 444, Coverage: 0.2277, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44287.8364
#
# --- MAP-Elite Step 201/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 444, Bins: 444, Coverage: 0.2277, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44287.9738
#
# --- MAP-Elite Step 202/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 445, Bins: 445, Coverage: 0.2282, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44387.8669
#
# --- MAP-Elite Step 203/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 445, Bins: 445, Coverage: 0.2282, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44388.0621
#
# --- MAP-Elite Step 204/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 445, Bins: 445, Coverage: 0.2282, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44388.2855
#
# --- MAP-Elite Step 205/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 445, Bins: 445, Coverage: 0.2282, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44388.4195
#
# --- MAP-Elite Step 206/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44488.2486
#
# --- MAP-Elite Step 207/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44488.3989
#
# --- MAP-Elite Step 208/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44488.5234
#
# --- MAP-Elite Step 209/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44488.7331
#
# --- MAP-Elite Step 210/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44488.9078
#
# --- MAP-Elite Step 211/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.24/0.25/0.33
# QD-score: 44489.0902
#
# --- MAP-Elite Step 212/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.23/0.25/0.33
# QD-score: 44489.2555
#
# --- MAP-Elite Step 213/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.23/0.25/0.33
# QD-score: 44489.4140
#
# --- MAP-Elite Step 214/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.23/0.25/0.33
# QD-score: 44489.5807
#
# --- MAP-Elite Step 215/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.23/0.25/0.33
# QD-score: 44489.7436
#
# --- MAP-Elite Step 216/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 446, Bins: 446, Coverage: 0.2287, Fitness min/mean/max: 0.23/0.25/0.33
# QD-score: 44489.9328
#
# --- MAP-Elite Step 217/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 447, Bins: 447, Coverage: 0.2292, Fitness min/mean/max: 0.23/0.25/0.33
# QD-score: 44589.9105
#
# --- MAP-Elite Step 218/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 447, Bins: 447, Coverage: 0.2292, Fitness min/mean/max: 0.23/0.25/0.33
# QD-score: 44590.0895
#
# --- MAP-Elite Step 219/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 447, Bins: 447, Coverage: 0.2292, Fitness min/mean/max: 0.23/0.25/0.33
# QD-score: 44590.2993
#
# --- MAP-Elite Step 220/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44690.2530
#
# --- MAP-Elite Step 221/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44690.4220
#
# --- MAP-Elite Step 222/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44690.6793
#
# --- MAP-Elite Step 223/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44690.8235
#
# --- MAP-Elite Step 224/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44690.9846
#
# --- MAP-Elite Step 225/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44691.1387
#
# --- MAP-Elite Step 226/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44691.3205
#
# --- MAP-Elite Step 227/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44691.4483
#
# --- MAP-Elite Step 228/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44691.6129
#
# --- MAP-Elite Step 229/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44691.7763
#
# --- MAP-Elite Step 230/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44691.9203
#
# --- MAP-Elite Step 231/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44692.0629
#
# --- MAP-Elite Step 232/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44692.1874
#
# --- MAP-Elite Step 233/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44692.3300
#
# --- MAP-Elite Step 234/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44692.4918
#
# --- MAP-Elite Step 235/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44692.6347
#
# --- MAP-Elite Step 236/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.33
# QD-score: 44692.7577
#
# --- MAP-Elite Step 237/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.32
# QD-score: 44692.9515
#
# --- MAP-Elite Step 238/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.32
# QD-score: 44693.1484
#
# --- MAP-Elite Step 239/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.32
# QD-score: 44693.3151
#
# --- MAP-Elite Step 240/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.32
# QD-score: 44693.4885
#
# --- MAP-Elite Step 241/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.23/0.24/0.32
# QD-score: 44693.6724
#
# --- MAP-Elite Step 242/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.22/0.24/0.32
# QD-score: 44693.8093
#
# --- MAP-Elite Step 243/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 448, Bins: 448, Coverage: 0.2297, Fitness min/mean/max: 0.22/0.24/0.32
# QD-score: 44693.9592
#
# --- MAP-Elite Step 244/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 449, Bins: 449, Coverage: 0.2303, Fitness min/mean/max: 0.22/0.24/0.32
# QD-score: 44793.8587
#
# --- MAP-Elite Step 245/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 450, Bins: 450, Coverage: 0.2308, Fitness min/mean/max: 0.22/0.24/0.32
# QD-score: 44893.7903
#
# --- MAP-Elite Step 246/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 451, Bins: 451, Coverage: 0.2313, Fitness min/mean/max: 0.22/0.24/0.32
# QD-score: 44993.7099
#
# --- MAP-Elite Step 247/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 451, Bins: 451, Coverage: 0.2313, Fitness min/mean/max: 0.22/0.24/0.32
# QD-score: 44993.9020
#
# --- MAP-Elite Step 248/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 451, Bins: 451, Coverage: 0.2313, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 44994.1265
#
# --- MAP-Elite Step 249/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 451, Bins: 451, Coverage: 0.2313, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 44994.3369
#
# --- MAP-Elite Step 250/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 451, Bins: 451, Coverage: 0.2313, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 44994.4771
#
# --- MAP-Elite Step 251/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 452, Bins: 452, Coverage: 0.2318, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45094.3861
#
# --- MAP-Elite Step 252/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 452, Bins: 452, Coverage: 0.2318, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45094.6172
#
# --- MAP-Elite Step 253/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 452, Bins: 452, Coverage: 0.2318, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45094.7665
#
# --- MAP-Elite Step 254/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 452, Bins: 452, Coverage: 0.2318, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45094.9093
#
# --- MAP-Elite Step 255/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 452, Bins: 452, Coverage: 0.2318, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45095.2054
#
# --- MAP-Elite Step 256/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 453, Bins: 453, Coverage: 0.2323, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45195.0896
#
# --- MAP-Elite Step 257/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 453, Bins: 453, Coverage: 0.2323, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45195.2913
#
# --- MAP-Elite Step 258/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 453, Bins: 453, Coverage: 0.2323, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45195.4629
#
# --- MAP-Elite Step 259/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 453, Bins: 453, Coverage: 0.2323, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45195.6266
#
# --- MAP-Elite Step 260/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 454, Bins: 454, Coverage: 0.2328, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45295.5950
#
# --- MAP-Elite Step 261/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 455, Bins: 455, Coverage: 0.2333, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45395.4587
#
# --- MAP-Elite Step 262/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 455, Bins: 455, Coverage: 0.2333, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45395.6598
#
# --- MAP-Elite Step 263/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45595.3119
#
# --- MAP-Elite Step 264/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45595.4754
#
# --- MAP-Elite Step 265/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45595.6233
#
# --- MAP-Elite Step 266/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45595.8118
#
# --- MAP-Elite Step 267/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45595.9924
#
# --- MAP-Elite Step 268/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45596.1777
#
# --- MAP-Elite Step 269/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45596.3843
#
# --- MAP-Elite Step 270/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.22/0.23/0.32
# QD-score: 45596.5976
#
# --- MAP-Elite Step 271/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.23/0.32
# QD-score: 45596.8335
#
# --- MAP-Elite Step 272/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.23/0.32
# QD-score: 45597.0282
#
# --- MAP-Elite Step 273/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45597.2123
#
# --- MAP-Elite Step 274/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45597.4545
#
# --- MAP-Elite Step 275/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45597.6574
#
# --- MAP-Elite Step 276/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45597.8779
#
# --- MAP-Elite Step 277/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45598.0322
#
# --- MAP-Elite Step 278/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45598.2012
#
# --- MAP-Elite Step 279/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45598.4273
#
# --- MAP-Elite Step 280/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45598.6169
#
# --- MAP-Elite Step 281/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45598.8079
#
# --- MAP-Elite Step 282/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45598.9814
#
# --- MAP-Elite Step 283/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45599.1527
#
# --- MAP-Elite Step 284/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45599.3374
#
# --- MAP-Elite Step 285/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45599.4854
#
# --- MAP-Elite Step 286/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45599.6810
#
# --- MAP-Elite Step 287/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45599.9140
#
# --- MAP-Elite Step 288/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45600.2222
#
# --- MAP-Elite Step 289/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45600.3956
#
# --- MAP-Elite Step 290/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45600.5684
#
# --- MAP-Elite Step 291/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 457, Bins: 457, Coverage: 0.2344, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45600.7648
#
# --- MAP-Elite Step 292/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 458, Bins: 458, Coverage: 0.2349, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45700.8184
#
# --- MAP-Elite Step 293/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 459, Bins: 459, Coverage: 0.2354, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45800.7179
#
# --- MAP-Elite Step 294/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 460, Bins: 460, Coverage: 0.2359, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 45900.6450
#
# --- MAP-Elite Step 295/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 461, Bins: 461, Coverage: 0.2364, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 46000.5301
#
# --- MAP-Elite Step 296/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 462, Bins: 462, Coverage: 0.2369, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 46100.4300
#
# --- MAP-Elite Step 297/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 463, Bins: 463, Coverage: 0.2374, Fitness min/mean/max: 0.21/0.22/0.32
# QD-score: 46200.3714
#
# --- MAP-Elite Step 298/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 464, Bins: 464, Coverage: 0.2379, Fitness min/mean/max: 0.20/0.21/0.32
# QD-score: 46300.3092
#
# --- MAP-Elite Step 299/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 465, Bins: 465, Coverage: 0.2385, Fitness min/mean/max: 0.20/0.21/0.32
# QD-score: 46400.2048
#
# --- MAP-Elite Step 300/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 465, Bins: 465, Coverage: 0.2385, Fitness min/mean/max: 0.20/0.21/0.32
# QD-score: 46400.3280
#
# --- MAP-Elite Step 301/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 465, Bins: 465, Coverage: 0.2385, Fitness min/mean/max: 0.20/0.21/0.31
# QD-score: 46400.5770
#
# --- MAP-Elite Step 302/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 466, Bins: 466, Coverage: 0.2390, Fitness min/mean/max: 0.20/0.21/0.31
# QD-score: 46500.5416
#
# --- MAP-Elite Step 303/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 467, Bins: 467, Coverage: 0.2395, Fitness min/mean/max: 0.20/0.21/0.31
# QD-score: 46600.4686
#
# --- MAP-Elite Step 304/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 467, Bins: 467, Coverage: 0.2395, Fitness min/mean/max: 0.20/0.21/0.31
# QD-score: 46600.5849
#
# --- MAP-Elite Step 305/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 467, Bins: 467, Coverage: 0.2395, Fitness min/mean/max: 0.20/0.21/0.31
# QD-score: 46600.7149
#
# --- MAP-Elite Step 306/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 468, Bins: 468, Coverage: 0.2400, Fitness min/mean/max: 0.20/0.21/0.31
# QD-score: 46700.6034
#
# --- MAP-Elite Step 307/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 469, Bins: 469, Coverage: 0.2405, Fitness min/mean/max: 0.20/0.21/0.30
# QD-score: 46800.5603
#
# --- MAP-Elite Step 308/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 469, Bins: 469, Coverage: 0.2405, Fitness min/mean/max: 0.20/0.21/0.30
# QD-score: 46800.7419
#
# --- MAP-Elite Step 309/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 469, Bins: 469, Coverage: 0.2405, Fitness min/mean/max: 0.20/0.21/0.30
# QD-score: 46800.8809
#
# --- MAP-Elite Step 310/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 470, Bins: 470, Coverage: 0.2410, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 46900.8119
#
# --- MAP-Elite Step 311/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 470, Bins: 470, Coverage: 0.2410, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 46900.9642
#
# --- MAP-Elite Step 312/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 470, Bins: 470, Coverage: 0.2410, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 46901.1165
#
# --- MAP-Elite Step 313/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 470, Bins: 470, Coverage: 0.2410, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 46901.2770
#
# --- MAP-Elite Step 314/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 471, Bins: 471, Coverage: 0.2415, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 47001.1803
#
# --- MAP-Elite Step 315/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 471, Bins: 471, Coverage: 0.2415, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 47001.3208
#
# --- MAP-Elite Step 316/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 471, Bins: 471, Coverage: 0.2415, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 47001.4530
#
# --- MAP-Elite Step 317/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 471, Bins: 471, Coverage: 0.2415, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 47001.6111
#
# --- MAP-Elite Step 318/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 472, Bins: 472, Coverage: 0.2421, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 47101.5766
#
# --- MAP-Elite Step 319/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 473, Bins: 473, Coverage: 0.2426, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 47201.5243
#
# --- MAP-Elite Step 320/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 476, Bins: 476, Coverage: 0.2441, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 47501.0063
#
# --- MAP-Elite Step 321/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 476, Bins: 476, Coverage: 0.2441, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 47501.1468
#
# --- MAP-Elite Step 322/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 476, Bins: 476, Coverage: 0.2441, Fitness min/mean/max: 0.20/0.21/0.29
# QD-score: 47501.3182
#
# --- MAP-Elite Step 323/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 476, Bins: 476, Coverage: 0.2441, Fitness min/mean/max: 0.20/0.21/0.25
# QD-score: 47501.4997
#
# --- MAP-Elite Step 324/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 476, Bins: 476, Coverage: 0.2441, Fitness min/mean/max: 0.20/0.21/0.25
# QD-score: 47501.6515
#
# --- MAP-Elite Step 325/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 476, Bins: 476, Coverage: 0.2441, Fitness min/mean/max: 0.20/0.21/0.25
# QD-score: 47501.8429
#
# --- MAP-Elite Step 326/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 476, Bins: 476, Coverage: 0.2441, Fitness min/mean/max: 0.20/0.21/0.25
# QD-score: 47502.0343
#
# --- MAP-Elite Step 327/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 477, Bins: 477, Coverage: 0.2446, Fitness min/mean/max: 0.20/0.21/0.25
# QD-score: 47601.9670
#
# --- MAP-Elite Step 328/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 477, Bins: 477, Coverage: 0.2446, Fitness min/mean/max: 0.19/0.21/0.25
# QD-score: 47602.0800
#
# --- MAP-Elite Step 329/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 477, Bins: 477, Coverage: 0.2446, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 47602.2540
#
# --- MAP-Elite Step 330/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 478, Bins: 478, Coverage: 0.2451, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 47702.2188
#
# --- MAP-Elite Step 331/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 480, Bins: 480, Coverage: 0.2462, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 47901.9892
#
# --- MAP-Elite Step 332/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 482, Bins: 482, Coverage: 0.2472, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 48101.7121
#
# --- MAP-Elite Step 333/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 484, Bins: 484, Coverage: 0.2482, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 48301.4444
#
# --- MAP-Elite Step 334/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 485, Bins: 485, Coverage: 0.2487, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 48401.4358
#
# --- MAP-Elite Step 335/1000 ---
#   Operator ratio - pse_mut: 247/500 (49%), pse_line: 253/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 486, Bins: 486, Coverage: 0.2492, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 48501.4345
#
# --- MAP-Elite Step 336/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 486, Bins: 486, Coverage: 0.2492, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 48501.6195
#
# --- MAP-Elite Step 337/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 491, Bins: 491, Coverage: 0.2518, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 49000.7400
#
# --- MAP-Elite Step 338/1000 ---
#   Operator ratio - pse_mut: 247/500 (49%), pse_line: 253/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 493, Bins: 493, Coverage: 0.2528, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 49200.4714
#
# --- MAP-Elite Step 339/1000 ---
#   Operator ratio - pse_mut: 246/500 (49%), pse_line: 254/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 493, Bins: 493, Coverage: 0.2528, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 49200.6646
#
# --- MAP-Elite Step 340/1000 ---
#   Operator ratio - pse_mut: 247/500 (49%), pse_line: 253/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 494, Bins: 494, Coverage: 0.2533, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 49300.6249
#
# --- MAP-Elite Step 341/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 497, Bins: 497, Coverage: 0.2549, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 49600.1055
#
# --- MAP-Elite Step 342/1000 ---
#   Operator ratio - pse_mut: 246/500 (49%), pse_line: 254/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 497, Bins: 497, Coverage: 0.2549, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 49600.3130
#
# --- MAP-Elite Step 343/1000 ---
#   Operator ratio - pse_mut: 247/500 (49%), pse_line: 253/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 498, Bins: 498, Coverage: 0.2554, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 49700.2818
#
# --- MAP-Elite Step 344/1000 ---
#   Operator ratio - pse_mut: 247/500 (49%), pse_line: 253/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 499, Bins: 499, Coverage: 0.2559, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 49800.2253
#
# --- MAP-Elite Step 345/1000 ---
#   Operator ratio - pse_mut: 246/500 (49%), pse_line: 254/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 499, Bins: 499, Coverage: 0.2559, Fitness min/mean/max: 0.19/0.20/0.25
# QD-score: 49800.3566
#
# --- MAP-Elite Step 346/1000 ---
#   Operator ratio - pse_mut: 247/500 (49%), pse_line: 253/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 499, Bins: 499, Coverage: 0.2559, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 49800.6022
#
# --- MAP-Elite Step 347/1000 ---
#   Operator ratio - pse_mut: 247/500 (49%), pse_line: 253/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 499, Bins: 499, Coverage: 0.2559, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 49800.8142
#
# --- MAP-Elite Step 348/1000 ---
#   Operator ratio - pse_mut: 247/500 (49%), pse_line: 253/500 (51%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 499, Bins: 499, Coverage: 0.2559, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 49800.9974
#
# --- MAP-Elite Step 349/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 499, Bins: 499, Coverage: 0.2559, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 49801.1567
#
# --- MAP-Elite Step 350/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 500, Bins: 500, Coverage: 0.2564, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 49901.1196
#
# --- MAP-Elite Step 351/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 500, Bins: 500, Coverage: 0.2564, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 49901.2865
#
# --- MAP-Elite Step 352/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 501, Bins: 501, Coverage: 0.2569, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 50001.1999
#
# --- MAP-Elite Step 353/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 501, Bins: 501, Coverage: 0.2569, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 50001.3737
#
# --- MAP-Elite Step 354/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 502, Bins: 502, Coverage: 0.2574, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 50101.2700
#
# --- MAP-Elite Step 355/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 502, Bins: 502, Coverage: 0.2574, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 50101.3976
#
# --- MAP-Elite Step 356/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 502, Bins: 502, Coverage: 0.2574, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 50101.5220
#
# --- MAP-Elite Step 357/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 502, Bins: 502, Coverage: 0.2574, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 50101.6652
#
# --- MAP-Elite Step 358/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 502, Bins: 502, Coverage: 0.2574, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 50101.7908
#
# --- MAP-Elite Step 359/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 502, Bins: 502, Coverage: 0.2574, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 50101.9110
#
# --- MAP-Elite Step 360/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 503, Bins: 503, Coverage: 0.2579, Fitness min/mean/max: 0.19/0.20/0.24
# QD-score: 50201.8069
#
# --- MAP-Elite Step 361/1000 ---
# ...
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 163, Bins: 163, Coverage: 0.0836, Fitness min/mean/max: 2.02/2.08/3.24
# QD-score: 15961.4867
#
# --- MAP-Elite Step 89/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 164, Bins: 164, Coverage: 0.0841, Fitness min/mean/max: 2.01/2.07/3.24
# QD-score: 16060.1037
#
# --- MAP-Elite Step 90/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 164, Bins: 164, Coverage: 0.0841, Fitness min/mean/max: 2.01/2.07/3.24
# QD-score: 16061.1193
#
# --- MAP-Elite Step 91/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 164, Bins: 164, Coverage: 0.0841, Fitness min/mean/max: 2.00/2.06/3.24
# QD-score: 16061.8553
#
# --- MAP-Elite Step 92/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 165, Bins: 165, Coverage: 0.0846, Fitness min/mean/max: 2.00/2.06/3.24
# QD-score: 16160.4970
#
# --- MAP-Elite Step 93/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 166, Bins: 166, Coverage: 0.0851, Fitness min/mean/max: 2.00/2.05/3.24
# QD-score: 16259.0064
#
# --- MAP-Elite Step 94/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 166, Bins: 166, Coverage: 0.0851, Fitness min/mean/max: 1.99/2.05/3.24
# QD-score: 16260.0198
#
# --- MAP-Elite Step 95/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 166, Bins: 166, Coverage: 0.0851, Fitness min/mean/max: 1.98/2.04/3.24
# QD-score: 16260.9006
#
# --- MAP-Elite Step 96/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 166, Bins: 166, Coverage: 0.0851, Fitness min/mean/max: 1.98/2.04/3.24
# QD-score: 16261.6539
#
# --- MAP-Elite Step 97/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 167, Bins: 167, Coverage: 0.0856, Fitness min/mean/max: 1.98/2.03/3.24
# QD-score: 16360.3379
#
# --- MAP-Elite Step 98/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 167, Bins: 167, Coverage: 0.0856, Fitness min/mean/max: 1.97/2.03/3.24
# QD-score: 16360.9902
#
# --- MAP-Elite Step 99/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 167, Bins: 167, Coverage: 0.0856, Fitness min/mean/max: 1.97/2.03/3.24
# QD-score: 16361.6046
#
# --- MAP-Elite Step 100/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 168, Bins: 168, Coverage: 0.0862, Fitness min/mean/max: 1.96/2.02/3.24
# QD-score: 16460.0251
#
# --- MAP-Elite Step 101/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 168, Bins: 168, Coverage: 0.0862, Fitness min/mean/max: 1.96/2.02/3.24
# QD-score: 16460.8554
#
# --- MAP-Elite Step 102/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 168, Bins: 168, Coverage: 0.0862, Fitness min/mean/max: 1.95/2.01/3.24
# QD-score: 16461.5277
#
# --- MAP-Elite Step 103/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 168, Bins: 168, Coverage: 0.0862, Fitness min/mean/max: 1.94/2.01/3.24
# QD-score: 16462.1484
#
# --- MAP-Elite Step 104/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 168, Bins: 168, Coverage: 0.0862, Fitness min/mean/max: 1.93/2.01/3.24
# QD-score: 16462.8721
#
# --- MAP-Elite Step 105/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 168, Bins: 168, Coverage: 0.0862, Fitness min/mean/max: 1.93/2.00/3.24
# QD-score: 16463.6046
#
# --- MAP-Elite Step 106/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 169, Bins: 169, Coverage: 0.0867, Fitness min/mean/max: 1.93/2.00/3.24
# QD-score: 16562.1680
#
# --- MAP-Elite Step 107/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 169, Bins: 169, Coverage: 0.0867, Fitness min/mean/max: 1.92/1.99/3.24
# QD-score: 16563.0360
#
# --- MAP-Elite Step 108/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 169, Bins: 169, Coverage: 0.0867, Fitness min/mean/max: 1.92/1.99/3.24
# QD-score: 16563.7503
#
# --- MAP-Elite Step 109/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 170, Bins: 170, Coverage: 0.0872, Fitness min/mean/max: 1.90/1.98/3.24
# QD-score: 16662.5736
#
# --- MAP-Elite Step 110/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 170, Bins: 170, Coverage: 0.0872, Fitness min/mean/max: 1.90/1.98/3.24
# QD-score: 16663.6508
#
# --- MAP-Elite Step 111/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 170, Bins: 170, Coverage: 0.0872, Fitness min/mean/max: 1.90/1.97/3.24
# QD-score: 16664.7281
#
# --- MAP-Elite Step 112/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 171, Bins: 171, Coverage: 0.0877, Fitness min/mean/max: 1.89/1.97/3.24
# QD-score: 16763.4968
#
# --- MAP-Elite Step 113/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 172, Bins: 172, Coverage: 0.0882, Fitness min/mean/max: 1.89/1.96/3.24
# QD-score: 16862.5782
#
# --- MAP-Elite Step 114/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 172, Bins: 172, Coverage: 0.0882, Fitness min/mean/max: 1.88/1.96/3.24
# QD-score: 16863.5744
#
# --- MAP-Elite Step 115/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 172, Bins: 172, Coverage: 0.0882, Fitness min/mean/max: 1.88/1.95/3.24
# QD-score: 16864.2830
#
# --- MAP-Elite Step 116/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 173, Bins: 173, Coverage: 0.0887, Fitness min/mean/max: 1.87/1.95/3.24
# QD-score: 16963.0355
#
# --- MAP-Elite Step 117/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 173, Bins: 173, Coverage: 0.0887, Fitness min/mean/max: 1.86/1.94/3.24
# QD-score: 16963.8724
#
# --- MAP-Elite Step 118/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 173, Bins: 173, Coverage: 0.0887, Fitness min/mean/max: 1.86/1.94/3.24
# QD-score: 16964.8025
#
# --- MAP-Elite Step 119/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 174, Bins: 174, Coverage: 0.0892, Fitness min/mean/max: 1.85/1.93/3.24
# QD-score: 17063.8014
#
# --- MAP-Elite Step 120/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 175, Bins: 175, Coverage: 0.0897, Fitness min/mean/max: 1.85/1.93/3.24
# QD-score: 17162.9083
#
# --- MAP-Elite Step 121/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 176, Bins: 176, Coverage: 0.0903, Fitness min/mean/max: 1.84/1.92/3.24
# QD-score: 17261.7158
#
# --- MAP-Elite Step 122/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 176, Bins: 176, Coverage: 0.0903, Fitness min/mean/max: 1.83/1.92/3.24
# QD-score: 17262.7382
#
# --- MAP-Elite Step 123/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 176, Bins: 176, Coverage: 0.0903, Fitness min/mean/max: 1.83/1.91/3.24
# QD-score: 17264.1770
#
# --- MAP-Elite Step 124/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 176, Bins: 176, Coverage: 0.0903, Fitness min/mean/max: 1.82/1.90/3.24
# QD-score: 17264.9793
#
# --- MAP-Elite Step 125/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 180, Bins: 180, Coverage: 0.0923, Fitness min/mean/max: 1.81/1.90/3.24
# QD-score: 17657.6608
#
# --- MAP-Elite Step 126/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 180, Bins: 180, Coverage: 0.0923, Fitness min/mean/max: 1.80/1.89/3.24
# QD-score: 17659.0758
#
# --- MAP-Elite Step 127/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 181, Bins: 181, Coverage: 0.0928, Fitness min/mean/max: 1.80/1.89/3.24
# QD-score: 17757.8491
#
# --- MAP-Elite Step 128/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 182, Bins: 182, Coverage: 0.0933, Fitness min/mean/max: 1.79/1.89/3.24
# QD-score: 17856.7448
#
# --- MAP-Elite Step 129/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 182, Bins: 182, Coverage: 0.0933, Fitness min/mean/max: 1.79/1.88/3.24
# QD-score: 17857.9384
#
# --- MAP-Elite Step 130/1000 ---
#   Operator ratio - pse_mut: 248/500 (50%), pse_line: 252/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 182, Bins: 182, Coverage: 0.0933, Fitness min/mean/max: 1.79/1.87/3.24
# QD-score: 17859.0411
#
# --- MAP-Elite Step 131/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 182, Bins: 182, Coverage: 0.0933, Fitness min/mean/max: 1.78/1.87/3.24
# QD-score: 17860.0323
#
# --- MAP-Elite Step 132/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 182, Bins: 182, Coverage: 0.0933, Fitness min/mean/max: 1.78/1.86/3.24
# QD-score: 17860.6625
#
# --- MAP-Elite Step 133/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 185, Bins: 185, Coverage: 0.0949, Fitness min/mean/max: 1.78/1.86/3.24
# QD-score: 18155.4381
#
# --- MAP-Elite Step 134/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 185, Bins: 185, Coverage: 0.0949, Fitness min/mean/max: 1.78/1.86/3.24
# QD-score: 18156.2042
#
# --- MAP-Elite Step 135/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 186, Bins: 186, Coverage: 0.0954, Fitness min/mean/max: 1.76/1.85/3.24
# QD-score: 18255.0279
#
# --- MAP-Elite Step 136/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 186, Bins: 186, Coverage: 0.0954, Fitness min/mean/max: 1.75/1.85/3.24
# QD-score: 18256.1203
#
# --- MAP-Elite Step 137/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 186, Bins: 186, Coverage: 0.0954, Fitness min/mean/max: 1.75/1.84/3.24
# QD-score: 18257.4206
#
# --- MAP-Elite Step 138/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 186, Bins: 186, Coverage: 0.0954, Fitness min/mean/max: 1.75/1.84/3.24
# QD-score: 18258.3891
#
# --- MAP-Elite Step 139/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 187, Bins: 187, Coverage: 0.0959, Fitness min/mean/max: 1.75/1.83/2.27
# QD-score: 18358.5667
#
# --- MAP-Elite Step 140/1000 ---
#   Operator ratio - pse_mut: 251/500 (50%), pse_line: 249/500 (50%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 187, Bins: 187, Coverage: 0.0959, Fitness min/mean/max: 1.74/1.82/2.27
# QD-score: 18359.4919
#
# --- MAP-Elite Step 141/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 187, Bins: 187, Coverage: 0.0959, Fitness min/mean/max: 1.74/1.82/2.27
# QD-score: 18360.2782
#
# --- MAP-Elite Step 142/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.73/1.81/2.27
# QD-score: 18459.0417
#
# --- MAP-Elite Step 143/1000 ---
#   Operator ratio - pse_mut: 251/500 (50%), pse_line: 249/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.73/1.81/2.27
# QD-score: 18460.0130
#
# --- MAP-Elite Step 144/1000 ---
#   Operator ratio - pse_mut: 251/500 (50%), pse_line: 249/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.72/1.80/2.27
# QD-score: 18460.8277
#
# --- MAP-Elite Step 145/1000 ---
#   Operator ratio - pse_mut: 251/500 (50%), pse_line: 249/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.72/1.80/2.27
# QD-score: 18461.6940
#
# --- MAP-Elite Step 146/1000 ---
#   Operator ratio - pse_mut: 251/500 (50%), pse_line: 249/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.72/1.80/2.27
# QD-score: 18462.2198
#
# --- MAP-Elite Step 147/1000 ---
#   Operator ratio - pse_mut: 251/500 (50%), pse_line: 249/500 (50%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.71/1.79/2.27
# QD-score: 18462.7602
#
# --- MAP-Elite Step 148/1000 ---
#   Operator ratio - pse_mut: 251/500 (50%), pse_line: 249/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 189, Bins: 189, Coverage: 0.0969, Fitness min/mean/max: 1.71/1.79/2.27
# QD-score: 18561.4157
#
# --- MAP-Elite Step 149/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 189, Bins: 189, Coverage: 0.0969, Fitness min/mean/max: 1.70/1.79/2.27
# QD-score: 18562.2633
#
# --- MAP-Elite Step 150/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 190, Bins: 190, Coverage: 0.0974, Fitness min/mean/max: 1.70/1.78/2.27
# QD-score: 18660.8741
#
# --- MAP-Elite Step 151/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 190, Bins: 190, Coverage: 0.0974, Fitness min/mean/max: 1.70/1.78/2.27
# QD-score: 18661.6303
#
# --- MAP-Elite Step 152/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 132/500 [2s elapsed, 5s remaining]
