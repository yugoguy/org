# %%
#!rm -rf org && git clone --filter=blob:none --sparse https://github.com/yugoguy/org.git
#!cd org && git sparse-checkout set dev/SSLVE && git checkout Latent-Variable-Evolution
# Out:
# Cloning into 'org'...
# branch 'Latent-Variable-Evolution' set up to track 'origin/Latent-Variable-Evolution'.
# Switched to a new branch 'Latent-Variable-Evolution'

# %%
import sys, os, glob
sys.path.insert(0, 'org/dev/SSLVE')
for f in sorted(glob.glob('org/dev/SSLVE/*.py')):
    print(f"Running: {f}")
    # %run {f}
# Out:
# Running: org/dev/SSLVE\AgentModules.py
# Running: org/dev/SSLVE\AuxLosses.py
# Running: org/dev/SSLVE\BehaviorDescriptors.py
# Running: org/dev/SSLVE\BehaviorMatchings.py
# Running: org/dev/SSLVE\CMAME.py
# Running: org/dev/SSLVE\Collectors.py
# Running: org/dev/SSLVE\ExperimentUtils.py
# Running: org/dev/SSLVE\LatentModules.py
# Running: org/dev/SSLVE\Main.py
# Running: org/dev/SSLVE\SearchPhases.py
# Running: org/dev/SSLVE\VariationOperators.py

# %%
#@title PlanarArmCVT LVE-ANY Multi-Seed Runner
import numpy as np
import random
import torch
import itertools

# =============================================================================
# Experiment Name (same for all settings)
# =============================================================================
EXP_NAME = 'BinPred-MixBinPred'  #@param {type:"string"}

# =============================================================================
# Sweep Settings
# =============================================================================
SEEDS = [123]
NOISE_SIGMAS = [0.0, 0.05]  # deterministic, uncertain
FITNESSES = ['angle_variance', 'sine_dependency']  # linear, non-linear

# =============================================================================
# Fixed Hyperparameters
# =============================================================================
N_JOINTS = 1000
END_EFFECTOR_DIM = 2
N_NOISE_EPISODES = 3

N_BINS = 1950
CENTERS = "Precomputed_CVT_1950"
TOP_K = 3

USE_PSE_MUT = True
USE_PSE_LINE = True
USE_LVE_MUT = True
USE_LVE_CROSS = True
USE_STD_SUPPORT_LVE = True
GREEDY_MEM = True

PSE_MUT_SIGMA = 0.05
LVE_MUT_SIGMA = 0.05
STD_SUPPORT_LO = -2.0
STD_SUPPORT_HI = 2.0

WARMUP_PSE_MUT = True
WARMUP_PSE_LINE = True

N_TOTAL = 500
WARMUP_THRESHOLD = 500
EMA_ALPHA = 0.1
TEMPERATURE = 10
MIN_PROPORTION = 0.05

USE_FLOW_PRIOR = False
LATENT_DIM = 32
HIDDEN_DIMS = [128]
BETA = 1e-2
NUM_FLOWS = 3
FLOW_HIDDEN = 128
FLOW_HIDDEN_LAYERS = 2
EPOCHS = 50
BATCH_SIZE = 512
LR = 1e-3

USE_BIN_PRED = True
GAMMA_BIN_PRED = 1e-3
USE_MIX_BIN_PRED = True
GAMMA_MIX_BIN_PRED = 1e-3
MIX_ALPHA_LO = -0.1
MIX_ALPHA_HI = 1.1

N_STEPS = 1000

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# =============================================================================
# Helpers
# =============================================================================
ANGLES_PER_JOINT = END_EFFECTOR_DIM - 1
GENE_DIM = N_JOINTS * ANGLES_PER_JOINT

def _get_metric(info, key):
    v = info[key]
    return np.mean(v) if isinstance(v, list) else v

FITNESS_FNS = {
    'angle_variance': lambda info: _get_metric(info, 'angle_variance'),
    'sine_dependency': lambda info: _get_metric(info, 'sine_dependency'),
}

FITNESS_LABELS = {
    'angle_variance': 'linear',
    'sine_dependency': 'nonlinear',
}

NOISE_LABELS = {
    0.0: 'deterministic',
    0.05: 'uncertain',
}

init_fn = lambda: np.random.uniform(-np.pi, np.pi, GENE_DIM)

# =============================================================================
# Run all settings
# =============================================================================
for noise_sigma, fitness_key, seed in itertools.product(NOISE_SIGMAS, FITNESSES, SEEDS):
    tag = f"{EXP_NAME}_{NOISE_LABELS[noise_sigma]}_{FITNESS_LABELS[fitness_key]}_seed{seed}"
    print(f"\n{'='*60}")
    print(f"  {tag}")
    print(f"{'='*60}\n")

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    fitness_fn = FITNESS_FNS[fitness_key]

    collector = PlanarArmCollector(
        n_joints=N_JOINTS,
        end_effector_dim=END_EFFECTOR_DIM,
        noise_sigma=noise_sigma,
        n_episodes=N_NOISE_EPISODES,
    )
    bd = PlanarArmBD_CVT(n_bins=N_BINS, centers=CENTERS, bd_dim=END_EFFECTOR_DIM)
    bm = MAPElitesBM(behavior_descriptor=bd, fitness_fn=fitness_fn, top_k=TOP_K, max_fitness=100)

    operators = []
    translate_fn = None
    if USE_PSE_MUT:
        operators.append(PSEMut(sigma=PSE_MUT_SIGMA, greedy_mem=GREEDY_MEM))
    if USE_PSE_LINE:
        operators.append(PSELine(greedy_mem=GREEDY_MEM))
    if USE_LVE_MUT:
        operators.append(LVEMut(sigma=LVE_MUT_SIGMA, greedy_mem=GREEDY_MEM))
    if USE_LVE_CROSS:
        operators.append(LVECross(greedy_mem=GREEDY_MEM))

    warmup_operators = []
    if WARMUP_PSE_MUT:
        warmup_operators.append(PSEMut(sigma=PSE_MUT_SIGMA, greedy_mem=GREEDY_MEM))
    if WARMUP_PSE_LINE:
        warmup_operators.append(PSELine(greedy_mem=GREEDY_MEM))

    aux_losses = []
    if USE_BIN_PRED:
        aux = BinPred(behavior_descriptor=bd, latent_dim=LATENT_DIM, output_dim=END_EFFECTOR_DIM)
        aux_losses.append((GAMMA_BIN_PRED, aux))
    if USE_MIX_BIN_PRED:
        mix_aux = MixBinPred(
            behavior_descriptor=bd, latent_dim=LATENT_DIM, output_dim=END_EFFECTOR_DIM,
            alpha_lo=MIX_ALPHA_LO, alpha_hi=MIX_ALPHA_HI,
        )
        aux_losses.append((GAMMA_MIX_BIN_PRED, mix_aux))

    if USE_FLOW_PRIOR:
        lm = BaseFlowVAE(
            input_dim=GENE_DIM, latent_dim=LATENT_DIM, hidden_dims=HIDDEN_DIMS,
            beta=BETA, num_flows=NUM_FLOWS, flow_hidden=FLOW_HIDDEN,
            flow_hidden_layers=FLOW_HIDDEN_LAYERS, aux_losses=aux_losses,
        )
        translate_fn = lm.translate
        if USE_MIX_BIN_PRED:
            mix_aux.to_base_fn = lambda z: lm.flow.f(z)[0]
            mix_aux.from_base_fn = lm.flow.f_inv
    else:
        lm = BaseBetaVAE(
            input_dim=GENE_DIM, latent_dim=LATENT_DIM, hidden_dims=HIDDEN_DIMS,
            beta=BETA, aux_losses=aux_losses,
        )

    if USE_STD_SUPPORT_LVE:
        operators.append(StandardNormalSupportLVE(lo=STD_SUPPORT_LO, hi=STD_SUPPORT_HI, translate_fn=translate_fn))

    sp = BoltzmannMix(
        agent_class=PlanarArmAgent, architecture=GENE_DIM,
        operators=operators, warmup_operators=warmup_operators,
        n_total=N_TOTAL, warmup_threshold=WARMUP_THRESHOLD,
        ema_alpha=EMA_ALPHA, temperature=TEMPERATURE,
        min_proportion=MIN_PROPORTION, init_fn=init_fn,
    )

    orchestrator = SSLVE(
        search_phase=sp, collector=collector,
        behavior_matching=bm, latent_module=lm, device=DEVICE,
    )

    print(f"Noise sigma: {noise_sigma}, Fitness: {fitness_key}, Seed: {seed}")
    print(f"Latent dim: {LATENT_DIM}, Hidden: {HIDDEN_DIMS}, Beta: {BETA}")
    print(f"Flow: {USE_FLOW_PRIOR}, BinPred: {USE_BIN_PRED}, MixBinPred: {USE_MIX_BIN_PRED}")
    print(f"Operators: {[op.name for op in operators]}")
    print()

    train_kwargs = {
        'epochs': EPOCHS, 'batch_size': BATCH_SIZE,
        'lr': LR, 'verbose': True,
    }
    histories = orchestrator.run(n_steps=N_STEPS, train_kwargs=train_kwargs)

    f_min, f_mean, f_max = bm.fitness_stats()
    print(f"\nFinal archive size: {bm.archive_size()}")
    print(f"Final coverage: {bm.coverage():.4f}")
    print(f"Best fitness ({fitness_key}): {f_min:.4f}")
    print(f"QD-score: {bm.qd_score():.4f}")

    save_path = f"./archive/{tag}/"
    save_checkpoint(save_path, bm, orchestrator.history, sp=sp, lm=lm)
    print(f"Saved to {save_path}")
# Out:
# ============================================================
#   BinPred-MixBinPred_deterministic_linear_seed123
# ============================================================
#
# Noise sigma: 0.0, Fitness: angle_variance, Seed: 123
# Latent dim: 32, Hidden: [128], Beta: 0.01
# Flow: False, BinPred: True, MixBinPred: True
# Operators: ['pse_mut', 'pse_line', 'lve_mut', 'lve_cross', 'std_support_lve']
#
#
# --- SSLVE Step 1/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%), pse_line: 0/500 (0%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 37, Bins: 14, Coverage: 0.0072, Fitness min/mean/max: 3.00/3.16/3.39
# QD-score: 1355.9657
#
# --- SSLVE Step 2/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 61, Bins: 24, Coverage: 0.0123, Fitness min/mean/max: 1.43/1.92/3.30
# QD-score: 2357.2644
#
# --- SSLVE Step 3/1000 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 93, Bins: 35, Coverage: 0.0179, Fitness min/mean/max: 0.73/1.11/2.96
# QD-score: 3466.4506
#
# --- SSLVE Step 4/1000 ---
#   Operator ratio - pse_mut: 256/500 (51%), pse_line: 244/500 (49%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 137, Bins: 58, Coverage: 0.0297, Fitness min/mean/max: 0.38/0.69/1.66
# QD-score: 5763.3307
#
# --- SSLVE Step 5/1000 ---
#   Operator ratio - pse_mut: 255/500 (51%), pse_line: 245/500 (49%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 202, Bins: 77, Coverage: 0.0395, Fitness min/mean/max: 0.28/0.49/1.66
# QD-score: 7666.6550
#
# --- SSLVE Step 6/1000 ---
#   Operator ratio - pse_mut: 266/500 (53%), pse_line: 234/500 (47%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 263, Bins: 101, Coverage: 0.0518, Fitness min/mean/max: 0.27/0.38/0.70
# QD-score: 10063.6611
#
# --- SSLVE Step 7/1000 ---
#   Operator ratio - pse_mut: 274/500 (55%), pse_line: 226/500 (45%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 324, Bins: 124, Coverage: 0.0636, Fitness min/mean/max: 0.26/0.33/0.55
# QD-score: 12360.8483
#
# --- SSLVE Step 8/1000 ---
#   Operator ratio - pse_mut: 275/500 (55%), pse_line: 225/500 (45%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 391, Bins: 148, Coverage: 0.0759, Fitness min/mean/max: 0.26/0.30/0.55
# QD-score: 14757.3060
#
# --- SSLVE Step 9/1000 ---
#   Operator ratio - pse_mut: 268/500 (54%), pse_line: 232/500 (46%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 454, Bins: 169, Coverage: 0.0867, Fitness min/mean/max: 0.26/0.29/0.45
# QD-score: 16853.0594
#
# --- SSLVE Step 10/1000 ---
#   Operator ratio - pse_mut: 261/500 (52%), pse_line: 239/500 (48%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 503, Bins: 178, Coverage: 0.0913, Fitness min/mean/max: 0.25/0.28/0.38
# QD-score: 17751.8821
#
# --- SSLVE Step 11/1000 ---
#   Operator ratio - pse_mut: 100/500 (20%), pse_line: 100/500 (20%), lve_mut: 100/500 (20%), lve_cross: 100/500 (20%), std_support_lve: 100/500 (20%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 609, Bins: 236, Coverage: 0.1210, Fitness min/mean/max: 0.01/0.19/0.36
# QD-score: 23569.8947
# Epoch 10/50 | Train Total: 0.1197, Recon: 0.1131, KL: 0.6536, bin_pred: 0.2682, mix_bin_pred: 0.3518
# Epoch 20/50 | Train Total: 0.0536, Recon: 0.0435, KL: 1.0097, bin_pred: 0.1213, mix_bin_pred: 0.1704
# Epoch 30/50 | Train Total: 0.0411, Recon: 0.0302, KL: 1.0931, bin_pred: 0.0790, mix_bin_pred: 0.0577
# Epoch 40/50 | Train Total: 0.0354, Recon: 0.0255, KL: 0.9848, bin_pred: 0.0798, mix_bin_pred: 0.0796
# Epoch 50/50 | Train Total: 0.0328, Recon: 0.0238, KL: 0.8974, bin_pred: 0.0790, mix_bin_pred: 0.0695
#
# --- SSLVE Step 12/1000 ---
#   Operator ratio - pse_mut: 87/500 (17%), pse_line: 92/500 (18%), lve_mut: 103/500 (21%), lve_cross: 120/500 (24%), std_support_lve: 98/500 (20%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 742, Bins: 328, Coverage: 0.1682, Fitness min/mean/max: 0.01/0.10/0.35
# QD-score: 32782.3177
# Epoch 10/50 | Train Total: 0.0254, Recon: 0.0181, KL: 0.7315, bin_pred: 0.1010, mix_bin_pred: 0.0881
# Epoch 20/50 | Train Total: 0.0233, Recon: 0.0156, KL: 0.7752, bin_pred: 0.0868, mix_bin_pred: 0.0805
# Epoch 30/50 | Train Total: 0.0219, Recon: 0.0145, KL: 0.7396, bin_pred: 0.0853, mix_bin_pred: 0.0796
# Epoch 40/50 | Train Total: 0.0207, Recon: 0.0132, KL: 0.7493, bin_pred: 0.0808, mix_bin_pred: 0.0649
# Epoch 50/50 | Train Total: 0.0199, Recon: 0.0124, KL: 0.7446, bin_pred: 0.0724, mix_bin_pred: 0.0541
#
# --- SSLVE Step 13/1000 ---
#   Operator ratio - pse_mut: 91/500 (18%), pse_line: 91/500 (18%), lve_mut: 104/500 (21%), lve_cross: 123/500 (25%), std_support_lve: 91/500 (18%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 940, Bins: 438, Coverage: 0.2246, Fitness min/mean/max: 0.00/0.06/0.31
# QD-score: 43786.0415
# Epoch 10/50 | Train Total: 0.0162, Recon: 0.0105, KL: 0.5758, bin_pred: 0.0759, mix_bin_pred: 0.0659
# Epoch 20/50 | Train Total: 0.0157, Recon: 0.0099, KL: 0.5806, bin_pred: 0.0733, mix_bin_pred: 0.0565
# Epoch 30/50 | Train Total: 0.0157, Recon: 0.0095, KL: 0.6201, bin_pred: 0.0656, mix_bin_pred: 0.0573
# Epoch 40/50 | Train Total: 0.0148, Recon: 0.0089, KL: 0.5915, bin_pred: 0.0620, mix_bin_pred: 0.0518
# Epoch 50/50 | Train Total: 0.0144, Recon: 0.0086, KL: 0.5779, bin_pred: 0.0609, mix_bin_pred: 0.0474
#
# --- SSLVE Step 14/1000 ---
#   Operator ratio - pse_mut: 93/500 (19%), pse_line: 98/500 (20%), lve_mut: 108/500 (22%), lve_cross: 125/500 (25%), std_support_lve: 76/500 (15%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 1169, Bins: 534, Coverage: 0.2738, Fitness min/mean/max: 0.00/0.04/0.31
# QD-score: 53387.3531
# Epoch 10/50 | Train Total: 0.0122, Recon: 0.0073, KL: 0.4847, bin_pred: 0.0651, mix_bin_pred: 0.0512
# Epoch 20/50 | Train Total: 0.0115, Recon: 0.0071, KL: 0.4485, bin_pred: 0.0643, mix_bin_pred: 0.0498
# Epoch 30/50 | Train Total: 0.0115, Recon: 0.0069, KL: 0.4553, bin_pred: 0.0614, mix_bin_pred: 0.0468
# Epoch 40/50 | Train Total: 0.0112, Recon: 0.0069, KL: 0.4276, bin_pred: 0.0617, mix_bin_pred: 0.0488
# Epoch 50/50 | Train Total: 0.0107, Recon: 0.0065, KL: 0.4251, bin_pred: 0.0608, mix_bin_pred: 0.0446
#
# --- SSLVE Step 15/1000 ---
#   Operator ratio - pse_mut: 95/500 (19%), pse_line: 108/500 (22%), lve_mut: 106/500 (21%), lve_cross: 123/500 (25%), std_support_lve: 68/500 (14%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 1382, Bins: 615, Coverage: 0.3154, Fitness min/mean/max: 0.00/0.03/0.31
# QD-score: 61487.8693
# Epoch 10/50 | Train Total: 0.0088, Recon: 0.0055, KL: 0.3332, bin_pred: 0.0637, mix_bin_pred: 0.0475
# Epoch 20/50 | Train Total: 0.0086, Recon: 0.0053, KL: 0.3275, bin_pred: 0.0628, mix_bin_pred: 0.0456
# Epoch 30/50 | Train Total: 0.0083, Recon: 0.0051, KL: 0.3135, bin_pred: 0.0651, mix_bin_pred: 0.0495
# Epoch 40/50 | Train Total: 0.0082, Recon: 0.0050, KL: 0.3110, bin_pred: 0.0637, mix_bin_pred: 0.0472
# Epoch 50/50 | Train Total: 0.0081, Recon: 0.0050, KL: 0.3121, bin_pred: 0.0637, mix_bin_pred: 0.0464
#
# --- SSLVE Step 16/1000 ---
#   Operator ratio - pse_mut: 96/500 (19%), pse_line: 111/500 (22%), lve_mut: 101/500 (20%), lve_cross: 121/500 (24%), std_support_lve: 71/500 (14%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 1510, Bins: 657, Coverage: 0.3369, Fitness min/mean/max: 0.00/0.02/0.29
# QD-score: 65688.1432
# Epoch 10/50 | Train Total: 0.0071, Recon: 0.0044, KL: 0.2654, bin_pred: 0.0671, mix_bin_pred: 0.0477
# Epoch 20/50 | Train Total: 0.0070, Recon: 0.0044, KL: 0.2594, bin_pred: 0.0647, mix_bin_pred: 0.0476
# Epoch 30/50 | Train Total: 0.0070, Recon: 0.0043, KL: 0.2671, bin_pred: 0.0663, mix_bin_pred: 0.0493
# Epoch 40/50 | Train Total: 0.0071, Recon: 0.0045, KL: 0.2627, bin_pred: 0.0684, mix_bin_pred: 0.0525
# Epoch 50/50 | Train Total: 0.0069, Recon: 0.0043, KL: 0.2602, bin_pred: 0.0695, mix_bin_pred: 0.0514
#
# --- SSLVE Step 17/1000 ---
#   Operator ratio - pse_mut: 113/500 (23%), pse_line: 115/500 (23%), lve_mut: 91/500 (18%), lve_cross: 106/500 (21%), std_support_lve: 75/500 (15%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 1643, Bins: 712, Coverage: 0.3651, Fitness min/mean/max: 0.00/0.02/0.28
# QD-score: 71188.5950
# Epoch 10/50 | Train Total: 0.0062, Recon: 0.0040, KL: 0.2204, bin_pred: 0.0697, mix_bin_pred: 0.0513
# Epoch 20/50 | Train Total: 0.0061, Recon: 0.0039, KL: 0.2136, bin_pred: 0.0708, mix_bin_pred: 0.0546
# Epoch 30/50 | Train Total: 0.0060, Recon: 0.0038, KL: 0.2181, bin_pred: 0.0717, mix_bin_pred: 0.0525
# Epoch 40/50 | Train Total: 0.0060, Recon: 0.0039, KL: 0.2175, bin_pred: 0.0696, mix_bin_pred: 0.0519
# Epoch 50/50 | Train Total: 0.0061, Recon: 0.0039, KL: 0.2197, bin_pred: 0.0709, mix_bin_pred: 0.0519
#
# --- SSLVE Step 18/1000 ---
#   Operator ratio - pse_mut: 125/500 (25%), pse_line: 126/500 (25%), lve_mut: 88/500 (18%), lve_cross: 87/500 (17%), std_support_lve: 74/500 (15%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 1778, Bins: 754, Coverage: 0.3867, Fitness min/mean/max: 0.00/0.02/0.28
# QD-score: 75388.4807
# Epoch 10/50 | Train Total: 0.0055, Recon: 0.0036, KL: 0.1890, bin_pred: 0.0728, mix_bin_pred: 0.0540
# Epoch 20/50 | Train Total: 0.0054, Recon: 0.0036, KL: 0.1870, bin_pred: 0.0741, mix_bin_pred: 0.0535
# Epoch 30/50 | Train Total: 0.0054, Recon: 0.0035, KL: 0.1935, bin_pred: 0.0744, mix_bin_pred: 0.0545
# Epoch 40/50 | Train Total: 0.0053, Recon: 0.0035, KL: 0.1845, bin_pred: 0.0758, mix_bin_pred: 0.0561
# Epoch 50/50 | Train Total: 0.0053, Recon: 0.0034, KL: 0.1874, bin_pred: 0.0742, mix_bin_pred: 0.0555
#
# --- SSLVE Step 19/1000 ---
#   Operator ratio - pse_mut: 140/500 (28%), pse_line: 131/500 (26%), lve_mut: 86/500 (17%), lve_cross: 72/500 (14%), std_support_lve: 71/500 (14%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 1906, Bins: 794, Coverage: 0.4072, Fitness min/mean/max: 0.00/0.02/0.27
# QD-score: 79388.5666
# Epoch 10/50 | Train Total: 0.0051, Recon: 0.0033, KL: 0.1742, bin_pred: 0.0802, mix_bin_pred: 0.0587
# Epoch 20/50 | Train Total: 0.0052, Recon: 0.0035, KL: 0.1716, bin_pred: 0.0801, mix_bin_pred: 0.0590
# Epoch 30/50 | Train Total: 0.0051, Recon: 0.0034, KL: 0.1743, bin_pred: 0.0797, mix_bin_pred: 0.0584
# Epoch 40/50 | Train Total: 0.0049, Recon: 0.0033, KL: 0.1658, bin_pred: 0.0819, mix_bin_pred: 0.0595
# Epoch 50/50 | Train Total: 0.0050, Recon: 0.0033, KL: 0.1660, bin_pred: 0.0787, mix_bin_pred: 0.0578
#
# --- SSLVE Step 20/1000 ---
#   Operator ratio - pse_mut: 156/500 (31%), pse_line: 138/500 (28%), lve_mut: 79/500 (16%), lve_cross: 63/500 (13%), std_support_lve: 64/500 (13%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2025, Bins: 836, Coverage: 0.4287, Fitness min/mean/max: 0.00/0.02/0.26
# QD-score: 83588.5612
# Epoch 10/50 | Train Total: 0.0048, Recon: 0.0033, KL: 0.1517, bin_pred: 0.0851, mix_bin_pred: 0.0636
# Epoch 20/50 | Train Total: 0.0048, Recon: 0.0033, KL: 0.1482, bin_pred: 0.0853, mix_bin_pred: 0.0630
# Epoch 30/50 | Train Total: 0.0047, Recon: 0.0032, KL: 0.1470, bin_pred: 0.0839, mix_bin_pred: 0.0618
# Epoch 40/50 | Train Total: 0.0047, Recon: 0.0032, KL: 0.1487, bin_pred: 0.0831, mix_bin_pred: 0.0622
# Epoch 50/50 | Train Total: 0.0046, Recon: 0.0031, KL: 0.1470, bin_pred: 0.0838, mix_bin_pred: 0.0643
#
# --- SSLVE Step 21/1000 ---
#   Operator ratio - pse_mut: 168/500 (34%), pse_line: 143/500 (29%), lve_mut: 71/500 (14%), lve_cross: 58/500 (12%), std_support_lve: 60/500 (12%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2146, Bins: 878, Coverage: 0.4503, Fitness min/mean/max: 0.00/0.02/0.26
# QD-score: 87788.7043
# Epoch 10/50 | Train Total: 0.0046, Recon: 0.0032, KL: 0.1369, bin_pred: 0.0891, mix_bin_pred: 0.0654
# Epoch 20/50 | Train Total: 0.0046, Recon: 0.0032, KL: 0.1350, bin_pred: 0.0897, mix_bin_pred: 0.0658
# Epoch 30/50 | Train Total: 0.0045, Recon: 0.0032, KL: 0.1334, bin_pred: 0.0882, mix_bin_pred: 0.0653
# Epoch 40/50 | Train Total: 0.0045, Recon: 0.0031, KL: 0.1354, bin_pred: 0.0873, mix_bin_pred: 0.0625
# Epoch 50/50 | Train Total: 0.0045, Recon: 0.0032, KL: 0.1358, bin_pred: 0.0874, mix_bin_pred: 0.0652
#
# --- SSLVE Step 22/1000 ---
#   Operator ratio - pse_mut: 175/500 (35%), pse_line: 146/500 (29%), lve_mut: 70/500 (14%), lve_cross: 51/500 (10%), std_support_lve: 58/500 (12%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2268, Bins: 926, Coverage: 0.4749, Fitness min/mean/max: 0.00/0.02/0.26
# QD-score: 92588.5934
# Epoch 10/50 | Train Total: 0.0044, Recon: 0.0032, KL: 0.1237, bin_pred: 0.0939, mix_bin_pred: 0.0700
# Epoch 20/50 | Train Total: 0.0044, Recon: 0.0032, KL: 0.1229, bin_pred: 0.0920, mix_bin_pred: 0.0689
# Epoch 30/50 | Train Total: 0.0043, Recon: 0.0031, KL: 0.1253, bin_pred: 0.0920, mix_bin_pred: 0.0668
# Epoch 40/50 | Train Total: 0.0043, Recon: 0.0031, KL: 0.1223, bin_pred: 0.0919, mix_bin_pred: 0.0685
# Epoch 50/50 | Train Total: 0.0044, Recon: 0.0031, KL: 0.1227, bin_pred: 0.0930, mix_bin_pred: 0.0707
#
# --- SSLVE Step 23/1000 ---
#   Operator ratio - pse_mut: 178/500 (36%), pse_line: 151/500 (30%), lve_mut: 66/500 (13%), lve_cross: 46/500 (9%), std_support_lve: 59/500 (12%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2381, Bins: 963, Coverage: 0.4938, Fitness min/mean/max: 0.00/0.01/0.17
# QD-score: 96288.6186
# Epoch 10/50 | Train Total: 0.0042, Recon: 0.0031, KL: 0.1119, bin_pred: 0.0944, mix_bin_pred: 0.0689
# Epoch 20/50 | Train Total: 0.0042, Recon: 0.0031, KL: 0.1098, bin_pred: 0.0950, mix_bin_pred: 0.0718
# Epoch 30/50 | Train Total: 0.0042, Recon: 0.0031, KL: 0.1111, bin_pred: 0.0949, mix_bin_pred: 0.0698
# Epoch 40/50 | Train Total: 0.0041, Recon: 0.0030, KL: 0.1093, bin_pred: 0.0945, mix_bin_pred: 0.0686
# Epoch 50/50 | Train Total: 0.0042, Recon: 0.0030, KL: 0.1115, bin_pred: 0.0949, mix_bin_pred: 0.0715
#
# --- SSLVE Step 24/1000 ---
#   Operator ratio - pse_mut: 178/500 (36%), pse_line: 156/500 (31%), lve_mut: 61/500 (12%), lve_cross: 44/500 (9%), std_support_lve: 61/500 (12%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2480, Bins: 999, Coverage: 0.5123, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 99888.7265
# Epoch 10/50 | Train Total: 0.0041, Recon: 0.0031, KL: 0.1031, bin_pred: 0.0969, mix_bin_pred: 0.0719
# Epoch 20/50 | Train Total: 0.0041, Recon: 0.0031, KL: 0.1006, bin_pred: 0.0990, mix_bin_pred: 0.0745
# Epoch 30/50 | Train Total: 0.0040, Recon: 0.0030, KL: 0.0993, bin_pred: 0.0974, mix_bin_pred: 0.0731
# Epoch 40/50 | Train Total: 0.0040, Recon: 0.0030, KL: 0.1003, bin_pred: 0.0991, mix_bin_pred: 0.0715
# Epoch 50/50 | Train Total: 0.0040, Recon: 0.0030, KL: 0.1021, bin_pred: 0.1000, mix_bin_pred: 0.0730
#
# --- SSLVE Step 25/1000 ---
#   Operator ratio - pse_mut: 180/500 (36%), pse_line: 159/500 (32%), lve_mut: 59/500 (12%), lve_cross: 41/500 (8%), std_support_lve: 61/500 (12%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2567, Bins: 1026, Coverage: 0.5262, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 102588.9915
# Epoch 10/50 | Train Total: 0.0039, Recon: 0.0030, KL: 0.0914, bin_pred: 0.1026, mix_bin_pred: 0.0745 | Val Total: 0.0041
# Epoch 20/50 | Train Total: 0.0039, Recon: 0.0030, KL: 0.0921, bin_pred: 0.1026, mix_bin_pred: 0.0744 | Val Total: 0.0041
# Epoch 30/50 | Train Total: 0.0039, Recon: 0.0030, KL: 0.0912, bin_pred: 0.1017, mix_bin_pred: 0.0785 | Val Total: 0.0041
# Epoch 40/50 | Train Total: 0.0039, Recon: 0.0030, KL: 0.0912, bin_pred: 0.1016, mix_bin_pred: 0.0746 | Val Total: 0.0041
# Epoch 50/50 | Train Total: 0.0039, Recon: 0.0029, KL: 0.0925, bin_pred: 0.1019, mix_bin_pred: 0.0759 | Val Total: 0.0041
#
# --- SSLVE Step 26/1000 ---
#   Operator ratio - pse_mut: 187/500 (37%), pse_line: 159/500 (32%), lve_mut: 56/500 (11%), lve_cross: 39/500 (8%), std_support_lve: 59/500 (12%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2648, Bins: 1050, Coverage: 0.5385, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 104989.0120
# Epoch 10/50 | Train Total: 0.0039, Recon: 0.0030, KL: 0.0830, bin_pred: 0.1067, mix_bin_pred: 0.0790 | Val Total: 0.0038
# Epoch 20/50 | Train Total: 0.0038, Recon: 0.0030, KL: 0.0828, bin_pred: 0.1064, mix_bin_pred: 0.0789 | Val Total: 0.0038
# Epoch 30/50 | Train Total: 0.0039, Recon: 0.0030, KL: 0.0825, bin_pred: 0.1056, mix_bin_pred: 0.0764 | Val Total: 0.0038
# Epoch 40/50 | Train Total: 0.0039, Recon: 0.0030, KL: 0.0826, bin_pred: 0.1062, mix_bin_pred: 0.0785 | Val Total: 0.0038
# Epoch 50/50 | Train Total: 0.0039, Recon: 0.0030, KL: 0.0816, bin_pred: 0.1055, mix_bin_pred: 0.0795 | Val Total: 0.0038
#
# --- SSLVE Step 27/1000 ---
#   Operator ratio - pse_mut: 187/500 (37%), pse_line: 163/500 (33%), lve_mut: 55/500 (11%), lve_cross: 38/500 (8%), std_support_lve: 57/500 (11%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2735, Bins: 1069, Coverage: 0.5482, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 106889.2782
# Epoch 10/50 | Train Total: 0.0038, Recon: 0.0030, KL: 0.0781, bin_pred: 0.1091, mix_bin_pred: 0.0806 | Val Total: 0.0039
# Epoch 20/50 | Train Total: 0.0037, Recon: 0.0029, KL: 0.0791, bin_pred: 0.1072, mix_bin_pred: 0.0774 | Val Total: 0.0038
# Epoch 30/50 | Train Total: 0.0037, Recon: 0.0029, KL: 0.0795, bin_pred: 0.1072, mix_bin_pred: 0.0782 | Val Total: 0.0039
# Epoch 40/50 | Train Total: 0.0037, Recon: 0.0029, KL: 0.0761, bin_pred: 0.1071, mix_bin_pred: 0.0785 | Val Total: 0.0039
# Epoch 50/50 | Train Total: 0.0037, Recon: 0.0029, KL: 0.0783, bin_pred: 0.1098, mix_bin_pred: 0.0824 | Val Total: 0.0039
#
# --- SSLVE Step 28/1000 ---
#   Operator ratio - pse_mut: 185/500 (37%), pse_line: 167/500 (33%), lve_mut: 54/500 (11%), lve_cross: 38/500 (8%), std_support_lve: 56/500 (11%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2816, Bins: 1098, Coverage: 0.5631, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 109789.2438
# Epoch 10/50 | Train Total: 0.0037, Recon: 0.0030, KL: 0.0694, bin_pred: 0.1132, mix_bin_pred: 0.0831 | Val Total: 0.0037
# Epoch 20/50 | Train Total: 0.0037, Recon: 0.0030, KL: 0.0701, bin_pred: 0.1096, mix_bin_pred: 0.0827 | Val Total: 0.0037
# Epoch 30/50 | Train Total: 0.0037, Recon: 0.0030, KL: 0.0686, bin_pred: 0.1117, mix_bin_pred: 0.0810 | Val Total: 0.0037
# Epoch 40/50 | Train Total: 0.0037, Recon: 0.0030, KL: 0.0722, bin_pred: 0.1126, mix_bin_pred: 0.0840 | Val Total: 0.0038
# Epoch 50/50 | Train Total: 0.0037, Recon: 0.0030, KL: 0.0695, bin_pred: 0.1125, mix_bin_pred: 0.0834 | Val Total: 0.0038
#
# --- SSLVE Step 29/1000 ---
#   Operator ratio - pse_mut: 188/500 (38%), pse_line: 171/500 (34%), lve_mut: 52/500 (10%), lve_cross: 37/500 (7%), std_support_lve: 52/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2889, Bins: 1117, Coverage: 0.5728, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 111689.3818
# Epoch 10/50 | Train Total: 0.0037, Recon: 0.0030, KL: 0.0654, bin_pred: 0.1143, mix_bin_pred: 0.0857 | Val Total: 0.0036
# Epoch 20/50 | Train Total: 0.0036, Recon: 0.0030, KL: 0.0654, bin_pred: 0.1153, mix_bin_pred: 0.0836 | Val Total: 0.0036
# Epoch 30/50 | Train Total: 0.0037, Recon: 0.0030, KL: 0.0646, bin_pred: 0.1152, mix_bin_pred: 0.0875 | Val Total: 0.0036
# Epoch 40/50 | Train Total: 0.0036, Recon: 0.0030, KL: 0.0672, bin_pred: 0.1151, mix_bin_pred: 0.0859 | Val Total: 0.0036
# Epoch 50/50 | Train Total: 0.0036, Recon: 0.0030, KL: 0.0644, bin_pred: 0.1143, mix_bin_pred: 0.0851 | Val Total: 0.0036
#
# --- SSLVE Step 30/1000 ---
#   Operator ratio - pse_mut: 183/500 (37%), pse_line: 172/500 (34%), lve_mut: 53/500 (11%), lve_cross: 37/500 (7%), std_support_lve: 55/500 (11%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 2989, Bins: 1148, Coverage: 0.5887, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 114789.3865
# Epoch 10/50 | Train Total: 0.0036, Recon: 0.0030, KL: 0.0621, bin_pred: 0.1174, mix_bin_pred: 0.0856 | Val Total: 0.0036
# Epoch 20/50 | Train Total: 0.0036, Recon: 0.0029, KL: 0.0641, bin_pred: 0.1193, mix_bin_pred: 0.0860 | Val Total: 0.0036
# Epoch 30/50 | Train Total: 0.0036, Recon: 0.0030, KL: 0.0621, bin_pred: 0.1187, mix_bin_pred: 0.0874 | Val Total: 0.0036
# Epoch 40/50 | Train Total: 0.0036, Recon: 0.0030, KL: 0.0604, bin_pred: 0.1174, mix_bin_pred: 0.0870 | Val Total: 0.0036
# Epoch 50/50 | Train Total: 0.0036, Recon: 0.0029, KL: 0.0629, bin_pred: 0.1144, mix_bin_pred: 0.0876 | Val Total: 0.0036
#
# --- SSLVE Step 31/1000 ---
#   Operator ratio - pse_mut: 187/500 (37%), pse_line: 174/500 (35%), lve_mut: 53/500 (11%), lve_cross: 36/500 (7%), std_support_lve: 50/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3061, Bins: 1173, Coverage: 0.6015, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 117289.4309
# Epoch 10/50 | Train Total: 0.0036, Recon: 0.0030, KL: 0.0585, bin_pred: 0.1227, mix_bin_pred: 0.0891 | Val Total: 0.0035
# Epoch 20/50 | Train Total: 0.0035, Recon: 0.0030, KL: 0.0586, bin_pred: 0.1210, mix_bin_pred: 0.0898 | Val Total: 0.0035
# Epoch 30/50 | Train Total: 0.0036, Recon: 0.0030, KL: 0.0595, bin_pred: 0.1222, mix_bin_pred: 0.0910 | Val Total: 0.0036
# Epoch 40/50 | Train Total: 0.0035, Recon: 0.0029, KL: 0.0586, bin_pred: 0.1196, mix_bin_pred: 0.0893 | Val Total: 0.0036
# Epoch 50/50 | Train Total: 0.0035, Recon: 0.0029, KL: 0.0594, bin_pred: 0.1224, mix_bin_pred: 0.0901 | Val Total: 0.0036
#
# --- SSLVE Step 32/1000 ---
#   Operator ratio - pse_mut: 185/500 (37%), pse_line: 178/500 (36%), lve_mut: 52/500 (10%), lve_cross: 36/500 (7%), std_support_lve: 49/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3131, Bins: 1191, Coverage: 0.6108, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 119089.5474
# Epoch 10/50 | Train Total: 0.0035, Recon: 0.0030, KL: 0.0541, bin_pred: 0.1245, mix_bin_pred: 0.0902 | Val Total: 0.0034
# Epoch 20/50 | Train Total: 0.0035, Recon: 0.0029, KL: 0.0552, bin_pred: 0.1236, mix_bin_pred: 0.0924 | Val Total: 0.0034
# Epoch 30/50 | Train Total: 0.0035, Recon: 0.0030, KL: 0.0547, bin_pred: 0.1252, mix_bin_pred: 0.0924 | Val Total: 0.0034
# Epoch 40/50 | Train Total: 0.0035, Recon: 0.0029, KL: 0.0535, bin_pred: 0.1224, mix_bin_pred: 0.0897 | Val Total: 0.0034
# Epoch 50/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0538, bin_pred: 0.1222, mix_bin_pred: 0.0898 | Val Total: 0.0034
#
# --- SSLVE Step 33/1000 ---
#   Operator ratio - pse_mut: 185/500 (37%), pse_line: 180/500 (36%), lve_mut: 50/500 (10%), lve_cross: 36/500 (7%), std_support_lve: 49/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3204, Bins: 1215, Coverage: 0.6231, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 121489.5708
# Epoch 10/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0491, bin_pred: 0.1280, mix_bin_pred: 0.0954 | Val Total: 0.0034
# Epoch 20/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0512, bin_pred: 0.1288, mix_bin_pred: 0.0942 | Val Total: 0.0035
# Epoch 30/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0515, bin_pred: 0.1273, mix_bin_pred: 0.0940 | Val Total: 0.0034
# Epoch 40/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0512, bin_pred: 0.1268, mix_bin_pred: 0.0925 | Val Total: 0.0034
# Epoch 50/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0500, bin_pred: 0.1272, mix_bin_pred: 0.0944 | Val Total: 0.0034
#
# --- SSLVE Step 34/1000 ---
#   Operator ratio - pse_mut: 178/500 (36%), pse_line: 184/500 (37%), lve_mut: 50/500 (10%), lve_cross: 37/500 (7%), std_support_lve: 51/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3259, Bins: 1230, Coverage: 0.6308, Fitness min/mean/max: 0.00/0.01/0.11
# QD-score: 122989.5793
# Epoch 10/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0470, bin_pred: 0.1289, mix_bin_pred: 0.0960 | Val Total: 0.0033
# Epoch 20/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0482, bin_pred: 0.1289, mix_bin_pred: 0.0926 | Val Total: 0.0033
# Epoch 30/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0481, bin_pred: 0.1298, mix_bin_pred: 0.0951 | Val Total: 0.0033
# Epoch 40/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0486, bin_pred: 0.1286, mix_bin_pred: 0.0940 | Val Total: 0.0034
# Epoch 50/50 | Train Total: 0.0034, Recon: 0.0029, KL: 0.0474, bin_pred: 0.1279, mix_bin_pred: 0.0948 | Val Total: 0.0034
#
# --- SSLVE Step 35/1000 ---
#   Operator ratio - pse_mut: 174/500 (35%), pse_line: 185/500 (37%), lve_mut: 51/500 (10%), lve_cross: 38/500 (8%), std_support_lve: 52/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3314, Bins: 1245, Coverage: 0.6385, Fitness min/mean/max: 0.00/0.01/0.06
# QD-score: 124489.6968
# Epoch 10/50 | Train Total: 0.0033, Recon: 0.0028, KL: 0.0446, bin_pred: 0.1313, mix_bin_pred: 0.0994 | Val Total: 0.0034
# Epoch 20/50 | Train Total: 0.0033, Recon: 0.0028, KL: 0.0449, bin_pred: 0.1327, mix_bin_pred: 0.0997 | Val Total: 0.0034
# Epoch 30/50 | Train Total: 0.0033, Recon: 0.0029, KL: 0.0437, bin_pred: 0.1296, mix_bin_pred: 0.0969 | Val Total: 0.0035
# Epoch 40/50 | Train Total: 0.0033, Recon: 0.0028, KL: 0.0431, bin_pred: 0.1316, mix_bin_pred: 0.0956 | Val Total: 0.0035
# Epoch 50/50 | Train Total: 0.0033, Recon: 0.0028, KL: 0.0427, bin_pred: 0.1313, mix_bin_pred: 0.0990 | Val Total: 0.0035
#
# --- SSLVE Step 36/1000 ---
#   Operator ratio - pse_mut: 173/500 (35%), pse_line: 184/500 (37%), lve_mut: 51/500 (10%), lve_cross: 39/500 (8%), std_support_lve: 53/500 (11%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3372, Bins: 1264, Coverage: 0.6482, Fitness min/mean/max: 0.00/0.01/0.06
# QD-score: 126389.7054
# Epoch 10/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0421, bin_pred: 0.1324, mix_bin_pred: 0.0975 | Val Total: 0.0033
# Epoch 20/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0414, bin_pred: 0.1330, mix_bin_pred: 0.0999 | Val Total: 0.0033
# Epoch 30/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0403, bin_pred: 0.1324, mix_bin_pred: 0.0982 | Val Total: 0.0033
# Epoch 40/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0413, bin_pred: 0.1325, mix_bin_pred: 0.0967 | Val Total: 0.0033
# Epoch 50/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0405, bin_pred: 0.1324, mix_bin_pred: 0.0994 | Val Total: 0.0033
#
# --- SSLVE Step 37/1000 ---
#   Operator ratio - pse_mut: 168/500 (34%), pse_line: 190/500 (38%), lve_mut: 51/500 (10%), lve_cross: 39/500 (8%), std_support_lve: 52/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3422, Bins: 1277, Coverage: 0.6549, Fitness min/mean/max: 0.00/0.01/0.06
# QD-score: 127689.8040
# Epoch 10/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0352, bin_pred: 0.1368, mix_bin_pred: 0.1019 | Val Total: 0.0033
# Epoch 20/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0350, bin_pred: 0.1353, mix_bin_pred: 0.1015 | Val Total: 0.0033
# Epoch 30/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0347, bin_pred: 0.1370, mix_bin_pred: 0.1004 | Val Total: 0.0033
# Epoch 40/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0346, bin_pred: 0.1368, mix_bin_pred: 0.1009 | Val Total: 0.0033
# Epoch 50/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0357, bin_pred: 0.1352, mix_bin_pred: 0.1002 | Val Total: 0.0033
#
# --- SSLVE Step 38/1000 ---
#   Operator ratio - pse_mut: 166/500 (33%), pse_line: 188/500 (38%), lve_mut: 53/500 (11%), lve_cross: 41/500 (8%), std_support_lve: 52/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3488, Bins: 1301, Coverage: 0.6672, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 130089.7341
# Epoch 10/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0355, bin_pred: 0.1377, mix_bin_pred: 0.1003 | Val Total: 0.0030
# Epoch 20/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0350, bin_pred: 0.1375, mix_bin_pred: 0.1034 | Val Total: 0.0030
# Epoch 30/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0333, bin_pred: 0.1405, mix_bin_pred: 0.1038 | Val Total: 0.0030
# Epoch 40/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0350, bin_pred: 0.1413, mix_bin_pred: 0.1030 | Val Total: 0.0030
# Epoch 50/50 | Train Total: 0.0032, Recon: 0.0028, KL: 0.0352, bin_pred: 0.1414, mix_bin_pred: 0.1016 | Val Total: 0.0030
#
# --- SSLVE Step 39/1000 ---
#   Operator ratio - pse_mut: 163/500 (33%), pse_line: 191/500 (38%), lve_mut: 52/500 (10%), lve_cross: 42/500 (8%), std_support_lve: 52/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3532, Bins: 1313, Coverage: 0.6733, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 131289.7354
# Epoch 10/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0337, bin_pred: 0.1437, mix_bin_pred: 0.1075 | Val Total: 0.0031
# Epoch 20/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0333, bin_pred: 0.1414, mix_bin_pred: 0.1050 | Val Total: 0.0031
# Epoch 30/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0332, bin_pred: 0.1420, mix_bin_pred: 0.1053 | Val Total: 0.0031
# Epoch 40/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0346, bin_pred: 0.1402, mix_bin_pred: 0.1031 | Val Total: 0.0031
# Epoch 50/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0332, bin_pred: 0.1414, mix_bin_pred: 0.1039 | Val Total: 0.0031
#
# --- SSLVE Step 40/1000 ---
#   Operator ratio - pse_mut: 159/500 (32%), pse_line: 191/500 (38%), lve_mut: 54/500 (11%), lve_cross: 43/500 (9%), std_support_lve: 53/500 (11%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3601, Bins: 1331, Coverage: 0.6826, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 133089.7880
# Epoch 10/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0323, bin_pred: 0.1444, mix_bin_pred: 0.1074 | Val Total: 0.0030
# Epoch 20/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0309, bin_pred: 0.1453, mix_bin_pred: 0.1080 | Val Total: 0.0030
# Epoch 30/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0314, bin_pred: 0.1440, mix_bin_pred: 0.1052 | Val Total: 0.0030
# Epoch 40/50 | Train Total: 0.0031, Recon: 0.0027, KL: 0.0316, bin_pred: 0.1424, mix_bin_pred: 0.1048 | Val Total: 0.0030
# Epoch 50/50 | Train Total: 0.0031, Recon: 0.0028, KL: 0.0308, bin_pred: 0.1417, mix_bin_pred: 0.1032 | Val Total: 0.0030
#
# --- SSLVE Step 41/1000 ---
#   Operator ratio - pse_mut: 154/500 (31%), pse_line: 200/500 (40%), lve_mut: 53/500 (11%), lve_cross: 42/500 (8%), std_support_lve: 51/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3667, Bins: 1350, Coverage: 0.6923, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 134989.8798
# Epoch 10/50 | Train Total: 0.0030, Recon: 0.0027, KL: 0.0283, bin_pred: 0.1475, mix_bin_pred: 0.1095 | Val Total: 0.0031
# Epoch 20/50 | Train Total: 0.0030, Recon: 0.0027, KL: 0.0304, bin_pred: 0.1454, mix_bin_pred: 0.1080 | Val Total: 0.0031
# Epoch 30/50 | Train Total: 0.0030, Recon: 0.0027, KL: 0.0292, bin_pred: 0.1480, mix_bin_pred: 0.1087 | Val Total: 0.0031
# Epoch 40/50 | Train Total: 0.0030, Recon: 0.0027, KL: 0.0292, bin_pred: 0.1450, mix_bin_pred: 0.1095 | Val Total: 0.0032
# Epoch 50/50 | Train Total: 0.0030, Recon: 0.0027, KL: 0.0295, bin_pred: 0.1455, mix_bin_pred: 0.1089 | Val Total: 0.0032
#
# --- SSLVE Step 42/1000 ---
#   Operator ratio - pse_mut: 152/500 (30%), pse_line: 203/500 (41%), lve_mut: 53/500 (11%), lve_cross: 42/500 (8%), std_support_lve: 50/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3719, Bins: 1360, Coverage: 0.6974, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 135989.9733
# Epoch 10/50 | Train Total: 0.0030, Recon: 0.0027, KL: 0.0266, bin_pred: 0.1483, mix_bin_pred: 0.1103 | Val Total: 0.0031
# Epoch 20/50 | Train Total: 0.0029, Recon: 0.0026, KL: 0.0262, bin_pred: 0.1485, mix_bin_pred: 0.1094 | Val Total: 0.0031
# Epoch 30/50 | Train Total: 0.0029, Recon: 0.0027, KL: 0.0255, bin_pred: 0.1479, mix_bin_pred: 0.1074 | Val Total: 0.0031
# Epoch 40/50 | Train Total: 0.0029, Recon: 0.0027, KL: 0.0264, bin_pred: 0.1468, mix_bin_pred: 0.1083 | Val Total: 0.0031
# Epoch 50/50 | Train Total: 0.0030, Recon: 0.0027, KL: 0.0275, bin_pred: 0.1473, mix_bin_pred: 0.1109 | Val Total: 0.0031
#
# --- SSLVE Step 43/1000 ---
#   Operator ratio - pse_mut: 152/500 (30%), pse_line: 200/500 (40%), lve_mut: 55/500 (11%), lve_cross: 43/500 (9%), std_support_lve: 50/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3760, Bins: 1364, Coverage: 0.6995, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 136390.1219
# Epoch 10/50 | Train Total: 0.0029, Recon: 0.0027, KL: 0.0256, bin_pred: 0.1510, mix_bin_pred: 0.1113 | Val Total: 0.0027
# Epoch 20/50 | Train Total: 0.0030, Recon: 0.0027, KL: 0.0265, bin_pred: 0.1504, mix_bin_pred: 0.1099 | Val Total: 0.0027
# Epoch 30/50 | Train Total: 0.0029, Recon: 0.0027, KL: 0.0263, bin_pred: 0.1525, mix_bin_pred: 0.1111 | Val Total: 0.0027
# Epoch 40/50 | Train Total: 0.0029, Recon: 0.0027, KL: 0.0266, bin_pred: 0.1494, mix_bin_pred: 0.1108 | Val Total: 0.0027
# Epoch 50/50 | Train Total: 0.0029, Recon: 0.0026, KL: 0.0256, bin_pred: 0.1484, mix_bin_pred: 0.1088 | Val Total: 0.0027
#
# --- SSLVE Step 44/1000 ---
#   Operator ratio - pse_mut: 153/500 (31%), pse_line: 195/500 (39%), lve_mut: 55/500 (11%), lve_cross: 45/500 (9%), std_support_lve: 52/500 (10%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3799, Bins: 1368, Coverage: 0.7015, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 136790.2219
# Epoch 10/50 | Train Total: 0.0029, Recon: 0.0026, KL: 0.0241, bin_pred: 0.1487, mix_bin_pred: 0.1077 | Val Total: 0.0029
# Epoch 20/50 | Train Total: 0.0029, Recon: 0.0026, KL: 0.0230, bin_pred: 0.1513, mix_bin_pred: 0.1143 | Val Total: 0.0028
# Epoch 30/50 | Train Total: 0.0029, Recon: 0.0026, KL: 0.0238, bin_pred: 0.1488, mix_bin_pred: 0.1115 | Val Total: 0.0029
# Epoch 40/50 | Train Total: 0.0029, Recon: 0.0026, KL: 0.0257, bin_pred: 0.1478, mix_bin_pred: 0.1096 | Val Total: 0.0029
# Epoch 50/50 | Train Total: 0.0029, Recon: 0.0026, KL: 0.0249, bin_pred: 0.1473, mix_bin_pred: 0.1077 | Val Total: 0.0029
#
# --- SSLVE Step 45/1000 ---
#   Operator ratio - pse_mut: 151/500 (30%), pse_line: 191/500 (38%), lve_mut: 57/500 (11%), lve_cross: 47/500 (9%), std_support_lve: 54/500 (11%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3835, Bins: 1380, Coverage: 0.7077, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 137990.2444
# Epoch 10/50 | Train Total: 0.0028, Recon: 0.0026, KL: 0.0223, bin_pred: 0.1503, mix_bin_pred: 0.1119 | Val Total: 0.0028
# Epoch 20/50 | Train Total: 0.0029, Recon: 0.0026, KL: 0.0231, bin_pred: 0.1491, mix_bin_pred: 0.1089 | Val Total: 0.0028
# Epoch 30/50 | Train Total: 0.0028, Recon: 0.0026, KL: 0.0231, bin_pred: 0.1518, mix_bin_pred: 0.1099 | Val Total: 0.0028
# Epoch 40/50 | Train Total: 0.0028, Recon: 0.0026, KL: 0.0214, bin_pred: 0.1517, mix_bin_pred: 0.1139 | Val Total: 0.0028
# Epoch 50/50 | Train Total: 0.0028, Recon: 0.0026, KL: 0.0226, bin_pred: 0.1498, mix_bin_pred: 0.1080 | Val Total: 0.0028
#
# --- SSLVE Step 46/1000 ---
#   Operator ratio - pse_mut: 149/500 (30%), pse_line: 191/500 (38%), lve_mut: 57/500 (11%), lve_cross: 48/500 (10%), std_support_lve: 55/500 (11%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3873, Bins: 1387, Coverage: 0.7113, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 138690.3144
# Epoch 10/50 | Train Total: 0.0028, Recon: 0.0026, KL: 0.0199, bin_pred: 0.1530, mix_bin_pred: 0.1143 | Val Total: 0.0026
# Epoch 20/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0199, bin_pred: 0.1536, mix_bin_pred: 0.1132 | Val Total: 0.0026
# Epoch 30/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0206, bin_pred: 0.1496, mix_bin_pred: 0.1083 | Val Total: 0.0027
# Epoch 40/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0205, bin_pred: 0.1514, mix_bin_pred: 0.1125 | Val Total: 0.0027
# Epoch 50/50 | Train Total: 0.0028, Recon: 0.0025, KL: 0.0209, bin_pred: 0.1517, mix_bin_pred: 0.1121 | Val Total: 0.0027
#
# --- SSLVE Step 47/1000 ---
#   Operator ratio - pse_mut: 147/500 (29%), pse_line: 188/500 (38%), lve_mut: 59/500 (12%), lve_cross: 50/500 (10%), std_support_lve: 56/500 (11%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3901, Bins: 1393, Coverage: 0.7144, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 139290.3775
# Epoch 10/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0198, bin_pred: 0.1517, mix_bin_pred: 0.1120 | Val Total: 0.0025
# Epoch 20/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0199, bin_pred: 0.1531, mix_bin_pred: 0.1117 | Val Total: 0.0025
# Epoch 30/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0193, bin_pred: 0.1531, mix_bin_pred: 0.1137 | Val Total: 0.0025
# Epoch 40/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0196, bin_pred: 0.1510, mix_bin_pred: 0.1089 | Val Total: 0.0025
# Epoch 50/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0194, bin_pred: 0.1534, mix_bin_pred: 0.1133 | Val Total: 0.0025
#
# --- SSLVE Step 48/1000 ---
#   Operator ratio - pse_mut: 145/500 (29%), pse_line: 186/500 (37%), lve_mut: 60/500 (12%), lve_cross: 52/500 (10%), std_support_lve: 57/500 (11%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3931, Bins: 1403, Coverage: 0.7195, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 140290.4162
# Epoch 10/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0190, bin_pred: 0.1534, mix_bin_pred: 0.1135 | Val Total: 0.0027
# Epoch 20/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0189, bin_pred: 0.1532, mix_bin_pred: 0.1123 | Val Total: 0.0027
# Epoch 30/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0190, bin_pred: 0.1530, mix_bin_pred: 0.1121 | Val Total: 0.0027
# Epoch 40/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0193, bin_pred: 0.1526, mix_bin_pred: 0.1153 | Val Total: 0.0027
# Epoch 50/50 | Train Total: 0.0027, Recon: 0.0025, KL: 0.0181, bin_pred: 0.1540, mix_bin_pred: 0.1145 | Val Total: 0.0027
#
# --- SSLVE Step 49/1000 ---
#   Operator ratio - pse_mut: 141/500 (28%), pse_line: 185/500 (37%), lve_mut: 62/500 (12%), lve_cross: 53/500 (11%), std_support_lve: 59/500 (12%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 3965, Bins: 1412, Coverage: 0.7241, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 141190.4666
# Epoch 10/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0173, bin_pred: 0.1555, mix_bin_pred: 0.1152 | Val Total: 0.0027
# Epoch 20/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0186, bin_pred: 0.1537, mix_bin_pred: 0.1138 | Val Total: 0.0027
# Epoch 30/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0182, bin_pred: 0.1553, mix_bin_pred: 0.1139 | Val Total: 0.0027
# Epoch 40/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0180, bin_pred: 0.1552, mix_bin_pred: 0.1143 | Val Total: 0.0028
# Epoch 50/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0177, bin_pred: 0.1540, mix_bin_pred: 0.1122 | Val Total: 0.0027
#
# --- SSLVE Step 50/1000 ---
#   Operator ratio - pse_mut: 136/500 (27%), pse_line: 187/500 (37%), lve_mut: 63/500 (13%), lve_cross: 54/500 (11%), std_support_lve: 60/500 (12%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 4005, Bins: 1426, Coverage: 0.7313, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 142590.4194
# Epoch 10/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0163, bin_pred: 0.1558, mix_bin_pred: 0.1143 | Val Total: 0.0024
# Epoch 20/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0175, bin_pred: 0.1561, mix_bin_pred: 0.1151 | Val Total: 0.0025
# Epoch 30/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0169, bin_pred: 0.1557, mix_bin_pred: 0.1150 | Val Total: 0.0024
# Epoch 40/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0173, bin_pred: 0.1560, mix_bin_pred: 0.1170 | Val Total: 0.0024
# Epoch 50/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0163, bin_pred: 0.1571, mix_bin_pred: 0.1164 | Val Total: 0.0025
#
# --- SSLVE Step 51/1000 ---
#   Operator ratio - pse_mut: 137/500 (27%), pse_line: 185/500 (37%), lve_mut: 64/500 (13%), lve_cross: 54/500 (11%), std_support_lve: 60/500 (12%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 4041, Bins: 1437, Coverage: 0.7369, Fitness min/mean/max: 0.00/0.01/0.05
# QD-score: 143690.4464
# Epoch 10/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0168, bin_pred: 0.1560, mix_bin_pred: 0.1141 | Val Total: 0.0025
# Epoch 20/50 | Train Total: 0.0025, Recon: 0.0024, KL: 0.0148, bin_pred: 0.1591, mix_bin_pred: 0.1202 | Val Total: 0.0025
# Epoch 30/50 | Train Total: 0.0025, Recon: 0.0024, KL: 0.0158, bin_pred: 0.1584, mix_bin_pred: 0.1198 | Val Total: 0.0025
# Epoch 40/50 | Train Total: 0.0025, Recon: 0.0024, KL: 0.0159, bin_pred: 0.1557, mix_bin_pred: 0.1150 | Val Total: 0.0025
# Epoch 50/50 | Train Total: 0.0026, Recon: 0.0024, KL: 0.0166, bin_pred: 0.1562, mix_bin_pred: 0.1150 | Val Total: 0.0025
#
# --- SSLVE Step 52/1000 ---
#   Operator ratio - pse_mut: 137/500 (27%), pse_line: 183/500 (37%), lve_mut: 65/500 (13%), lve_cross: 55/500 (11%), std_support_lve: 60/500 (12%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 4063, Bins: 1444, Coverage: 0.7405, Fitness min/mean/max: 0.00/0.01/0.04
# QD-score: 144390.4802
# Epoch 10/50 | Train Total: 0.0025, Recon: 0.0023, KL: 0.0163, bin_pred: 0.1591, mix_bin_pred: 0.1174 | Val Total: 0.0027
# Epoch 20/50 | Train Total: 0.0025, Recon: 0.0023, KL: 0.0163, bin_pred: 0.1565, mix_bin_pred: 0.1141 | Val Total: 0.0027
# Epoch 30/50 | Train Total: 0.0025, Recon: 0.0023, KL: 0.0163, bin_pred: 0.1569, mix_bin_pred: 0.1157 | Val Total: 0.0027
# Epoch 40/50 | Train Total: 0.0025, Recon: 0.0023, KL: 0.0164, bin_pred: 0.1564, mix_bin_pred: 0.1167 | Val Total: 0.0027
# Epoch 50/50 | Train Total: 0.0025, Recon: 0.0023, KL: 0.0162, bin_pred: 0.1561, mix_bin_pred: 0.1168 | Val Total: 0.0027
#
# --- SSLVE Step 53/1000 ---
#   Operator ratio - pse_mut: 135/500 (27%), pse_line: 180/500 (36%), lve_mut: 66/500 (13%), lve_cross: 58/500 (12%), std_support_lve: 61/500 (12%)
# Collecting: 500/500 [6s elapsed, 0s remaining]
# Archive: 4082, Bins: 1447, Coverage: 0.7421, Fitness min/mean/max: 0.00/0.01/0.04
# QD-score: 144690.5456
# Epoch 10/50 | Train Total: 0.0024, Recon: 0.0023, KL: 0.0145, bin_pred: 0.1580, mix_bin_pred: 0.1176 | Val Total: 0.0025
# Epoch 20/50 | Train Total: 0.0024, Recon: 0.0023, KL: 0.0146, bin_pred: 0.1563, mix_bin_pred: 0.1156 | Val Total: 0.0025
# Epoch 30/50 | Train Total: 0.0024, Recon: 0.0023, KL: 0.0141, bin_pred: 0.1598, mix_bin_pred: 0.1190 | Val Total: 0.0025
# Epoch 40/50 | Train Total: 0.0024, Recon: 0.0023, KL: 0.0146, bin_pred: 0.1555, mix_bin_pred: 0.1132 | Val Total: 0.0025
# Epoch 50/50 | Train Total: 0.0024, Recon: 0.0023, KL: 0.0153, bin_pred: 0.1543, mix_bin_pred: 0.1144 | Val Total: 0.0025
#
# --- SSLVE Step 54/1000 ---
#   Operator ratio - pse_mut: 133/500 (27%), pse_line: 177/500 (35%), lve_mut: 67/500 (13%), lve_cross: 60/500 (12%), std_support_lve: 63/500 (13%)
# Collecting: 500/500 [6s elapsed, 0s remaining]
# Archive: 4106, Bins: 1455, Coverage: 0.7462, Fitness min/mean/max: 0.00/0.01/0.04
# QD-score: 145490.5614
# Epoch 10/50 | Train Total: 0.0024, Recon: 0.0022, KL: 0.0157, bin_pred: 0.1569, mix_bin_pred: 0.1167 | Val Total: 0.0024
# Epoch 20/50 | Train Total: 0.0024, Recon: 0.0023, KL: 0.0151, bin_pred: 0.1593, mix_bin_pred: 0.1193 | Val Total: 0.0024
# Epoch 30/50 | Train Total: 0.0024, Recon: 0.0023, KL: 0.0143, bin_pred: 0.1574, mix_bin_pred: 0.1155 | Val Total: 0.0024
# Epoch 40/50 | Train Total: 0.0024, Recon: 0.0023, KL: 0.0151, bin_pred: 0.1589, mix_bin_pred: 0.1185 | Val Total: 0.0024
# Epoch 50/50 | Train Total: 0.0024, Recon: 0.0023, KL: 0.0158, bin_pred: 0.1586, mix_bin_pred: 0.1184 | Val Total: 0.0024
#
# --- SSLVE Step 55/1000 ---
#   Operator ratio - pse_mut: 132/500 (26%), pse_line: 174/500 (35%), lve_mut: 69/500 (14%), lve_cross: 61/500 (12%), std_support_lve: 64/500 (13%)
# Collecting: 500/500 [6s elapsed, 0s remaining]
# Archive: 4132, Bins: 1460, Coverage: 0.7487, Fitness min/mean/max: 0.00/0.01/0.04
# QD-score: 145990.5993
# Epoch 10/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0135, bin_pred: 0.1613, mix_bin_pred: 0.1197 | Val Total: 0.0025
# Epoch 20/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0138, bin_pred: 0.1582, mix_bin_pred: 0.1170 | Val Total: 0.0024
# Epoch 30/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0137, bin_pred: 0.1585, mix_bin_pred: 0.1170 | Val Total: 0.0025
# Epoch 40/50 | Train Total: 0.0024, Recon: 0.0022, KL: 0.0136, bin_pred: 0.1579, mix_bin_pred: 0.1160 | Val Total: 0.0025
# Epoch 50/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0136, bin_pred: 0.1585, mix_bin_pred: 0.1198 | Val Total: 0.0025
#
# --- SSLVE Step 56/1000 ---
#   Operator ratio - pse_mut: 133/500 (27%), pse_line: 170/500 (34%), lve_mut: 70/500 (14%), lve_cross: 62/500 (12%), std_support_lve: 65/500 (13%)
# Collecting: 500/500 [6s elapsed, 0s remaining]
# Archive: 4157, Bins: 1469, Coverage: 0.7533, Fitness min/mean/max: 0.00/0.01/0.04
# QD-score: 146890.5841
# Epoch 10/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0137, bin_pred: 0.1580, mix_bin_pred: 0.1167 | Val Total: 0.0024
# Epoch 20/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0140, bin_pred: 0.1593, mix_bin_pred: 0.1152 | Val Total: 0.0024
# Epoch 30/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0137, bin_pred: 0.1623, mix_bin_pred: 0.1200 | Val Total: 0.0024
# Epoch 40/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0142, bin_pred: 0.1591, mix_bin_pred: 0.1178 | Val Total: 0.0024
# Epoch 50/50 | Train Total: 0.0024, Recon: 0.0022, KL: 0.0141, bin_pred: 0.1589, mix_bin_pred: 0.1158 | Val Total: 0.0024
#
# --- SSLVE Step 57/1000 ---
#   Operator ratio - pse_mut: 131/500 (26%), pse_line: 171/500 (34%), lve_mut: 70/500 (14%), lve_cross: 63/500 (13%), std_support_lve: 65/500 (13%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 4176, Bins: 1471, Coverage: 0.7544, Fitness min/mean/max: 0.00/0.01/0.04
# QD-score: 147090.6707
# Epoch 10/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0139, bin_pred: 0.1594, mix_bin_pred: 0.1205 | Val Total: 0.0024
# Epoch 20/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0142, bin_pred: 0.1598, mix_bin_pred: 0.1184 | Val Total: 0.0024
# Epoch 30/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0134, bin_pred: 0.1590, mix_bin_pred: 0.1174 | Val Total: 0.0024
# Epoch 40/50 | Train Total: 0.0023, Recon: 0.0021, KL: 0.0137, bin_pred: 0.1578, mix_bin_pred: 0.1189 | Val Total: 0.0024
# Epoch 50/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0139, bin_pred: 0.1588, mix_bin_pred: 0.1171 | Val Total: 0.0023
#
# --- SSLVE Step 58/1000 ---
#   Operator ratio - pse_mut: 131/500 (26%), pse_line: 167/500 (33%), lve_mut: 71/500 (14%), lve_cross: 64/500 (13%), std_support_lve: 67/500 (13%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 4195, Bins: 1475, Coverage: 0.7564, Fitness min/mean/max: 0.00/0.01/0.04
# QD-score: 147490.7016
# Epoch 10/50 | Train Total: 0.0023, Recon: 0.0021, KL: 0.0135, bin_pred: 0.1581, mix_bin_pred: 0.1181 | Val Total: 0.0022
# Epoch 20/50 | Train Total: 0.0023, Recon: 0.0021, KL: 0.0135, bin_pred: 0.1584, mix_bin_pred: 0.1178 | Val Total: 0.0022
# Epoch 30/50 | Train Total: 0.0023, Recon: 0.0022, KL: 0.0138, bin_pred: 0.1601, mix_bin_pred: 0.1193 | Val Total: 0.0022
# Epoch 40/50 | Train Total: 0.0023, Recon: 0.0021, KL: 0.0137, bin_pred: 0.1590, mix_bin_pred: 0.1167 | Val Total: 0.0022
# Epoch 50/50 | Train Total: 0.0023, Recon: 0.0021, KL: 0.0136, bin_pred: 0.1589, mix_bin_pred: 0.1171 | Val Total: 0.0022
#
# --- SSLVE Step 59/1000 ---
#   Operator ratio - pse_mut: 127/500 (25%), pse_line: 165/500 (33%), lve_mut: 73/500 (15%), lve_cross: 67/500 (13%), std_support_lve: 68/500 (14%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 4214, Bins: 1477, Coverage: 0.7574, Fitness min/mean/max: 0.00/0.01/0.04
# QD-score: 147690.7512
# Epoch 10/50 | Train Total: 0.0022, Recon: 0.0021, KL: 0.0123, bin_pred: 0.1599, mix_bin_pred: 0.1197 | Val Total: 0.0025
# Epoch 20/50 | Train Total: 0.0022, Recon: 0.0021, KL: 0.0123, bin_pred: 0.1597, mix_bin_pred: 0.1178 | Val Total: 0.0025
# Epoch 30/50 | Train Total: 0.0022, Recon: 0.0021, KL: 0.0128, bin_pred: 0.1606, mix_bin_pred: 0.1197 | Val Total: 0.0025
# Epoch 40/50 | Train Total: 0.0022, Recon: 0.0021, KL: 0.0120, bin_pred: 0.1583, mix_bin_pred: 0.1157 | Val Total: 0.0025
# Epoch 50/50 | Train Total: 0.0022, Recon: 0.0021, KL: 0.0118, bin_pred: 0.1612, mix_bin_pred: 0.1202 | Val Total: 0.0025
#
# --- SSLVE Step 60/1000 ---
#   Operator ratio - pse_mut: 125/500 (25%), pse_line: 163/500 (33%), lve_mut: 75/500 (15%), lve_cross: 68/500 (14%), std_support_lve: 69/500 (14%)
# Collecting: 500/500 [5s elapsed, 0s remaining]
# Archive: 4234, Bins: 1481, Coverage: 0.7595, Fitness min/mean/max: 0.00/0.01/0.04
# QD-score: 148090.8115
# Epoch 10/50 | Train Total: 0.0022, Recon: 0.0021, KL: 0.0124, bin_pred: 0.1568, mix_bin_pred: 0.1166 | Val Total: 0.0023
# Epoch 20/50 | Train Total: 0.0022, Recon: 0.0021, KL: 0.0121, bin_pred: 0.1605, mix_bin_pred: 0.1186 | Val Total: 0.0023
# Epoch 30/50 | Train Total: 0.0022, Recon: 0.0021, KL: 0.0118, bin_pred: 0.1607, mix_bin_pred: 0.1194 | Val Total: 0.0022
# Epoch 40/50 | Train Total: 0.0022, Recon: 0.0021, KL: 0.0122, bin_pred: 0.1587, mix_bin_pred: 0.1158 | Val Total: 0.0023
# Epoch 50/50 | Train Total: 0.0022, Recon: 0.0021, KL: 0.0122, bin_pred: 0.1605, mix_bin_pred: 0.1187 | Val Total: 0.0023
#
# --- SSLVE Step 61/1000 ---
# ...
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 5263, Bins: 1767, Coverage: 0.9062, Fitness min/mean/max: 0.04/0.04/0.10
# QD-score: 176624.1700
# Epoch 10/50 | Train Total: 0.0005, Recon: 0.0003, KL: 0.0167, bin_pred: 0.1409, mix_bin_pred: 0.1033 | Val Total: 0.0004
# Epoch 20/50 | Train Total: 0.0005, Recon: 0.0003, KL: 0.0167, bin_pred: 0.1440, mix_bin_pred: 0.1078 | Val Total: 0.0004
# Epoch 30/50 | Train Total: 0.0005, Recon: 0.0003, KL: 0.0164, bin_pred: 0.1436, mix_bin_pred: 0.1070 | Val Total: 0.0004
# Epoch 40/50 | Train Total: 0.0005, Recon: 0.0003, KL: 0.0164, bin_pred: 0.1423, mix_bin_pred: 0.1046 | Val Total: 0.0005
# Epoch 50/50 | Train Total: 0.0005, Recon: 0.0003, KL: 0.0164, bin_pred: 0.1447, mix_bin_pred: 0.1096 | Val Total: 0.0004
#
# --- SSLVE Step 980/1000 ---
#   Operator ratio - pse_mut: 100/500 (20%), pse_line: 100/500 (20%), lve_mut: 100/500 (20%), lve_cross: 100/500 (20%), std_support_lve: 100/500 (20%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 5263, Bins: 1767, Coverage: 0.9062, Fitness min/mean/max: 0.04/0.04/0.10
# QD-score: 176624.1749
# Epoch 10/50 | Train Total: 0.0004, Recon: 0.0003, KL: 0.0163, bin_pred: 0.1454, mix_bin_pred: 0.1073 | Val Total: 0.0005
# Epoch 20/50 | Train Total: 0.0005, Recon: 0.0003, KL: 0.0162, bin_pred: 0.1449, mix_bin_pred: 0.1043 | Val Total: 0.0005
# Epoch 30/50 | Train Total: 0.0004, Recon: 0.0003, KL: 0.0163, bin_pred: 0.1442, mix_bin_pred: 0.1060 | Val Total: 0.0005
# Epoch 40/50 | Train Total: 0.0004, Recon: 0.0003, KL: 0.0158, bin_pred: 0.1456, mix_bin_pred: 0.1083 | Val Total: 0.0004
# Epoch 50/50 | Train Total: 0.0005, Recon: 0.0003, KL: 0.0164, bin_pred: 0.1453, mix_bin_pred: 0.1071 | Val Total: 0.0005
#
# --- SSLVE Step 981/1000 ---
#   Operator ratio - pse_mut: 100/500 (20%), pse_line: 100/500 (20%), lve_mut: 100/500 (20%), lve_cross: 100/500 (20%), std_support_lve: 100/500 (20%)
# Collecting: 389/500 [5s elapsed, 2s remaining]Epoch 20/50 | Train Total: 0.0005, Recon: 0.0003, KL: 0.0171, bin_pred: 0.1432, mix_bin_pred: 0.1080 | Val Total: 0.0004
# Epoch 30/50 | Train Total: 0.0004, Recon: 0.0003, KL: 0.0164, bin_pred: 0.1462, mix_bin_pred: 0.1076 | Val Total: 0.0004
# Epoch 40/50 | Train Total: 0.0004, Recon: 0.0003, KL: 0.0164, bin_pred: 0.1475, mix_bin_pred: 0.1103 | Val Total: 0.0004
# Epoch 50/50 | Train Total: 0.0005, Recon: 0.0003, KL: 0.0170, bin_pred: 0.1423, mix_bin_pred: 0.1059 | Val Total: 0.0004
#
# --- SSLVE Step 999/1000 ---
#   Operator ratio - pse_mut: 100/500 (20%), pse_line: 100/500 (20%), lve_mut: 100/500 (20%), lve_cross: 100/500 (20%), std_support_lve: 100/500 (20%)
# Collecting: 500/500 [6s elapsed, 0s remaining]
# Archive: 5267, Bins: 1768, Coverage: 0.9067, Fitness min/mean/max: 0.04/0.04/0.10
# QD-score: 176724.2724
# Epoch 10/50 | Train Total: 0.0004, Recon: 0.0003, KL: 0.0170, bin_pred: 0.1458, mix_bin_pred: 0.1082 | Val Total: 0.0005
# Epoch 20/50 | Train Total: 0.0004, Recon: 0.0003, KL: 0.0167, bin_pred: 0.1418, mix_bin_pred: 0.1031 | Val Total: 0.0005
# Epoch 30/50 | Train Total: 0.0004, Recon: 0.0003, KL: 0.0173, bin_pred: 0.1420, mix_bin_pred: 0.1054 | Val Total: 0.0005
# Epoch 40/50 | Train Total: 0.0004, Recon: 0.0003, KL: 0.0165, bin_pred: 0.1471, mix_bin_pred: 0.1084 | Val Total: 0.0005
# Epoch 50/50 | Train Total: 0.0004, Recon: 0.0003, KL: 0.0167, bin_pred: 0.1428, mix_bin_pred: 0.1063 | Val Total: 0.0005
#
# --- SSLVE Step 1000/1000 ---
#   Operator ratio - pse_mut: 100/500 (20%), pse_line: 100/500 (20%), lve_mut: 100/500 (20%), lve_cross: 100/500 (20%), std_support_lve: 100/500 (20%)
# Collecting: 500/500 [17s elapsed, 0s remaining]
# Archive: 226, Bins: 86, Coverage: 0.0441, Fitness min/mean/max: 0.32/0.37/0.98
# QD-score: 8567.6985
#
# --- SSLVE Step 10/1000 ---
#   Operator ratio - pse_mut: 270/500 (54%), pse_line: 230/500 (46%)
# Collecting: 500/500 [16s elapsed, 0s remaining]
# Archive: 234, Bins: 87, Coverage: 0.0446, Fitness min/mean/max: 0.32/0.37/0.98
# QD-score: 8668.3955
#
# --- SSLVE Step 11/1000 ---
#   Operator ratio - pse_mut: 269/500 (54%), pse_line: 231/500 (46%)
# Collecting: 500/500 [15s elapsed, 0s remaining]
# Archive: 244, Bins: 90, Coverage: 0.0462, Fitness min/mean/max: 0.32/0.36/0.64
# QD-score: 8968.2576
#
# --- SSLVE Step 12/1000 ---
#   Operator ratio - pse_mut: 269/500 (54%), pse_line: 231/500 (46%)
# Collecting: 500/500 [15s elapsed, 0s remaining]
# Archive: 252, Bins: 91, Coverage: 0.0467, Fitness min/mean/max: 0.32/0.35/0.64
# QD-score: 9068.1142
#
# --- SSLVE Step 13/1000 ---
#   Operator ratio - pse_mut: 268/500 (54%), pse_line: 232/500 (46%)
# Collecting: 500/500 [11s elapsed, 0s remaining]
# Archive: 460, Bins: 165, Coverage: 0.0846, Fitness min/mean/max: 0.28/0.30/0.38
# QD-score: 16451.1925
#
# --- SSLVE Step 58/1000 ---
#   Operator ratio - pse_mut: 249/500 (50%), pse_line: 251/500 (50%)
# Collecting: 500/500 [11s elapsed, 0s remaining]
# Archive: 2519, Bins: 944, Coverage: 0.4841, Fitness min/mean/max: 0.00/0.01/0.31
# QD-score: 94395.2423
# Epoch 10/50 | Train Total: 0.0011, Recon: 0.0008, KL: 0.0279, bin_pred: 0.0971, mix_bin_pred: 0.0724
# Epoch 20/50 | Train Total: 0.0011, Recon: 0.0008, KL: 0.0265, bin_pred: 0.0986, mix_bin_pred: 0.0739
# Epoch 30/50 | Train Total: 0.0011, Recon: 0.0008, KL: 0.0280, bin_pred: 0.0955, mix_bin_pred: 0.0702
# Epoch 40/50 | Train Total: 0.0011, Recon: 0.0008, KL: 0.0250, bin_pred: 0.0950, mix_bin_pred: 0.0707
# Epoch 50/50 | Train Total: 0.0011, Recon: 0.0008, KL: 0.0251, bin_pred: 0.0964, mix_bin_pred: 0.0702
#
# --- SSLVE Step 96/1000 ---
#   Operator ratio - pse_mut: 119/500 (24%), pse_line: 112/500 (22%), lve_mut: 90/500 (18%), lve_cross: 86/500 (17%), std_support_lve: 93/500 (19%)
# Collecting: 500/500 [11s elapsed, 0s remaining]
# Archive: 3037, Bins: 1089, Coverage: 0.5585, Fitness min/mean/max: 0.00/0.00/0.04
# QD-score: 108895.4711
# Epoch 10/50 | Train Total: 0.0009, Recon: 0.0008, KL: 0.0095, bin_pred: 0.1254, mix_bin_pred: 0.0931 | Val Total: 0.0008
# Epoch 20/50 | Train Total: 0.0009, Recon: 0.0008, KL: 0.0091, bin_pred: 0.1259, mix_bin_pred: 0.0918 | Val Total: 0.0008
# Epoch 30/50 | Train Total: 0.0009, Recon: 0.0008, KL: 0.0097, bin_pred: 0.1262, mix_bin_pred: 0.0920 | Val Total: 0.0008
# Epoch 40/50 | Train Total: 0.0009, Recon: 0.0008, KL: 0.0091, bin_pred: 0.1240, mix_bin_pred: 0.0896 | Val Total: 0.0008
# Epoch 50/50 | Train Total: 0.0009, Recon: 0.0008, KL: 0.0098, bin_pred: 0.1259, mix_bin_pred: 0.0948 | Val Total: 0.0008
#
# --- SSLVE Step 140/1000 ---
#   Operator ratio - pse_mut: 108/500 (22%), pse_line: 109/500 (22%), lve_mut: 97/500 (19%), lve_cross: 94/500 (19%), std_support_lve: 92/500 (18%)
# Collecting: 500/500 [12s elapsed, 0s remaining]
# Archive: 3466, Bins: 1236, Coverage: 0.6338, Fitness min/mean/max: 0.00/0.00/0.02
# QD-score: 123595.1166
# Epoch 10/50 | Train Total: 0.0008, Recon: 0.0007, KL: 0.0040, bin_pred: 0.1464, mix_bin_pred: 0.1080 | Val Total: 0.0009
# Epoch 20/50 | Train Total: 0.0008, Recon: 0.0008, KL: 0.0038, bin_pred: 0.1470, mix_bin_pred: 0.1076 | Val Total: 0.0009
# Epoch 30/50 | Train Total: 0.0008, Recon: 0.0008, KL: 0.0036, bin_pred: 0.1469, mix_bin_pred: 0.1095 | Val Total: 0.0009
# Epoch 40/50 | Train Total: 0.0008, Recon: 0.0008, KL: 0.0036, bin_pred: 0.1469, mix_bin_pred: 0.1097 | Val Total: 0.0009
# Epoch 50/50 | Train Total: 0.0008, Recon: 0.0007, KL: 0.0041, bin_pred: 0.1463, mix_bin_pred: 0.1074 | Val Total: 0.0009
#
# --- SSLVE Step 236/1000 ---
#   Operator ratio - pse_mut: 103/500 (21%), pse_line: 107/500 (21%), lve_mut: 98/500 (20%), lve_cross: 96/500 (19%), std_support_lve: 96/500 (19%)
# Collecting: 500/500 [17s elapsed, 0s remaining]
# Archive: 4101, Bins: 1410, Coverage: 0.7231, Fitness min/mean/max: 0.00/0.00/0.02
# QD-score: 140995.0687
# Epoch 10/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0053, bin_pred: 0.1674, mix_bin_pred: 0.1227 | Val Total: 0.0004
# Epoch 20/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0050, bin_pred: 0.1672, mix_bin_pred: 0.1259 | Val Total: 0.0004
# Epoch 30/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0047, bin_pred: 0.1699, mix_bin_pred: 0.1250 | Val Total: 0.0004
# Epoch 40/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0053, bin_pred: 0.1693, mix_bin_pred: 0.1272 | Val Total: 0.0004
# Epoch 50/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0051, bin_pred: 0.1701, mix_bin_pred: 0.1249 | Val Total: 0.0004
#
# --- SSLVE Step 911/1000 ---
#   Operator ratio - pse_mut: 100/500 (20%), pse_line: 100/500 (20%), lve_mut: 100/500 (20%), lve_cross: 100/500 (20%), std_support_lve: 100/500 (20%)
# Collecting: 500/500 [17s elapsed, 0s remaining]
# Archive: 4102, Bins: 1410, Coverage: 0.7231, Fitness min/mean/max: 0.00/0.00/0.02
# QD-score: 140995.0695
# Epoch 10/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0049, bin_pred: 0.1690, mix_bin_pred: 0.1248 | Val Total: 0.0005
# Epoch 20/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0048, bin_pred: 0.1686, mix_bin_pred: 0.1242 | Val Total: 0.0005
# Epoch 30/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0050, bin_pred: 0.1693, mix_bin_pred: 0.1271 | Val Total: 0.0005
# Epoch 40/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0047, bin_pred: 0.1694, mix_bin_pred: 0.1247 | Val Total: 0.0005
# Epoch 50/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0046, bin_pred: 0.1691, mix_bin_pred: 0.1246 | Val Total: 0.0005
#
# --- SSLVE Step 912/1000 ---
#   Operator ratio - pse_mut: 100/500 (20%), pse_line: 101/500 (20%), lve_mut: 99/500 (20%), lve_cross: 100/500 (20%), std_support_lve: 100/500 (20%)
# Collecting: 500/500 [13s elapsed, 0s remaining]
# Archive: 4103, Bins: 1411, Coverage: 0.7236, Fitness min/mean/max: 0.00/0.00/0.02
# QD-score: 141095.0586
# Epoch 10/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0049, bin_pred: 0.1691, mix_bin_pred: 0.1243 | Val Total: 0.0004
# Epoch 20/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0052, bin_pred: 0.1704, mix_bin_pred: 0.1272 | Val Total: 0.0004
# Epoch 30/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0052, bin_pred: 0.1692, mix_bin_pred: 0.1252 | Val Total: 0.0004
# Epoch 40/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0055, bin_pred: 0.1680, mix_bin_pred: 0.1222 | Val Total: 0.0004
# Epoch 50/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0052, bin_pred: 0.1683, mix_bin_pred: 0.1264 | Val Total: 0.0004
#
# --- SSLVE Step 915/1000 ---
#   Operator ratio - pse_mut: 100/500 (20%), pse_line: 100/500 (20%), lve_mut: 100/500 (20%), lve_cross: 100/500 (20%), std_support_lve: 100/500 (20%)
# Collecting: 500/500 [13s elapsed, 0s remaining]
# Archive: 4103, Bins: 1411, Coverage: 0.7236, Fitness min/mean/max: 0.00/0.00/0.02
# QD-score: 141095.0591
# Epoch 10/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0053, bin_pred: 0.1698, mix_bin_pred: 0.1248 | Val Total: 0.0004
# Epoch 20/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0051, bin_pred: 0.1682, mix_bin_pred: 0.1260 | Val Total: 0.0004
# Epoch 30/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0051, bin_pred: 0.1689, mix_bin_pred: 0.1245 | Val Total: 0.0005
# Epoch 40/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0051, bin_pred: 0.1701, mix_bin_pred: 0.1251 | Val Total: 0.0004
# Epoch 50/50 | Train Total: 0.0004, Recon: 0.0004, KL: 0.0051, bin_pred: 0.1688, mix_bin_pred: 0.1266 | Val Total: 0.0004
#
# --- SSLVE Step 916/1000 ---
#   Operator ratio - pse_mut: 100/500 (20%), pse_line: 100/500 (20%), lve_mut: 100/500 (20%), lve_cross: 100/500 (20%), std_support_lve: 100/500 (20%)
# Collecting: 500/500 [11s elapsed, 0s remaining]
# Archive: 214, Bins: 86, Coverage: 0.0441, Fitness min/mean/max: 2.83/3.27/5.18
# QD-score: 8321.7920
#
# --- SSLVE Step 9/1000 ---
#   Operator ratio - pse_mut: 257/500 (51%), pse_line: 243/500 (49%)
# Collecting: 500/500 [11s elapsed, 0s remaining]
# Archive: 245, Bins: 96, Coverage: 0.0492, Fitness min/mean/max: 2.82/3.20/4.97
# QD-score: 9294.2503
#
# --- SSLVE Step 10/1000 ---
#   Operator ratio - pse_mut: 259/500 (52%), pse_line: 241/500 (48%)
# Collecting: 500/500 [11s elapsed, 0s remaining]
# Archive: 466, Bins: 168, Coverage: 0.0862, Fitness min/mean/max: 2.53/2.94/3.74
# QD-score: 16307.1982
#
# --- SSLVE Step 50/1000 ---
#   Operator ratio - pse_mut: 253/500 (51%), pse_line: 247/500 (49%)
# Collecting: 500/500 [11s elapsed, 0s remaining]
# Archive: 467, Bins: 168, Coverage: 0.0862, Fitness min/mean/max: 2.53/2.93/3.74
# QD-score: 16308.2419
#
# --- SSLVE Step 51/1000 ---
#   Operator ratio - pse_mut: 253/500 (51%), pse_line: 247/500 (49%)
# Collecting: 500/500 [11s elapsed, 0s remaining]
# Archive: 2609, Bins: 975, Coverage: 0.5000, Fitness min/mean/max: 0.04/0.09/3.50
# QD-score: 97432.4495
# Epoch 10/50 | Train Total: 0.0012, Recon: 0.0008, KL: 0.0381, bin_pred: 0.0922, mix_bin_pred: 0.0685 | Val Total: 0.0012
# Epoch 20/50 | Train Total: 0.0012, Recon: 0.0008, KL: 0.0383, bin_pred: 0.0904, mix_bin_pred: 0.0672 | Val Total: 0.0012
# Epoch 30/50 | Train Total: 0.0012, Recon: 0.0008, KL: 0.0378, bin_pred: 0.0902, mix_bin_pred: 0.0656 | Val Total: 0.0012
# Epoch 40/50 | Train Total: 0.0012, Recon: 0.0008, KL: 0.0384, bin_pred: 0.0912, mix_bin_pred: 0.0661 | Val Total: 0.0012
# Epoch 50/50 | Train Total: 0.0012, Recon: 0.0008, KL: 0.0388, bin_pred: 0.0916, mix_bin_pred: 0.0698 | Val Total: 0.0012
#
# --- SSLVE Step 91/1000 ---
#   Operator ratio - pse_mut: 87/500 (17%), pse_line: 128/500 (26%), lve_mut: 112/500 (22%), lve_cross: 96/500 (19%), std_support_lve: 77/500 (15%)
# Collecting: 500/500 [12s elapsed, 0s remaining]
# Archive: 2830, Bins: 1022, Coverage: 0.5241, Fitness min/mean/max: 0.04/0.07/3.44
# QD-score: 102134.2433
# Epoch 10/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0287, bin_pred: 0.0975, mix_bin_pred: 0.0713 | Val Total: 0.0010
# Epoch 20/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0292, bin_pred: 0.0975, mix_bin_pred: 0.0721 | Val Total: 0.0010
# Epoch 30/50 | Train Total: 0.0010, Recon: 0.0006, KL: 0.0311, bin_pred: 0.0971, mix_bin_pred: 0.0726 | Val Total: 0.0010
# Epoch 40/50 | Train Total: 0.0009, Recon: 0.0007, KL: 0.0290, bin_pred: 0.0988, mix_bin_pred: 0.0749 | Val Total: 0.0010
# Epoch 50/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0299, bin_pred: 0.0978, mix_bin_pred: 0.0729 | Val Total: 0.0010
#
# --- SSLVE Step 99/1000 ---
#   Operator ratio - pse_mut: 94/500 (19%), pse_line: 106/500 (21%), lve_mut: 106/500 (21%), lve_cross: 93/500 (19%), std_support_lve: 101/500 (20%)
# Collecting: 500/500 [12s elapsed, 0s remaining]
# Archive: 2854, Bins: 1029, Coverage: 0.5277, Fitness min/mean/max: 0.04/0.07/3.38
# QD-score: 102833.8905
# Epoch 10/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0273, bin_pred: 0.0963, mix_bin_pred: 0.0711 | Val Total: 0.0011
# Epoch 20/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0286, bin_pred: 0.0979, mix_bin_pred: 0.0730 | Val Total: 0.0011
# Epoch 30/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0279, bin_pred: 0.0965, mix_bin_pred: 0.0711 | Val Total: 0.0010
# Epoch 40/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0288, bin_pred: 0.0971, mix_bin_pred: 0.0704 | Val Total: 0.0011
# Epoch 50/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0276, bin_pred: 0.0971, mix_bin_pred: 0.0716 | Val Total: 0.0011
#
# --- SSLVE Step 100/1000 ---
#   Operator ratio - pse_mut: 92/500 (18%), pse_line: 107/500 (21%), lve_mut: 105/500 (21%), lve_cross: 93/500 (19%), std_support_lve: 103/500 (21%)
# Collecting: 500/500 [11s elapsed, 0s remaining]
# Archive: 2871, Bins: 1032, Coverage: 0.5292, Fitness min/mean/max: 0.04/0.07/3.38
# QD-score: 103134.3777
# Epoch 10/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0283, bin_pred: 0.0968, mix_bin_pred: 0.0724 | Val Total: 0.0009
# Epoch 20/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0299, bin_pred: 0.0955, mix_bin_pred: 0.0710 | Val Total: 0.0009
# Epoch 30/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0285, bin_pred: 0.0972, mix_bin_pred: 0.0721 | Val Total: 0.0009
# Epoch 40/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0280, bin_pred: 0.0970, mix_bin_pred: 0.0733 | Val Total: 0.0009
# Epoch 50/50 | Train Total: 0.0009, Recon: 0.0006, KL: 0.0277, bin_pred: 0.0978, mix_bin_pred: 0.0720 | Val Total: 0.0009
#
# --- SSLVE Step 101/1000 ---
#   Operator ratio - pse_mut: 92/500 (18%), pse_line: 105/500 (21%), lve_mut: 102/500 (20%), lve_cross: 94/500 (19%), std_support_lve: 107/500 (21%)
# Collecting: 18/500 [0s elapsed, 10s remaining]
