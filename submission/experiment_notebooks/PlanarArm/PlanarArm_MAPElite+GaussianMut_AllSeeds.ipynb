# %% [markdown]
# # MAP-Elite (Gaussian Mutation) — Baseline
#
# **Method:** MAP-Elites with PSE Gaussian Mutation only (`PSEMut`)
# **Environments:** 4 Planar Arm settings (Det_Linear, Unc_Linear, Det_NonLinear, Unc_NonLinear)
# **Seeds:** 3 per environment
# **Task:** 1000-joint Planar Arm (CVT, 1950 bins)

# %%
# ============================================================
# Cell 1: Setup — mount Drive, clone repo, load SSLVE modules
# Run this cell once at the start of each Colab session.
# ============================================================
from google.colab import drive
drive.mount('/content/drive')

# !rm -rf org && git clone --filter=blob:none --sparse https://github.com/yugoguy/org.git
# !cd org && git sparse-checkout set dev/SSLVE && git checkout Latent-Variable-Evolution
# !pip install cma -q

import sys, os, glob
sys.path.insert(0, 'org/dev/SSLVE')
for f in sorted(glob.glob('org/dev/SSLVE/*.py')):
    # %run {f}

print('Setup complete.')
# Out:
# Mounted at /content/drive
# Cloning into 'org'...
# remote: Enumerating objects: 1726, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (191/191), done.
# remote: Total 1726 (delta 140), reused 34 (delta 34), pack-reused 1501 (from 2)
# Receiving objects: 100% (1726/1726), 484.56 KiB | 14.25 MiB/s, done.
# Resolving deltas: 100% (692/692), done.
# remote: Enumerating objects: 1, done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 1 (from 1)
# Receiving objects: 100% (1/1), 255 bytes | 255.00 KiB/s, done.
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 18 (delta 4), reused 1 (delta 1), pack-reused 7 (from 1)
# Receiving objects: 100% (18/18), 73.23 KiB | 4.58 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Branch 'Latent-Variable-Evolution' set up to track remote branch 'Latent-Variable-Evolution' from 'origin'.
# Switched to a new branch 'Latent-Variable-Evolution'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 12.7 MB/s eta 0:00:00
# Setup complete.

# %%
# ============================================================
# Cell 2: Method Hyperparameters
# ============================================================
import numpy as np
import random
import torch

# --- Architecture ---
N_JOINTS         = 1000   #@param {type:"integer"}
END_EFFECTOR_DIM = 2      #@param {type:"integer"}
N_BINS           = 1950   #@param {type:"integer"}
CENTERS          = "Precomputed_CVT_1950"  #@param ["Precomputed_CVT_1950", "CVT", "random"]
TOP_K            = 1      #@param {type:"integer"}
GREEDY_MEM       = True   #@param {type:"boolean"}

# --- Mutation sigma (key hyperparameter to report) ---
PSE_MUT_SIGMA    = 0.05   #@param {type:"number"}

# --- Search budget (must match other methods for fair comparison) ---
N_TOTAL          = 500   #@param {type:"integer"}
N_STEPS          = 1000   #@param {type:"integer"}

# --- Checkpoint base directory (saved to Google Drive) ---
CKPT_BASE_DIR    = '/content/drive/MyDrive/shared_ckpts/planar_arm/PlanarArm_MAPElite_GaussianMut/'  #@param {type:"string"}

print(f'Method: MAP-Elite (Gaussian Mutation)')
print(f'N_JOINTS={N_JOINTS}, N_BINS={N_BINS}, TOP_K={TOP_K}')
print(f'PSE_MUT_SIGMA={PSE_MUT_SIGMA}, N_TOTAL={N_TOTAL}, N_STEPS={N_STEPS}')
print(f'Checkpoints will be saved to: {CKPT_BASE_DIR}')
# Out:
# Method: MAP-Elite (Gaussian Mutation)
# N_JOINTS=1000, N_BINS=1950, TOP_K=1
# PSE_MUT_SIGMA=0.05, N_TOTAL=500, N_STEPS=1000
# Checkpoints will be saved to: /content/drive/MyDrive/shared_ckpts/planar_arm/PlanarArm_MAPElite_GaussianMut/

# %%
# ============================================================
# Cell 3: Run All Experiments (4 envs x 3 seeds)
# Each run saves a checkpoint + plots immediately after finishing.
# ============================================================

ENV_CONFIGS = [
    {'name': 'Det_Linear',    'noise_sigma': 0.0,  'n_episodes': 1, 'fitness': 'angle_variance'},
    {'name': 'Unc_Linear',    'noise_sigma': 0.05, 'n_episodes': 3, 'fitness': 'angle_variance'},
    {'name': 'Det_NonLinear', 'noise_sigma': 0.0,  'n_episodes': 1, 'fitness': 'sine_dependency'},
    {'name': 'Unc_NonLinear', 'noise_sigma': 0.05, 'n_episodes': 3, 'fitness': 'sine_dependency'},
]

SEEDS = [42, 123, 456]

FITNESS_FNS = {
    'angle_variance':  lambda info: (np.mean(info['angle_variance'])  if isinstance(info['angle_variance'],  list) else info['angle_variance']),
    'sine_dependency': lambda info: (np.mean(info['sine_dependency']) if isinstance(info['sine_dependency'], list) else info['sine_dependency']),
}

all_results = []

ANGLES_PER_JOINT = END_EFFECTOR_DIM - 1
GENE_DIM = N_JOINTS * ANGLES_PER_JOINT
init_fn = lambda: np.random.uniform(-np.pi, np.pi, GENE_DIM)

for env_cfg in ENV_CONFIGS:
    env_name    = env_cfg['name']
    noise_sig   = env_cfg['noise_sigma']
    n_eps       = env_cfg['n_episodes']
    fitness_key = env_cfg['fitness']
    fitness_fn  = FITNESS_FNS[fitness_key]

    for seed in SEEDS:
        print(f'\n========== {env_name} | seed={seed} ==========')

        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)

        collector = PlanarArmCollector(
            n_joints=N_JOINTS,
            end_effector_dim=END_EFFECTOR_DIM,
            noise_sigma=noise_sig,
            n_episodes=n_eps,
        )
        bd = PlanarArmBD_CVT(n_bins=N_BINS, centers=CENTERS, bd_dim=END_EFFECTOR_DIM)
        bm = MAPElitesBM(behavior_descriptor=bd, fitness_fn=fitness_fn, top_k=TOP_K, max_fitness=100)

        sp = BoltzmannMix(
            agent_class=PlanarArmAgent,
            architecture=GENE_DIM,
            operators=[PSEMut(sigma=PSE_MUT_SIGMA, greedy_mem=GREEDY_MEM)],
            n_total=N_TOTAL,
            warmup_threshold=999999,
            init_fn=init_fn,
        )

        me = MAPElite(search_phase=sp, collector=collector, behavior_matching=bm)
        me.run(n_steps=N_STEPS)

        # Save checkpoint immediately after this run
        ckpt_path = os.path.join(
            CKPT_BASE_DIR,
            f'MAPElite_Gauss_sigma{PSE_MUT_SIGMA}_{env_name}_seed{seed}/'
        )
        save_checkpoint(ckpt_path, bm, me.history, sp=sp)
        print(f'Checkpoint saved: {ckpt_path}')

        # Save plots into checkpoint folder
        me.plot_history(save_path=ckpt_path + 'plot_history.png')
        sp.plot_allocation(save_path=ckpt_path + 'plot_allocation.png')
        print(f'Plots saved to: {ckpt_path}')

        # Force Drive sync after each run
        from google.colab import drive
        drive.flush_and_unmount()
        drive.mount('/content/drive')
        print('Drive re-synced.')

        # Print results
        f_min, f_mean, f_max = bm.fitness_stats()
        qd  = bm.qd_score()
        cov = bm.coverage()
        print(f'QD-score: {qd:.4f} | Coverage: {cov:.4f} | Best fitness: {f_min:.6f}')

        all_results.append({
            'env': env_name, 'seed': seed,
            'qd_score': qd, 'coverage': cov,
        })

print('\n====== All runs complete ======')
# Out:
# Streaming output truncated to the last 5000 lines.
# QD-score: 10575.9019
#
# --- MAP-Elite Step 168/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 109, Bins: 109, Coverage: 0.0559, Fitness min/mean/max: 1.92/2.07/2.22
# QD-score: 10674.0644
#
# --- MAP-Elite Step 169/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 109, Bins: 109, Coverage: 0.0559, Fitness min/mean/max: 1.92/2.07/2.22
# QD-score: 10674.3692
#
# --- MAP-Elite Step 170/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 109, Bins: 109, Coverage: 0.0559, Fitness min/mean/max: 1.91/2.07/2.22
# QD-score: 10674.7820
#
# --- MAP-Elite Step 171/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 109, Bins: 109, Coverage: 0.0559, Fitness min/mean/max: 1.91/2.06/2.22
# QD-score: 10674.9625
#
# --- MAP-Elite Step 172/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 109, Bins: 109, Coverage: 0.0559, Fitness min/mean/max: 1.91/2.06/2.22
# QD-score: 10675.4874
#
# --- MAP-Elite Step 173/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 109, Bins: 109, Coverage: 0.0559, Fitness min/mean/max: 1.90/2.06/2.22
# QD-score: 10675.8565
#
# --- MAP-Elite Step 174/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 109, Bins: 109, Coverage: 0.0559, Fitness min/mean/max: 1.90/2.05/2.22
# QD-score: 10676.2000
#
# --- MAP-Elite Step 175/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 109, Bins: 109, Coverage: 0.0559, Fitness min/mean/max: 1.90/2.05/2.22
# QD-score: 10676.5871
#
# --- MAP-Elite Step 176/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 109, Bins: 109, Coverage: 0.0559, Fitness min/mean/max: 1.89/2.04/2.22
# QD-score: 10677.1374
#
# --- MAP-Elite Step 177/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 110, Bins: 110, Coverage: 0.0564, Fitness min/mean/max: 1.88/2.04/2.22
# QD-score: 10775.3975
#
# --- MAP-Elite Step 178/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 110, Bins: 110, Coverage: 0.0564, Fitness min/mean/max: 1.88/2.04/2.22
# QD-score: 10775.7429
#
# --- MAP-Elite Step 179/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 110, Bins: 110, Coverage: 0.0564, Fitness min/mean/max: 1.88/2.04/2.22
# QD-score: 10776.1322
#
# --- MAP-Elite Step 180/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 111, Bins: 111, Coverage: 0.0569, Fitness min/mean/max: 1.87/2.03/2.22
# QD-score: 10874.3033
#
# --- MAP-Elite Step 181/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 111, Bins: 111, Coverage: 0.0569, Fitness min/mean/max: 1.87/2.03/2.22
# QD-score: 10874.8813
#
# --- MAP-Elite Step 182/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 111, Bins: 111, Coverage: 0.0569, Fitness min/mean/max: 1.86/2.03/2.22
# QD-score: 10875.1793
#
# --- MAP-Elite Step 183/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 111, Bins: 111, Coverage: 0.0569, Fitness min/mean/max: 1.86/2.02/2.22
# QD-score: 10875.5539
#
# --- MAP-Elite Step 184/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 111, Bins: 111, Coverage: 0.0569, Fitness min/mean/max: 1.86/2.01/2.22
# QD-score: 10876.3485
#
# --- MAP-Elite Step 185/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 111, Bins: 111, Coverage: 0.0569, Fitness min/mean/max: 1.85/2.01/2.22
# QD-score: 10876.6548
#
# --- MAP-Elite Step 186/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 112, Bins: 112, Coverage: 0.0574, Fitness min/mean/max: 1.85/2.01/2.22
# QD-score: 10974.6689
#
# --- MAP-Elite Step 187/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 112, Bins: 112, Coverage: 0.0574, Fitness min/mean/max: 1.85/2.00/2.22
# QD-score: 10975.5118
#
# --- MAP-Elite Step 188/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 112, Bins: 112, Coverage: 0.0574, Fitness min/mean/max: 1.84/2.00/2.22
# QD-score: 10975.9788
#
# --- MAP-Elite Step 189/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 112, Bins: 112, Coverage: 0.0574, Fitness min/mean/max: 1.84/2.00/2.22
# QD-score: 10976.3274
#
# --- MAP-Elite Step 190/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 112, Bins: 112, Coverage: 0.0574, Fitness min/mean/max: 1.83/1.99/2.22
# QD-score: 10976.6551
#
# --- MAP-Elite Step 191/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 112, Bins: 112, Coverage: 0.0574, Fitness min/mean/max: 1.83/1.99/2.22
# QD-score: 10976.8840
#
# --- MAP-Elite Step 192/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 112, Bins: 112, Coverage: 0.0574, Fitness min/mean/max: 1.83/1.99/2.22
# QD-score: 10977.4618
#
# --- MAP-Elite Step 193/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 112, Bins: 112, Coverage: 0.0574, Fitness min/mean/max: 1.82/1.98/2.22
# QD-score: 10977.7668
#
# --- MAP-Elite Step 194/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.82/1.98/2.22
# QD-score: 11076.2378
#
# --- MAP-Elite Step 195/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.82/1.97/2.22
# QD-score: 11076.9592
#
# --- MAP-Elite Step 196/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.81/1.97/2.22
# QD-score: 11077.3815
#
# --- MAP-Elite Step 197/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.81/1.97/2.22
# QD-score: 11077.6039
#
# --- MAP-Elite Step 198/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.81/1.96/2.22
# QD-score: 11078.0715
#
# --- MAP-Elite Step 199/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.80/1.96/2.22
# QD-score: 11078.6214
#
# --- MAP-Elite Step 200/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.79/1.96/2.22
# QD-score: 11078.8048
#
# --- MAP-Elite Step 201/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.79/1.95/2.22
# QD-score: 11079.2715
#
# --- MAP-Elite Step 202/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.78/1.95/2.22
# QD-score: 11079.6842
#
# --- MAP-Elite Step 203/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.78/1.95/2.22
# QD-score: 11080.0117
#
# --- MAP-Elite Step 204/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.78/1.94/2.22
# QD-score: 11080.3721
#
# --- MAP-Elite Step 205/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.78/1.94/2.22
# QD-score: 11080.6199
#
# --- MAP-Elite Step 206/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.77/1.94/2.22
# QD-score: 11080.8254
#
# --- MAP-Elite Step 207/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.77/1.94/2.22
# QD-score: 11081.1749
#
# --- MAP-Elite Step 208/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.76/1.93/2.22
# QD-score: 11081.5275
#
# --- MAP-Elite Step 209/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.76/1.93/2.22
# QD-score: 11081.8367
#
# --- MAP-Elite Step 210/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.75/1.93/2.22
# QD-score: 11082.3404
#
# --- MAP-Elite Step 211/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.75/1.92/2.22
# QD-score: 11082.8834
#
# --- MAP-Elite Step 212/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.75/1.92/2.22
# QD-score: 11083.1734
#
# --- MAP-Elite Step 213/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.75/1.91/2.22
# QD-score: 11083.8475
#
# --- MAP-Elite Step 214/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.74/1.91/2.22
# QD-score: 11084.1812
#
# --- MAP-Elite Step 215/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.74/1.91/2.22
# QD-score: 11084.4738
#
# --- MAP-Elite Step 216/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.74/1.90/2.22
# QD-score: 11085.0500
#
# --- MAP-Elite Step 217/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.74/1.90/2.22
# QD-score: 11085.6463
#
# --- MAP-Elite Step 218/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.73/1.89/2.22
# QD-score: 11085.9415
#
# --- MAP-Elite Step 219/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.73/1.89/2.22
# QD-score: 11086.3936
#
# --- MAP-Elite Step 220/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.72/1.89/2.22
# QD-score: 11086.8535
#
# --- MAP-Elite Step 221/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.72/1.88/2.22
# QD-score: 11087.2314
#
# --- MAP-Elite Step 222/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.72/1.88/2.22
# QD-score: 11087.5787
#
# --- MAP-Elite Step 223/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.71/1.88/2.22
# QD-score: 11087.9809
#
# --- MAP-Elite Step 224/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.71/1.87/2.22
# QD-score: 11088.2530
#
# --- MAP-Elite Step 225/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.71/1.87/2.22
# QD-score: 11088.4933
#
# --- MAP-Elite Step 226/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.71/1.87/2.22
# QD-score: 11088.7417
#
# --- MAP-Elite Step 227/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.70/1.87/2.22
# QD-score: 11089.2265
#
# --- MAP-Elite Step 228/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.70/1.86/2.22
# QD-score: 11089.5582
#
# --- MAP-Elite Step 229/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.70/1.86/2.22
# QD-score: 11089.8847
#
# --- MAP-Elite Step 230/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.69/1.85/2.22
# QD-score: 11090.4785
#
# --- MAP-Elite Step 231/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.69/1.85/2.22
# QD-score: 11090.7662
#
# --- MAP-Elite Step 232/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.68/1.85/2.22
# QD-score: 11091.1599
#
# --- MAP-Elite Step 233/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.68/1.84/2.22
# QD-score: 11091.6141
#
# --- MAP-Elite Step 234/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.67/1.84/2.22
# QD-score: 11092.3449
#
# --- MAP-Elite Step 235/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.66/1.83/2.22
# QD-score: 11092.6544
#
# --- MAP-Elite Step 236/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.66/1.83/2.22
# QD-score: 11092.9444
#
# --- MAP-Elite Step 237/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.66/1.83/2.22
# QD-score: 11093.2639
#
# --- MAP-Elite Step 238/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.66/1.83/2.22
# QD-score: 11093.5995
#
# --- MAP-Elite Step 239/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.65/1.82/2.22
# QD-score: 11094.6440
#
# --- MAP-Elite Step 240/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.65/1.81/2.22
# QD-score: 11095.1145
#
# --- MAP-Elite Step 241/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.64/1.81/2.22
# QD-score: 11095.4041
#
# --- MAP-Elite Step 242/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.64/1.81/2.22
# QD-score: 11095.6410
#
# --- MAP-Elite Step 243/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.64/1.81/2.22
# QD-score: 11095.9363
#
# --- MAP-Elite Step 244/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.64/1.80/2.22
# QD-score: 11096.4551
#
# --- MAP-Elite Step 245/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.63/1.80/2.22
# QD-score: 11096.8200
#
# --- MAP-Elite Step 246/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.63/1.80/2.22
# QD-score: 11097.1466
#
# --- MAP-Elite Step 247/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 113, Bins: 113, Coverage: 0.0579, Fitness min/mean/max: 1.62/1.79/2.22
# QD-score: 11097.3163
#
# --- MAP-Elite Step 248/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.62/1.79/2.22
# QD-score: 11195.4565
#
# --- MAP-Elite Step 249/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.61/1.79/2.22
# QD-score: 11195.8612
#
# --- MAP-Elite Step 250/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.61/1.78/2.22
# QD-score: 11196.5959
#
# --- MAP-Elite Step 251/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.61/1.78/2.22
# QD-score: 11197.1497
#
# --- MAP-Elite Step 252/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.61/1.78/2.22
# QD-score: 11197.4130
#
# --- MAP-Elite Step 253/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.60/1.77/2.22
# QD-score: 11197.8864
#
# --- MAP-Elite Step 254/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.60/1.77/2.22
# QD-score: 11198.5124
#
# --- MAP-Elite Step 255/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.60/1.77/2.22
# QD-score: 11198.7051
#
# --- MAP-Elite Step 256/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.59/1.76/2.22
# QD-score: 11199.0453
#
# --- MAP-Elite Step 257/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.59/1.76/2.22
# QD-score: 11199.2473
#
# --- MAP-Elite Step 258/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.58/1.76/2.22
# QD-score: 11199.4758
#
# --- MAP-Elite Step 259/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.58/1.76/2.22
# QD-score: 11199.8183
#
# --- MAP-Elite Step 260/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 114, Bins: 114, Coverage: 0.0585, Fitness min/mean/max: 1.57/1.75/2.22
# QD-score: 11200.0122
#
# --- MAP-Elite Step 261/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.57/1.76/2.22
# QD-score: 11298.0361
#
# --- MAP-Elite Step 262/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.57/1.75/2.22
# QD-score: 11298.2123
#
# --- MAP-Elite Step 263/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.56/1.75/2.22
# QD-score: 11298.5323
#
# --- MAP-Elite Step 264/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.56/1.75/2.22
# QD-score: 11298.9953
#
# --- MAP-Elite Step 265/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.55/1.74/2.22
# QD-score: 11299.4025
#
# --- MAP-Elite Step 266/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.55/1.74/2.22
# QD-score: 11300.1796
#
# --- MAP-Elite Step 267/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.55/1.73/2.22
# QD-score: 11300.6536
#
# --- MAP-Elite Step 268/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.55/1.73/2.22
# QD-score: 11300.8248
#
# --- MAP-Elite Step 269/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.55/1.73/2.22
# QD-score: 11301.3774
#
# --- MAP-Elite Step 270/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.55/1.73/2.22
# QD-score: 11301.5497
#
# --- MAP-Elite Step 271/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.54/1.72/2.22
# QD-score: 11302.3319
#
# --- MAP-Elite Step 272/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.54/1.71/2.22
# QD-score: 11303.0548
#
# --- MAP-Elite Step 273/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 115, Bins: 115, Coverage: 0.0590, Fitness min/mean/max: 1.53/1.71/2.22
# QD-score: 11303.8855
#
# --- MAP-Elite Step 274/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 116, Bins: 116, Coverage: 0.0595, Fitness min/mean/max: 1.53/1.71/2.22
# QD-score: 11401.9875
#
# --- MAP-Elite Step 275/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 116, Bins: 116, Coverage: 0.0595, Fitness min/mean/max: 1.53/1.71/2.22
# QD-score: 11402.1434
#
# --- MAP-Elite Step 276/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 116, Bins: 116, Coverage: 0.0595, Fitness min/mean/max: 1.52/1.70/2.22
# QD-score: 11402.3425
#
# --- MAP-Elite Step 277/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 116, Bins: 116, Coverage: 0.0595, Fitness min/mean/max: 1.52/1.70/2.22
# QD-score: 11402.5310
#
# --- MAP-Elite Step 278/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 116, Bins: 116, Coverage: 0.0595, Fitness min/mean/max: 1.52/1.70/2.22
# QD-score: 11403.2552
#
# --- MAP-Elite Step 279/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 116, Bins: 116, Coverage: 0.0595, Fitness min/mean/max: 1.52/1.69/2.22
# QD-score: 11403.5915
#
# --- MAP-Elite Step 280/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 117, Bins: 117, Coverage: 0.0600, Fitness min/mean/max: 1.51/1.69/2.23
# QD-score: 11502.6532
#
# --- MAP-Elite Step 281/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 117, Bins: 117, Coverage: 0.0600, Fitness min/mean/max: 1.51/1.68/2.23
# QD-score: 11502.9132
#
# --- MAP-Elite Step 282/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 118, Bins: 118, Coverage: 0.0605, Fitness min/mean/max: 1.51/1.69/2.23
# QD-score: 11601.0285
#
# --- MAP-Elite Step 283/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 118, Bins: 118, Coverage: 0.0605, Fitness min/mean/max: 1.50/1.68/2.23
# QD-score: 11601.7803
#
# --- MAP-Elite Step 284/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 118, Bins: 118, Coverage: 0.0605, Fitness min/mean/max: 1.50/1.68/2.23
# QD-score: 11601.9415
#
# --- MAP-Elite Step 285/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 119, Bins: 119, Coverage: 0.0610, Fitness min/mean/max: 1.49/1.68/2.23
# QD-score: 11700.1866
#
# --- MAP-Elite Step 286/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 119, Bins: 119, Coverage: 0.0610, Fitness min/mean/max: 1.49/1.67/2.23
# QD-score: 11701.0849
#
# --- MAP-Elite Step 287/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 119, Bins: 119, Coverage: 0.0610, Fitness min/mean/max: 1.49/1.67/2.23
# QD-score: 11701.3298
#
# --- MAP-Elite Step 288/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 119, Bins: 119, Coverage: 0.0610, Fitness min/mean/max: 1.49/1.67/2.23
# QD-score: 11701.8031
#
# --- MAP-Elite Step 289/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 119, Bins: 119, Coverage: 0.0610, Fitness min/mean/max: 1.49/1.66/2.23
# QD-score: 11702.6260
#
# --- MAP-Elite Step 290/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 119, Bins: 119, Coverage: 0.0610, Fitness min/mean/max: 1.48/1.65/2.23
# QD-score: 11703.4485
#
# --- MAP-Elite Step 291/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 119, Bins: 119, Coverage: 0.0610, Fitness min/mean/max: 1.48/1.65/2.23
# QD-score: 11704.1878
#
# --- MAP-Elite Step 292/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 119, Bins: 119, Coverage: 0.0610, Fitness min/mean/max: 1.48/1.64/2.23
# QD-score: 11704.7910
#
# --- MAP-Elite Step 293/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 119, Bins: 119, Coverage: 0.0610, Fitness min/mean/max: 1.47/1.64/2.23
# QD-score: 11705.3079
#
# --- MAP-Elite Step 294/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 120, Bins: 120, Coverage: 0.0615, Fitness min/mean/max: 1.47/1.63/2.23
# QD-score: 11804.8222
#
# --- MAP-Elite Step 295/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 120, Bins: 120, Coverage: 0.0615, Fitness min/mean/max: 1.47/1.62/2.23
# QD-score: 11805.1522
#
# --- MAP-Elite Step 296/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 120, Bins: 120, Coverage: 0.0615, Fitness min/mean/max: 1.46/1.62/2.23
# QD-score: 11806.0426
#
# --- MAP-Elite Step 297/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 121, Bins: 121, Coverage: 0.0621, Fitness min/mean/max: 1.46/1.60/2.23
# QD-score: 11906.3553
#
# --- MAP-Elite Step 298/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [4s elapsed, 0s remaining]
# Archive: 121, Bins: 121, Coverage: 0.0621, Fitness min/mean/max: 1.46/1.60/2.23
# QD-score: 11906.5876
#
# --- MAP-Elite Step 299/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 121, Bins: 121, Coverage: 0.0621, Fitness min/mean/max: 1.45/1.58/2.22
# QD-score: 11908.5164
#
# --- MAP-Elite Step 300/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 121, Bins: 121, Coverage: 0.0621, Fitness min/mean/max: 1.45/1.58/2.22
# QD-score: 11908.9208
#
# --- MAP-Elite Step 301/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 121, Bins: 121, Coverage: 0.0621, Fitness min/mean/max: 1.45/1.58/2.22
# QD-score: 11909.2944
#
# --- MAP-Elite Step 302/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 122, Bins: 122, Coverage: 0.0626, Fitness min/mean/max: 1.45/1.56/2.22
# QD-score: 12009.0883
#
# --- MAP-Elite Step 303/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 122, Bins: 122, Coverage: 0.0626, Fitness min/mean/max: 1.44/1.56/2.22
# QD-score: 12009.4061
#
# --- MAP-Elite Step 304/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 122, Bins: 122, Coverage: 0.0626, Fitness min/mean/max: 1.44/1.56/2.22
# QD-score: 12009.6374
#
# --- MAP-Elite Step 305/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 122, Bins: 122, Coverage: 0.0626, Fitness min/mean/max: 1.44/1.55/2.22
# QD-score: 12011.0664
#
# --- MAP-Elite Step 306/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 122, Bins: 122, Coverage: 0.0626, Fitness min/mean/max: 1.44/1.54/2.22
# QD-score: 12012.0097
#
# --- MAP-Elite Step 307/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 122, Bins: 122, Coverage: 0.0626, Fitness min/mean/max: 1.43/1.54/2.22
# QD-score: 12012.4806
#
# --- MAP-Elite Step 308/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 122, Bins: 122, Coverage: 0.0626, Fitness min/mean/max: 1.43/1.53/2.22
# QD-score: 12012.7374
#
# --- MAP-Elite Step 309/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 122, Bins: 122, Coverage: 0.0626, Fitness min/mean/max: 1.43/1.53/2.22
# QD-score: 12013.0739
#
# --- MAP-Elite Step 310/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 125, Bins: 125, Coverage: 0.0641, Fitness min/mean/max: 1.42/1.53/2.22
# QD-score: 12308.8109
#
# --- MAP-Elite Step 311/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 127, Bins: 127, Coverage: 0.0651, Fitness min/mean/max: 1.42/1.53/2.22
# QD-score: 12505.9924
#
# --- MAP-Elite Step 312/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 127, Bins: 127, Coverage: 0.0651, Fitness min/mean/max: 1.42/1.52/2.22
# QD-score: 12506.9520
#
# --- MAP-Elite Step 313/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 128, Bins: 128, Coverage: 0.0656, Fitness min/mean/max: 1.41/1.52/2.22
# QD-score: 12605.6644
#
# --- MAP-Elite Step 314/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 128, Bins: 128, Coverage: 0.0656, Fitness min/mean/max: 1.41/1.52/2.22
# QD-score: 12605.9680
#
# --- MAP-Elite Step 315/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 130, Bins: 130, Coverage: 0.0667, Fitness min/mean/max: 1.41/1.52/2.22
# QD-score: 12803.0026
#
# --- MAP-Elite Step 316/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 132, Bins: 132, Coverage: 0.0677, Fitness min/mean/max: 1.41/1.51/2.22
# QD-score: 13000.0761
#
# --- MAP-Elite Step 317/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 132, Bins: 132, Coverage: 0.0677, Fitness min/mean/max: 1.40/1.51/2.22
# QD-score: 13000.2494
#
# --- MAP-Elite Step 318/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 132, Bins: 132, Coverage: 0.0677, Fitness min/mean/max: 1.40/1.51/2.22
# QD-score: 13000.7387
#
# --- MAP-Elite Step 319/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 132, Bins: 132, Coverage: 0.0677, Fitness min/mean/max: 1.40/1.50/2.20
# QD-score: 13001.6163
#
# --- MAP-Elite Step 320/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 132, Bins: 132, Coverage: 0.0677, Fitness min/mean/max: 1.39/1.50/2.20
# QD-score: 13001.7607
#
# --- MAP-Elite Step 321/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 134, Bins: 134, Coverage: 0.0687, Fitness min/mean/max: 1.39/1.50/1.63
# QD-score: 13199.4772
#
# --- MAP-Elite Step 322/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 136, Bins: 136, Coverage: 0.0697, Fitness min/mean/max: 1.39/1.50/1.63
# QD-score: 13396.3923
#
# --- MAP-Elite Step 323/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 137, Bins: 137, Coverage: 0.0703, Fitness min/mean/max: 1.39/1.50/1.63
# QD-score: 13494.9979
#
# --- MAP-Elite Step 324/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 138, Bins: 138, Coverage: 0.0708, Fitness min/mean/max: 1.39/1.50/1.63
# QD-score: 13593.6146
#
# --- MAP-Elite Step 325/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 138, Bins: 138, Coverage: 0.0708, Fitness min/mean/max: 1.38/1.49/1.63
# QD-score: 13594.0250
#
# --- MAP-Elite Step 326/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 139, Bins: 139, Coverage: 0.0713, Fitness min/mean/max: 1.38/1.49/1.63
# QD-score: 13692.7720
#
# --- MAP-Elite Step 327/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 140, Bins: 140, Coverage: 0.0718, Fitness min/mean/max: 1.38/1.49/1.63
# QD-score: 13791.5515
#
# --- MAP-Elite Step 328/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 141, Bins: 141, Coverage: 0.0723, Fitness min/mean/max: 1.37/1.49/1.63
# QD-score: 13890.2318
#
# --- MAP-Elite Step 329/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 143, Bins: 143, Coverage: 0.0733, Fitness min/mean/max: 1.37/1.49/1.63
# QD-score: 14087.3856
#
# --- MAP-Elite Step 330/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 144, Bins: 144, Coverage: 0.0738, Fitness min/mean/max: 1.37/1.49/1.63
# QD-score: 14186.1020
#
# --- MAP-Elite Step 331/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 144, Bins: 144, Coverage: 0.0738, Fitness min/mean/max: 1.37/1.48/1.63
# QD-score: 14186.5363
#
# --- MAP-Elite Step 332/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 145, Bins: 145, Coverage: 0.0744, Fitness min/mean/max: 1.36/1.48/1.63
# QD-score: 14285.5359
#
# --- MAP-Elite Step 333/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 147, Bins: 147, Coverage: 0.0754, Fitness min/mean/max: 1.36/1.48/1.63
# QD-score: 14482.8318
#
# --- MAP-Elite Step 334/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 148, Bins: 148, Coverage: 0.0759, Fitness min/mean/max: 1.36/1.47/1.63
# QD-score: 14581.7527
#
# --- MAP-Elite Step 335/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 150, Bins: 150, Coverage: 0.0769, Fitness min/mean/max: 1.35/1.47/1.63
# QD-score: 14778.8828
#
# --- MAP-Elite Step 336/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 150, Bins: 150, Coverage: 0.0769, Fitness min/mean/max: 1.35/1.47/1.63
# QD-score: 14779.3620
#
# --- MAP-Elite Step 337/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 153, Bins: 153, Coverage: 0.0785, Fitness min/mean/max: 1.35/1.47/1.63
# QD-score: 15075.1371
#
# --- MAP-Elite Step 338/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 154, Bins: 154, Coverage: 0.0790, Fitness min/mean/max: 1.34/1.47/1.63
# QD-score: 15174.3208
#
# --- MAP-Elite Step 339/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 155, Bins: 155, Coverage: 0.0795, Fitness min/mean/max: 1.34/1.46/1.63
# QD-score: 15273.3721
#
# --- MAP-Elite Step 340/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 156, Bins: 156, Coverage: 0.0800, Fitness min/mean/max: 1.34/1.46/1.63
# QD-score: 15372.3512
#
# --- MAP-Elite Step 341/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 158, Bins: 158, Coverage: 0.0810, Fitness min/mean/max: 1.33/1.46/1.63
# QD-score: 15569.5089
#
# --- MAP-Elite Step 342/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 158, Bins: 158, Coverage: 0.0810, Fitness min/mean/max: 1.33/1.45/1.63
# QD-score: 15570.2314
#
# --- MAP-Elite Step 343/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 159, Bins: 159, Coverage: 0.0815, Fitness min/mean/max: 1.33/1.45/1.63
# QD-score: 15668.8512
#
# --- MAP-Elite Step 344/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 159, Bins: 159, Coverage: 0.0815, Fitness min/mean/max: 1.33/1.45/1.63
# QD-score: 15669.1543
#
# --- MAP-Elite Step 345/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 159, Bins: 159, Coverage: 0.0815, Fitness min/mean/max: 1.32/1.45/1.63
# QD-score: 15669.9381
#
# --- MAP-Elite Step 346/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 160, Bins: 160, Coverage: 0.0821, Fitness min/mean/max: 1.32/1.45/1.63
# QD-score: 15768.7462
#
# --- MAP-Elite Step 347/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 161, Bins: 161, Coverage: 0.0826, Fitness min/mean/max: 1.31/1.44/1.64
# QD-score: 15867.6147
#
# --- MAP-Elite Step 348/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 161, Bins: 161, Coverage: 0.0826, Fitness min/mean/max: 1.31/1.44/1.64
# QD-score: 15868.2885
#
# --- MAP-Elite Step 349/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 161, Bins: 161, Coverage: 0.0826, Fitness min/mean/max: 1.31/1.44/1.64
# QD-score: 15868.8155
#
# --- MAP-Elite Step 350/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 161, Bins: 161, Coverage: 0.0826, Fitness min/mean/max: 1.31/1.43/1.64
# QD-score: 15869.2437
#
# --- MAP-Elite Step 351/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 161, Bins: 161, Coverage: 0.0826, Fitness min/mean/max: 1.30/1.43/1.64
# QD-score: 15870.0062
#
# --- MAP-Elite Step 352/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 162, Bins: 162, Coverage: 0.0831, Fitness min/mean/max: 1.30/1.43/1.64
# QD-score: 15968.8926
#
# --- MAP-Elite Step 353/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 162, Bins: 162, Coverage: 0.0831, Fitness min/mean/max: 1.30/1.42/1.64
# QD-score: 15969.3935
#
# --- MAP-Elite Step 354/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 162, Bins: 162, Coverage: 0.0831, Fitness min/mean/max: 1.30/1.42/1.64
# QD-score: 15969.9112
#
# --- MAP-Elite Step 355/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 163, Bins: 163, Coverage: 0.0836, Fitness min/mean/max: 1.29/1.42/1.64
# QD-score: 16068.5606
#
# --- MAP-Elite Step 356/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 163, Bins: 163, Coverage: 0.0836, Fitness min/mean/max: 1.29/1.42/1.64
# QD-score: 16069.0388
#
# --- MAP-Elite Step 357/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 165, Bins: 165, Coverage: 0.0846, Fitness min/mean/max: 1.29/1.42/1.64
# QD-score: 16266.1253
#
# --- MAP-Elite Step 358/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 169, Bins: 169, Coverage: 0.0867, Fitness min/mean/max: 1.29/1.42/1.64
# QD-score: 16660.2681
#
# --- MAP-Elite Step 359/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 169, Bins: 169, Coverage: 0.0867, Fitness min/mean/max: 1.28/1.42/1.64
# QD-score: 16660.5437
#
# --- MAP-Elite Step 360/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 169, Bins: 169, Coverage: 0.0867, Fitness min/mean/max: 1.28/1.41/1.64
# QD-score: 16660.9780
#
# --- MAP-Elite Step 361/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 169, Bins: 169, Coverage: 0.0867, Fitness min/mean/max: 1.28/1.41/1.64
# QD-score: 16661.5016
#
# --- MAP-Elite Step 362/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 170, Bins: 170, Coverage: 0.0872, Fitness min/mean/max: 1.27/1.41/1.64
# QD-score: 16760.1225
#
# --- MAP-Elite Step 363/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 174, Bins: 174, Coverage: 0.0892, Fitness min/mean/max: 1.27/1.41/1.64
# QD-score: 17153.9224
#
# --- MAP-Elite Step 364/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 177, Bins: 177, Coverage: 0.0908, Fitness min/mean/max: 1.27/1.41/1.64
# QD-score: 17449.5581
#
# --- MAP-Elite Step 365/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 180, Bins: 180, Coverage: 0.0923, Fitness min/mean/max: 1.27/1.42/1.64
# QD-score: 17744.9597
#
# --- MAP-Elite Step 366/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 181, Bins: 181, Coverage: 0.0928, Fitness min/mean/max: 1.27/1.42/1.64
# QD-score: 17843.7237
#
# --- MAP-Elite Step 367/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 182, Bins: 182, Coverage: 0.0933, Fitness min/mean/max: 1.26/1.42/1.64
# QD-score: 17942.3977
#
# --- MAP-Elite Step 368/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 182, Bins: 182, Coverage: 0.0933, Fitness min/mean/max: 1.26/1.41/1.64
# QD-score: 17942.7525
#
# --- MAP-Elite Step 369/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 183, Bins: 183, Coverage: 0.0938, Fitness min/mean/max: 1.26/1.41/1.64
# QD-score: 18041.4152
#
# --- MAP-Elite Step 370/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 184, Bins: 184, Coverage: 0.0944, Fitness min/mean/max: 1.26/1.41/1.64
# QD-score: 18140.1500
#
# --- MAP-Elite Step 371/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 184, Bins: 184, Coverage: 0.0944, Fitness min/mean/max: 1.25/1.41/1.64
# QD-score: 18140.3613
#
# --- MAP-Elite Step 372/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 186, Bins: 186, Coverage: 0.0954, Fitness min/mean/max: 1.25/1.41/1.64
# QD-score: 18337.7746
#
# --- MAP-Elite Step 373/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 187, Bins: 187, Coverage: 0.0959, Fitness min/mean/max: 1.25/1.41/1.64
# QD-score: 18436.4983
#
# --- MAP-Elite Step 374/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 187, Bins: 187, Coverage: 0.0959, Fitness min/mean/max: 1.25/1.40/1.64
# QD-score: 18437.4742
#
# --- MAP-Elite Step 375/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.25/1.40/1.64
# QD-score: 18536.2303
#
# --- MAP-Elite Step 376/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.25/1.40/1.64
# QD-score: 18536.6957
#
# --- MAP-Elite Step 377/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.25/1.40/1.64
# QD-score: 18537.1490
#
# --- MAP-Elite Step 378/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.24/1.40/1.64
# QD-score: 18537.6375
#
# --- MAP-Elite Step 379/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.24/1.39/1.64
# QD-score: 18538.2373
#
# --- MAP-Elite Step 380/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 188, Bins: 188, Coverage: 0.0964, Fitness min/mean/max: 1.24/1.39/1.64
# QD-score: 18538.6873
#
# --- MAP-Elite Step 381/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [3s elapsed, 0s remaining]
# Archive: 189, Bins: 189, Coverage: 0.0969, Fitness min/mean/max: 1.24/1.39/1.64
# ...
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.42/2.29/3.79
# QD-score: 4006.2370
#
# --- MAP-Elite Step 543/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.42/2.29/3.79
# QD-score: 4006.2492
#
# --- MAP-Elite Step 544/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.42/2.28/3.79
# QD-score: 4006.3795
#
# --- MAP-Elite Step 545/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.42/2.28/3.79
# QD-score: 4006.3921
#
# --- MAP-Elite Step 546/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.42/2.28/3.79
# QD-score: 4006.4153
#
# --- MAP-Elite Step 547/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.41/2.28/3.79
# QD-score: 4006.4852
#
# --- MAP-Elite Step 548/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.41/2.28/3.79
# QD-score: 4006.5279
#
# --- MAP-Elite Step 549/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.41/2.28/3.79
# QD-score: 4006.6195
#
# --- MAP-Elite Step 550/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.41/2.25/3.79
# QD-score: 4007.5725
#
# --- MAP-Elite Step 551/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.41/2.25/3.79
# QD-score: 4007.6015
#
# --- MAP-Elite Step 552/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.40/2.25/3.79
# QD-score: 4007.6726
#
# --- MAP-Elite Step 553/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.40/2.25/3.79
# QD-score: 4007.6937
#
# --- MAP-Elite Step 554/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.39/2.25/3.79
# QD-score: 4007.7198
#
# --- MAP-Elite Step 555/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.39/2.25/3.79
# QD-score: 4007.7294
#
# --- MAP-Elite Step 556/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.39/2.25/3.79
# QD-score: 4007.7376
#
# --- MAP-Elite Step 557/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.39/2.25/3.79
# QD-score: 4007.7769
#
# --- MAP-Elite Step 558/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.39/2.25/3.79
# QD-score: 4007.7893
#
# --- MAP-Elite Step 559/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.38/2.24/3.79
# QD-score: 4008.0578
#
# --- MAP-Elite Step 560/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.38/2.24/3.79
# QD-score: 4008.1004
#
# --- MAP-Elite Step 561/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.38/2.24/3.79
# QD-score: 4008.1096
#
# --- MAP-Elite Step 562/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.37/2.24/3.79
# QD-score: 4008.1756
#
# --- MAP-Elite Step 563/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.37/2.24/3.79
# QD-score: 4008.2241
#
# --- MAP-Elite Step 564/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.37/2.24/3.79
# QD-score: 4008.2928
#
# --- MAP-Elite Step 565/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.37/2.24/3.79
# QD-score: 4008.3059
#
# --- MAP-Elite Step 566/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.37/2.24/3.79
# QD-score: 4008.3077
#
# --- MAP-Elite Step 567/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.36/2.24/3.79
# QD-score: 4008.3521
#
# --- MAP-Elite Step 568/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.36/2.24/3.79
# QD-score: 4008.3601
#
# --- MAP-Elite Step 569/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.36/2.23/3.79
# QD-score: 4008.3733
#
# --- MAP-Elite Step 570/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.35/2.23/3.79
# QD-score: 4008.4104
#
# --- MAP-Elite Step 571/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.35/2.23/3.79
# QD-score: 4008.4581
#
# --- MAP-Elite Step 572/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.35/2.23/3.79
# QD-score: 4008.5021
#
# --- MAP-Elite Step 573/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.35/2.23/3.79
# QD-score: 4008.5214
#
# --- MAP-Elite Step 574/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.35/2.23/3.79
# QD-score: 4008.5446
#
# --- MAP-Elite Step 575/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.34/2.23/3.79
# QD-score: 4008.5779
#
# --- MAP-Elite Step 576/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.34/2.23/3.79
# QD-score: 4008.7377
#
# --- MAP-Elite Step 577/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.34/2.22/3.79
# QD-score: 4008.8455
#
# --- MAP-Elite Step 578/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.33/2.22/3.79
# QD-score: 4008.8493
#
# --- MAP-Elite Step 579/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.33/2.22/3.79
# QD-score: 4008.8573
#
# --- MAP-Elite Step 580/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.33/2.22/3.79
# QD-score: 4008.8792
#
# --- MAP-Elite Step 581/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.33/2.22/3.79
# QD-score: 4008.8962
#
# --- MAP-Elite Step 582/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.33/2.22/3.79
# QD-score: 4008.9226
#
# --- MAP-Elite Step 583/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.33/2.22/3.79
# QD-score: 4008.9423
#
# --- MAP-Elite Step 584/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.33/2.22/3.79
# QD-score: 4008.9539
#
# --- MAP-Elite Step 585/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.33/2.22/3.79
# QD-score: 4008.9861
#
# --- MAP-Elite Step 586/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.32/2.20/3.79
# QD-score: 4009.6202
#
# --- MAP-Elite Step 587/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.32/2.20/3.79
# QD-score: 4009.6285
#
# --- MAP-Elite Step 588/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.32/2.20/3.79
# QD-score: 4009.6391
#
# --- MAP-Elite Step 589/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.32/2.20/3.79
# QD-score: 4009.6506
#
# --- MAP-Elite Step 590/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.32/2.20/3.79
# QD-score: 4009.6653
#
# --- MAP-Elite Step 591/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.32/2.20/3.79
# QD-score: 4009.6653
#
# --- MAP-Elite Step 592/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.32/2.20/3.79
# QD-score: 4009.6654
#
# --- MAP-Elite Step 593/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.32/2.19/3.79
# QD-score: 4010.2999
#
# --- MAP-Elite Step 594/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.31/2.19/3.79
# QD-score: 4010.3090
#
# --- MAP-Elite Step 595/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.31/2.19/3.79
# QD-score: 4010.3319
#
# --- MAP-Elite Step 596/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.31/2.17/3.79
# QD-score: 4010.9368
#
# --- MAP-Elite Step 597/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.31/2.17/3.79
# QD-score: 4010.9524
#
# --- MAP-Elite Step 598/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.31/2.17/3.79
# QD-score: 4010.9580
#
# --- MAP-Elite Step 599/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.31/2.17/3.79
# QD-score: 4010.9588
#
# --- MAP-Elite Step 600/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.30/2.17/3.79
# QD-score: 4010.9708
#
# --- MAP-Elite Step 601/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.30/2.17/3.79
# QD-score: 4010.9822
#
# --- MAP-Elite Step 602/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.30/2.17/3.79
# QD-score: 4010.9944
#
# --- MAP-Elite Step 603/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.30/2.17/3.79
# QD-score: 4011.0016
#
# --- MAP-Elite Step 604/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.30/2.17/3.79
# QD-score: 4011.0437
#
# --- MAP-Elite Step 605/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [9s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.30/2.17/3.79
# QD-score: 4011.0896
#
# --- MAP-Elite Step 606/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.29/2.17/3.79
# QD-score: 4011.1445
#
# --- MAP-Elite Step 607/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.29/2.17/3.79
# QD-score: 4011.1724
#
# --- MAP-Elite Step 608/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.29/2.17/3.79
# QD-score: 4011.2020
#
# --- MAP-Elite Step 609/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.29/2.17/3.79
# QD-score: 4011.2035
#
# --- MAP-Elite Step 610/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.29/2.17/3.79
# QD-score: 4011.2124
#
# --- MAP-Elite Step 611/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [8s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.28/2.16/3.79
# QD-score: 4011.4134
#
# --- MAP-Elite Step 612/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.28/2.16/3.79
# QD-score: 4011.4206
#
# --- MAP-Elite Step 613/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [7s elapsed, 0s remaining]
# Archive: 41, Bins: 41, Coverage: 0.0210, Fitness min/mean/max: 1.28/2.16/3.79
# QD-score: 4011.4300
#
# --- MAP-Elite Step 614/1000 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 330/500 [5s elapsed, 3s remaining]
