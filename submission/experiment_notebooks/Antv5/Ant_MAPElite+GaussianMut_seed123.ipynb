# %% [markdown]
# # MAP-Elite (Gaussian Mutation) — Baseline (Local)
#
# **Method:** MAP-Elites with PSE Gaussian Mutation only (`PSEMut`)
# **Seeds:** 2 (42, 123)
# **Task:** Ant-v5 Unidirectional Gait (4D Gait BD, 10×10×10×10 = 10000 bins)
# **Budget:** N_TOTAL × N_STEPS = 1e5

# %%
# ============================================================
# Cell 0: Install dependencies (run once, then restart kernel)
# ============================================================
import subprocess, sys
subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'cma', 'gymnasium[mujoco]', 'torch', 'numpy', 'pandas', 'matplotlib', '-q'])
# Out:
# 0

# %%
# ============================================================
# Cell 1: Setup — load SSLVE modules from local repo
# ============================================================
import sys, os, glob

SSLVE_PATH = os.path.expanduser('~/Downloads/org-Latent-Variable-Evolution 3/dev/SSLVE')
sys.path.insert(0, SSLVE_PATH)
for f in sorted(glob.glob(os.path.join(SSLVE_PATH, '*.py'))):
    exec(open(f).read())

print('Setup complete.')
# Out:
# Setup complete.

# %%
# ============================================================
# Cell 2: Method Hyperparameters
# ============================================================
import numpy as np
import random
import torch

# --- Architecture ---
ARCHITECTURE     = [27, 64, 64, 8]  #@param
OUTPUT_ACTIVATION = 'tanh'  #@param {type:"string"}
MAX_STEPS        = 500   #@param {type:"integer"}
N_EPISODES       = 3     #@param {type:"integer"}
CTRL_COST_WEIGHT = 0.5   #@param {type:"number"}

# --- Gait BD Grid ---
BIN_SIZES        = [10, 10, 10, 10]  #@param

# --- Fitness ---
TOP_K            = 1     #@param {type:"integer"}
MAX_FITNESS      = 500.0 #@param {type:"number"}
GREEDY_MEM       = True  #@param {type:"boolean"}

# --- Mutation sigma ---
PSE_MUT_SIGMA    = 0.05  #@param {type:"number"}

# --- Search budget ---
N_TOTAL          = 500   #@param {type:"integer"}
N_STEPS          = 200   #@param {type:"integer"}

# --- Checkpoint base directory (local) ---
CKPT_BASE_DIR    = os.path.expanduser('~/Downloads/ant_gait_ckpts/Ant_MAPElite_GaussianMut/')

print(f'Method: MAP-Elite (Gaussian Mutation)')
print(f'Architecture: {ARCHITECTURE}, Output: {OUTPUT_ACTIVATION}')
print(f'Gait BD: {BIN_SIZES} ({np.prod(BIN_SIZES)} bins)')
print(f'PSE_MUT_SIGMA={PSE_MUT_SIGMA}, N_TOTAL={N_TOTAL}, N_STEPS={N_STEPS}')
print(f'Checkpoints will be saved to: {CKPT_BASE_DIR}')
# Out:
# Method: MAP-Elite (Gaussian Mutation)
# Architecture: [27, 64, 64, 8], Output: tanh
# Gait BD: [10, 10, 10, 10] (10000 bins)
# PSE_MUT_SIGMA=0.05, N_TOTAL=500, N_STEPS=200
# Checkpoints will be saved to: /Users/frankh/Downloads/ant_gait_ckpts/Ant_MAPElite_GaussianMut/

# %%
# ============================================================
# Cell 3: Run All Experiments (2 seeds)
# Each run saves a checkpoint + plots immediately after finishing.
# ============================================================

SEEDS = [123]  # seed 42 already completed

fitness_fn = lambda info: -info['forward_sum']

all_results = []

weight_dim = MLP_Agent(ARCHITECTURE, output_activation=OUTPUT_ACTIVATION).get_weight_dim()
print(f'Weight dim: {weight_dim}')

for seed in SEEDS:
    print(f'\n========== seed={seed} ==========')

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    collector = AntOmniCollector(
        max_steps=MAX_STEPS,
        n_episodes=N_EPISODES,
        ctrl_cost_weight=CTRL_COST_WEIGHT,
        seed=seed,
    )
    bd = AntGaitBD(bin_sizes=BIN_SIZES)
    bm = MAPElitesBM(behavior_descriptor=bd, fitness_fn=fitness_fn, top_k=TOP_K, max_fitness=MAX_FITNESS)

    sp = BoltzmannMix(
        agent_class=MLP_Agent,
        architecture=ARCHITECTURE,
        agent_kwargs={'output_activation': OUTPUT_ACTIVATION},
        operators=[PSEMut(sigma=PSE_MUT_SIGMA, greedy_mem=GREEDY_MEM)],
        n_total=N_TOTAL,
        warmup_threshold=999999,
    )

    me = MAPElite(search_phase=sp, collector=collector, behavior_matching=bm)
    me.run(n_steps=N_STEPS)

    # Save checkpoint immediately after this run
    ckpt_path = os.path.join(
        CKPT_BASE_DIR,
        f'MAPElite_Gauss_sigma{PSE_MUT_SIGMA}_seed{seed}/'
    )
    save_checkpoint(ckpt_path, bm, me.history, sp=sp)
    print(f'Checkpoint saved: {ckpt_path}')

    # Save plots into checkpoint folder
    me.plot_history(save_path=ckpt_path + 'plot_history.png')
    sp.plot_allocation(save_path=ckpt_path + 'plot_allocation.png')
    print(f'Plots saved to: {ckpt_path}')

    # Print results
    f_min, f_mean, f_max = bm.fitness_stats()
    qd  = bm.qd_score()
    cov = bm.coverage()
    print(f'QD-score: {qd:.4f} | Coverage: {cov:.4f} | Best fitness: {f_min:.6f}')

    all_results.append({
        'seed': seed,
        'qd_score': qd, 'coverage': cov,
    })

print('\n====== All runs complete ======')
# Out:
# Weight dim: 6472
#
# ========== seed=123 ==========
#
# --- MAP-Elite Step 1/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [75s elapsed, 0s remaining]]
# Archive: 117, Bins: 117, Coverage: 0.0117, Fitness min/mean/max: -98.76/-3.82/45.78
# QD-score: 58946.8759
#
# --- MAP-Elite Step 2/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [103s elapsed, 0s remaining]
# Archive: 279, Bins: 279, Coverage: 0.0279, Fitness min/mean/max: -140.32/-3.08/76.50
# QD-score: 140359.9573
#
# --- MAP-Elite Step 3/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [105s elapsed, 0s remaining]
# Archive: 403, Bins: 403, Coverage: 0.0403, Fitness min/mean/max: -140.32/-4.49/76.50
# QD-score: 203310.2586
#
# --- MAP-Elite Step 4/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [108s elapsed, 0s remaining]
# Archive: 508, Bins: 508, Coverage: 0.0508, Fitness min/mean/max: -140.32/-6.15/71.19
# QD-score: 257125.1277
#
# --- MAP-Elite Step 5/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [112s elapsed, 0s remaining]]
# Archive: 627, Bins: 627, Coverage: 0.0627, Fitness min/mean/max: -140.32/-6.99/71.19
# QD-score: 317881.6142
#
# --- MAP-Elite Step 6/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [123s elapsed, 0s remaining]]
# Archive: 725, Bins: 725, Coverage: 0.0725, Fitness min/mean/max: -140.32/-7.33/71.23
# QD-score: 367811.6602
#
# --- MAP-Elite Step 7/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 
200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [139s elapsed, 0s remaining]]
# Archive: 3608, Bins: 3608, Coverage: 0.3608, Fitness min/mean/max: -250.18/-21.62/58.15
# QD-score: 1881992.1785
#
# --- MAP-Elite Step 71/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [136s elapsed, 0s remaining]]
# Archive: 3635, Bins: 3635, Coverage: 0.3635, Fitness min/mean/max: -250.18/-21.79/39.63
# QD-score: 1896707.4666
#
# --- MAP-Elite Step 72/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [248s elapsed, 0s remaining]]
# Archive: 3659, Bins: 3659, Coverage: 0.3659, Fitness min/mean/max: -250.18/-21.85/39.63
# QD-score: 1909466.9992
#
# --- MAP-Elite Step 73/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [230s elapsed, 0s remaining]]]
# Archive: 3689, Bins: 3689, Coverage: 0.3689, Fitness min/mean/max: -250.18/-21.95/39.63
# QD-score: 1925491.3995
#
# --- MAP-Elite Step 74/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [162s elapsed, 0s remaining]]
# Archive: 3707, Bins: 3707, Coverage: 0.3707, Fitness min/mean/max: -250.18/-22.06/53.00
# QD-score: 1935272.7220
#
# --- MAP-Elite Step 75/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [175s elapsed, 0s remaining]]
# Archive: 3732, Bins: 3732, Coverage: 0.3732, Fitness min/mean/max: -250.18/-22.20/53.00
# QD-score: 1948837.9599
#
# --- MAP-Elite Step 76/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [175s elapsed, 0s remaining]]
# Archive: 3758, Bins: 3758, Coverage: 0.3758, Fitness min/mean/max: -250.18/-22.32/53.00
# QD-score: 1962875.0278
#
# --- MAP-Elite Step 77/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [187s elapsed, 0s remaining]]]
# Archive: 3773, Bins: 3773, Coverage: 0.3773, Fitness min/mean/max: -250.18/-22.42/53.00
# QD-score: 1971083.6256
#
# --- MAP-Elite Step 78/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [186s elapsed, 0s remaining]]
# Archive: 3785, Bins: 3785, Coverage: 0.3785, Fitness min/mean/max: -250.18/-22.71/53.00
# QD-score: 1978468.2458
#
# --- MAP-Elite Step 79/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [176s elapsed, 0s remaining]]
# Archive: 3808, Bins: 3808, Coverage: 0.3808, Fitness min/mean/max: -250.18/-22.85/53.00
# QD-score: 1991002.6337
#
# --- MAP-Elite Step 80/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [181s elapsed, 0s remaining]]
# Archive: 3830, Bins: 3830, Coverage: 0.3830, Fitness min/mean/max: -250.18/-22.95/53.00
# QD-score: 2002899.9867
#
# --- MAP-Elite Step 81/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [186s elapsed, 0s remaining]]
# Archive: 3860, Bins: 3860, Coverage: 0.3860, Fitness min/mean/max: -250.18/-23.05/53.00
# QD-score: 2018974.2602
#
# --- MAP-Elite Step 82/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [184s elapsed, 0s remaining]]
# Archive: 3885, Bins: 3885, Coverage: 0.3885, Fitness min/mean/max: -250.18/-23.18/53.00
# QD-score: 2032542.2255
#
# --- MAP-Elite Step 83/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [183s elapsed, 0s remaining]]]
# Archive: 3900, Bins: 3900, Coverage: 0.3900, Fitness min/mean/max: -250.18/-23.33/53.00
# QD-score: 2041001.5851
#
# --- MAP-Elite Step 84/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [144s elapsed, 0s remaining]]
# Archive: 3919, Bins: 3919, Coverage: 0.3919, Fitness min/mean/max: -250.18/-23.41/53.00
# QD-score: 2051247.8289
#
# --- MAP-Elite Step 85/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [152s elapsed, 0s remaining]]
# Archive: 3939, Bins: 3939, Coverage: 0.3939, Fitness min/mean/max: -250.18/-23.48/53.00
# QD-score: 2061997.6272
#
# --- MAP-Elite Step 86/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [149s elapsed, 0s remaining]]
# Archive: 3964, Bins: 3964, Coverage: 0.3964, Fitness min/mean/max: -250.18/-23.55/53.00
# QD-score: 2075363.6850
#
# --- MAP-Elite Step 87/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [153s elapsed, 0s remaining]]
# Archive: 3982, Bins: 3982, Coverage: 0.3982, Fitness min/mean/max: -250.18/-23.71/53.00
# QD-score: 2085394.2508
#
# --- MAP-Elite Step 88/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [138s elapsed, 0s remaining]]
# Archive: 4004, Bins: 4004, Coverage: 0.4004, Fitness min/mean/max: -250.18/-23.88/53.00
# QD-score: 2097596.7107
#
# --- MAP-Elite Step 89/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [141s elapsed, 0s remaining]]
# Archive: 4027, Bins: 4027, Coverage: 0.4027, Fitness min/mean/max: -250.18/-24.00/53.00
# QD-score: 2110141.1968
#
# --- MAP-Elite Step 90/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [139s elapsed, 0s remaining]]
# Archive: 4045, Bins: 4045, Coverage: 0.4045, Fitness min/mean/max: -250.18/-24.09/53.00
# QD-score: 2119947.9353
#
# --- MAP-Elite Step 91/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [142s elapsed, 0s remaining]]
# Archive: 4071, Bins: 4071, Coverage: 0.4071, Fitness min/mean/max: -250.18/-24.12/53.00
# QD-score: 2133700.1233
#
# --- MAP-Elite Step 92/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [137s elapsed, 0s remaining]]
# Archive: 4087, Bins: 4087, Coverage: 0.4087, Fitness min/mean/max: -250.18/-24.27/53.00
# QD-score: 2142674.9894
#
# --- MAP-Elite Step 93/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [144s elapsed, 0s remaining]]
# Archive: 4104, Bins: 4104, Coverage: 0.4104, Fitness min/mean/max: -250.18/-24.35/53.00
# QD-score: 2151928.1830
#
# --- MAP-Elite Step 94/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [143s elapsed, 0s remaining]]
# Archive: 4123, Bins: 4123, Coverage: 0.4123, Fitness min/mean/max: -250.18/-24.48/53.00
# QD-score: 2162412.0584
#
# --- MAP-Elite Step 95/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [146s elapsed, 0s remaining]]
# Archive: 4141, Bins: 4141, Coverage: 0.4141, Fitness min/mean/max: -250.18/-24.56/53.00
# QD-score: 2172216.4556
#
# --- MAP-Elite Step 96/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [143s elapsed, 0s remaining]]
# Archive: 4158, Bins: 4158, Coverage: 0.4158, Fitness min/mean/max: -250.18/-24.72/53.00
# QD-score: 2181785.8962
#
# --- MAP-Elite Step 97/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [140s elapsed, 0s remaining]]
# Archive: 4181, Bins: 4181, Coverage: 0.4181, Fitness min/mean/max: -250.18/-24.78/53.00
# QD-score: 2194105.8251
#
# --- MAP-Elite Step 98/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [146s elapsed, 0s remaining]]
# Archive: 4198, Bins: 4198, Coverage: 0.4198, Fitness min/mean/max: -250.18/-24.91/53.00
# QD-score: 2203563.0473
#
# --- MAP-Elite Step 99/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [150s elapsed, 0s remaining]]
# Archive: 4216, Bins: 4216, Coverage: 0.4216, Fitness min/mean/max: -250.18/-25.02/53.00
# QD-score: 2213487.4649
#
# --- MAP-Elite Step 100/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [149s elapsed, 0s remaining]]
# Archive: 4234, Bins: 4234, Coverage: 0.4234, Fitness min/mean/max: -250.18/-25.03/68.33
# QD-score: 2222994.6675
#
# --- MAP-Elite Step 101/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [143s elapsed, 0s remaining]]
# Archive:
200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [130s elapsed, 0s remaining]]
# Archive: 5337, Bins: 5337, Coverage: 0.5337, Fitness min/mean/max: -309.14/-30.92/53.00
# QD-score: 2833509.4012
#
# --- MAP-Elite Step 187/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [130s elapsed, 0s remaining]]
# Archive: 5347, Bins: 5347, Coverage: 0.5347, Fitness min/mean/max: -309.14/-31.01/53.00
# QD-score: 2839284.3622
#
# --- MAP-Elite Step 188/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [130s elapsed, 0s remaining]]
# Archive: 5351, Bins: 5351, Coverage: 0.5351, Fitness min/mean/max: -309.14/-31.10/51.26
# QD-score: 2841890.9893
#
# --- MAP-Elite Step 189/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [131s elapsed, 0s remaining]]
# Archive: 5361, Bins: 5361, Coverage: 0.5361, Fitness min/mean/max: -309.14/-31.16/51.26
# QD-score: 2847568.3183
#
# --- MAP-Elite Step 190/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [130s elapsed, 0s remaining]]
# Archive: 5374, Bins: 5374, Coverage: 0.5374, Fitness min/mean/max: -309.14/-31.23/51.26
# QD-score: 2854834.6131
#
# --- MAP-Elite Step 191/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [133s elapsed, 0s remaining]]
# Archive: 5382, Bins: 5382, Coverage: 0.5382, Fitness min/mean/max: -309.14/-31.27/51.26
# QD-score: 2859318.5572
#
# --- MAP-Elite Step 192/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [128s elapsed, 0s remaining]]
# Archive: 5392, Bins: 5392, Coverage: 0.5392, Fitness min/mean/max: -309.14/-31.32/51.26
# QD-score: 2864857.5816
#
# --- MAP-Elite Step 193/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [134s elapsed, 0s remaining]]
# Archive: 5401, Bins: 5401, Coverage: 0.5401, Fitness min/mean/max: -309.14/-31.38/51.26
# QD-score: 2869962.1834
#
# --- MAP-Elite Step 194/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [133s elapsed, 0s remaining]]
# Archive: 5404, Bins: 5404, Coverage: 0.5404, Fitness min/mean/max: -309.14/-31.44/51.26
# QD-score: 2871881.1124
#
# --- MAP-Elite Step 195/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [128s elapsed, 0s remaining]]
# Archive: 5415, Bins: 5415, Coverage: 0.5415, Fitness min/mean/max: -309.14/-31.49/51.26
# QD-score: 2877991.9191
#
# --- MAP-Elite Step 196/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [131s elapsed, 0s remaining]]
# Archive: 5425, Bins: 5425, Coverage: 0.5425, Fitness min/mean/max: -309.14/-31.54/51.26
# QD-score: 2883598.6606
#
# --- MAP-Elite Step 197/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [130s elapsed, 0s remaining]]
# Archive: 5432, Bins: 5432, Coverage: 0.5432, Fitness min/mean/max: -309.14/-31.62/51.26
# QD-score: 2887783.3195
#
# --- MAP-Elite Step 198/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [133s elapsed, 0s remaining]]
# Archive: 5443, Bins: 5443, Coverage: 0.5443, Fitness min/mean/max: -309.14/-31.65/51.26
# QD-score: 2893780.9646
#
# --- MAP-Elite Step 199/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [126s elapsed, 0s remaining]]
# Archive: 5452, Bins: 5452, Coverage: 0.5452, Fitness min/mean/max: -309.14/-31.69/51.26
# QD-score: 2898796.0251
#
# --- MAP-Elite Step 200/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [143s elapsed, 0s remaining]]
# Archive: 5463, Bins: 5463, Coverage: 0.5463, Fitness min/mean/max: -309.14/-31.75/51.26
# QD-score: 2904972.0977
# Checkpoint saved: /Users/frankh/Downloads/ant_gait_ckpts/Ant_MAPElite_GaussianMut/MAPElite_Gauss_sigma0.05_seed123/
# Plots saved to: /Users/frankh/Downloads/ant_gait_ckpts/Ant_MAPElite_GaussianMut/MAPElite_Gauss_sigma0.05_seed123/
# QD-score: 2904972.0977 | Coverage: 0.5463 | Best fitness: -309.136219
#
# ====== All runs complete ======
