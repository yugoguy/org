# %%
#!rm -rf org && git clone --filter=blob:none --sparse https://github.com/yugoguy/org.git
#!cd org && git sparse-checkout set dev/SSLVE && git checkout Latent-Variable-Evolution

# %%
import sys, os, glob
sys.path.insert(0, 'org/dev/SSLVE')
for f in sorted(glob.glob('org/dev/SSLVE/*.py')):
    print(f"Running: {f}")
    # %run {f}
# Out:
# Running: org/dev/SSLVE\AgentModules.py
# Running: org/dev/SSLVE\AuxLosses.py
# Running: org/dev/SSLVE\BehaviorDescriptors.py
# Running: org/dev/SSLVE\BehaviorMatchings.py
# Running: org/dev/SSLVE\CMAME.py
# Running: org/dev/SSLVE\Collectors.py
# Running: org/dev/SSLVE\ExperimentUtils.py
# Running: org/dev/SSLVE\LatentModules.py
# Running: org/dev/SSLVE\Main.py
# Running: org/dev/SSLVE\SearchPhases.py
# Running: org/dev/SSLVE\VariationOperators.py

# %%
#@title AntGaitUni LVE Any (Flow + AuxLoss)
import numpy as np
import random
import torch

# =============================================================================
# Hyperparameters
# =============================================================================
ARCHITECTURE = [27, 64, 64, 8]  #@param
OUTPUT_ACTIVATION = 'tanh'  #@param {type:"string"}
MAX_STEPS = 500  #@param {type:"integer"}
N_EPISODES = 3  #@param {type:"integer"}
CTRL_COST_WEIGHT = 0.5  #@param {type:"number"}

# --- Gait BD Grid ---
BIN_SIZES = [10, 10, 10, 10]  #@param

# --- Fitness ---
TOP_K = 3  #@param {type:"integer"}
MAX_FITNESS = 500.0  #@param {type:"number"}

# --- Variation Operators ---
USE_PSE_MUT = True  #@param {type:"boolean"}
USE_PSE_LINE = True  #@param {type:"boolean"}
USE_LVE_MUT = True  #@param {type:"boolean"}
USE_LVE_CROSS = True  #@param {type:"boolean"}
USE_STD_SUPPORT_LVE = True  #@param {type:"boolean"}
GREEDY_MEM = True  #@param {type:"boolean"}

PSE_MUT_SIGMA = 0.05  #@param {type:"number"}
LVE_MUT_SIGMA = 0.05  #@param {type:"number"}
STD_SUPPORT_LO = -2.0  #@param {type:"number"}
STD_SUPPORT_HI = 2.0  #@param {type:"number"}

# --- Warmup Operators ---
WARMUP_PSE_MUT = True  #@param {type:"boolean"}
WARMUP_PSE_LINE = True  #@param {type:"boolean"}

N_TOTAL = 500  #@param {type:"integer"}
WARMUP_THRESHOLD = 4096  #@param {type:"integer"}
EMA_ALPHA = 0.25  #@param {type:"number"}
TEMPERATURE = 10  #@param {type:"number"}
MIN_PROPORTION = 0.05  #@param {type:"number"}

# --- Latent Module ---
USE_FLOW_PRIOR = False  #@param {type:"boolean"}
LATENT_DIM = 64  #@param {type:"integer"}
HIDDEN_DIMS = [256]  #@param
BETA = 1e-3  #@param {type:"number"}
NUM_FLOWS = 3  #@param {type:"integer"}
FLOW_HIDDEN = 128  #@param {type:"integer"}
FLOW_HIDDEN_LAYERS = 2  #@param {type:"integer"}
EPOCHS = 50  #@param {type:"integer"}
BATCH_SIZE = 1024  #@param {type:"integer"}
LR = 1e-3  #@param {type:"number"}

# --- Aux Losses ---
USE_BIN_PRED = True  #@param {type:"boolean"}
GAMMA_BIN_PRED = 1e-3  #@param {type:"number"}
USE_MIX_BIN_PRED = True  #@param {type:"boolean"}
GAMMA_MIX_BIN_PRED = 1e-3  #@param {type:"number"}
MIX_ALPHA_LO = -0.1  #@param {type:"number"}
MIX_ALPHA_HI = 1.1  #@param {type:"number"}

N_STEPS = 200  #@param {type:"integer"}

# --- Checkpoint ---
CHECKPOINT_PATH = ''  #@param {type:"string"}

SEED = 42  #@param {type:"integer"}
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# =============================================================================
# Setup
# =============================================================================
weight_dim = MLP_Agent(ARCHITECTURE, output_activation=OUTPUT_ACTIVATION).get_weight_dim()

fitness_fn = lambda info: -info['forward_sum']

collector = AntOmniCollector(
    max_steps=MAX_STEPS,
    n_episodes=N_EPISODES,
    ctrl_cost_weight=CTRL_COST_WEIGHT,
    seed=SEED,
)
bd = AntGaitBD(bin_sizes=BIN_SIZES)
bm = MAPElitesBM(behavior_descriptor=bd, fitness_fn=fitness_fn, top_k=TOP_K, max_fitness=MAX_FITNESS)

operators = []
translate_fn = None
if USE_PSE_MUT:
    operators.append(PSEMut(sigma=PSE_MUT_SIGMA, greedy_mem=GREEDY_MEM))
if USE_PSE_LINE:
    operators.append(PSELine(greedy_mem=GREEDY_MEM))
if USE_LVE_MUT:
    operators.append(LVEMut(sigma=LVE_MUT_SIGMA, greedy_mem=GREEDY_MEM))
if USE_LVE_CROSS:
    operators.append(LVECross(greedy_mem=GREEDY_MEM))
assert len(operators) > 0

warmup_operators = []
if WARMUP_PSE_MUT:
    warmup_operators.append(PSEMut(sigma=PSE_MUT_SIGMA, greedy_mem=GREEDY_MEM))
if WARMUP_PSE_LINE:
    warmup_operators.append(PSELine(greedy_mem=GREEDY_MEM))
assert len(warmup_operators) > 0

aux_losses = []
if USE_BIN_PRED:
    aux = BinPred(behavior_descriptor=bd, latent_dim=LATENT_DIM, output_dim=4)
    aux_losses.append((GAMMA_BIN_PRED, aux))

if USE_MIX_BIN_PRED:
    mix_aux = MixBinPred(
        behavior_descriptor=bd, latent_dim=LATENT_DIM, output_dim=4,
        alpha_lo=MIX_ALPHA_LO, alpha_hi=MIX_ALPHA_HI,
    )
    aux_losses.append((GAMMA_MIX_BIN_PRED, mix_aux))

if USE_FLOW_PRIOR:
    lm = BaseFlowVAE(
        input_dim=weight_dim,
        latent_dim=LATENT_DIM,
        hidden_dims=HIDDEN_DIMS,
        beta=BETA,
        num_flows=NUM_FLOWS,
        flow_hidden=FLOW_HIDDEN,
        flow_hidden_layers=FLOW_HIDDEN_LAYERS,
        aux_losses=aux_losses,
    )
    translate_fn = lm.translate
    if USE_MIX_BIN_PRED:
        mix_aux.to_base_fn = lambda z: lm.flow.f(z)[0]
        mix_aux.from_base_fn = lm.flow.f_inv
else:
    lm = BaseBetaVAE(
        input_dim=weight_dim,
        latent_dim=LATENT_DIM,
        hidden_dims=HIDDEN_DIMS,
        beta=BETA,
        aux_losses=aux_losses,
    )

if USE_STD_SUPPORT_LVE:
    operators.append(StandardNormalSupportLVE(lo=STD_SUPPORT_LO, hi=STD_SUPPORT_HI, translate_fn=translate_fn))

sp = BoltzmannMix(
    agent_class=MLP_Agent,
    architecture=ARCHITECTURE,
    agent_kwargs={'output_activation': OUTPUT_ACTIVATION},
    operators=operators,
    warmup_operators=warmup_operators,
    n_total=N_TOTAL,
    warmup_threshold=WARMUP_THRESHOLD,
    ema_alpha=EMA_ALPHA,
    temperature=TEMPERATURE,
    min_proportion=MIN_PROPORTION,
)

orchestrator = SSLVE(
    search_phase=sp,
    collector=collector,
    behavior_matching=bm,
    latent_module=lm,
    device=DEVICE,
)

if CHECKPOINT_PATH:
    load_checkpoint(CHECKPOINT_PATH, bm, orchestrator.history, sp=sp, lm=lm, device=DEVICE)
    print(f"Loaded checkpoint from {CHECKPOINT_PATH}")
    print(f"Archive size: {bm.archive_size()}, Coverage: {bm.coverage():.4f}")

# =============================================================================
# Run
# =============================================================================
print(f"Architecture: {ARCHITECTURE}")
print(f"Weight dim: {weight_dim}")
print(f"Fitness: -forward_sum")
if USE_FLOW_PRIOR:
    print(f"Flow prior: {NUM_FLOWS} flows, hidden: {FLOW_HIDDEN}x{FLOW_HIDDEN_LAYERS}")
print(f"Latent dim: {LATENT_DIM}, Hidden: {HIDDEN_DIMS}, Beta: {BETA}")
print(f"Device: {DEVICE}")
print(f"Gait BD grid: {BIN_SIZES} ({bd.total_bins()} bins)")
print(f"Samples per step: {N_TOTAL}")
print(f"Warmup threshold: {WARMUP_THRESHOLD}")
print(f"Operators: {[op.name for op in operators]}")
print(f"Warmup operators: {[op.name for op in warmup_operators]}")
if USE_BIN_PRED:
    print(f"BinPred gamma: {GAMMA_BIN_PRED}")
if USE_MIX_BIN_PRED:
    print(f"MixBinPred gamma: {GAMMA_MIX_BIN_PRED}, alpha: [{MIX_ALPHA_LO}, {MIX_ALPHA_HI}]")
print(f"Mode: SSLVE")
print()

train_kwargs = {
    'epochs': EPOCHS,
    'batch_size': BATCH_SIZE,
    'lr': LR,
    'verbose': True,
}
histories = orchestrator.run(n_steps=N_STEPS, train_kwargs=train_kwargs)

f_min, f_mean, f_max = bm.fitness_stats()
print(f"\nFinal archive size: {bm.archive_size()}")
print(f"Final coverage: {bm.coverage():.4f}")
print(f"Best fitness: {f_min:.4f}")
print(f"QD-score: {bm.qd_score():.4f}")

orchestrator.plot_history()
sp.plot_allocation()
# Out:
# Architecture: [27, 64, 64, 8]
# Weight dim: 6472
# Fitness: -forward_sum
# Latent dim: 64, Hidden: [256], Beta: 0.001
# Device: cpu
# Gait BD grid: [10, 10, 10, 10] (10000 bins)
# Samples per step: 500
# Warmup threshold: 4096
# Operators: ['pse_mut', 'pse_line', 'lve_mut', 'lve_cross', 'std_support_lve']
# Warmup operators: ['pse_mut', 'pse_line']
# BinPred gamma: 0.001
# MixBinPred gamma: 0.001, alpha: [-0.1, 1.1]
# Mode: SSLVE
#
#
# --- SSLVE Step 1/200 ---
#   Operator ratio - pse_mut: 500/500 (100%), pse_line: 0/500 (0%)
# Collecting: 500/500 [126s elapsed, 0s remaining]]
# Archive: 180, Bins: 123, Coverage: 0.0123, Fitness min/mean/max: -72.65/-5.91/43.92
# QD-score: 62259.6586
#
# --- SSLVE Step 2/200 ---
#   Operator ratio - pse_mut: 250/500 (50%), pse_line: 250/500 (50%)
# Collecting: 500/500 [196s elapsed, 0s remaining]]
# Archive: 406, Bins: 281, Coverage: 0.0281, Fitness min/mean/max: -92.52/-5.93/62.30
# QD-score: 142549.9421
#
# --- SSLVE Step 3/200 ---
#   Operator ratio - pse_mut: 44/500 (9%), pse_line: 456/500 (91%)
# Collecting: 500/500 [251s elapsed, 0s remaining]]]
# Archive: 687, Bins: 461, Coverage: 0.0461, Fitness min/mean/max: -96.76/-4.72/65.48
# QD-score: 233504.6189
#
# --- SSLVE Step 4/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [271s elapsed, 0s remaining]]]
# Archive: 927, Bins: 617, Coverage: 0.0617, Fitness min/mean/max: -96.76/-4.50/76.68
# QD-score: 312730.0915
#
# --- SSLVE Step 5/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [283s elapsed, 0s remaining]]]
# Archive: 1179, Bins: 774, Coverage: 0.0774, Fitness min/mean/max: -135.45/-4.28/100.35
# QD-score: 392414.6978
#
# --- SSLVE Step 6/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [283s elapsed, 0s remaining]]]
# Archive: 1392, Bins: 907, Coverage: 0.0907, Fitness min/mean/max: -146.50/-4.76/100.35
# QD-score: 460197.2955
#
# --- SSLVE Step 7/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [290s elapsed, 0s remaining]]]
# Archive: 1593, Bins: 1037, Coverage: 0.1037, Fitness min/mean/max: -146.50/-5.13/100.35
# QD-score: 526477.1022
#
# --- SSLVE Step 8/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [290s elapsed, 0s remaining]]]
# Archive: 1806, Bins: 1165, Coverage: 0.1165, Fitness min/mean/max: -146.50/-5.23/100.35
# QD-score: 591635.7452
#
# --- SSLVE Step 9/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [295s elapsed, 0s remaining]]]
# Archive: 2006, Bins: 1267, Coverage: 0.1267, Fitness min/mean/max: -146.50/-5.29/137.03
# QD-score: 643681.8169
#
# --- SSLVE Step 10/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [291s elapsed, 0s remaining]]]
# Archive: 2194, Bins: 1373, Coverage: 0.1373, Fitness min/mean/max: -146.50/-5.27/137.03
# QD-score: 697391.1840
#
# --- SSLVE Step 11/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [296s elapsed, 0s remaining]]]
# Archive: 2375, Bins: 1470, Coverage: 0.1470, Fitness min/mean/max: -146.50/-5.49/137.03
# QD-score: 746831.6789
#
# --- SSLVE Step 12/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [296s elapsed, 0s remaining]]]
# Archive: 2542, Bins: 1552, Coverage: 0.1552, Fitness min/mean/max: -146.50/-5.59/137.03
# QD-score: 788824.2581
#
# --- SSLVE Step 13/200 ---
#   Operator ratio - pse_mut: 36/500 (7%), pse_line: 464/500 (93%)
# Collecting: 500/500 [292s elapsed, 0s remaining]]]
# Archive: 2730, Bins: 1647, Coverage: 0.1647, Fitness min/mean/max: -146.50/-5.71/137.03
# QD-score: 837378.7807
#
# --- SSLVE Step 14/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [295s elapsed, 0s remaining]]]
# Archive: 2889, Bins: 1726, Coverage: 0.1726, Fitness min/mean/max: -146.50/-5.85/137.03
# QD-score: 877943.3746
#
# --- SSLVE Step 15/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 475/500 (95%)
# Collecting: 500/500 [296s elapsed, 0s remaining]]]
# Archive: 3052, Bins: 1804, Coverage: 0.1804, Fitness min/mean/max: -146.50/-5.84/137.03
# QD-score: 917617.6011
#
# --- SSLVE Step 16/200 ---
#   Operator ratio - pse_mut: 176/500 (35%), pse_line: 324/500 (65%)
# Collecting: 500/500 [285s elapsed, 0s remaining]]]
# Archive: 3208, Bins: 1899, Coverage: 0.1899, Fitness min/mean/max: -176.66/-6.15/137.03
# QD-score: 966415.5881
#
# --- SSLVE Step 17/200 ---
#   Operator ratio - pse_mut: 186/500 (37%), pse_line: 314/500 (63%)
# Collecting: 500/500 [288s elapsed, 0s remaining]]]
# Archive: 3349, Bins: 1966, Coverage: 0.1966, Fitness min/mean/max: -176.66/-6.43/137.03
# QD-score: 1001054.5769
#
# --- SSLVE Step 18/200 ---
#   Operator ratio - pse_mut: 193/500 (39%), pse_line: 307/500 (61%)
# Collecting: 500/500 [286s elapsed, 0s remaining]]]
# Archive: 3509, Bins: 2041, Coverage: 0.2041, Fitness min/mean/max: -176.66/-6.48/137.03
# QD-score: 1039575.8797
#
# --- SSLVE Step 19/200 ---
#   Operator ratio - pse_mut: 237/500 (47%), pse_line: 263/500 (53%)
# Collecting: 500/500 [286s elapsed, 0s remaining]]]
# Archive: 3652, Bins: 2110, Coverage: 0.2110, Fitness min/mean/max: -176.66/-6.72/105.41
# QD-score: 1075113.3706
#
# --- SSLVE Step 20/200 ---
#   Operator ratio - pse_mut: 195/500 (39%), pse_line: 305/500 (61%)
# Collecting: 500/500 [287s elapsed, 0s remaining]]]
# Archive: 3801, Bins: 2184, Coverage: 0.2184, Fitness min/mean/max: -176.66/-7.01/105.41
# QD-score: 1113618.7312
#
# --- SSLVE Step 21/200 ---
#   Operator ratio - pse_mut: 268/500 (54%), pse_line: 232/500 (46%)
# Collecting: 500/500 [280s elapsed, 0s remaining]]]
# Archive: 3948, Bins: 2259, Coverage: 0.2259, Fitness min/mean/max: -176.66/-7.06/105.41
# QD-score: 1152093.2825
#
# --- SSLVE Step 22/200 ---
#   Operator ratio - pse_mut: 233/500 (47%), pse_line: 267/500 (53%)
# Collecting: 500/500 [287s elapsed, 0s remaining]]]
# Archive: 4078, Bins: 2315, Coverage: 0.2315, Fitness min/mean/max: -176.66/-7.10/105.41
# QD-score: 1181075.3063
#
# --- SSLVE Step 23/200 ---
#   Operator ratio - pse_mut: 110/500 (22%), pse_line: 390/500 (78%)
# Collecting: 500/500 [298s elapsed, 0s remaining]]]
# Archive: 4209, Bins: 2377, Coverage: 0.2377, Fitness min/mean/max: -176.66/-7.15/105.41
# QD-score: 1212828.8714
#
# --- SSLVE Step 24/200 ---
#   Operator ratio - pse_mut: 100/500 (20%), pse_line: 100/500 (20%), lve_mut: 100/500 (20%), lve_cross: 100/500 (20%), std_support_lve: 100/500 (20%)
# Collecting: 500/500 [231s elapsed, 0s remaining]]]
# Archive: 4277, Bins: 2408, Coverage: 0.2408, Fitness min/mean/max: -176.66/-7.18/105.41
# QD-score: 1228638.3149
# Epoch 10/50 | Train Total: 0.0198, Recon: 0.0183, KL: 1.4933, bin_pred: 0.1019, mix_bin_pred: 0.0720
# Epoch 20/50 | Train Total: 0.0185, Recon: 0.0177, KL: 0.8808, bin_pred: 0.0962, mix_bin_pred: 0.0749
# Epoch 30/50 | Train Total: 0.0174, Recon: 0.0167, KL: 0.7660, bin_pred: 0.1017, mix_bin_pred: 0.0819
# Epoch 40/50 | Train Total: 0.0154, Recon: 0.0146, KL: 0.8438, bin_pred: 0.0962, mix_bin_pred: 0.0783
# Epoch 50/50 | Train Total: 0.0132, Recon: 0.0123, KL: 0.9356, bin_pred: 0.0893, mix_bin_pred: 0.0704
#
# --- SSLVE Step 25/200 ---
#   Operator ratio - pse_mut: 110/500 (22%), pse_line: 308/500 (62%), lve_mut: 32/500 (6%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [298s elapsed, 0s remaining]]]
# Archive: 4387, Bins: 2458, Coverage: 0.2458, Fitness min/mean/max: -176.66/-7.33/105.41
# QD-score: 1254529.4418
# Epoch 10/50 | Train Total: 0.0096, Recon: 0.0085, KL: 1.0586, bin_pred: 0.0840, mix_bin_pred: 0.0676
# Epoch 20/50 | Train Total: 0.0069, Recon: 0.0058, KL: 1.1146, bin_pred: 0.0772, mix_bin_pred: 0.0617
# Epoch 30/50 | Train Total: 0.0053, Recon: 0.0042, KL: 1.1213, bin_pred: 0.0754, mix_bin_pred: 0.0593
# Epoch 40/50 | Train Total: 0.0043, Recon: 0.0032, KL: 1.1223, bin_pred: 0.0710, mix_bin_pred: 0.0553
# Epoch 50/50 | Train Total: 0.0036, Recon: 0.0024, KL: 1.1094, bin_pred: 0.0685, mix_bin_pred: 0.0520
#
# --- SSLVE Step 26/200 ---
#   Operator ratio - pse_mut: 113/500 (23%), pse_line: 312/500 (62%), lve_mut: 25/500 (5%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [298s elapsed, 0s remaining]]]
# Archive: 4521, Bins: 2509, Coverage: 0.2509, Fitness min/mean/max: -176.66/-7.41/119.93
# QD-score: 1280935.1581
# Epoch 10/50 | Train Total: 0.0033, Recon: 0.0022, KL: 1.1005, bin_pred: 0.0690, mix_bin_pred: 0.0533
# Epoch 20/50 | Train Total: 0.0030, Recon: 0.0019, KL: 1.0725, bin_pred: 0.0673, mix_bin_pred: 0.0511
# Epoch 30/50 | Train Total: 0.0028, Recon: 0.0018, KL: 1.0462, bin_pred: 0.0665, mix_bin_pred: 0.0503
# Epoch 40/50 | Train Total: 0.0027, Recon: 0.0017, KL: 1.0239, bin_pred: 0.0653, mix_bin_pred: 0.0490
# Epoch 50/50 | Train Total: 0.0027, Recon: 0.0017, KL: 0.9975, bin_pred: 0.0642, mix_bin_pred: 0.0487
#
# --- SSLVE Step 27/200 ---
#   Operator ratio - pse_mut: 136/500 (27%), pse_line: 289/500 (58%), lve_mut: 25/500 (5%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [297s elapsed, 0s remaining]]]
# Archive: 4643, Bins: 2562, Coverage: 0.2562, Fitness min/mean/max: -176.66/-7.41/119.93
# QD-score: 1307879.1391
# Epoch 10/50 | Train Total: 0.0026, Recon: 0.0016, KL: 0.9993, bin_pred: 0.0648, mix_bin_pred: 0.0486
# Epoch 20/50 | Train Total: 0.0025, Recon: 0.0015, KL: 0.9882, bin_pred: 0.0640, mix_bin_pred: 0.0471
# Epoch 30/50 | Train Total: 0.0024, Recon: 0.0015, KL: 0.9717, bin_pred: 0.0629, mix_bin_pred: 0.0472
# Epoch 40/50 | Train Total: 0.0024, Recon: 0.0014, KL: 0.9661, bin_pred: 0.0616, mix_bin_pred: 0.0463
# Epoch 50/50 | Train Total: 0.0023, Recon: 0.0014, KL: 0.9567, bin_pred: 0.0600, mix_bin_pred: 0.0458
#
# --- SSLVE Step 28/200 ---
#   Operator ratio - pse_mut: 184/500 (37%), pse_line: 196/500 (39%), lve_mut: 70/500 (14%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [293s elapsed, 0s remaining]]]
# Archive: 4766, Bins: 2615, Coverage: 0.2615, Fitness min/mean/max: -176.66/-7.50/119.93
# QD-score: 1335150.3599
# Epoch 10/50 | Train Total: 0.0024, Recon: 0.0014, KL: 0.9458, bin_pred: 0.0610, mix_bin_pred: 0.0448
# Epoch 20/50 | Train Total: 0.0023, Recon: 0.0013, KL: 0.9501, bin_pred: 0.0600, mix_bin_pred: 0.0450
# Epoch 30/50 | Train Total: 0.0023, Recon: 0.0013, KL: 0.9401, bin_pred: 0.0585, mix_bin_pred: 0.0436
# Epoch 40/50 | Train Total: 0.0022, Recon: 0.0013, KL: 0.9268, bin_pred: 0.0579, mix_bin_pred: 0.0436
# Epoch 50/50 | Train Total: 0.0022, Recon: 0.0013, KL: 0.9213, bin_pred: 0.0573, mix_bin_pred: 0.0430
#
# --- SSLVE Step 29/200 ---
#   Operator ratio - pse_mut: 115/500 (23%), pse_line: 193/500 (39%), lve_mut: 142/500 (28%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [299s elapsed, 0s remaining]]]
# Archive: 4891, Bins: 2662, Coverage: 0.2662, Fitness min/mean/max: -176.66/-7.63/119.93
# QD-score: 1359578.1449
# Epoch 10/50 | Train Total: 0.0023, Recon: 0.0013, KL: 0.9271, bin_pred: 0.0579, mix_bin_pred: 0.0439
# Epoch 20/50 | Train Total: 0.0022, Recon: 0.0013, KL: 0.9126, bin_pred: 0.0582, mix_bin_pred: 0.0437
# Epoch 30/50 | Train Total: 0.0022, Recon: 0.0013, KL: 0.9083, bin_pred: 0.0574, mix_bin_pred: 0.0424
# Epoch 40/50 | Train Total: 0.0022, Recon: 0.0013, KL: 0.9018, bin_pred: 0.0558, mix_bin_pred: 0.0419
# Epoch 50/50 | Train Total: 0.0022, Recon: 0.0013, KL: 0.9052, bin_pred: 0.0549, mix_bin_pred: 0.0413
#
# --- SSLVE Step 30/200 ---
#   Operator ratio - pse_mut: 72/500 (14%), pse_line: 189/500 (38%), lve_mut: 189/500 (38%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [308s elapsed, 0s remaining]]]
# Archive: 5014, Bins: 2710, Coverage: 0.2710, Fitness min/mean/max: -176.66/-7.84/119.93
# QD-score: 1384748.3966
# Epoch 10/50 | Train Total: 0.0022, Recon: 0.0013, KL: 0.9018, bin_pred: 0.0570, mix_bin_pred: 0.0421
# Epoch 20/50 | Train Total: 0.0021, Recon: 0.0012, KL: 0.8995, bin_pred: 0.0566, mix_bin_pred: 0.0435
# Epoch 30/50 | Train Total: 0.0022, Recon: 0.0013, KL: 0.8808, bin_pred: 0.0552, mix_bin_pred: 0.0419
# Epoch 40/50 | Train Total: 0.0021, Recon: 0.0013, KL: 0.8927, bin_pred: 0.0544, mix_bin_pred: 0.0406
# Epoch 50/50 | Train Total: 0.0021, Recon: 0.0012, KL: 0.8890, bin_pred: 0.0544, mix_bin_pred: 0.0406
#
# --- SSLVE Step 31/200 ---
#   Operator ratio - pse_mut: 60/500 (12%), pse_line: 145/500 (29%), lve_mut: 245/500 (49%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [308s elapsed, 0s remaining]]]
# Archive: 5146, Bins: 2767, Coverage: 0.2767, Fitness min/mean/max: -176.66/-8.05/119.93
# QD-score: 1414889.6349
# Epoch 10/50 | Train Total: 0.0021, Recon: 0.0012, KL: 0.8820, bin_pred: 0.0538, mix_bin_pred: 0.0410 | Val Total: 0.0021
# Epoch 20/50 | Train Total: 0.0021, Recon: 0.0012, KL: 0.8778, bin_pred: 0.0529, mix_bin_pred: 0.0394 | Val Total: 0.0021
# Epoch 30/50 | Train Total: 0.0021, Recon: 0.0012, KL: 0.8893, bin_pred: 0.0525, mix_bin_pred: 0.0397 | Val Total: 0.0021
# Epoch 40/50 | Train Total: 0.0021, Recon: 0.0012, KL: 0.8744, bin_pred: 0.0520, mix_bin_pred: 0.0385 | Val Total: 0.0021
# Epoch 50/50 | Train Total: 0.0020, Recon: 0.0012, KL: 0.8603, bin_pred: 0.0515, mix_bin_pred: 0.0377 | Val Total: 0.0021
#
# --- SSLVE Step 32/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 68/500 (14%), lve_mut: 357/500 (71%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [305s elapsed, 0s remaining]]]
# Archive: 5288, Bins: 2823, Coverage: 0.2823, Fitness min/mean/max: -176.66/-8.26/119.93
# QD-score: 1444820.7807
# Epoch 10/50 | Train Total: 0.0020, Recon: 0.0011, KL: 0.8617, bin_pred: 0.0525, mix_bin_pred: 0.0388 | Val Total: 0.0021
# Epoch 20/50 | Train Total: 0.0019, Recon: 0.0011, KL: 0.8512, bin_pred: 0.0523, mix_bin_pred: 0.0394 | Val Total: 0.0021
# Epoch 30/50 | Train Total: 0.0019, Recon: 0.0011, KL: 0.8428, bin_pred: 0.0518, mix_bin_pred: 0.0383 | Val Total: 0.0021
# Epoch 40/50 | Train Total: 0.0019, Recon: 0.0011, KL: 0.8462, bin_pred: 0.0516, mix_bin_pred: 0.0390 | Val Total: 0.0022
# Epoch 50/50 | Train Total: 0.0019, Recon: 0.0011, KL: 0.8360, bin_pred: 0.0512, mix_bin_pred: 0.0380 | Val Total: 0.0022
#
# --- SSLVE Step 33/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [311s elapsed, 0s remaining]]]
# Archive: 5427, Bins: 2871, Coverage: 0.2871, Fitness min/mean/max: -176.66/-8.42/119.93
# QD-score: 1470109.0536
# Epoch 10/50 | Train Total: 0.0019, Recon: 0.0011, KL: 0.8436, bin_pred: 0.0507, mix_bin_pred: 0.0381 | Val Total: 0.0019
# Epoch 20/50 | Train Total: 0.0019, Recon: 0.0011, KL: 0.8396, bin_pred: 0.0492, mix_bin_pred: 0.0369 | Val Total: 0.0019
# Epoch 30/50 | Train Total: 0.0019, Recon: 0.0011, KL: 0.8382, bin_pred: 0.0496, mix_bin_pred: 0.0367 | Val Total: 0.0019
# Epoch 40/50 | Train Total: 0.0019, Recon: 0.0011, KL: 0.8340, bin_pred: 0.0491, mix_bin_pred: 0.0370 | Val Total: 0.0020
# Epoch 50/50 | Train Total: 0.0019, Recon: 0.0010, KL: 0.8431, bin_pred: 0.0485, mix_bin_pred: 0.0365 | Val Total: 0.0020
#
# --- SSLVE Step 34/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [311s elapsed, 0s remaining]]]
# Archive: 5559, Bins: 2932, Coverage: 0.2932, Fitness min/mean/max: -176.66/-8.64/119.93
# QD-score: 1501872.3482
# Epoch 10/50 | Train Total: 0.0019, Recon: 0.0010, KL: 0.8277, bin_pred: 0.0502, mix_bin_pred: 0.0379 | Val Total: 0.0019
# Epoch 20/50 | Train Total: 0.0018, Recon: 0.0010, KL: 0.8247, bin_pred: 0.0498, mix_bin_pred: 0.0368 | Val Total: 0.0020
# Epoch 30/50 | Train Total: 0.0018, Recon: 0.0010, KL: 0.8234, bin_pred: 0.0488, mix_bin_pred: 0.0367 | Val Total: 0.0020
# Epoch 40/50 | Train Total: 0.0018, Recon: 0.0010, KL: 0.8268, bin_pred: 0.0486, mix_bin_pred: 0.0361 | Val Total: 0.0020
# Epoch 50/50 | Train Total: 0.0018, Recon: 0.0010, KL: 0.8200, bin_pred: 0.0484, mix_bin_pred: 0.0354 | Val Total: 0.0020
#
# --- SSLVE Step 35/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [309s elapsed, 0s remaining]]]
# Archive: 5702, Bins: 2995, Coverage: 0.2995, Fitness min/mean/max: -181.35/-8.96/119.93
# QD-score: 1535236.1826
# Epoch 10/50 | Train Total: 0.0018, Recon: 0.0010, KL: 0.8129, bin_pred: 0.0490, mix_bin_pred: 0.0367 | Val Total: 0.0018
# Epoch 20/50 | Train Total: 0.0018, Recon: 0.0010, KL: 0.8020, bin_pred: 0.0493, mix_bin_pred: 0.0363 | Val Total: 0.0019
# Epoch 30/50 | Train Total: 0.0018, Recon: 0.0010, KL: 0.8133, bin_pred: 0.0487, mix_bin_pred: 0.0362 | Val Total: 0.0019
# Epoch 40/50 | Train Total: 0.0018, Recon: 0.0010, KL: 0.8014, bin_pred: 0.0483, mix_bin_pred: 0.0362 | Val Total: 0.0019
# Epoch 50/50 | Train Total: 0.0018, Recon: 0.0010, KL: 0.7965, bin_pred: 0.0475, mix_bin_pred: 0.0357 | Val Total: 0.0020
#
# --- SSLVE Step 36/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [308s elapsed, 0s remaining]]]
# Archive: 5844, Bins: 3044, Coverage: 0.3044, Fitness min/mean/max: -181.35/-9.14/105.41
# QD-score: 1561121.2380
# Epoch 10/50 | Train Total: 0.0017, Recon: 0.0009, KL: 0.8111, bin_pred: 0.0479, mix_bin_pred: 0.0358 | Val Total: 0.0018
# Epoch 20/50 | Train Total: 0.0017, Recon: 0.0009, KL: 0.7989, bin_pred: 0.0471, mix_bin_pred: 0.0360 | Val Total: 0.0018
# Epoch 30/50 | Train Total: 0.0017, Recon: 0.0009, KL: 0.7952, bin_pred: 0.0471, mix_bin_pred: 0.0352 | Val Total: 0.0019
# Epoch 40/50 | Train Total: 0.0017, Recon: 0.0009, KL: 0.7933, bin_pred: 0.0468, mix_bin_pred: 0.0346 | Val Total: 0.0019
# Epoch 50/50 | Train Total: 0.0017, Recon: 0.0009, KL: 0.7906, bin_pred: 0.0469, mix_bin_pred: 0.0348 | Val Total: 0.0019
#
# --- SSLVE Step 37/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [311s elapsed, 0s remaining]]]
# Archive: 5961, Bins: 3084, Coverage: 0.3084, Fitness min/mean/max: -181.35/-9.40/105.41
# QD-score: 1582744.4639
# Epoch 10/50 | Train Total: 0.0017, Recon: 0.0009, KL: 0.7793, bin_pred: 0.0485, mix_bin_pred: 0.0355 | Val Total: 0.0018
# Epoch 20/50 | Train Total: 0.0017, Recon: 0.0009, KL: 0.7803, bin_pred: 0.0477, mix_bin_pred: 0.0349 | Val Total: 0.0018
# Epoch 30/50 | Train Total: 0.0017, Recon: 0.0009, KL: 0.7855, bin_pred: 0.0483, mix_bin_pred: 0.0357 | Val Total: 0.0018
# Epoch 40/50 | Train Total: 0.0017, Recon: 0.0009, KL: 0.7730, bin_pred: 0.0470, mix_bin_pred: 0.0341 | Val Total: 0.0018
# Epoch 50/50 | Train Total: 0.0017, Recon: 0.0009, KL: 0.7763, bin_pred: 0.0472, mix_bin_pred: 0.0353 | Val Total: 0.0018
#
# --- SSLVE Step 38/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [306s elapsed, 0s remaining]]]
# Archive: 6098, Bins: 3137, Coverage: 0.3137, Fitness min/mean/max: -181.35/-9.58/105.41
# QD-score: 1610502.5980
# Epoch 10/50 | Train Total: 0.0016, Recon: 0.0009, KL: 0.7714, bin_pred: 0.0481, mix_bin_pred: 0.0359 | Val Total: 0.0017
# Epoch 20/50 | Train Total: 0.0016, Recon: 0.0009, KL: 0.7652, bin_pred: 0.0480, mix_bin_pred: 0.0353 | Val Total: 0.0018
# Epoch 30/50 | Train Total: 0.0016, Recon: 0.0009, KL: 0.7631, bin_pred: 0.0476, mix_bin_pred: 0.0351 | Val Total: 0.0018
# Epoch 40/50 | Train Total: 0.0016, Recon: 0.0009, KL: 0.7682, bin_pred: 0.0473, mix_bin_pred: 0.0357 | Val Total: 0.0018
# Epoch 50/50 | Train Total: 0.0016, Recon: 0.0009, KL: 0.7654, bin_pred: 0.0472, mix_bin_pred: 0.0347 | Val Total: 0.0018
#
# --- SSLVE Step 39/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [310s elapsed, 0s remaining]]]
# Archive: 6211, Bins: 3187, Coverage: 0.3187, Fitness min/mean/max: -181.35/-9.88/105.41
# QD-score: 1637271.5262
# Epoch 10/50 | Train Total: 0.0016, Recon: 0.0009, KL: 0.7665, bin_pred: 0.0475, mix_bin_pred: 0.0351 | Val Total: 0.0017
# Epoch 20/50 | Train Total: 0.0016, Recon: 0.0009, KL: 0.7563, bin_pred: 0.0467, mix_bin_pred: 0.0343 | Val Total: 0.0017
# Epoch 30/50 | Train Total: 0.0016, Recon: 0.0008, KL: 0.7600, bin_pred: 0.0474, mix_bin_pred: 0.0352 | Val Total: 0.0017
# Epoch 40/50 | Train Total: 0.0016, Recon: 0.0008, KL: 0.7675, bin_pred: 0.0469, mix_bin_pred: 0.0350 | Val Total: 0.0017
# Epoch 50/50 | Train Total: 0.0016, Recon: 0.0009, KL: 0.7435, bin_pred: 0.0471, mix_bin_pred: 0.0351 | Val Total: 0.0018
#
# --- SSLVE Step 40/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [313s elapsed, 0s remaining]]]
# Archive: 6334, Bins: 3238, Coverage: 0.3238, Fitness min/mean/max: -181.35/-10.11/105.41
# QD-score: 1664243.3209
# Epoch 10/50 | Train Total: 0.0016, Recon: 0.0008, KL: 0.7462, bin_pred: 0.0482, mix_bin_pred: 0.0355 | Val Total: 0.0017
# Epoch 20/50 | Train Total: 0.0016, Recon: 0.0008, KL: 0.7519, bin_pred: 0.0470, mix_bin_pred: 0.0355 | Val Total: 0.0017
# Epoch 30/50 | Train Total: 0.0016, Recon: 0.0008, KL: 0.7358, bin_pred: 0.0478, mix_bin_pred: 0.0358 | Val Total: 0.0017
# Epoch 40/50 | Train Total: 0.0016, Recon: 0.0008, KL: 0.7436, bin_pred: 0.0470, mix_bin_pred: 0.0352 | Val Total: 0.0017
# Epoch 50/50 | Train Total: 0.0016, Recon: 0.0008, KL: 0.7440, bin_pred: 0.0470, mix_bin_pred: 0.0353 | Val Total: 0.0017
#
# --- SSLVE Step 41/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [315s elapsed, 0s remaining]]]
# Archive: 6463, Bins: 3283, Coverage: 0.3283, Fitness min/mean/max: -181.35/-10.34/105.41
# QD-score: 1688166.4143
# Epoch 10/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7405, bin_pred: 0.0472, mix_bin_pred: 0.0353 | Val Total: 0.0016
# Epoch 20/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7370, bin_pred: 0.0474, mix_bin_pred: 0.0353 | Val Total: 0.0017
# Epoch 30/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7390, bin_pred: 0.0468, mix_bin_pred: 0.0348 | Val Total: 0.0017
# Epoch 40/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7317, bin_pred: 0.0468, mix_bin_pred: 0.0344 | Val Total: 0.0017
# Epoch 50/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7317, bin_pred: 0.0461, mix_bin_pred: 0.0338 | Val Total: 0.0017
#
# --- SSLVE Step 42/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [316s elapsed, 0s remaining]]]
# Archive: 6572, Bins: 3325, Coverage: 0.3325, Fitness min/mean/max: -181.35/-10.62/105.41
# QD-score: 1710705.8170
# Epoch 10/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7295, bin_pred: 0.0461, mix_bin_pred: 0.0337 | Val Total: 0.0016
# Epoch 20/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7220, bin_pred: 0.0463, mix_bin_pred: 0.0342 | Val Total: 0.0016
# Epoch 30/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7177, bin_pred: 0.0462, mix_bin_pred: 0.0345 | Val Total: 0.0016
# Epoch 40/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7194, bin_pred: 0.0462, mix_bin_pred: 0.0341 | Val Total: 0.0016
# Epoch 50/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7169, bin_pred: 0.0459, mix_bin_pred: 0.0339 | Val Total: 0.0016
#
# --- SSLVE Step 43/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [317s elapsed, 0s remaining]]]
# Archive: 6701, Bins: 3378, Coverage: 0.3378, Fitness min/mean/max: -183.94/-10.86/105.41
# QD-score: 1739103.8922
# Epoch 10/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7191, bin_pred: 0.0465, mix_bin_pred: 0.0343 | Val Total: 0.0016
# Epoch 20/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7094, bin_pred: 0.0464, mix_bin_pred: 0.0340 | Val Total: 0.0016
# Epoch 30/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7137, bin_pred: 0.0459, mix_bin_pred: 0.0342 | Val Total: 0.0016
# Epoch 40/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7117, bin_pred: 0.0457, mix_bin_pred: 0.0336 | Val Total: 0.0016
# Epoch 50/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7084, bin_pred: 0.0458, mix_bin_pred: 0.0339 | Val Total: 0.0016
#
# --- SSLVE Step 44/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [316s elapsed, 0s remaining]]]
# Archive: 6821, Bins: 3418, Coverage: 0.3418, Fitness min/mean/max: -183.94/-11.01/105.41
# QD-score: 1760410.8256
# Epoch 10/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.7059, bin_pred: 0.0464, mix_bin_pred: 0.0343 | Val Total: 0.0015
# Epoch 20/50 | Train Total: 0.0015, Recon: 0.0008, KL: 0.6999, bin_pred: 0.0463, mix_bin_pred: 0.0347 | Val Total: 0.0015
# Epoch 30/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.7010, bin_pred: 0.0466, mix_bin_pred: 0.0351 | Val Total: 0.0015
# Epoch 40/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6982, bin_pred: 0.0465, mix_bin_pred: 0.0348 | Val Total: 0.0016
# Epoch 50/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6990, bin_pred: 0.0460, mix_bin_pred: 0.0341 | Val Total: 0.0016
#
# --- SSLVE Step 45/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [314s elapsed, 0s remaining]]]
# Archive: 6952, Bins: 3462, Coverage: 0.3462, Fitness min/mean/max: -183.94/-11.24/105.41
# QD-score: 1784178.2079
# Epoch 10/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6960, bin_pred: 0.0468, mix_bin_pred: 0.0346 | Val Total: 0.0015
# Epoch 20/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6930, bin_pred: 0.0468, mix_bin_pred: 0.0344 | Val Total: 0.0015
# Epoch 30/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6909, bin_pred: 0.0464, mix_bin_pred: 0.0346 | Val Total: 0.0015
# Epoch 40/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6868, bin_pred: 0.0457, mix_bin_pred: 0.0341 | Val Total: 0.0015
# Epoch 50/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6955, bin_pred: 0.0461, mix_bin_pred: 0.0341 | Val Total: 0.0016
#
# --- SSLVE Step 46/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [311s elapsed, 0s remaining]]]
# Archive: 7088, Bins: 3517, Coverage: 0.3517, Fitness min/mean/max: -183.94/-11.43/105.41
# QD-score: 1813391.0021
# Epoch 10/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6919, bin_pred: 0.0468, mix_bin_pred: 0.0348 | Val Total: 0.0015
# Epoch 20/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6817, bin_pred: 0.0467, mix_bin_pred: 0.0342 | Val Total: 0.0015
# Epoch 30/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6776, bin_pred: 0.0466, mix_bin_pred: 0.0344 | Val Total: 0.0015
# Epoch 40/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6813, bin_pred: 0.0465, mix_bin_pred: 0.0351 | Val Total: 0.0015
# Epoch 50/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6744, bin_pred: 0.0461, mix_bin_pred: 0.0339 | Val Total: 0.0015
#
# --- SSLVE Step 47/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [314s elapsed, 0s remaining]]]
# Archive: 7202, Bins: 3553, Coverage: 0.3553, Fitness min/mean/max: -183.94/-11.68/105.41
# QD-score: 1833011.9124
# Epoch 10/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6744, bin_pred: 0.0464, mix_bin_pred: 0.0348 | Val Total: 0.0014
# Epoch 20/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6728, bin_pred: 0.0459, mix_bin_pred: 0.0340 | Val Total: 0.0015
# Epoch 30/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6691, bin_pred: 0.0465, mix_bin_pred: 0.0346 | Val Total: 0.0015
# Epoch 40/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6668, bin_pred: 0.0463, mix_bin_pred: 0.0339 | Val Total: 0.0015
# Epoch 50/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6687, bin_pred: 0.0463, mix_bin_pred: 0.0344 | Val Total: 0.0015
#
# --- SSLVE Step 48/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [320s elapsed, 0s remaining]]]
# Archive: 7302, Bins: 3593, Coverage: 0.3593, Fitness min/mean/max: -183.94/-11.89/105.41
# QD-score: 1854272.1074
# Epoch 10/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6615, bin_pred: 0.0462, mix_bin_pred: 0.0339 | Val Total: 0.0015
# Epoch 20/50 | Train Total: 0.0014, Recon: 0.0007, KL: 0.6586, bin_pred: 0.0469, mix_bin_pred: 0.0347 | Val Total: 0.0015
# Epoch 30/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6655, bin_pred: 0.0461, mix_bin_pred: 0.0341 | Val Total: 0.0015
# Epoch 40/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6613, bin_pred: 0.0453, mix_bin_pred: 0.0336 | Val Total: 0.0015
# Epoch 50/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6603, bin_pred: 0.0458, mix_bin_pred: 0.0337 | Val Total: 0.0015
#
# --- SSLVE Step 49/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [313s elapsed, 0s remaining]]]
# Archive: 7416, Bins: 3627, Coverage: 0.3627, Fitness min/mean/max: -183.94/-12.07/133.37
# QD-score: 1872768.2029
# Epoch 10/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6587, bin_pred: 0.0463, mix_bin_pred: 0.0341 | Val Total: 0.0013
# Epoch 20/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6574, bin_pred: 0.0465, mix_bin_pred: 0.0344 | Val Total: 0.0013
# Epoch 30/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6495, bin_pred: 0.0468, mix_bin_pred: 0.0354 | Val Total: 0.0014
# Epoch 40/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6527, bin_pred: 0.0466, mix_bin_pred: 0.0345 | Val Total: 0.0014
# Epoch 50/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6493, bin_pred: 0.0463, mix_bin_pred: 0.0337 | Val Total: 0.0014
#
# --- SSLVE Step 50/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [310s elapsed, 0s remaining]]]
# Archive: 7541, Bins: 3668, Coverage: 0.3668, Fitness min/mean/max: -183.94/-12.26/133.37
# QD-score: 1894811.9139
# Epoch 10/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6560, bin_pred: 0.0466, mix_bin_pred: 0.0347 | Val Total: 0.0013
# Epoch 20/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6510, bin_pred: 0.0465, mix_bin_pred: 0.0342 | Val Total: 0.0014
# Epoch 30/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6438, bin_pred: 0.0464, mix_bin_pred: 0.0344 | Val Total: 0.0013
# Epoch 40/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6468, bin_pred: 0.0467, mix_bin_pred: 0.0347 | Val Total: 0.0014
# Epoch 50/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6457, bin_pred: 0.0460, mix_bin_pred: 0.0337 | Val Total: 0.0014
#
# --- SSLVE Step 51/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 40/500 (8%), lve_mut: 385/500 (77%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [312s elapsed, 0s remaining]]]
# Archive: 7644, Bins: 3699, Coverage: 0.3699, Fitness min/mean/max: -183.94/-12.47/133.37
# QD-score: 1911720.5241
# Epoch 10/50 | Train Total: 0.0013, Recon: 0.0006, KL: 0.6437, bin_pred: 0.0462, mix_bin_pred: 0.0338 | Val Total: 0.0013
# Epoch 20/50 | Train Total: 0.0013, Recon: 0.0006, KL: 0.6427, bin_pred: 0.0465, mix_bin_pred: 0.0343 | Val Total: 0.0013
# Epoch 30/50 | Train Total: 0.0013, Recon: 0.0006, KL: 0.6436, bin_pred: 0.0460, mix_bin_pred: 0.0339 | Val Total: 0.0013
# Epoch 40/50 | Train Total: 0.0013, Recon: 0.0007, KL: 0.6257, bin_pred: 0.0467, mix_bin_pred: 0.0343 | Val Total: 0.0013
# Epoch 50/50 | Train Total: 0.0013, Recon: 0.0006, KL: 0.6374, bin_pred: 0.0464, mix_bin_pred: 0.0344 | Val Total: 0.0014
#
# --- SSLVE Step 52/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [307s elapsed, 0s remaining]]]
# Archive: 7748, Bins: 3731, Coverage: 0.3731, Fitness min/mean/max: -183.94/-12.70/133.37
# QD-score: 1929024.9486
# Epoch 10/50 | Train Total: 0.0013, Recon: 0.0006, KL: 0.6276, bin_pred: 0.0470, mix_bin_pred: 0.0348 | Val Total: 0.0013
# Epoch 20/50 | Train Total: 0.0013, Recon: 0.0006, KL: 0.6317, bin_pred: 0.0470, mix_bin_pred: 0.0351 | Val Total: 0.0013
# Epoch 30/50 | Train Total: 0.0013, Recon: 0.0006, KL: 0.6283, bin_pred: 0.0465, mix_bin_pred: 0.0347 | Val Total: 0.0013
# Epoch 40/50 | Train Total: 0.0013, Recon: 0.0006, KL: 0.6362, bin_pred: 0.0462, mix_bin_pred: 0.0344 | Val Total: 0.0013
# Epoch 50/50 | Train Total: 0.0013, Recon: 0.0006, KL: 0.6311, bin_pred: 0.0468, mix_bin_pred: 0.0345 | Val Total: 0.0013
#
# --- SSLVE Step 53/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [310s elapsed, 0s remaining]]]
# Archive: 7866, Bins: 3767, Coverage: 0.3767, Fitness min/mean/max: -183.94/-12.84/133.37
# QD-score: 1948319.1783
# Epoch 10/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6189, bin_pred: 0.0472, mix_bin_pred: 0.0343 | Val Total: 0.0013
# Epoch 20/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6249, bin_pred: 0.0470, mix_bin_pred: 0.0343 | Val Total: 0.0013
# Epoch 30/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6269, bin_pred: 0.0468, mix_bin_pred: 0.0352 | Val Total: 0.0013
# Epoch 40/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6168, bin_pred: 0.0473, mix_bin_pred: 0.0350 | Val Total: 0.0013
# Epoch 50/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6212, bin_pred: 0.0469, mix_bin_pred: 0.0344 | Val Total: 0.0013
#
# --- SSLVE Step 54/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [311s elapsed, 0s remaining]]]
# Archive: 7967, Bins: 3805, Coverage: 0.3805, Fitness min/mean/max: -183.94/-13.04/133.37
# QD-score: 1968646.3970
# Epoch 10/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6132, bin_pred: 0.0474, mix_bin_pred: 0.0352 | Val Total: 0.0013
# Epoch 20/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6146, bin_pred: 0.0471, mix_bin_pred: 0.0350 | Val Total: 0.0013
# Epoch 30/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6131, bin_pred: 0.0474, mix_bin_pred: 0.0352 | Val Total: 0.0013
# Epoch 40/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6076, bin_pred: 0.0475, mix_bin_pred: 0.0351 | Val Total: 0.0013
# Epoch 50/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6121, bin_pred: 0.0467, mix_bin_pred: 0.0345 | Val Total: 0.0013
#
# --- SSLVE Step 55/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [321s elapsed, 0s remaining]]]
# Archive: 8072, Bins: 3844, Coverage: 0.3844, Fitness min/mean/max: -183.94/-13.27/133.37
# QD-score: 1989548.8725
# Epoch 10/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6024, bin_pred: 0.0476, mix_bin_pred: 0.0358 | Val Total: 0.0013
# Epoch 20/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6074, bin_pred: 0.0474, mix_bin_pred: 0.0349 | Val Total: 0.0013
# Epoch 30/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6069, bin_pred: 0.0475, mix_bin_pred: 0.0355 | Val Total: 0.0013
# Epoch 40/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5983, bin_pred: 0.0474, mix_bin_pred: 0.0351 | Val Total: 0.0013
# Epoch 50/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6025, bin_pred: 0.0473, mix_bin_pred: 0.0351 | Val Total: 0.0013
#
# --- SSLVE Step 56/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 33/500 (7%), lve_mut: 392/500 (78%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [323s elapsed, 0s remaining]]]
# Archive: 8164, Bins: 3876, Coverage: 0.3876, Fitness min/mean/max: -183.94/-13.53/133.37
# QD-score: 2007265.6353
# Epoch 10/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.6015, bin_pred: 0.0472, mix_bin_pred: 0.0353 | Val Total: 0.0013
# Epoch 20/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5930, bin_pred: 0.0473, mix_bin_pred: 0.0355 | Val Total: 0.0013
# Epoch 30/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5973, bin_pred: 0.0474, mix_bin_pred: 0.0348 | Val Total: 0.0013
# Epoch 40/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5905, bin_pred: 0.0475, mix_bin_pred: 0.0353 | Val Total: 0.0013
# Epoch 50/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5989, bin_pred: 0.0466, mix_bin_pred: 0.0344 | Val Total: 0.0013
#
# --- SSLVE Step 57/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 52/500 (10%), lve_mut: 373/500 (75%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [326s elapsed, 0s remaining]]]
# Archive: 8268, Bins: 3913, Coverage: 0.3913, Fitness min/mean/max: -183.94/-13.70/133.37
# QD-score: 2027155.9613
# Epoch 10/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5867, bin_pred: 0.0477, mix_bin_pred: 0.0349 | Val Total: 0.0012
# Epoch 20/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5854, bin_pred: 0.0474, mix_bin_pred: 0.0355 | Val Total: 0.0012
# Epoch 30/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5874, bin_pred: 0.0472, mix_bin_pred: 0.0345 | Val Total: 0.0013
# Epoch 40/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5865, bin_pred: 0.0475, mix_bin_pred: 0.0350 | Val Total: 0.0013
# Epoch 50/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5870, bin_pred: 0.0472, mix_bin_pred: 0.0353 | Val Total: 0.0013
#
# --- SSLVE Step 58/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 36/500 (7%), lve_mut: 389/500 (78%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [325s elapsed, 0s remaining]]]
# Archive: 8360, Bins: 3947, Coverage: 0.3947, Fitness min/mean/max: -183.94/-13.94/133.37
# QD-score: 2046028.5691
# Epoch 10/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5872, bin_pred: 0.0480, mix_bin_pred: 0.0353 | Val Total: 0.0012
# Epoch 20/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5927, bin_pred: 0.0474, mix_bin_pred: 0.0349 | Val Total: 0.0012
# Epoch 30/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5830, bin_pred: 0.0478, mix_bin_pred: 0.0357 | Val Total: 0.0012
# Epoch 40/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5889, bin_pred: 0.0473, mix_bin_pred: 0.0352 | Val Total: 0.0013
# Epoch 50/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5870, bin_pred: 0.0472, mix_bin_pred: 0.0345 | Val Total: 0.0013
#
# --- SSLVE Step 59/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 81/500 (16%), lve_mut: 344/500 (69%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [331s elapsed, 0s remaining]]]
# Archive: 8457, Bins: 3987, Coverage: 0.3987, Fitness min/mean/max: -185.43/-14.15/133.37
# QD-score: 2067817.7194
# Epoch 10/50 | Train Total: 0.0011, Recon: 0.0006, KL: 0.5810, bin_pred: 0.0472, mix_bin_pred: 0.0353 | Val Total: 0.0012
# Epoch 20/50 | Train Total: 0.0011, Recon: 0.0006, KL: 0.5804, bin_pred: 0.0475, mix_bin_pred: 0.0354 | Val Total: 0.0012
# Epoch 30/50 | Train Total: 0.0012, Recon: 0.0006, KL: 0.5779, bin_pred: 0.0477, mix_bin_pred: 0.0346 | Val Total: 0.0012
# Epoch 40/50 | Train Total: 0.0011, Recon: 0.0006, KL: 0.5797, bin_pred: 0.0471, mix_bin_pred: 0.0352 | Val Total: 0.0012
# Epoch 50/50 | Train Total: 0.0011, Recon: 0.0006, KL: 0.5701, bin_pred: 0.0474, mix_bin_pred: 0.0351 | Val Total: 0.0012
#
# --- SSLVE Step 60/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 32/500 (6%), lve_mut: 393/500 (79%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 148/500 [91s elapsed, 215s remaining]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Collecting: 500/500 [341s elapsed, 0s remaining]]
# Archive: 12826, Bins: 5304, Coverage: 0.5304, Fitness min/mean/max: -285.55/-23.30/102.90
# QD-score: 2802645.7576
# Epoch 10/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4408, bin_pred: 0.0482, mix_bin_pred: 0.0357 | Val Total: 0.0008
# Epoch 20/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4443, bin_pred: 0.0481, mix_bin_pred: 0.0353 | Val Total: 0.0008
# Epoch 30/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4439, bin_pred: 0.0482, mix_bin_pred: 0.0355 | Val Total: 0.0008
# Epoch 40/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4470, bin_pred: 0.0479, mix_bin_pred: 0.0354 | Val Total: 0.0008
# Epoch 50/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4491, bin_pred: 0.0474, mix_bin_pred: 0.0348 | Val Total: 0.0008
#
# --- SSLVE Step 116/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [339s elapsed, 0s remaining]]]
# Archive: 12890, Bins: 5328, Coverage: 0.5328, Fitness min/mean/max: -285.55/-23.45/102.90
# QD-score: 2816115.4993
# Epoch 10/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4409, bin_pred: 0.0483, mix_bin_pred: 0.0356 | Val Total: 0.0008
# Epoch 20/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4461, bin_pred: 0.0480, mix_bin_pred: 0.0355 | Val Total: 0.0008
# Epoch 30/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4444, bin_pred: 0.0480, mix_bin_pred: 0.0357 | Val Total: 0.0008
# Epoch 40/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4449, bin_pred: 0.0476, mix_bin_pred: 0.0353 | Val Total: 0.0008
# Epoch 50/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4442, bin_pred: 0.0486, mix_bin_pred: 0.0358 | Val Total: 0.0008
#
# --- SSLVE Step 117/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [344s elapsed, 0s remaining]]]
# Archive: 12943, Bins: 5341, Coverage: 0.5341, Fitness min/mean/max: -285.55/-23.59/102.90
# QD-score: 2823784.7251
# Epoch 10/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4372, bin_pred: 0.0480, mix_bin_pred: 0.0358 | Val Total: 0.0008
# Epoch 20/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4381, bin_pred: 0.0477, mix_bin_pred: 0.0353 | Val Total: 0.0008
# Epoch 30/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4406, bin_pred: 0.0477, mix_bin_pred: 0.0354 | Val Total: 0.0008
# Epoch 40/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4450, bin_pred: 0.0476, mix_bin_pred: 0.0356 | Val Total: 0.0008
# Epoch 50/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4373, bin_pred: 0.0479, mix_bin_pred: 0.0357 | Val Total: 0.0008
#
# --- SSLVE Step 118/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [341s elapsed, 0s remaining]]]
# Archive: 13001, Bins: 5352, Coverage: 0.5352, Fitness min/mean/max: -285.55/-23.75/102.90
# QD-score: 2830991.1117
# Epoch 10/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4405, bin_pred: 0.0480, mix_bin_pred: 0.0358 | Val Total: 0.0008
# Epoch 20/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4462, bin_pred: 0.0480, mix_bin_pred: 0.0358 | Val Total: 0.0008
# Epoch 30/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4444, bin_pred: 0.0479, mix_bin_pred: 0.0356 | Val Total: 0.0008
# Epoch 40/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4356, bin_pred: 0.0479, mix_bin_pred: 0.0355 | Val Total: 0.0008
# Epoch 50/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4393, bin_pred: 0.0476, mix_bin_pred: 0.0356 | Val Total: 0.0008
#
# --- SSLVE Step 119/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [329s elapsed, 0s remaining]]]
# Archive: 13055, Bins: 5366, Coverage: 0.5366, Fitness min/mean/max: -285.55/-23.88/102.90
# QD-score: 2839011.5153
# Epoch 10/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4403, bin_pred: 0.0478, mix_bin_pred: 0.0355 | Val Total: 0.0008
# Epoch 20/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4376, bin_pred: 0.0479, mix_bin_pred: 0.0357 | Val Total: 0.0008
# Epoch 30/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4409, bin_pred: 0.0475, mix_bin_pred: 0.0354 | Val Total: 0.0008
# Epoch 40/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4426, bin_pred: 0.0477, mix_bin_pred: 0.0355 | Val Total: 0.0008
# Epoch 50/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4386, bin_pred: 0.0477, mix_bin_pred: 0.0353 | Val Total: 0.0008
#
# --- SSLVE Step 120/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [321s elapsed, 0s remaining]]]
# Archive: 13117, Bins: 5385, Coverage: 0.5385, Fitness min/mean/max: -285.55/-23.98/102.90
# QD-score: 2849499.4638
# Epoch 10/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4358, bin_pred: 0.0477, mix_bin_pred: 0.0353 | Val Total: 0.0008
# Epoch 20/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4401, bin_pred: 0.0478, mix_bin_pred: 0.0355 | Val Total: 0.0008
# Epoch 30/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4364, bin_pred: 0.0476, mix_bin_pred: 0.0353 | Val Total: 0.0008
# Epoch 40/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4436, bin_pred: 0.0479, mix_bin_pred: 0.0360 | Val Total: 0.0008
# Epoch 50/50 | Train Total: 0.0008, Recon: 0.0003, KL: 0.4410, bin_pred: 0.0479, mix_bin_pred: 0.0358 | Val Total: 0.0008
#
# --- SSLVE Step 121/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [321s elapsed, 0s remaining]]]
# Archive: 13167, Bins: 5403, Coverage: 0.5403, Fitness min/mean/max: -285.55/-24.07/102.90
# QD-score: 2859375.6093
# Epoch 10/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4378, bin_pred: 0.0478, mix_bin_pred: 0.0353 | Val Total: 0.0008
# Epoch 20/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4354, bin_pred: 0.0476, mix_bin_pred: 0.0356 | Val Total: 0.0008
# Epoch 30/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4392, bin_pred: 0.0477, mix_bin_pred: 0.0354 | Val Total: 0.0008
# Epoch 40/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4367, bin_pred: 0.0472, mix_bin_pred: 0.0348 | Val Total: 0.0008
# Epoch 50/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4380, bin_pred: 0.0472, mix_bin_pred: 0.0354 | Val Total: 0.0008
#
# --- SSLVE Step 122/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 25/500 (5%), lve_mut: 400/500 (80%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [328s elapsed, 0s remaining]]]
# Archive: 13216, Bins: 5415, Coverage: 0.5415, Fitness min/mean/max: -285.55/-24.21/102.90
# QD-score: 2866614.6868
# Epoch 10/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4382, bin_pred: 0.0479, mix_bin_pred: 0.0352 | Val Total: 0.0007
# Epoch 20/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4405, bin_pred: 0.0475, mix_bin_pred: 0.0351 | Val Total: 0.0007
# Epoch 30/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4380, bin_pred: 0.0479, mix_bin_pred: 0.0356 | Val Total: 0.0008
# Epoch 40/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4339, bin_pred: 0.0479, mix_bin_pred: 0.0355 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4354, bin_pred: 0.0476, mix_bin_pred: 0.0352 | Val Total: 0.0008
#
# --- SSLVE Step 123/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 60/500 (12%), lve_mut: 365/500 (73%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [333s elapsed, 0s remaining]]]
# Archive: 13268, Bins: 5426, Coverage: 0.5426, Fitness min/mean/max: -285.55/-24.35/102.90
# QD-score: 2873163.2470
# Epoch 10/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4292, bin_pred: 0.0477, mix_bin_pred: 0.0352 | Val Total: 0.0008
# Epoch 20/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4314, bin_pred: 0.0478, mix_bin_pred: 0.0354 | Val Total: 0.0008
# Epoch 30/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4311, bin_pred: 0.0480, mix_bin_pred: 0.0357 | Val Total: 0.0008
# Epoch 40/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4397, bin_pred: 0.0476, mix_bin_pred: 0.0355 | Val Total: 0.0008
# ...
# Collecting: 500/500 [357s elapsed, 0s remaining]]]
# Archive: 15518, Bins: 5946, Coverage: 0.5946, Fitness min/mean/max: -285.55/-30.28/102.90
# QD-score: 3185356.7445
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3970, bin_pred: 0.0466, mix_bin_pred: 0.0345 | Val Total: 0.0007
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0003, KL: 0.3965, bin_pred: 0.0467, mix_bin_pred: 0.0348 | Val Total: 0.0007
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0003, KL: 0.3967, bin_pred: 0.0467, mix_bin_pred: 0.0341 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3970, bin_pred: 0.0468, mix_bin_pred: 0.0345 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0003, KL: 0.3967, bin_pred: 0.0467, mix_bin_pred: 0.0344 | Val Total: 0.0007
#
# --- SSLVE Step 185/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 155/500 (31%), lve_mut: 270/500 (54%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [366s elapsed, 0s remaining]]]
# Archive: 15534, Bins: 5949, Coverage: 0.5949, Fitness min/mean/max: -285.55/-30.39/102.90
# QD-score: 3187501.5001
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3961, bin_pred: 0.0469, mix_bin_pred: 0.0349 | Val Total: 0.0006
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0003, KL: 0.3989, bin_pred: 0.0467, mix_bin_pred: 0.0348 | Val Total: 0.0007
# Epoch 30/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4020, bin_pred: 0.0464, mix_bin_pred: 0.0344 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4006, bin_pred: 0.0465, mix_bin_pred: 0.0343 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0003, KL: 0.3971, bin_pred: 0.0464, mix_bin_pred: 0.0349 | Val Total: 0.0007
#
# --- SSLVE Step 186/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 133/500 (27%), lve_mut: 292/500 (58%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [367s elapsed, 0s remaining]]]
# Archive: 15567, Bins: 5955, Coverage: 0.5955, Fitness min/mean/max: -285.55/-30.44/102.90
# QD-score: 3191055.1190
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0003, KL: 0.3975, bin_pred: 0.0469, mix_bin_pred: 0.0347 | Val Total: 0.0007
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3993, bin_pred: 0.0472, mix_bin_pred: 0.0349 | Val Total: 0.0007
# Epoch 30/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.3987, bin_pred: 0.0468, mix_bin_pred: 0.0349 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0003, KL: 0.3994, bin_pred: 0.0468, mix_bin_pred: 0.0351 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.3999, bin_pred: 0.0467, mix_bin_pred: 0.0344 | Val Total: 0.0007
#
# --- SSLVE Step 187/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 90/500 (18%), lve_mut: 335/500 (67%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [363s elapsed, 0s remaining]]]
# Archive: 15589, Bins: 5960, Coverage: 0.5960, Fitness min/mean/max: -285.55/-30.54/102.90
# QD-score: 3194262.0096
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3946, bin_pred: 0.0469, mix_bin_pred: 0.0349 | Val Total: 0.0007
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3939, bin_pred: 0.0467, mix_bin_pred: 0.0345 | Val Total: 0.0007
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3986, bin_pred: 0.0466, mix_bin_pred: 0.0347 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3954, bin_pred: 0.0466, mix_bin_pred: 0.0348 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.3955, bin_pred: 0.0469, mix_bin_pred: 0.0346 | Val Total: 0.0007
#
# --- SSLVE Step 188/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 105/500 (21%), lve_mut: 320/500 (64%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [360s elapsed, 0s remaining]]]
# Archive: 15619, Bins: 5967, Coverage: 0.5967, Fitness min/mean/max: -285.55/-30.63/102.90
# QD-score: 3198367.0450
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3993, bin_pred: 0.0464, mix_bin_pred: 0.0345 | Val Total: 0.0006
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3981, bin_pred: 0.0463, mix_bin_pred: 0.0343 | Val Total: 0.0006
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3981, bin_pred: 0.0465, mix_bin_pred: 0.0346 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3962, bin_pred: 0.0465, mix_bin_pred: 0.0343 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0003, KL: 0.3960, bin_pred: 0.0463, mix_bin_pred: 0.0344 | Val Total: 0.0006
#
# --- SSLVE Step 189/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 82/500 (16%), lve_mut: 343/500 (69%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [350s elapsed, 0s remaining]]]
# Archive: 15656, Bins: 5977, Coverage: 0.5977, Fitness min/mean/max: -285.55/-30.70/102.90
# QD-score: 3204286.9490
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3958, bin_pred: 0.0466, mix_bin_pred: 0.0345 | Val Total: 0.0007
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3960, bin_pred: 0.0468, mix_bin_pred: 0.0347 | Val Total: 0.0007
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3960, bin_pred: 0.0469, mix_bin_pred: 0.0345 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0007, Recon: 0.0003, KL: 0.4002, bin_pred: 0.0463, mix_bin_pred: 0.0340 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3970, bin_pred: 0.0470, mix_bin_pred: 0.0346 | Val Total: 0.0007
#
# --- SSLVE Step 190/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 58/500 (12%), lve_mut: 367/500 (73%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [341s elapsed, 0s remaining]]]
# Archive: 15689, Bins: 5989, Coverage: 0.5989, Fitness min/mean/max: -285.55/-30.79/102.90
# QD-score: 3211178.8569
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3963, bin_pred: 0.0467, mix_bin_pred: 0.0345 | Val Total: 0.0007
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3987, bin_pred: 0.0464, mix_bin_pred: 0.0342 | Val Total: 0.0007
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3933, bin_pred: 0.0466, mix_bin_pred: 0.0345 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3986, bin_pred: 0.0466, mix_bin_pred: 0.0349 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3972, bin_pred: 0.0462, mix_bin_pred: 0.0345 | Val Total: 0.0007
#
# --- SSLVE Step 191/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 89/500 (18%), lve_mut: 336/500 (67%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [334s elapsed, 0s remaining]]]
# Archive: 15715, Bins: 5998, Coverage: 0.5998, Fitness min/mean/max: -285.55/-30.87/102.90
# QD-score: 3216580.4266
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3961, bin_pred: 0.0466, mix_bin_pred: 0.0346 | Val Total: 0.0007
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3922, bin_pred: 0.0465, mix_bin_pred: 0.0343 | Val Total: 0.0007
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3971, bin_pred: 0.0469, mix_bin_pred: 0.0347 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3945, bin_pred: 0.0462, mix_bin_pred: 0.0344 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.4012, bin_pred: 0.0462, mix_bin_pred: 0.0338 | Val Total: 0.0007
#
# --- SSLVE Step 192/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 83/500 (17%), lve_mut: 333/500 (67%), lve_cross: 34/500 (7%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [313s elapsed, 0s remaining]]]
# Archive: 15739, Bins: 6005, Coverage: 0.6005, Fitness min/mean/max: -285.55/-30.94/102.90
# QD-score: 3220707.8559
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3938, bin_pred: 0.0469, mix_bin_pred: 0.0349 | Val Total: 0.0007
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3935, bin_pred: 0.0466, mix_bin_pred: 0.0345 | Val Total: 0.0007
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3951, bin_pred: 0.0464, mix_bin_pred: 0.0344 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3997, bin_pred: 0.0462, mix_bin_pred: 0.0343 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3941, bin_pred: 0.0467, mix_bin_pred: 0.0347 | Val Total: 0.0007
#
# --- SSLVE Step 193/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 68/500 (14%), lve_mut: 352/500 (70%), lve_cross: 30/500 (6%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [309s elapsed, 0s remaining]]]
# Archive: 15766, Bins: 6014, Coverage: 0.6014, Fitness min/mean/max: -285.55/-31.04/102.90
# QD-score: 3226128.9217
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3956, bin_pred: 0.0466, mix_bin_pred: 0.0341 | Val Total: 0.0007
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3914, bin_pred: 0.0464, mix_bin_pred: 0.0345 | Val Total: 0.0006
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3931, bin_pred: 0.0463, mix_bin_pred: 0.0343 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3866, bin_pred: 0.0466, mix_bin_pred: 0.0345 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3972, bin_pred: 0.0463, mix_bin_pred: 0.0341 | Val Total: 0.0007
#
# --- SSLVE Step 194/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 60/500 (12%), lve_mut: 364/500 (73%), lve_cross: 26/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [309s elapsed, 0s remaining]]]
# Archive: 15790, Bins: 6020, Coverage: 0.6020, Fitness min/mean/max: -285.55/-31.14/102.90
# QD-score: 3229927.4512
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3943, bin_pred: 0.0464, mix_bin_pred: 0.0346 | Val Total: 0.0006
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3922, bin_pred: 0.0467, mix_bin_pred: 0.0344 | Val Total: 0.0007
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3944, bin_pred: 0.0467, mix_bin_pred: 0.0346 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3942, bin_pred: 0.0467, mix_bin_pred: 0.0348 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3941, bin_pred: 0.0466, mix_bin_pred: 0.0347 | Val Total: 0.0007
#
# --- SSLVE Step 195/200 ---
#   Operator ratio - pse_mut: 25/500 (5%), pse_line: 70/500 (14%), lve_mut: 355/500 (71%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [305s elapsed, 0s remaining]]]
# Archive: 15814, Bins: 6025, Coverage: 0.6025, Fitness min/mean/max: -285.55/-31.24/102.90
# QD-score: 3233190.2089
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3933, bin_pred: 0.0464, mix_bin_pred: 0.0347 | Val Total: 0.0006
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3980, bin_pred: 0.0464, mix_bin_pred: 0.0343 | Val Total: 0.0006
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3933, bin_pred: 0.0473, mix_bin_pred: 0.0351 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3903, bin_pred: 0.0475, mix_bin_pred: 0.0351 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3953, bin_pred: 0.0461, mix_bin_pred: 0.0340 | Val Total: 0.0007
#
# --- SSLVE Step 196/200 ---
#   Operator ratio - pse_mut: 34/500 (7%), pse_line: 67/500 (13%), lve_mut: 349/500 (70%), lve_cross: 25/500 (5%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [318s elapsed, 0s remaining]]]
# Archive: 15833, Bins: 6030, Coverage: 0.6030, Fitness min/mean/max: -285.55/-31.33/102.90
# QD-score: 3236463.0313
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3941, bin_pred: 0.0466, mix_bin_pred: 0.0345 | Val Total: 0.0006
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3924, bin_pred: 0.0465, mix_bin_pred: 0.0342 | Val Total: 0.0006
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3949, bin_pred: 0.0465, mix_bin_pred: 0.0343 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3961, bin_pred: 0.0468, mix_bin_pred: 0.0344 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3905, bin_pred: 0.0470, mix_bin_pred: 0.0346 | Val Total: 0.0006
#
# --- SSLVE Step 197/200 ---
#   Operator ratio - pse_mut: 32/500 (6%), pse_line: 59/500 (12%), lve_mut: 351/500 (70%), lve_cross: 33/500 (7%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [310s elapsed, 0s remaining]]]
# Archive: 15851, Bins: 6036, Coverage: 0.6036, Fitness min/mean/max: -285.55/-31.42/102.90
# QD-score: 3240085.0279
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3930, bin_pred: 0.0465, mix_bin_pred: 0.0345 | Val Total: 0.0006
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3921, bin_pred: 0.0467, mix_bin_pred: 0.0348 | Val Total: 0.0006
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3945, bin_pred: 0.0468, mix_bin_pred: 0.0344 | Val Total: 0.0007
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3942, bin_pred: 0.0467, mix_bin_pred: 0.0344 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3962, bin_pred: 0.0466, mix_bin_pred: 0.0346 | Val Total: 0.0007
#
# --- SSLVE Step 198/200 ---
#   Operator ratio - pse_mut: 57/500 (11%), pse_line: 53/500 (11%), lve_mut: 325/500 (65%), lve_cross: 40/500 (8%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [307s elapsed, 0s remaining]]]
# Archive: 15876, Bins: 6041, Coverage: 0.6041, Fitness min/mean/max: -285.55/-31.49/102.90
# QD-score: 3243198.8743
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3940, bin_pred: 0.0462, mix_bin_pred: 0.0341 | Val Total: 0.0006
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3891, bin_pred: 0.0464, mix_bin_pred: 0.0340 | Val Total: 0.0006
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3913, bin_pred: 0.0471, mix_bin_pred: 0.0351 | Val Total: 0.0006
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3956, bin_pred: 0.0466, mix_bin_pred: 0.0348 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3937, bin_pred: 0.0466, mix_bin_pred: 0.0346 | Val Total: 0.0006
#
# --- SSLVE Step 199/200 ---
#   Operator ratio - pse_mut: 41/500 (8%), pse_line: 43/500 (9%), lve_mut: 331/500 (66%), lve_cross: 60/500 (12%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [309s elapsed, 0s remaining]]]
# Archive: 15903, Bins: 6051, Coverage: 0.6051, Fitness min/mean/max: -285.55/-31.58/100.35
# QD-score: 3249070.6847
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3903, bin_pred: 0.0471, mix_bin_pred: 0.0346 | Val Total: 0.0006
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3920, bin_pred: 0.0466, mix_bin_pred: 0.0342 | Val Total: 0.0006
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3878, bin_pred: 0.0466, mix_bin_pred: 0.0346 | Val Total: 0.0006
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3913, bin_pred: 0.0469, mix_bin_pred: 0.0349 | Val Total: 0.0006
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3936, bin_pred: 0.0460, mix_bin_pred: 0.0343 | Val Total: 0.0006
#
# --- SSLVE Step 200/200 ---
#   Operator ratio - pse_mut: 31/500 (6%), pse_line: 43/500 (9%), lve_mut: 356/500 (71%), lve_cross: 45/500 (9%), std_support_lve: 25/500 (5%)
# Collecting: 500/500 [308s elapsed, 0s remaining]]]
# Archive: 15935, Bins: 6060, Coverage: 0.6060, Fitness min/mean/max: -285.55/-31.68/100.35
# QD-score: 3254382.5885
# Epoch 10/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3888, bin_pred: 0.0466, mix_bin_pred: 0.0344 | Val Total: 0.0006
# Epoch 20/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3950, bin_pred: 0.0468, mix_bin_pred: 0.0344 | Val Total: 0.0006
# Epoch 30/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3879, bin_pred: 0.0467, mix_bin_pred: 0.0347 | Val Total: 0.0006
# Epoch 40/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3898, bin_pred: 0.0470, mix_bin_pred: 0.0350 | Val Total: 0.0007
# Epoch 50/50 | Train Total: 0.0006, Recon: 0.0002, KL: 0.3931, bin_pred: 0.0471, mix_bin_pred: 0.0350 | Val Total: 0.0006
#
# Final archive size: 15935
# Final coverage: 0.6060
# Best fitness: -285.5459
# QD-score: 3254382.5885

# %%
save_dir = './archive/'

run_dir = save_dir + 'LVE-Proposed_seed42/'
os.makedirs(run_dir, exist_ok=True)

save_checkpoint(run_dir, bm, orchestrator.history, sp=sp, lm=lm)
