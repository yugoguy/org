# %% [markdown]
# # MAP-Elite (Gaussian Mutation) — Baseline
#
# **Method:** MAP-Elites with PSE Gaussian Mutation only (`PSEMut`)
# **Seeds:** 2 (42, 123)
# **Task:** Ant-v5 Unidirectional Gait (4D Gait BD, 10×10×10×10 = 10000 bins)
# **Budget:** N_TOTAL × N_STEPS = 1e5

# %%
# ============================================================
# Cell 1: Setup — mount Drive, clone repo, load SSLVE modules
# Run this cell once at the start of each Colab session.
# ============================================================
from google.colab import drive
drive.mount('/content/drive')

# !rm -rf org && git clone --filter=blob:none --sparse https://github.com/yugoguy/org.git
# !cd org && git sparse-checkout set dev/SSLVE && git checkout Latent-Variable-Evolution
# !pip install cma gymnasium[mujoco] -q

import sys, os, glob
sys.path.insert(0, 'org/dev/SSLVE')
for f in sorted(glob.glob('org/dev/SSLVE/*.py')):
    # %run {f}

print('Setup complete.')
# Out:
# Mounted at /content/drive
# Cloning into 'org'...
# remote: Enumerating objects: 1903, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (185/185), done.
# remote: Total 1903 (delta 144), reused 34 (delta 34), pack-reused 1681 (from 1)
# Receiving objects: 100% (1903/1903), 531.72 KiB | 11.56 MiB/s, done.
# Resolving deltas: 100% (803/803), done.
# remote: Enumerating objects: 1, done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 1 (from 1)
# Receiving objects: 100% (1/1), 255 bytes | 255.00 KiB/s, done.
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 18 (delta 5), reused 1 (delta 1), pack-reused 6 (from 1)
# Receiving objects: 100% (18/18), 72.87 KiB | 4.86 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Branch 'Latent-Variable-Evolution' set up to track remote branch 'Latent-Variable-Evolution' from 'origin'.
# Switched to a new branch 'Latent-Variable-Evolution'
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 92.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 12.3 MB/s eta 0:00:00
# Setup complete.

# %%
# ============================================================
# Cell 2: Method Hyperparameters
# ============================================================
import numpy as np
import random
import torch

# --- Architecture ---
ARCHITECTURE     = [27, 64, 64, 8]  #@param
OUTPUT_ACTIVATION = 'tanh'  #@param {type:"string"}
MAX_STEPS        = 500   #@param {type:"integer"}
N_EPISODES       = 3     #@param {type:"integer"}
CTRL_COST_WEIGHT = 0.5   #@param {type:"number"}

# --- Gait BD Grid ---
BIN_SIZES        = [10, 10, 10, 10]  #@param

# --- Fitness ---
TOP_K            = 1     #@param {type:"integer"}
MAX_FITNESS      = 500.0 #@param {type:"number"}
GREEDY_MEM       = True  #@param {type:"boolean"}

# --- Mutation sigma ---
PSE_MUT_SIGMA    = 0.05  #@param {type:"number"}

# --- Search budget ---
N_TOTAL          = 500   #@param {type:"integer"}
N_STEPS          = 200   #@param {type:"integer"}

# --- Checkpoint base directory (saved to Google Drive) ---
CKPT_BASE_DIR    = '/content/drive/MyDrive/shared_ckpts/ant_gait/Ant_MAPElite_GaussianMut/'  #@param {type:"string"}

print(f'Method: MAP-Elite (Gaussian Mutation)')
print(f'Architecture: {ARCHITECTURE}, Output: {OUTPUT_ACTIVATION}')
print(f'Gait BD: {BIN_SIZES} ({np.prod(BIN_SIZES)} bins)')
print(f'PSE_MUT_SIGMA={PSE_MUT_SIGMA}, N_TOTAL={N_TOTAL}, N_STEPS={N_STEPS}')
print(f'Checkpoints will be saved to: {CKPT_BASE_DIR}')
# Out:
# Method: MAP-Elite (Gaussian Mutation)
# Architecture: [27, 64, 64, 8], Output: tanh
# Gait BD: [10, 10, 10, 10] (10000 bins)
# PSE_MUT_SIGMA=0.05, N_TOTAL=500, N_STEPS=200
# Checkpoints will be saved to: /content/drive/MyDrive/shared_ckpts/ant_gait/Ant_MAPElite_GaussianMut/

# %%
# ============================================================
# Cell 3: Run All Experiments (2 seeds)
# Each run saves a checkpoint + plots immediately after finishing.
# ============================================================

SEEDS = [42, 123]

fitness_fn = lambda info: -info['forward_sum']

all_results = []

weight_dim = MLP_Agent(ARCHITECTURE, output_activation=OUTPUT_ACTIVATION).get_weight_dim()
print(f'Weight dim: {weight_dim}')

for seed in SEEDS:
    print(f'\n========== seed={seed} ==========')

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    collector = AntOmniCollector(
        max_steps=MAX_STEPS,
        n_episodes=N_EPISODES,
        ctrl_cost_weight=CTRL_COST_WEIGHT,
        seed=seed,
    )
    bd = AntGaitBD(bin_sizes=BIN_SIZES)
    bm = MAPElitesBM(behavior_descriptor=bd, fitness_fn=fitness_fn, top_k=TOP_K, max_fitness=MAX_FITNESS)

    sp = BoltzmannMix(
        agent_class=MLP_Agent,
        architecture=ARCHITECTURE,
        agent_kwargs={'output_activation': OUTPUT_ACTIVATION},
        operators=[PSEMut(sigma=PSE_MUT_SIGMA, greedy_mem=GREEDY_MEM)],
        n_total=N_TOTAL,
        warmup_threshold=999999,
    )

    me = MAPElite(search_phase=sp, collector=collector, behavior_matching=bm)
    me.run(n_steps=N_STEPS)

    # Save checkpoint immediately after this run
    ckpt_path = os.path.join(
        CKPT_BASE_DIR,
        f'MAPElite_Gauss_sigma{PSE_MUT_SIGMA}_seed{seed}/'
    )
    save_checkpoint(ckpt_path, bm, me.history, sp=sp)
    print(f'Checkpoint saved: {ckpt_path}')

    # Save plots into checkpoint folder
    me.plot_history(save_path=ckpt_path + 'plot_history.png')
    sp.plot_allocation(save_path=ckpt_path + 'plot_allocation.png')
    print(f'Plots saved to: {ckpt_path}')

    # Force Drive sync after each run
    from google.colab import drive
    drive.flush_and_unmount()
    drive.mount('/content/drive')
    print('Drive re-synced.')

    # Print results
    f_min, f_mean, f_max = bm.fitness_stats()
    qd  = bm.qd_score()
    cov = bm.coverage()
    print(f'QD-score: {qd:.4f} | Coverage: {cov:.4f} | Best fitness: {f_min:.6f}')

    all_results.append({
        'seed': seed,
        'qd_score': qd, 'coverage': cov,
    })

print('\n====== All runs complete ======')
# Out:
# Weight dim: 6472
#
# ========== seed=42 ==========
#
# --- MAP-Elite Step 1/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [193s elapsed, 0s remaining]
# Archive: 128, Bins: 128, Coverage: 0.0128, Fitness min/mean/max: -65.40/-5.71/74.24
# QD-score: 64730.8806
#
# --- MAP-Elite Step 2/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [264s elapsed, 0s remaining]
# Archive: 258, Bins: 258, Coverage: 0.0258, Fitness min/mean/max: -174.97/-6.26/74.24
# QD-score: 130614.6572
#
# --- MAP-Elite Step 3/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 
200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [384s elapsed, 0s remaining]
# Archive: 4377, Bins: 4377, Coverage: 0.4377, Fitness min/mean/max: -321.76/-27.39/79.91
# QD-score: 2308371.0125
#
# --- MAP-Elite Step 128/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [393s elapsed, 0s remaining]
# Archive: 4388, Bins: 4388, Coverage: 0.4388, Fitness min/mean/max: -321.76/-27.49/79.91
# QD-score: 2314619.5408
#
# --- MAP-Elite Step 129/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [390s elapsed, 0s remaining]
# Archive: 4399, Bins: 4399, Coverage: 0.4399, Fitness min/mean/max: -321.76/-27.59/79.91
# QD-score: 2320870.6753
#
# --- MAP-Elite Step 130/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [382s elapsed, 0s remaining]
# Archive: 4413, Bins: 4413, Coverage: 0.4413, Fitness min/mean/max: -321.76/-27.66/79.91
# QD-score: 2328581.5855
#
# --- MAP-Elite Step 131/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [381s elapsed, 0s remaining]
# Archive: 4429, Bins: 4429, Coverage: 0.4429, Fitness min/mean/max: -321.76/-27.74/79.91
# QD-score: 2337375.5958
#
# --- MAP-Elite Step 132/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [392s elapsed, 0s remaining]
# Archive: 4449, Bins: 4449, Coverage: 0.4449, Fitness min/mean/max: -321.76/-27.82/79.91
# QD-score: 2348284.8185
#
# --- MAP-Elite Step 133/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [386s elapsed, 0s remaining]
# Archive: 4461, Bins: 4461, Coverage: 0.4461, Fitness min/mean/max: -321.76/-27.94/79.91
# QD-score: 2355140.2046
#
# --- MAP-Elite Step 134/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [382s elapsed, 0s remaining]
# Archive: 4476, Bins: 4476, Coverage: 0.4476, Fitness min/mean/max: -321.76/-28.07/79.91
# QD-score: 2363627.6101
#
# --- MAP-Elite Step 135/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [379s elapsed, 0s remaining]
# Archive: 4492, Bins: 4492, Coverage: 0.4492, Fitness min/mean/max: -321.76/-28.16/79.91
# QD-score: 2372472.5045
#
# --- MAP-Elite Step 136/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [377s elapsed, 0s remaining]
# Archive: 4502, Bins: 4502, Coverage: 0.4502, Fitness min/mean/max: -321.76/-28.24/79.91
# QD-score: 2378141.9628
#
# --- MAP-Elite Step 137/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [395s elapsed, 0s remaining]
# Archive: 4515, Bins: 4515, Coverage: 0.4515, Fitness min/mean/max: -321.76/-28.31/79.91
# QD-score: 2385301.2886
#
# --- MAP-Elite Step 138/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [374s elapsed, 0s remaining]
# Archive: 4532, Bins: 4532, Coverage: 0.4532, Fitness min/mean/max: -321.76/-28.33/79.91
# QD-score: 2394379.0219
#
# --- MAP-Elite Step 139/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [391s elapsed, 0s remaining]
# Archive: 4540, Bins: 4540, Coverage: 0.4540, Fitness min/mean/max: -321.76/-28.42/79.91
# QD-score: 2399007.7494
#
# --- MAP-Elite Step 140/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [391s elapsed, 0s remaining]
# Archive: 4548, Bins: 4548, Coverage: 0.4548, Fitness min/mean/max: -321.76/-28.54/79.91
# QD-score: 2403781.7263
#
# --- MAP-Elite Step 141/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [382s elapsed, 0s remaining]
# Archive: 4561, Bins: 4561, Coverage: 0.4561, Fitness min/mean/max: -321.76/-28.67/79.91
# QD-score: 2411259.4867
#
# --- MAP-Elite Step 142/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [390s elapsed, 0s remaining]
# Archive: 4573, Bins: 4573, Coverage: 0.4573, Fitness min/mean/max: -321.76/-28.80/79.91
# QD-score: 2418181.5999
#
# --- MAP-Elite Step 143/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [386s elapsed, 0s remaining]
# Archive: 4585, Bins: 4585, Coverage: 0.4585, Fitness min/mean/max: -321.76/-28.83/79.91
# QD-score: 2424674.6401
#
# --- MAP-Elite Step 144/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [381s elapsed, 0s remaining]
# Archive: 4593, Bins: 4593, Coverage: 0.4593, Fitness min/mean/max: -321.76/-28.92/79.91
# QD-score: 2429318.2771
#
# --- MAP-Elite Step 145/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [392s elapsed, 0s remaining]
# Archive: 4608, Bins: 4608, Coverage: 0.4608, Fitness min/mean/max: -321.76/-29.02/79.91
# QD-score: 2437738.4154
#
# --- MAP-Elite Step 146/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [386s elapsed, 0s remaining]
# Archive: 4617, Bins: 4617, Coverage: 0.4617, Fitness min/mean/max: -321.76/-29.06/79.91
# QD-score: 2442680.5097
#
# --- MAP-Elite Step 147/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [391s elapsed, 0s remaining]
# Archive: 4631, Bins: 4631, Coverage: 0.4631, Fitness min/mean/max: -321.76/-29.14/79.91
# QD-score: 2450429.0137
#
# --- MAP-Elite Step 148/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [390s elapsed, 0s remaining]
# Archive: 4652, Bins: 4652, Coverage: 0.4652, Fitness min/mean/max: -321.76/-29.10/79.91
# QD-score: 2461371.2754
#
# --- MAP-Elite Step 149/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [396s elapsed, 0s remaining]
# Archive: 4666, Bins: 4666, Coverage: 0.4666, Fitness min/mean/max: -321.76/-29.12/79.91
# QD-score: 2468867.7406
#
# --- MAP-Elite Step 150/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [396s elapsed, 0s remaining]
# Archive: 4679, Bins: 4679, Coverage: 0.4679, Fitness min/mean/max: -321.76/-29.23/79.91
# QD-score: 2476278.9691
#
# --- MAP-Elite Step 151/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [408s elapsed, 0s remaining]
# Archive: 4695, Bins: 4695, Coverage: 0.4695, Fitness min/mean/max: -321.76/-29.29/79.91
# QD-score: 2484999.6531
#
# --- MAP-Elite Step 152/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [408s elapsed, 0s remaining]
# Archive: 4703, Bins: 4703, Coverage: 0.4703, Fitness min/mean/max: -321.76/-29.38/79.91
# QD-score: 2489678.9588
#
# --- MAP-Elite Step 153/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [403s elapsed, 0s remaining]
# Archive: 4716, Bins: 4716, Coverage: 0.4716, Fitness min/mean/max: -321.76/-29.42/79.91
# QD-score: 2496740.8597
#
# --- MAP-Elite Step 154/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [388s elapsed, 0s remaining]
# Archive: 4730, Bins: 4730, Coverage: 0.4730, Fitness min/mean/max: -321.76/-29.50/79.91
# QD-score: 2504553.1755
#
# --- MAP-Elite Step 155/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [387s elapsed, 0s remaining]
# Archive: 4744, Bins: 4744, Coverage: 0.4744, Fitness min/mean/max: -321.76/-29.63/79.91
# QD-score: 2512574.4999
#
# --- MAP-Elite Step 156/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [391s elapsed, 0s remaining]
# Archive: 4762, Bins: 4762, Coverage: 0.4762, Fitness min/mean/max: -321.76/-29.68/79.91
# QD-score: 2522316.4455
#
# --- MAP-Elite Step 157/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [407s elapsed, 0s remaining]
# Archive: 4775, Bins: 4775, Coverage: 0.4775, Fitness min/mean/max: -321.76/-29.77/79.91
# QD-score: 2529647.2425
#
# --- MAP-Elite Step 158/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [407s elapsed, 0s remaining]
# Archive: 4787, Bins: 4787, Coverage: 0.4787, Fitness min/mean/max: -321.76/-29.83/79.91
# QD-score: 2536299.9937
#
# --- MAP-Elite Step 159/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [418s elapsed, 0s remaining]
# Archive: 4797, Bins: 4797, Coverage: 0.4797, Fitness min/mean/max: -321.76/-29.96/79.91
# QD-score: 2542215.7642
#
# --- MAP-Elite Step 160/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [397s elapsed, 0s remaining]
# Archive: 4804, Bins: 4804, Coverage: 0.4804, Fitness min/mean/max: -321.76/-30.05/79.91
# QD-score: 2546365.8563
#
# --- MAP-Elite Step 161/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [421s elapsed, 0s remaining]
# Archive: 4819, Bins: 4819, Coverage: 0.4819, Fitness min/mean/max: -321.76/-30.10/79.91
# QD-score: 2554553.5505
#
# --- MAP-Elite Step 162/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [410s elapsed, 0s remaining]
# Archive: 4826, Bins: 4826, Coverage: 0.4826, Fitness min/mean/max: -321.76/-30.22/79.91
# QD-score: 2558854.3212
#
# --- MAP-Elite Step 163/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [412s elapsed, 0s remaining]
# Archive: 4834, Bins: 4834, Coverage: 0.4834, Fitness min/mean/max: -321.76/-30.28/79.91
# QD-score: 2563369.6902
#
# --- MAP-Elite Step 164/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [414s elapsed, 0s remaining]
# Archive: 4843, Bins: 4843, Coverage: 0.4843, Fitness min/mean/max: -321.76/-30.33/79.91
# QD-score: 2568390.8651
#
# --- MAP-Elite Step 165/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [415s elapsed, 0s remaining]
# Archive: 4851, Bins: 4851, Coverage: 0.4851, Fitness min/mean/max: -321.76/-30.40/79.91
# QD-score: 2572978.0879
#
# --- MAP-Elite Step 166/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [428s elapsed, 0s remaining]
# Archive: 4859, Bins: 4859, Coverage: 0.4859, Fitness min/mean/max: -321.76/-30.52/79.91
# QD-score: 2577787.9991
#
# --- MAP-Elite Step 167/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [423s elapsed, 0s remaining]
# Archive: 4872, Bins: 4872, Coverage: 0.4872, Fitness min/mean/max: -321.76/-30.58/79.91
# QD-score: 2584985.8561
#
# --- MAP-Elite Step 168/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [415s elapsed, 0s remaining]
# Archive: 4886, Bins: 4886, Coverage: 0.4886, Fitness min/mean/max: -321.76/-30.70/79.91
# QD-score: 2592996.2477
#
# --- MAP-Elite Step 169/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [411s elapsed, 0s remaining]
# Archive: 4894, Bins: 4894, Coverage: 0.4894, Fitness min/mean/max: -321.76/-30.81/79.91
# QD-score: 2597762.3191
#
# --- MAP-Elite Step 170/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [407s elapsed, 0s remaining]
# Archive: 4902, Bins: 4902, Coverage: 0.4902, Fitness min/mean/max: -321.76/-30.90/79.91
# QD-score: 2602489.3033
#
# --- MAP-Elite Step 171/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [409s elapsed, 0s remaining]
# Archive: 4916, Bins: 4916, Coverage: 0.4916, Fitness min/mean/max: -321.76/-30.92/79.91
# QD-score: 2609989.0002
#
# --- MAP-Elite Step 172/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [400s elapsed, 0s remaining]
# Archive: 4924, Bins: 4924, Coverage: 0.4924, Fitness min/mean/max: -321.76/-30.96/79.91
# QD-score: 2614443.9943
#
# --- MAP-Elite Step 173/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [406s elapsed, 0s remaining]
# Archive: 4937, Bins: 4937, Coverage: 0.4937, Fitness min/mean/max: -321.76/-31.02/79.91
# QD-score: 2621623.1432
#
# --- MAP-Elite Step 174/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [429s elapsed, 0s remaining]
# Archive: 4949, Bins: 4949, Coverage: 0.4949, Fitness min/mean/max: -321.76/-31.04/79.91
# QD-score: 2628125.6252
#
# --- MAP-Elite Step 175/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [428s elapsed, 0s remaining]
# Archive: 4964, Bins: 4964, Coverage: 0.4964, Fitness min/mean/max: -321.76/-31.11/79.91
# QD-score: 2636437.6787
#
# --- MAP-Elite Step 176/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [412s elapsed, 0s remaining]
# Archive: 4971, Bins: 4971, Coverage: 0.4971, Fitness min/mean/max: -321.76/-31.25/79.91
# QD-score: 2640847.3264
#
# --- MAP-Elite Step 177/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [414s elapsed, 0s remaining]
# Archive: 4981, Bins: 4981, Coverage: 0.4981, Fitness min/mean/max: -321.76/-31.38/79.91
# QD-score: 2646800.9143
#
# --- MAP-Elite Step 178/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [419s elapsed, 0s remaining]
# Archive: 4993, Bins: 4993, Coverage: 0.4993, Fitness min/mean/max: -321.76/-31.44/79.91
# QD-score: 2653481.1635
#
# --- MAP-Elite Step 179/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [411s elapsed, 0s remaining]
# Archive: 5003, Bins: 5003, Coverage: 0.5003, Fitness min/mean/max: -321.76/-31.47/79.91
# QD-score: 2658936.0752
#
# --- MAP-Elite Step 180/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [433s elapsed, 0s remaining]
# Archive: 5011, Bins: 5011, Coverage: 0.5011, Fitness min/mean/max: -321.76/-31.52/79.91
# QD-score: 2663437.2392
#
# --- MAP-Elite Step 181/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [442s elapsed, 0s remaining]
# Archive: 5021, Bins: 5021, Coverage: 0.5021, Fitness min/mean/max: -338.52/-31.65/79.91
# QD-score: 2669405.4488
#
# --- MAP-Elite Step 182/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [443s elapsed, 0s remaining]
# Archive: 5032, Bins: 5032, Coverage: 0.5032, Fitness min/mean/max: -338.52/-31.71/79.91
# QD-score: 2675564.3516
#
# --- MAP-Elite Step 183/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [449s elapsed, 0s remaining]
# Archive: 5040, Bins: 5040, Coverage: 0.5040, Fitness min/mean/max: -338.52/-31.74/79.91
# QD-score: 2679987.0283
#
# --- MAP-Elite Step 184/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [441s elapsed, 0s remaining]
# Archive: 5049, Bins: 5049, Coverage: 0.5049, Fitness min/mean/max: -338.52/-31.79/79.91
# QD-score: 2685031.2159
#
# --- MAP-Elite Step 185/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [422s elapsed, 0s remaining]
# Archive: 5058, Bins: 5058, Coverage: 0.5058, Fitness min/mean/max: -338.52/-31.82/79.91
# QD-score: 2689929.8582
#
# --- MAP-Elite Step 186/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [433s elapsed, 0s remaining]
# Archive: 5072, Bins: 5072, Coverage: 0.5072, Fitness min/mean/max: -348.25/-31.92/79.91
# QD-score: 2697907.5862
#
# --- MAP-Elite Step 187/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [421s elapsed, 0s remaining]
# Archive: 5081, Bins: 5081, Coverage: 0.5081, Fitness min/mean/max: -348.25/-32.01/79.91
# QD-score: 2703143.7726
#
# --- MAP-Elite Step 188/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [402s elapsed, 0s remaining]
# Archive: 5089, Bins: 5089, Coverage: 0.5089, Fitness min/mean/max: -348.25/-32.07/79.91
# QD-score: 2707725.6397
#
# --- MAP-Elite Step 189/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [412s elapsed, 0s remaining]
# Archive: 5098, Bins: 5098, Coverage: 0.5098, Fitness min/mean/max: -348.25/-32.12/79.91
# QD-score: 2712761.8376
#
# --- MAP-Elite Step 190/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [406s elapsed, 0s remaining]
# Archive: 5105, Bins: 5105, Coverage: 0.5105, Fitness min/mean/max: -348.25/-32.21/79.91
# QD-score: 2716950.1233
#
# --- MAP-Elite Step 191/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [424s elapsed, 0s remaining]
# Archive: 5116, Bins: 5116, Coverage: 0.5116, Fitness min/mean/max: -348.25/-32.31/79.91
# QD-score: 2723313.1916
#
# --- MAP-Elite Step 192/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [420s elapsed, 0s remaining]
# Archive: 5125, Bins: 5125, Coverage: 0.5125, Fitness min/mean/max: -348.25/-32.36/79.91
# QD-score: 2728360.6073
#
# --- MAP-Elite Step 193/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [423s elapsed, 0s remaining]
# Archive: 5138, Bins: 5138, Coverage: 0.5138, Fitness min/mean/max: -348.25/-32.38/79.91
# QD-score: 2735356.6563
#
# --- MAP-Elite Step 194/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [454s elapsed, 0s remaining]
# Archive: 5150, Bins: 5150, Coverage: 0.5150, Fitness min/mean/max: -348.25/-32.48/79.91
# QD-score: 2742278.3274
#
# --- MAP-Elite Step 195/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [427s elapsed, 0s remaining]
# Archive: 5158, Bins: 5158, Coverage: 0.5158, Fitness min/mean/max: -348.25/-32.56/79.91
# QD-score: 2746936.1145
#
# --- MAP-Elite Step 196/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [419s elapsed, 0s remaining]
# Archive: 5167, Bins: 5167, Coverage: 0.5167, Fitness min/mean/max: -348.25/-32.64/79.91
# QD-score: 2752129.6167
#
# --- MAP-Elite Step 197/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [408s elapsed, 0s remaining]
# Archive: 5177, Bins: 5177, Coverage: 0.5177, Fitness min/mean/max: -348.25/-32.74/79.91
# QD-score: 2757993.8781
#
# --- MAP-Elite Step 198/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [402s elapsed, 0s remaining]
# Archive: 5189, Bins: 5189, Coverage: 0.5189, Fitness min/mean/max: -348.25/-32.75/79.91
# QD-score: 2764434.9669
#
# --- MAP-Elite Step 199/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [407s elapsed, 0s remaining]
# Archive: 5201, Bins: 5201, Coverage: 0.5201, Fitness min/mean/max: -348.25/-32.78/79.91
# QD-score: 2770975.4785
#
# --- MAP-Elite Step 200/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [439s elapsed, 0s remaining]
# Archive: 5206, Bins: 5206, Coverage: 0.5206, Fitness min/mean/max: -348.25/-32.87/79.91
# QD-score: 2774145.2857
# Checkpoint saved: /content/drive/MyDrive/shared_ckpts/ant_gait/Ant_MAPElite_GaussianMut/MAPElite_Gauss_sigma0.05_seed42/
# Plots saved to: /content/drive/MyDrive/shared_ckpts/ant_gait/Ant_MAPElite_GaussianMut/MAPElite_Gauss_sigma0.05_seed42/
# Mounted at /content/drive
# Drive re-synced.
# QD-score: 2774145.2857 | Coverage: 0.5206 | Best fitness: -348.250664
#
# ========== seed=123 ==========
#
# --- MAP-Elite Step 1/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [209s elapsed, 0s remaining]
# Archive: 117, Bins: 117, Coverage: 0.0117, Fitness min/mean/max: -85.86/-4.57/52.70
# QD-score: 59034.9047
#
# --- MAP-Elite Step 2/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [289s elapsed, 0s remaining]
# Archive: 264, Bins: 264, Coverage: 0.0264, Fitness min/mean/max: -99.13/-5.27/41.68
# QD-score: 133391.2908
#
# --- MAP-Elite Step 3/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [317s elapsed, 0s remaining]
# Archive: 407, Bins: 407, Coverage: 0.0407, Fitness min/mean/max: -99.13/-5.08/61.59
# QD-score: 205566.4859
#
# --- MAP-Elite Step 4/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [317s elapsed, 0s remaining]
# Archive: 521, Bins: 521, Coverage: 0.0521, Fitness min/mean/max: -99.13/-5.74/61.59
# QD-score: 263490.7672
#
# --- MAP-Elite Step 5/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [325s elapsed, 0s remaining]
# Archive: 654, Bins: 654, Coverage: 0.0654, Fitness min/mean/max: -99.13/-6.11/62.01
# QD-score: 330994.8279
#
# --- MAP-Elite Step 6/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [323s elapsed, 0s remaining]
# Archive: 754, Bins: 754, Coverage: 0.0754, Fitness min/mean/max: -99.13/-7.38/62.01
# QD-score: 382567.4093
#
# --- MAP-Elite Step 7/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [325s elapsed, 0s remaining]
# Archive: 832, Bins: 832, Coverage: 0.0832, Fitness min/mean/max: -99.13/-8.03/62.01
# QD-score: 422678.9259
#
# --- MAP-Elite Step 8/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [342s elapsed, 0s remaining]
# Archive: 923, Bins: 923, Coverage: 0.0923, Fitness min/mean/max: -99.13/-8.28/62.01
# QD-score: 469139.2349
#
# --- MAP-Elite Step 9/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [334s elapsed, 0s remaining]
# Archive: 996, Bins: 996, Coverage: 0.0996, Fitness min/mean/max: -99.13/-8.69/62.01
# QD-score: 506653.1144
#
# --- MAP-Elite Step 10/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [336s elapsed, 0s remaining]
# Archive: 1077, Bins: 1077, Coverage: 0.1077, Fitness min/mean/max: -127.73/-9.09/95.29
# QD-score: 548291.4816
#
# --- MAP-Elite Step 11/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [350s elapsed, 0s remaining]
# Archive: 1154, Bins: 1154, Coverage: 0.1154, Fitness min/mean/max: -127.73/-9.81/95.29
# QD-score: 588323.1815
#
# --- MAP-Elite Step 12/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [353s elapsed, 0s remaining]
# Archive: 1223, Bins: 1223, Coverage: 0.1223, Fitness min/mean/max: -127.73/-9.95/95.29
# QD-score: 623665.5249
#
# --- MAP-Elite Step 13/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [354s elapsed, 0s remaining]
# Archive: 1294, Bins: 1294, Coverage: 0.1294, Fitness min/mean/max: -127.73/-10.18/95.29
# QD-score: 660171.3218
#
# --- MAP-Elite Step 14/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [358s elapsed, 0s remaining]
# Archive: 1361, Bins: 1361, Coverage: 0.1361, Fitness min/mean/max: -127.73/-10.39/95.29
# QD-score: 694639.5513
#
# --- MAP-Elite Step 15/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [348s elapsed, 0s remaining]
# Archive: 1428, Bins: 1428, Coverage: 0.1428, Fitness min/mean/max: -127.73/-10.56/95.29
# QD-score: 729074.0873
#
# --- MAP-Elite Step 16/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [367s elapsed, 0s remaining]
# Archive: 1487, Bins: 1487, Coverage: 0.1487, Fitness min/mean/max: -127.73/-10.99/95.29
# QD-score: 759835.8199
#
# --- MAP-Elite Step 17/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [363s elapsed, 0s remaining]
# Archive: 1543, Bins: 1543, Coverage: 0.1543, Fitness min/mean/max: -127.73/-10.99/95.29
# QD-score: 788459.9082
#
# --- MAP-Elite Step 18/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [370s elapsed, 0s remaining]
# Archive: 1602, Bins: 1602, Coverage: 0.1602, Fitness min/mean/max: -127.73/-11.20/95.29
# QD-score: 818936.0886
#
# --- MAP-Elite Step 19/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [370s elapsed, 0s remaining]
# Archive: 1680, Bins: 1680, Coverage: 0.1680, Fitness min/mean/max: -127.73/-11.35/95.29
# QD-score: 859068.1402
#
# --- MAP-Elite Step 20/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [365s elapsed, 0s remaining]
# Archive: 1742, Bins: 1742, Coverage: 0.1742, Fitness min/mean/max: -140.18/-11.68/95.29
# QD-score: 891345.5665
#
# --- MAP-Elite Step 21/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [379s elapsed, 0s remaining]
# Archive: 1809, Bins: 1809, Coverage: 0.1809, Fitness min/mean/max: -140.18/-11.92/95.29
# QD-score: 926056.9435
#
# --- MAP-Elite Step 22/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [344s elapsed, 0s remaining]
# Archive: 1856, Bins: 1856, Coverage: 0.1856, Fitness min/mean/max: -140.18/-11.99/95.29
# QD-score: 950245.6659
#
# --- MAP-Elite Step 23/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [354s elapsed, 0s remaining]
# Archive: 1908, Bins: 1908, Coverage: 0.1908, Fitness min/mean/max: -140.18/-12.53/95.29
# QD-score: 977910.0721
#
# --- MAP-Elite Step 24/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [358s elapsed, 0s remaining]
# Archive: 1964, Bins: 1964, Coverage: 0.1964, Fitness min/mean/max: -140.18/-12.66/95.29
# QD-score: 1006870.9541
#
# --- MAP-Elite Step 25/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [348s elapsed, 0s remaining]
# Archive: 2028, Bins: 2028, Coverage: 0.2028, Fitness min/mean/max: -140.18/-12.89/95.29
# QD-score: 1040134.7840
#
# --- MAP-Elite Step 26/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [367s elapsed, 0s remaining]
# Archive: 2078, Bins: 2078, Coverage: 0.2078, Fitness min/mean/max: -140.18/-13.24/95.29
# QD-score: 1066502.9197
#
# --- MAP-Elite Step 27/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [358s elapsed, 0s remaining]
# Archive: 2123, Bins: 2123, Coverage: 0.2123, Fitness min/mean/max: -140.18/-13.33/95.29
# QD-score: 1089809.4042
#
# --- MAP-Elite Step 28/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [354s elapsed, 0s remaining]
# Archive: 2166, Bins: 2166, Coverage: 0.2166, Fitness min/mean/max: -140.18/-13.52/95.29
# QD-score: 1112285.3440
#
# --- MAP-Elite Step 29/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [382s elapsed, 0s remaining]
# Archive: 2215, Bins: 2215, Coverage: 0.2215, Fitness min/mean/max: -140.18/-13.70/95.29
# QD-score: 1137843.2212
#
# --- MAP-Elite Step 30/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 500/500 [373s elapsed, 0s remaining]
# Archive: 2261, Bins: 2261, Coverage: 0.2261, Fitness min/mean/max: -140.18/-13.89/95.29
# QD-score: 1161915.4759
#
# --- MAP-Elite Step 31/200 ---
#   Operator ratio - pse_mut: 500/500 (100%)
# Collecting: 317/500 [236s elapsed, 136s remaining]
