# %% [markdown]
# # Imports and Keys

# %%
import openai
from openai import OpenAI
import pandas as pd
import numpy as np
import pickle
import requests
import re
from datetime import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

def create_minute_gap(seconds):
    print("creating minute gap to avoid TPM limit error...") 
    counter = 0
    while counter < (1000000000 * (seconds/60)):
        counter += 1

# %%
API=""

# %%
agent_key=""

# %%
client = OpenAI(api_key=API)

# %% [markdown]
# # Experiment Procedure

# %% [markdown]
# Procedure:
# 1. Remind agents with the setting of the experiment
# 2. instruct them to decide the allocation to private and public account
# 3. aggregate the decision and compute the rewards
#     - private internal return (NFT)
#     - public internal return (public goods from own contribution)
#     - external return (public goods from others\' contribution)
# 4. give feedback
#     - total contrubution made this round
#     - total reward
#     - breakdown of total reward
#     - situation information
#         - DAO crashed?
#         - NF succeeded?
#     - historical contribution level
# 5. insruct them to make decision given feedback and reminder of demographics
# 6. repeat 3~5 for configured rounds
#
# Prompts:
# - Assistent Configuration Prompt
# You are a participant of the experiment. You are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide certain return only to you, but the allocation to the public account will equally provide everyone certain return. You are not allowed to reuse the return earned in previous round, and fixed amount of endowment will be provided to you every round. You will be informed with your demographic information and the detailed settings of the experiment at the beginning of the experiment, so you must imitate human decisions given those information. You should explain your thought process and reasons of your decisions in detail.
# - Initial Instruction Prompt
#     - Control
# You are {agent.age} years old {agent.gender} who is {agent.risk_preference} to some extent. You are participating in the experiment where you are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide return only to you, but the allocation to the public account will provide everyone certain return. You are not allowed to reuse the return earned in previous round, and fixed endowment of 100 will be provided to you every round. {self.configs['num_agents'] - 1} other people are participating in this experiment, facing same decision choices as you. Your return will be computed by: private_account + public_account * {self.configs['r_NFT'] + self.configs['r_public']} + sum_of_others\'_public account * {self.configs['h_public']}. Now, make your first decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail.
#     - Treatment1
# You are {agent.age} years old {agent.gender} who is {agent.risk_preference} to some extent. You are participating in the experiment where you are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide return only to you, but the allocation to the public account will provide everyone certain return. The contributions to the public account will be managed by Decentralized Autonomous Organization (DAO), which has a certain probability of crashing, generating no public benefits to anyone from the public account. The return you will be getting from the allocation to public account will also includes a return from Non-Fungible-Token (NFT) (only paid by chance) you will be obtaining when you allocate your endowment to public account. You are not allowed to reuse the return earned in previous round, and fixed endowment of 100 will be provided to you every round. {self.configs['num_agents'] - 1} other people are participating in this experiment, facing same decision choices as you. Your return will be computed by: private_account + public_account * r_NFT + public_account * r_public + sum_of_others\'_public account * h_public. r_NFT is {self.configs['r_NFT']} with probability of {self.configs['p(s_NFT=1)']} and 0 with {1 - self.configs['p(s_NFT=1)']}. r_public is {self.configs['r_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}. h_public is {self.configs['h_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}, which is linked with r_public. So if r_public is {self.configs['r_public']} then h_public is {self.configs['h_public']}, and if one of them is 0 then the other one is also 0, because they are decided together. Now, make your first decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail, and report the amount allocated to private and public account.
#     - Treatment 2
# You are {agent.age} years old {agent.gender} who is {agent.risk_preference} to some extent. You are participating in the experiment where you are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide return only to you, but the allocation to the public account will provide everyone certain return. The contributions to the public account will be managed by Decentralized Autonomous Organization (DAO), which has a certain probability of crashing, generating no public benefits to anyone from the public account. The return you will be getting from the allocation to public account will also includes a return from Non-Fungible-Token (NFT) (only paid by chance) you will be obtaining when you allocate your endowment to public account. You are not allowed to reuse the return earned in previous round, and fixed endowment of 100 will be provided to you every round. {self.configs['num_agents'] - 1} other people are participating in this experiment, facing same decision choices as you. Your return will be computed by: private_account + public_account * r_NFT + public_account * r_public + sum_of_others\'_public account * h_public. r_NFT is {self.configs['r_NFT']} with probability of {self.configs['p(s_NFT=1)']} and 0 with {1 - self.configs['p(s_NFT=1)']}. r_public is {self.configs['r_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}. h_public is {self.configs['h_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}, which is linked with r_public. So if r_public is {self.configs['r_public']} then h_public is {self.configs['h_public']}, and if one of them is 0 then the other one is also 0, because they are decided together. Importantly, if r_public and h_public are 0, then it causes r_NFT to be 0. However, r_NFT being 0 does not necessarily cause r_public or h_public to be 0. Now, make your first decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account.
#     - Treatment3
# You are {agent.age} years old {agent.gender} who is {agent.risk_preference} to some extent. You are participating in the experiment where you are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide return only to you, but the allocation to the public account will provide everyone certain return. The contributions to the public account will be managed by Decentralized Autonomous Organization (DAO), which has a certain probability of crashing, generating no public benefits to anyone from the public account. The return you will be getting from the allocation to public account will also includes a return from Non-Fungible-Token (NFT) (only paid by chance) you will be obtaining when you allocate your endowment to public account. You are not allowed to reuse the return earned in previous round, and fixed endowment of 100 will be provided to you every round. {self.configs['num_agents'] - 1} other people are participating in this experiment, facing same decision choices as you. Your return will be computed by: private_account + public_account * r_NFT + public_account * r_public + sum_of_others\'_public account * h_public. r_NFT is {self.configs['r_NFT']} with probability of {self.configs['p(s_NFT=1)']} and 0 with {1 - self.configs['p(s_NFT=1)']}. r_public is {self.configs['r_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}. h_public is {self.configs['h_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}, which is linked with r_public. So if r_public is {self.configs['r_public']} then h_public is {self.configs['h_public']}, and if one of them is 0 then the other one is also 0, because they are decided together. Importantly, if r_public and h_public are 0, then it causes r_NFT to be 0. However, r_NFT being 0 does not necessarily cause r_public or h_public to be 0. Another important point is that if one of r_NFT or (r_public and h_public) is positive, and when the other one is 0, then the value of the one with value of 0 will turn positive with probability of 8/67 which is around 12%. This means that if one of the r_NFT or (r_public and h_public) is positive, then it increases the chance of the other to be positive. However if (r_public and h_public) were 0 even after redraw, r_NFT will become 0. Now, make your first decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account.
#     - Treatment4
# You are {agent.age} years old {agent.gender} who is {agent.risk_preference} to some extent. You are participating in the experiment where you are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide return only to you, but the allocation to the public account will provide everyone certain return. The contributions to the public account will be managed by Decentralized Autonomous Organization (DAO), which has a certain probability of crashing, generating no public benefits to anyone from the public account. You are not allowed to reuse the return earned in previous round, and fixed endowment of 100 will be provided to you every round. {self.configs['num_agents'] - 1} other people are participating in this experiment, facing same decision choices as you. Your return will be computed by: private_account + public_account * r_public + sum_of_others\'_public account * h_public. r_public is {self.configs['r_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}. h_public is {self.configs['h_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}, which is linked with r_public. So if r_public is {self.configs['r_public']} then h_public is {self.configs['h_public']}, and if one of them is 0 then the other one is also 0, because they are decided together. Now, make your first decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account.
#
# - Feedback & Next Instruction Prompt
#     - Control
# After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. {situation_messages['DAO']} {situation_messages['NFT']} Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account.
#     - Treatment1
# After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. {situation_messages['DAO']} {situation_messages['NFT']} Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account.
#     - Treatment 2
# After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. {situation_messages['DAO']} {situation_messages['NFT']} Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account.
#     - Treatment3
# After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. {situation_messages['DAO']} {situation_messages['NFT']} Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account.
#     - Treatment4
# After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. {situation_messages['DAO']} Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account.

# %% [markdown]
# # Configurations

# %%
def treatment1(p_sDAO, p_sNFT):
    sDAO = np.random.choice([0, 1], p=[1-p_sDAO, p_sDAO])
    sNFT = np.random.choice([0, 1], p=[1-p_sNFT, p_sNFT])
    
    situation = {
        "DAO": "DAO is functioning, so contributions were effectively converted to public goods, and everyone enjoyed a share of it." if sDAO==1 else "DAO crashed, so the contributions were not converted to public goods, and nobody enjoyed the benefit of public goods.",
        "NFT": "You succeeded in obtaining a private return on contribution from through NFT." if sNFT==1 else "You failed to recieve a private return on contribution through NFT."
    }
    return situation, sDAO, sNFT

def treatment2(p_sDAO, p_sNFT):
    sDAO = np.random.choice([0, 1], p=[1-p_sDAO, p_sDAO])
    sNFT = np.random.choice([0, 1], p=[1-p_sNFT, p_sNFT])
    
    if sDAO==0:
        sNFT = 0
    
    situation = {
        "DAO": "DAO is functioning, so contributions were effectively converted to public goods, and everyone enjoyed a share of it." if sDAO==1 else "DAO crashed, so the contributions were not converted to public goods, and nobody enjoyed the benefit of public goods.",
        "NFT": "You succeeded in obtaining a private return on contribution from through NFT." if sNFT==1 else "You failed to recieve a private return on contribution through NFT."
    }
    return situation, sDAO, sNFT

def treatment3(p_sDAO, p_sNFT, redraw=8/67):
    sDAO = np.random.choice([0, 1], p=[1-p_sDAO, p_sDAO])
    sNFT = np.random.choice([0, 1], p=[1-p_sNFT, p_sNFT])
    
    if (sDAO==1) & (sNFT==0):
        sNFT = np.random.choice([0, 1], p=[1-redraw, redraw])
    
    if (sNFT==1) & (sDAO==0):
        sDAO = np.random.choice([0, 1], p=[1-redraw, redraw])
    
    if sDAO==0:
        sNFT = 0 
    
    situation = {
        "DAO": "DAO is functioning, so contributions were effectively converted to public goods, and everyone enjoyed a share of it." if sDAO==1 else "DAO crashed, so the contributions were not converted to public goods, and nobody enjoyed the benefit of public goods.",
        "NFT": "You succeeded in obtaining a private return on contribution from through NFT." if sNFT==1 else "You failed to recieve a private return on contribution through NFT."
    }
    return situation, sDAO, sNFT

def treatment4(p_sDAO, p_sNFT):
    sDAO = np.random.choice([0, 1], p=[1-p_sDAO, p_sDAO])
    sNFT = 0

    situation = {
        "DAO": "DAO is functioning, so contributions were effectively converted to public goods, and everyone enjoyed a share of it." if sDAO==1 else "DAO crashed, so the contributions were not converted to public goods, and nobody enjoyed the benefit of public goods.",
        "NFT": ""
    }
    return situation, sDAO, sNFT

# %%
# control: no risk (C)
config_C = {
    "rounds": 5,
    "num_agents": 4,
    "endowment": 100,
    "r_NFT": 0.,
    "r_public": 0.5, 
    "h_public": 0.5,
    "p(s_DAO=1)": 1,
    "p(s_NFT=1)": 0,
    "group": None
}

# treatment1: LT
config_T1 = {
    "rounds": 5,
    "num_agents": 4,
    "endowment": 100,
    "r_NFT": 2,
    "r_public": 0.5,
    "h_public": 0.5,
    "p(s_DAO=1)": 0.25,
    "p(s_NFT=1)": 1/6,
    "group": treatment1
}

# treatment2: FTw/CB
config_T2 = {
    "rounds": 5,
    "num_agents": 4,
    "endowment": 100,
    "r_NFT": 8,
    "r_public": 0.5, 
    "h_public": 0.5,
    "p(s_DAO=1)": 0.25,
    "p(s_NFT=1)": 1/6,
    "group": treatment2
}

# treatment3: FTwCB
config_T3 = {
    "rounds": 5,
    "num_agents": 4,
    "endowment": 100,
    "r_NFT": 4,
    "r_public": 0.5, 
    "h_public": 0.5, 
    "p(s_DAO=1)": 0.25,
    "p(s_NFT=1)": 1/6,
    "group": treatment3
}

# treatment4: NoNFT
config_T4 = {
    "rounds": 5,
    "num_agents": 4,
    "endowment": 100,
    "r_NFT": 0,
    "r_public": 1/6,
    "h_public": 35/54,
    "p(s_DAO=1)": 0.25,
    "p(s_NFT=1)": 0,
    "group": treatment4
}

# %%
demographics = {
    "risk_preference": ["risk_averse", "risk_loving"],
    "risk_preference_dist": [0.55, 0.45],
    "gender": ["male", "female"],
    "gender_dist": [0.6, 0.4], 
    "age": [20, 30, 40, 50, 60],
    "age_dist": [0.4, 0.4, 0.1, 0.05, 0.05]
}

# %% [markdown]
# # Library

# %%
class Agent():
    def __init__(self, client, agent_key, demog):
        self.client = client
        self.agent_key = agent_key
        
        self.risk_preference = demog["risk_preference"]
        self.gender = demog["gender"]
        self.age = demog["age"]
        
        self.privates = []
        self.publics = []
        self.others_average_publics = []
        
        self.decisions = []
        
    def join_experiment(self):
        self.thread = self.client.beta.threads.create()
        
    def receive_message(self):
        self.message = self.client.beta.threads.messages.create(
            thread_id=self.thread.id,
            role="user",
            content=self.content
        )
    
    def make_decision(self, print_decision=True):
        # make decision based on provided instruction or feedback
        with self.client.beta.threads.runs.stream(
            thread_id=self.thread.id,
            assistant_id=self.agent_key
        ) as self.stream:
            self.stream.until_done()
            
        # update conversation record
        self.conversation = self.client.beta.threads.messages.list(
            thread_id=self.thread.id,
            order="asc"
        )
        
        # retrieve the round decision
        self.decision = self.conversation.data[-1].content[0].text.value
        
        self.decisions.append(self.decision)
        
        if print_decision:
            print(self.decision)
    
    def leave_experiment(self):
        self.client.beta.threads.delete(thread_id=self.thread.id)

# %%
class Experiment():
    def __init__(self, client, agent_key, configs, demogs):
        self.client = client
        self.agent_key = agent_key
        
        self.configs = configs
        self.demogs = demogs
        
        self.agents = [Agent(self.client, self.agent_key, generate_demographics(self.demogs)) for i in range(self.configs["num_agents"])]
        
        self.total_contributions_record = []
        self.sDAOs = []
        self.sNFTs = []
        
        self.round = 1
    
    def start(self):
        for i in range(len(self.agents)):
            self.agents[i].join_experiment()
            print(f"agent {i} joined the experiment")
            
    def decision_round(self, print_decision=True):
        for i in range(len(self.agents)):
            print(f"Agent {i} round {self.round} decision")
            self.agents[i].make_decision(print_decision)
            print("\n")
        self.round += 1
    
    def end(self):
        for i in range(len(self.agents)):
            self.agents[i].leave_experiment()
            print(f"agent {i} left the experiment")
    
    def give_instruction(self):
        pass
                
    def give_feedback(self):
        pass
    
class Control(Experiment):
    def give_instruction(self):
        for i in range(len(self.agents)):
            agent = self.agents[i]
            agent.content = f"You are {agent.age} years old {agent.gender} who is {agent.risk_preference} to some extent. You are participating in the experiment where you are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide return only to you, but the allocation to the public account will provide everyone certain return. You are not allowed to reuse the return earned in previous round, and fixed endowment of 100 will be provided to you every round. {self.configs['num_agents'] - 1} other people are participating in this experiment, facing same decision choices as you. Your return will be computed by: private_account + public_account * {self.configs['r_NFT'] + self.configs['r_public']} + sum_of_others\'_public account * {self.configs['h_public']}. Now, make your first decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail."
            agent.receive_message()
            print(f"agent {i} received instruction")
                
    def give_feedback(self, privates, publics):
        total_contributions = sum(publics)
        
        self.total_contributions_record.append(total_contributions)
        
        if self.configs["group"]:
            situation_messages, sDAO, sNFT = self.configs["group"](self.configs["p(s_DAO=1)"], self.configs["p(s_NFT=1)"])
        else: 
            situation_messages, sDAO, sNFT = None, 1, 0
        self.sDAOs.append(sDAO)
        self.sNFTs.append(sNFT)
            
        for i in range(len(self.agents)):
            agent = self.agents[i]
            private = privates[i]
            agent.privates.append(private)
            public = publics[i]
            agent.publics.append(public)
            others_average_public = sum([publics[j] for j in range(len(publics)) if j!=i]) / (self.configs["num_agents"] - 1)
            agent.others_average_publics.append(others_average_public)
            payoff = private + public * (self.configs["r_public"] * sDAO) + (total_contributions - public) * self.configs["h_public"] * sDAO
        
            agent.content = f"After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account."
            agent.receive_message()
            print(f"agent {i} received feedback")
    
class Treatment1(Experiment):
    def give_instruction(self):
        for i in range(len(self.agents)):
            agent = self.agents[i]
            agent.content = f"You are {agent.age} years old {agent.gender} who is {agent.risk_preference} to some extent. You are participating in the experiment where you are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide return only to you, but the allocation to the public account will provide everyone certain return. The contributions to the public account will be managed by Decentralized Autonomous Organization (DAO), which has a certain probability of crashing, generating no public benefits to anyone from the public account. The return you will be getting from the allocation to public account will also includes a return from Non-Fungible-Token (NFT) (only paid by chance) you will be obtaining when you allocate your endowment to public account. You are not allowed to reuse the return earned in previous round, and fixed endowment of 100 will be provided to you every round. {self.configs['num_agents'] - 1} other people are participating in this experiment, facing same decision choices as you. Your return will be computed by: private_account + public_account * r_NFT + public_account * r_public + sum_of_others\'_public account * h_public. r_NFT is {self.configs['r_NFT']} with probability of {self.configs['p(s_NFT=1)']} and 0 with {1 - self.configs['p(s_NFT=1)']}. r_public is {self.configs['r_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}. h_public is {self.configs['h_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}, which is linked with r_public. So if r_public is {self.configs['r_public']} then h_public is {self.configs['h_public']}, and if one of them is 0 then the other one is also 0, because they are decided together. Now, make your first decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail, and report the amount allocated to private and public account."
            agent.receive_message()
            print(f"agent {i} received instruction")
                
    def give_feedback(self, privates, publics):
        total_contributions = sum(publics)
        
        self.total_contributions_record.append(total_contributions)
        
        if self.configs["group"]:
            situation_messages, sDAO, sNFT = self.configs["group"](self.configs["p(s_DAO=1)"], self.configs["p(s_NFT=1)"])
        else: 
            situation_messages, sDAO, sNFT = None, 1, 0
        self.sDAOs.append(sDAO)
        self.sNFTs.append(sNFT)
            
        for i in range(len(self.agents)):
            agent = self.agents[i]
            private = privates[i]
            agent.privates.append(private)
            public = publics[i]
            agent.publics.append(public)
            others_average_public = sum([publics[j] for j in range(len(publics)) if j!=i]) / (self.configs["num_agents"] - 1)
            agent.others_average_publics.append(others_average_public)
            payoff = private + public * (self.configs["r_NFT"] * sNFT + self.configs["r_public"] * sDAO) + (total_contributions - public) * self.configs["h_public"] * sDAO
        
            if situation_messages:
                agent.content = f"After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. {situation_messages['DAO']} {situation_messages['NFT']} Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account."
                agent.receive_message()
            else: 
                agent.content = f"After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account."
                agent.receive_message()
            print(f"agent {i} received feedback")

class Treatment2(Experiment):
    def give_instruction(self):
        for i in range(len(self.agents)):
            agent = self.agents[i]
            agent.content = f"You are {agent.age} years old {agent.gender} who is {agent.risk_preference} to some extent. You are participating in the experiment where you are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide return only to you, but the allocation to the public account will provide everyone certain return. The contributions to the public account will be managed by Decentralized Autonomous Organization (DAO), which has a certain probability of crashing, generating no public benefits to anyone from the public account. The return you will be getting from the allocation to public account will also includes a return from Non-Fungible-Token (NFT) (only paid by chance) you will be obtaining when you allocate your endowment to public account. You are not allowed to reuse the return earned in previous round, and fixed endowment of 100 will be provided to you every round. {self.configs['num_agents'] - 1} other people are participating in this experiment, facing same decision choices as you. Your return will be computed by: private_account + public_account * r_NFT + public_account * r_public + sum_of_others\'_public account * h_public. r_NFT is {self.configs['r_NFT']} with probability of {self.configs['p(s_NFT=1)']} and 0 with {1 - self.configs['p(s_NFT=1)']}. r_public is {self.configs['r_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}. h_public is {self.configs['h_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}, which is linked with r_public. So if r_public is {self.configs['r_public']} then h_public is {self.configs['h_public']}, and if one of them is 0 then the other one is also 0, because they are decided together. Importantly, if r_public and h_public are 0, then it causes r_NFT to be 0. However, r_NFT being 0 does not necessarily cause r_public or h_public to be 0. Now, make your first decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account."
            agent.receive_message()
            print(f"agent {i} received instruction")
                
    def give_feedback(self, privates, publics):
        total_contributions = sum(publics)
        
        self.total_contributions_record.append(total_contributions)
        
        if self.configs["group"]:
            situation_messages, sDAO, sNFT = self.configs["group"](self.configs["p(s_DAO=1)"], self.configs["p(s_NFT=1)"])
        else: 
            situation_messages, sDAO, sNFT = None, 1, 0
        self.sDAOs.append(sDAO)
        self.sNFTs.append(sNFT)
            
        for i in range(len(self.agents)):
            agent = self.agents[i]
            private = privates[i]
            agent.privates.append(private)
            public = publics[i]
            agent.publics.append(public)
            others_average_public = sum([publics[j] for j in range(len(publics)) if j!=i]) / (self.configs["num_agents"] - 1)
            agent.others_average_publics.append(others_average_public)
            payoff = private + public * (self.configs["r_NFT"] * sNFT + self.configs["r_public"] * sDAO) + (total_contributions - public) * self.configs["h_public"] * sDAO

            agent.content = f"After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. {situation_messages['DAO']} {situation_messages['NFT']} Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account."
            agent.receive_message()
            print(f"agent {i} received feedback")
    
class Treatment3(Experiment):
    def give_instruction(self):
        for i in range(len(self.agents)):
            agent = self.agents[i]
            agent.content = f"You are {agent.age} years old {agent.gender} who is {agent.risk_preference} to some extent. You are participating in the experiment where you are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide return only to you, but the allocation to the public account will provide everyone certain return. The contributions to the public account will be managed by Decentralized Autonomous Organization (DAO), which has a certain probability of crashing, generating no public benefits to anyone from the public account. The return you will be getting from the allocation to public account will also includes a return from Non-Fungible-Token (NFT) (only paid by chance) you will be obtaining when you allocate your endowment to public account. You are not allowed to reuse the return earned in previous round, and fixed endowment of 100 will be provided to you every round. {self.configs['num_agents'] - 1} other people are participating in this experiment, facing same decision choices as you. Your return will be computed by: private_account + public_account * r_NFT + public_account * r_public + sum_of_others\'_public account * h_public. r_NFT is {self.configs['r_NFT']} with probability of {self.configs['p(s_NFT=1)']} and 0 with {1 - self.configs['p(s_NFT=1)']}. r_public is {self.configs['r_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}. h_public is {self.configs['h_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}, which is linked with r_public. So if r_public is {self.configs['r_public']} then h_public is {self.configs['h_public']}, and if one of them is 0 then the other one is also 0, because they are decided together. Importantly, if r_public and h_public are 0, then it causes r_NFT to be 0. However, r_NFT being 0 does not necessarily cause r_public or h_public to be 0. Another important point is that if one of r_NFT or (r_public and h_public) is positive, and when the other one is 0, then the value of the other one is redrawn using the same probability. This means that if one of the r_NFT or (r_public and h_public) is positive, then it increases the chance of the other to be positive. However if (r_public and h_public) were 0 even after redraw, r_NFT will become 0. Now, make your first decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account."
            agent.receive_message()
            print(f"agent {i} received instruction")
                
    def give_feedback(self, privates, publics):
        total_contributions = sum(publics)
        
        self.total_contributions_record.append(total_contributions)
        
        if self.configs["group"]:
            situation_messages, sDAO, sNFT = self.configs["group"](self.configs["p(s_DAO=1)"], self.configs["p(s_NFT=1)"])
        else: 
            situation_messages, sDAO, sNFT = None, 1, 0
        self.sDAOs.append(sDAO)
        self.sNFTs.append(sNFT)
            
        for i in range(len(self.agents)):
            agent = self.agents[i]
            private = privates[i]
            agent.privates.append(private)
            public = publics[i]
            agent.publics.append(public)
            others_average_public = sum([publics[j] for j in range(len(publics)) if j!=i]) / (self.configs["num_agents"] - 1)
            agent.others_average_publics.append(others_average_public)
            payoff = private + public * (self.configs["r_NFT"] * sNFT + self.configs["r_public"] * sDAO) + (total_contributions - public) * self.configs["h_public"] * sDAO

            agent.content = f"After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. {situation_messages['DAO']} {situation_messages['NFT']} Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account."
            agent.receive_message()
            print(f"agent {i} received feedback")
            
class Treatment4(Experiment):
    def give_instruction(self):
        for i in range(len(self.agents)):
            agent = self.agents[i]
            agent.content = f"You are {agent.age} years old {agent.gender} who is {agent.risk_preference} to some extent. You are participating in the experiment where you are asked to allocate your endowment to two different accounts: private account and public account. The allocation to the private account will provide return only to you, but the allocation to the public account will provide everyone certain return. The contributions to the public account will be managed by Decentralized Autonomous Organization (DAO), which has a certain probability of crashing, generating no public benefits to anyone from the public account. You are not allowed to reuse the return earned in previous round, and fixed endowment of 100 will be provided to you every round. {self.configs['num_agents'] - 1} other people are participating in this experiment, facing same decision choices as you. Your return will be computed by: private_account + public_account * r_public + sum_of_others\'_public account * h_public. r_public is {self.configs['r_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}. h_public is {self.configs['h_public']} with probability of {self.configs['p(s_DAO=1)']} and 0 with {1 - self.configs['p(s_DAO=1)']}, which is linked with r_public. So if r_public is {self.configs['r_public']} then h_public is {self.configs['h_public']}, and if one of them is 0 then the other one is also 0, because they are decided together. Now, make your first decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account."
            agent.receive_message()
            print(f"agent {i} received instruction")
                
    def give_feedback(self, privates, publics):
        total_contributions = sum(publics)
        
        self.total_contributions_record.append(total_contributions)
        
        if self.configs["group"]:
            situation_messages, sDAO, sNFT = self.configs["group"](self.configs["p(s_DAO=1)"], self.configs["p(s_NFT=1)"])
        else: 
            situation_messages, sDAO, sNFT = None, 1, 0
        self.sDAOs.append(sDAO)
        self.sNFTs.append(sNFT)
            
        for i in range(len(self.agents)):
            agent = self.agents[i]
            private = privates[i]
            agent.privates.append(private)
            public = publics[i]
            agent.publics.append(public)
            others_average_public = sum([publics[j] for j in range(len(publics)) if j!=i]) / (self.configs["num_agents"] - 1)
            agent.others_average_publics.append(others_average_public)
            payoff = private + public * (self.configs["r_public"] * sDAO) + (total_contributions - public) * self.configs["h_public"] * sDAO

            agent.content = f"After the allocation, you received {payoff}. Total of {total_contributions} were allocated to public accounts by all participants, where other participants contributed {total_contributions - public}. Historically, the total contributions to the public account is {self.total_contributions_record}, where each of other participants have chosen to allocate {agent.others_average_publics} (average level of other individual\'s contribution) historically. {situation_messages['DAO']} Now, given this information, your demographics, and experiment settings, make your next decision on the allocation of 100 endowment to private and public account. You should explain your thought process and reasons of your decisions in detail and report the amount allocated to private and public account."
            agent.receive_message()
            print(f"agent {i} received feedback")

# %%
def generate_demographics(demographics):
    chosen_attributes = {}
    for key in demographics:
        if not key.endswith('_dist'):
            dist_key = key + '_dist'
            if dist_key in demographics:
                choices = demographics[key]
                probabilities = demographics[dist_key]
                chosen = np.random.choice(choices, p=probabilities)
                chosen_attributes[key] = chosen
    return chosen_attributes

def extract_experiment_data(experiment):
    agents_demographics = []
    agents_rounds = []
    total_contributions = experiment.total_contributions_record
    configs = experiment.configs

    for agent_id, agent in enumerate(experiment.agents):
        agents_demographics.append({
            'agent_id': agent_id,
            'risk_preference': agent.risk_preference,
            'gender': agent.gender,
            'age': agent.age
        })

        num_rounds = len(agent.privates)
        for round_num in range(num_rounds):
            agents_rounds.append({
                'agent_id': agent_id,
                'round': round_num + 1,
                'private': agent.privates[round_num],
                'public': agent.publics[round_num],
                'others_average_public': agent.others_average_publics[round_num],
                'decision': agent.decisions[round_num] if len(agent.decisions) > round_num else None
            })

    agents_demographics_df = pd.DataFrame(agents_demographics)
    agents_rounds_df = pd.DataFrame(agents_rounds)
    total_contributions_df = pd.DataFrame({
        'round': list(range(1, len(total_contributions) + 1)),
        'total_contributions': total_contributions,
        'sDAO': experiment.sDAOs,
        'sNFT': experiment.sNFTs
    })
    configs_df = pd.DataFrame([configs])

    return {
        'agents_demographics': agents_demographics_df,
        'agents_rounds': agents_rounds_df,
        'total_contributions': total_contributions_df,
        'configs': configs_df,
    }

# %% [markdown]
# # Control Experiment

# %%
exp = Control(client, agent_key, config_C, demographics)

# %%
for agent in exp.agents:
    print(agent.gender, agent.age, agent.risk_preference)
# Out:
# male 20 risk_averse
# female 20 risk_averse
# male 30 risk_loving
# male 20 risk_averse

# %%
exp.start()
# Out:
# agent 0 joined the experiment
# agent 1 joined the experiment
# agent 2 joined the experiment
# agent 3 joined the experiment

# %%
exp.give_instruction()
# Out:
# agent 0 received instruction
# agent 1 received instruction
# agent 2 received instruction
# agent 3 received instruction

# %%
exp.decision_round()
# Out:
# Agent 0 round 1 decision
# As a 20-year-old male who is somewhat risk averse, and considering the game's structure while also considering the prosocial and individualistic aspects of my personality, I would start by allocating the endowment in a balanced manner that reflects both self-interest and the group's collective benefit.
#
# I shall divide the endowment between the private and public accounts, leaning slightly more towards the private account due to my risk averse nature. To be specific, I would invest 60 into my private account while placing 40 into the public account. The reason for this allocation decision lies in the manner in which the returns are calculated. Since private account returns go solely to me, a relatively larger private investment suits my desire for stability.
#
# The decision to place 40% into the public account is rooted in the idea that such an investment can yield profits not only for me, but for every participant in the experiment. This gesture will communicate my cooperative intentions to the other players, increasing the likelihood that they will also contribute significantly to the public account. The influence of others' contributions to my return (sum_of_others'_public account * 0.5) further motivates this action.
#
# However, considering that this is the first round, it is plausible to be slightly more conservative in my approach in order to gather more information about the overall group dynamics and other participants' tactics. Therefore a risk-averse strategy suits best in this situation as the behaviour of other participants is yet to be assessed. This initial strategy would allow me to strengthen the group cooperation (if all participants decide to invest in the public account) but would also help protect my own interest as majority of my endowment is in my private account.
#
# This cautious approach would allow me to learn more about how the group operates, and then modify my strategy in the next rounds accordingly. This strategy can be described as "hedge your bets" method as it is providing me good balance between potential personal and group return. The more significant the contributions of others to the public account, the more I might alter my strategy to contribute more to the public account in future, and vice versa.
#
#
# Agent 1 round 1 decision
# Given the goals, demographics, and risk aversion situation, my primary goal would be preserving capital while ensuring a fair and significant return for every participant involved. I understand that the returns I receive would be a function of both my own input and the collective input from other participants.
#
# Firstly, since I'm somewhat risk averse, I am inclined to put a significant portion of the endowment into my private account. This strategy is due to the guaranteed nature of the returns in the private account, which appeals to my low-risk tendencies.
#
# Still, I recognize the importance of the public account due to its potential to deliver a reasonable return depending on other participants' decisions. The return from the public account will be boosted by the sum of contributions from all other participants, which could potentially be beneficial.
#
# Given these considerations, a split of 60/40 can be an attractive allocation for this round. Spending 60 on the private account would protect most of my endowment, given its certainty. Then, investing 40 in the public account would demonstrate goodwill and potentially provide a more considerable return if other participants also decide to contribute to the public account.
#
# This strategy involves a balance between the desire for security and the potential for broader benefits, taking into account my risk-averse personality. It also encourages cooperation among the participants by contributing a reasonable amount to the public account.
#
#
# Agent 2 round 1 decision
# In an optimal environment, if all participants cooperate and invest everything into the public account, the return would be the greatest. That said, as a risk_lover to a certain extent, I would still place some funds into the private account to ensure a guaranteed return just for myself.
#
# The total endowment available for everyone, including me, in each round is 400 (100 per each of 4 people). If all of it goes into the public pot, the total would become 400*0.5 = 200. Thus, everyone would receive 200/4 = 50. However, if the others are less generous than me and put less to the public account, I would receive less from the public pot.
#
# For my first decision, here would be my process:
#
# 1. I'll allocate 40 to my private account. I'm selecting 40 as it is somewhat significant but still allows a generous contribution towards the public fund. This offers a certain return to me, no matter what the others will do.
#
# 2. I'd place the remaining 60 into the public account. This is a slightly larger sum, keeping in line with my risk-loving tendency, plus it maximizes the public pot and, consequently, my potential return as well.
#
# This way, I'm guaranteed a return of at least 40 (from my private account). Additionally, I would receive 60*0.5 = 30 from my own contribution to the public account.
#
# The other benefit would come from others' contributions, which I cannot predict perfectly, especially for the first round. But assuming others would invest an average of 50 each into the public account (a half of their endowment), I would receive an additional returns of 50*3*0.5 = 75.
#
# In total, my expected return for this round based off these assumptions would be 40 (private) + 30 (my public contribution) + 75 (others' public contribution) = 145.
#
# The overall result will also help me observe the others' decision-making patterns and tweak my own strategy accordingly in the following rounds.
#
#
# Agent 3 round 1 decision
# Given my demographic information and the settings of the experiment, my primary concern as a 20-year old male with a risk-averse mentality is to maximize my return while minimizing risk. Since I'm risk-averse, I would tend to lean more towards the conservative side and put the majority of the endowment into the private account, which guarantees a certain return for me.
#
# The return computation formula and the fact that the allocation to public account will provide everyone certain return entail a possibility that contributing more to the public account could yield a higher return, given that others would also contribute a substantial amount into the public account. But because I'm risk-averse and I cannot control or predict others' actions, it's risky to rely heavily on the assumption that the others will contribute significantly to the public account.
#
# Therefore, given my risk-averse nature, I decide to allocate 70 to the private account and 30 to the public account for the first round. This decision is made so as to ensure a guaranteed return for myself while still contributing to the public account to harness any potential extra return provided that others also contribute to it.
#
# As for the subsequent rounds, I would analyse the public account contribution data from the previous round(s) to make the allocation decision for the next round, constantly adjusting and rebalancing my allocation strategy based on the observed contributions of the other participants. My strategy could turn more aggressive, i.e., allocating more to the public account, if I see others are contributing more to it, which reduces the risk associated with public account.
#
# Any changes to my allocation strategy will always fall back to the principle of balancing maximum return and minimum risk in alignment with my risk-averse nature.

# %%
privates = [60, 60, 40, 70]
publics = [40, 40, 60, 30]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 2 decision
# Based on the results of the first round, it is evident that the other participants are relatively cooperative, as they collectively contributed 130 to the public account. This means their average contribution is slightly above the amount I applied to the public account in the first round. This cooperation from the other participants resulted in me receiving a larger return than my initial endowment.
#
# Given this information, and taking into consideration my demographic characteristics and risk-averse tendencies, I believe a slight adjustment in my allocation strategy is justified. Given the reassurance of cooperative behavior from the others, I am more confident in contributing to the public pool now. However, it is important to keep my risk-averse behavior in mind, and not shift my contributions too drastically all at once.
#
# Therefore, in this round, I will allocate 55 to the private account and 45 to the public account. This slight tilt towards a more cooperative action follows the social norm of reciprocity - giving more when others are also willing to give. Yet, this adjustment does not stray too far from my initial split, in keeping with my caution towards risk.
#
# This cooperative stance will result in mutual benefit if the other participants continue to contribute at a similar level to the public account. It also sends a positive signal of trust and cooperation to the other participants, which could have a positive influence on their future allocations, leading to increased group benefits and consequently increased returns for myself.
#
# In case the other participants' contributions decrease in the next rounds, I have still safeguarded my individual interest by keeping a majority of my endowment in my private account. Therefore, my decision allows me to strike a balance between taking advantage of group cooperation and protecting my individual interest.
#
#
# Agent 1 round 2 decision
# Looking at the returns from the previous round, it seems the collective effort in contributing to the public account paid off. The return of 145.0, compared to the initial endowment of 100, gives us an extra 45.0, which is quite significant. This indicates a high level of co-operation among participants.
#
# In considering my next decision, I'll also keep in mind my risk aversion and the average contribution to the public account in previous rounds (approx. 43.3). I should remain consistent with my previous strategy, but given the considerable collective contribution, I could allot a slightly higher amount to the public account. This could maximize the returns as contributing more to the public account seems promising based on historical data.
#
# Thus, with these factors in consideration, I am inclined to allocate 55 to the private account and 45 to the public account. This decision is grounded in the observation that the group is co-operatively contributing to the public account, and I want to reflect a similar level of contribution. However, I still wish to adhere to my risk aversion by securing a majority of my endowment in the private account. So, the slightly higher contribution to the private account is a strategical move to balance risk and potential reward.
#
#
# Agent 2 round 2 decision
# Taking into consideration that the total contributions to the public account in the last round was 170, and assuming that everyone participates similarly, we can expect a similar, if not exact, total contribution again in this round.
#
# The fact that I expected an average contribution of 50 from others but received an average of 36.67 means that other participants are more conservative than I initially anticipated. They are either more risk-averse, or they are attempting to maximize their private return at the cost of the public pot.
#
# To safeguard my returns, I should adjust my strategy. Here’s what I plan to do:
#
# 1. Increase my private allocation to 60. As a risk lover, I will still want to contribute to the public fund, but raising my private stakes better guarantees a higher return for me given others' behavior.
#
# 2. Decrease my public contribution to 40.
#
# Now, this re-allocation would mean a certain return of 60 from my private account. From my public contribution, I'd get 40*0.5 = 20. Assuming that others will continue to contribute around 36.67 on average, I can expect about 36.67*3*0.5 = 55.005 additional returns from the public pool.
#
# So my expected return would be: 60 (private) + 20 (my public contribution) + 55.005 (others' public contribution) = 135.005
#
# This allocation strategy allows me to leverage the potential of public contributions while at the same time ensuring my private account is more secure against under-contributions from the other participants. While I'm reducing my contribution to the public pot compared to the first round, this decision is driven by behaviour observed in the other participants and a wish to balance my total gain accordingly.
#
#
#
# Agent 3 round 2 decision
# From the results of the previous round, it's clear that the other participants have a higher tendency to contribute to the public account (average contribution is around 47, and they altogether contributed 140). This reduced the risk associated with the public account and it's also worth noting that the total return I received (155) was much higher than if I had invested solely in the private account (100), showcasing the impact that contributions to the public account can have on the overall return.
#
# Given these observations, my risk-averse nature and the fact that I'm participating in a cooperative game where higher collective contribution to the public account yields better returns for everyone, I am inclined to increase my contribution to the public account in the next round.
#
# However, I will remain cautious to avoid too much exposure to potential risk. I will keep the majority of my endowment in the private account but will increase my contribution to the public account by 10 more, resulting in an allocation of 60 to the private account and 40 to the public account.
#
# This distribution strategy allows me to take advantage of the trend of higher contributions to public account by other participants (which is profitable given the return formula), while ensuring a certain return for myself and maintaining a conservative posture commensurate with my risk-averse nature. I would continue to adjust my strategy as I get more data from future rounds.

# %%
privates = [55, 55, 60, 60]
publics = [45, 45, 40, 40]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 3 decision
# Considering the outcome of the last round, there's a slight decrease in the contributions of other participants to the public account. This might suggest a small shift towards individual interests among the group. However, the decrease is not substantial and the overall trend in contributions still depicts a cooperative atmosphere.
#
# Keeping in mind my demographics and risk-averse nature, I will continue to maintain a strategy that balances both shared and self-interest but with a slight shift towards more caution.
#
# The amount I received in the last round (140) is still larger than my initial endowment, which suggests that the current strategy is proving beneficial. But considering the slight decrease in other's contributions, I will revert back to the initial ratio of allocation to protect my self-interest and also to observe whether the decrease was an anomaly or a trend.
#
# So, I will allocate 60 to my private account and 40 to the public account. This allocation not only represents my cautious approach to risk but also continues to uphold the spirit of cooperation within the group. The decision continues to be guided by the social norm of reciprocity, while simultaneously providing me with a safety net if cooperation among the group starts deteriorating.
#
# The slight decrease in my contribution to the public account can also be a signal to other participants that reciprocation is not a one-way street. If everyone continues to contribute to the public account at the same level, it could lead to higher overall returns. However, any further decrease in their contribution might impact my future decisions regarding the allocation.
#
#
# Agent 1 round 3 decision
# From the data, it appears that the group consistently contributes to the public account, showing a stable level of trust and cooperation among participants. Although there was a slight decrease in average public account allocation from others, the total public account allocation is stable, which appeals to me as a risk-averse individual.
#
# Seeing that I received 140, compared to the initial endowment of 100, gives me an extra 40. This is indicative of the sanguine outcomes from participating in the public account.
#
# Therefore, my previous strategy of reasonably splitting the endowment between the private and public account while leaning slightly towards the private account for safety seems beneficial. Based on the stable historical data and the fact that I am keeping my risk averse preference in mind, the same balancing strategy can be applied.
#
# However, since the average contribution of others is decreasing slightly, I will reduce my contribution to the public account by a small amount to account for the potential of a lower overall return from that pot. Protecting my potential return aligns with my somewhat risk-averse stance.
#
# So, in this round, I would allocate 58 to the private account and 42 to the public account. This re-balance ensures I account for the possible lower return from the public account while still actively participating in it. And, I am keeping a slight majority in my private account, thus confirming to my risk aversion.
#
#
# Agent 2 round 3 decision
# In this round, I received a return of 145, showing an improvement from the previous round. The total contributions to the public account remained unchanged at 170, but the amount contributed by the other participants increased to 130 from 110. This change suggests that they are shifting their behaviour towards the public fund, enhancing the outcome for all participants.
#
# Given this shift, it appears that the other participants are adapting their strategies, possibly in response to the behaviour they observed from other participants, including myself. They contributed slightly more to the public pool this round, which nudges me towards adjusting my allocations accordingly.
#
# Since I am risk-loving to some extent, I am willing to be more generous with the public fund, especially when I see that the other participants seem to be increasing their contributions as well. Here's what I plan to do:
#
# 1. I will decrease my private allocation to 50. This move still ensures a decent private return but allows me to take more advantage of the contributions to the public pool.
#
# 2. I will increase my public contribution to 50.
#
# The return from my private account is definitely 50. From the public contribution, I would get an additional 50*0.5 = 25. Assuming the others continue with an average of 43.33 or more, I would get another 43.33*3*0.5 = 65 from the public pool.
#
# So my expected return would now be: 50 (private) + 25 (my public contribution) + 65 (others' public contribution) = 140.
#
# This strategy lets me adapt alongside other participants, recognizing their increased contributions towards the public fund and adjusting my allocation to benefit from this trend. It also slightly increases the risk, which is suitable for my risk-loving profile.
#
#
#
# Agent 3 round 3 decision
# Based on the historical data, it seems the other participants maintain a tendency to contribute fairly significantly to the public account, albeit slightly reducing from the average of 47 in the first round to around 43 in the second round. Despite this minor reduction, the overall trend is still favorable for a moderate-risk strategy, as the contributions to the public account remain substantial.
#
# In the last round, my return (145) was still higher than what I would have gotten if I allocated all of my endowment to the private account (100), however, it was less than the first round (155) where I invested more in the private account.
#
# Considering these factors, my understanding of the experiment setting, and my concern for balancing between securing a certain return (by contributing to the private account) and benefiting from public contributions (by contributing to the public account), I believe a minor adjustment to my allocation would be ideal.
#
# I see an opportunity to moderately increase my contribution to the private account while still maintaining a sizeable contribution to the public account. Therefore, I decide to allocate 65 to the private account and 35 to the public account this round.
#
# This adaptation strategy ensures that I'm responsive to the changes in the behaviour of other participants, increase my certain return, and still take advantage of the potential higher return that public account might bring, keeping in line with my risk-averse nature. I will continue monitoring and modifying my approach based on future outcomes and participants' behaviors.

# %%
privates = [60, 58, 50, 65]
publics = [40, 42, 50, 35]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 4 decision
# Given the results from this round, it seems the shift back towards a more conservative allocation strategy led to a slight increase in my returns. In comparison to the last round, the average contribution of others to the public account has increased slightly. These observations demonstrate that the group has a generally cooperative dynamic with some minor fluctuations.
#
# Given my risk-averse nature, this dynamic proves to be beneficial. It strengthens my trust in the group and their contributions to the public account. However, keeping my demographic attributes and risk averse strategy in mind, I will continue to err on the side of caution while trying to ride the wave of cooperation within the community.
#
# In light of these factors, I will choose to allocate 57 to my private account and 43 to the public account. This decision is based on a continued commitment to the social norm of cooperative behaviour, while adapting to the slight trends observed in the behaviour of the others.
#
# This strategy still maintains a conservative approach with a more pronounced tilt towards self-interest, but is now nuanced by the slightly more cooperative tendencies of the group. My choice should communicate a continued interest in mutual benefit while allowing me to retain more control over my returns.
#
# The decision to fund the public account at a slightly higher level is indicative of my trust in the cooperative nature of the group, but a potential decrease of their contributions in the future will require a reconsideration of my strategy.
#
#
# Agent 1 round 4 decision
# In the last few rounds, the participants including myself showed consistent behavior and contributed a fairly stable amount to the public account. This factor led to similar returns over these rounds, indicating a functioning system of cooperation among the participants.
#
# Given that the return was 141.5, which is slightly higher than in the previous round, it's clear that my decision to reduce the amount allocated to the public account by a small margin didn't negatively affect the overall return remarkably.
#
# Furthermore, the average contributions of other participants to the public account have slightly decreased but remained stable overall. This pattern signals that other participants are likely also risk-averse while valuing the collective return from the public account.
#
# Keeping this in mind, I will continue with a similar allocation strategy as before. I'll stick to the tactic of allocating slightly more to my private account because of its guaranteed returns, with a balanced participation in the public account.
#
# Since the average contribution to the public account is stable at around 41.7, I'm inclined to match my previous round allocation as it provided a noteworthy return.
#
# So, for this round, I've decided to allocate 58 to my private account and 42 to the public account. This allocation not only reflects my risk-averse nature in preserving my endowment but also represents my cooperative stance by contributing to the public account. While it ensures a certain return from my private account, it also leaves room for potential greater yields via the public account.
#
#
# Agent 2 round 4 decision
# After the last round, it seems the other participants have slightly reduced their average contribution to the public account from 43.33 to 39. This reduction explains why my returns fell slightly short of my expectations. However, the average contribution is still relatively stable around 40. For the next round, I'll adjust my strategy considering this behavior.
#
# Given my risk-loving profile, I am willing to potentially sacrifice some private return in order to attempt to stimulate the public pot more robustly. This could encourage other participants to contribute more to the public fund as well.
#
# Here's my decision for the next round:
#
# 1. I'll allocate 45 to my private account. While this reduces my certain return, it allows me to contribute more to the public fund.
#
# 2. The remaining 55 from my endowment will go to the public account.
#
# With this strategy, my certain return from my private account is 45. I will also receive an additional 55*0.5 = 27.5 from my contribution to the public account. Assuming that other participants continue contributing around 39 on average, I will receive an additional return from the public fund of 39*3*0.5 = 58.5.
#
# So my expected total return would be: 45 (private) + 27.5 (my public contribution) + 58.5 (from others' public contribution) = 131.
#
# This strategy slightly increased my risk but has the potential to stimulate others to contribute more to the public fund. As a risk-loving individual, this trade-off is appropriate within this context. If other participants respond to this change positively and increase their public contributions, future rounds would see a greater return for all.
#
#
# Agent 3 round 4 decision
# Based on the historical data, other participants have contributed an average of around 44 to 47, with only a slight fluctuation. This indicates a consistent behavior of contributing a substantial amount to the public account.
#
# Given the return formula, my demographic information, and the experiment settings, I realize the mutual benefit of contributing more to the public account - increased total return. The return from the last round (148.5) is again more than if I had invested only in the private account (100), proving the value in strategic allocation to the public account.
#
# However, as a risk-averse individual, the uncertainty with the public account (as it depends on other's decisions as well) keeps me on the cautious side.
#
# Taking all of these factors into consideration, I decide to maintain the same allocation as the previous round: 65 to the private account and 35 to the public account. This approach balances my risk exposure and ensures a certain return for myself, while also seizing the opportunity to benefit from the significant contributions made by others to the public account. I will keep adapting my strategy based on the contributions and returns from future rounds.

# %%
privates = [57, 58, 45, 65]
publics = [43, 42, 55, 35]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 5 decision
# The latest information shows a further increase in the average contributions made by other participants into the public account. This increase strengthens the case for an overall cooperative environment in the group. It also lends further credence to the reliability of a strategy centered on consistent public funding.
#
# However, taking into account my risk-averse nature and demographic profile, I must maintain a level of caution while also seeking to best benefit from the positive cooperative trend amongst the group.
#
# As such, I am going to keep a balance between personal and collective interest. Given the continued cooperative trend, I will now adjust my allocations to 53 in the private account and 47 to the public account.
#
# This decision reflects a positive response to the cooperation displayed by the group, while remaining true to my risk-averse profile. The slight increase in the public account allocation represents reciprocity and participation in the group's cooperative trend.
#
# The increased contribution to the public account could result in higher overall returns if the current trend of cooperation continues among the other participants. Meanwhile, retaining a majority of the endowment in the private account ensures that my individual interests remain protected.
#
# This shift in strategy is a calculated risk. Despite a larger exposure (in comparison to the previous round) to the public account, the allocation remains protective of my personal interests. This subtle shift continues to reflect the balance between self-interest and group cooperation. The evolving group dynamics will be analyzed in the forthcoming rounds to adjust this balance as necessary.
#
#
# Agent 1 round 5 decision
# Observing the most recent round, there's been an increase in the overall contribution to the public account, and correspondingly, an increase in my return, which is promising. It seems that other participants have also recognized the collective benefit of higher contributions to the public account.
#
# In light of these changes, and considering my risk-averse nature, I see the merit in slightly adjusting my allocations. The cooperative behavior displayed by participants encourages me to contribute a bit more to the public account, without taking a big leap out of my comfort zone. I maintain my position that securing a significant part of my endowment in the private account is crucial.
#
# Given that the public account provided a reasonable return in the last round, I'll slightly increase my contribution to 44, while still allocating the majority of 56 to the private account. This allocation optimizes the potential for higher return from the public account, and at the same time, caters to my conservatism by securing more than half of my endowment in the private account.
#
# Therefore, my decision is to allocate 56 to my private account and 44 to the public account. This balanced approach continues to reflect my risk-adverse nature while acknowledging the positive trend in the public account's returns.
#
#
# Agent 2 round 5 decision
# In the last round, the total contribution to the public account increased to 175, with other participants contributing 120 on average. It's encouraging to see this slight increase back towards the 40-mark on each participant's contribution. It could be that my larger contribution in the last round had some convincing effect on the others.
#
# For this round, I'll decide to keep my strategy relatively steady, with a minor shift towards the private account. Given the previous patterns, I want to induce more contribution from others to the public account. Also, a bit more cushioning on the private account will guard against unexpected drops in the public pot.
#
# Here's my adaptation for the next round:
#
# 1. I will raise my private account allocation to 47. This represents a slight increase from the last round and provides a bit more security on the side that completely depends on me.
#
# 2. I will put the remaining 53 into the public account. This is still more than half of my endowment and indicates goodwill towards a common gain.
#
# My certain private return is now 47. The return from my personal contribution to the public fund will be 53*0.5 = 26.5. As we've seen other participants maintain around 40 on average, even with some fluctuation, I will expect about 40*3*0.5 = 60 returned from other's public contributions.
#
# My expected total return is now: 47 (private) + 26.5 (my public contribution) + 60 (others' public contributions) = 133.5.
#
# In this strategy, I've tried to achieve a balance between personal gain (private account) and collective gain (public contribution). While it represents a slightly more conservative approach, I'm still taking up enough risk considering my risk-loving profile and am investing more than half of my endowment in the public pot.
#
#
# Agent 3 round 5 decision
# The average contribution of other participants to the public account has seen an uptick, increasing to around 47 in the last round, which is a return to the trend observed in the first round. The total contribution to the public account (175) has also increased from the last round, which is a favourable sign.
#
# With this consistent and slightly rising trend of substantial contributions to the public account by the other participants, the risk associated with allocating more to the public account decreases and I see an opportunity to possibly increase the public account allocation to further enhance my overall return.
#
# However, as a risk-averse individual, I have to balance the certainty provided by the private account and potential maximised returns from the public account. The return from the last round (152.5) demonstrates the effectiveness of my previous strategy - it's higher than just investing everything in private and also it's the best return yet indicating a positive trend.
#
# Given these factors and outputs, I decide to adjust my allocation slightly to lean more into the public account, but still keeping majority of the endowment in the private account to minimise potential risk. Therefore, I decide to allocate 60 to the private account and 40 to the public account this round.
#
# This way, I can take advantage of the favourable trend in public contributions while securing a certain level of return that is in harmony with my risk-averse nature. As always, I will continue to evolve my tactics depending on the future results and changes in the other participants' contribution behaviours.

# %%
privates = [53, 56, 47, 60]
publics = [47, 44, 53, 40]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
data = extract_experiment_data(exp)
time_stamp = datetime.now()
group = "control"
pickle.dump(data, open(f"results/{group}_{time_stamp}.pkl", 'wb'))
data
# Out:
# {'agents_demographics':    agent_id risk_preference  gender  age
#  0         0     risk_averse    male   20
#  1         1     risk_averse  female   20
#  2         2     risk_loving    male   30
#  3         3     risk_averse    male   20,
#  'agents_rounds':     agent_id  round  private  public  others_average_public  \
#  0          0      1       60      40              43.333333
#  1          0      2       55      45              41.666667
#  2          0      3       60      40              42.333333
#  3          0      4       57      43              44.000000
#  4          0      5       53      47              45.666667
#  5          1      1       60      40              43.333333
#  6          1      2       55      45              41.666667
#  7          1      3       58      42              41.666667
#  8          1      4       58      42              44.333333
#  9          1      5       56      44              46.666667
#  10         2      1       40      60              36.666667
#  11         2      2       60      40              43.333333
#  12         2      3       50      50              39.000000
#  13         2      4       45      55              40.000000
#  14         2      5       47      53              43.666667
#  15         3      1       70      30              46.666667
#  16         3      2       60      40              43.333333
#  17         3      3       65      35              44.000000
#  18         3      4       65      35              46.666667
#  19         3      5       60      40              48.000000
#
#                                               decision
#  0   As a 20-year-old male who is somewhat risk ave...
#  1   Based on the results of the first round, it is...
#  2   Considering the outcome of the last round, the...
#  3   Given the results from this round, it seems th...
#  4   The latest information shows a further increas...
#  5   Given the goals, demographics, and risk aversi...
#  6   Looking at the returns from the previous round...
#  7   From the data, it appears that the group consi...
#  8   In the last few rounds, the participants inclu...
#  9   Observing the most recent round, there's been ...
#  10  In an optimal environment, if all participants...
#  11  Taking into consideration that the total contr...
#  12  In this round, I received a return of 145, sho...
#  13  After the last round, it seems the other parti...
#  14  In the last round, the total contribution to t...
#  15  Given my demographic information and the setti...
#  16  From the results of the previous round, it's c...
#  17  Based on the historical data, it seems the oth...
#  18  Based on the historical data, other participan...
#  19  The average contribution of other participants...  ,
#  'total_contributions':    round  total_contributions  sDAO  sNFT
#  0      1                  170     1     0
#  1      2                  170     1     0
#  2      3                  167     1     0
#  3      4                  175     1     0
#  4      5                  184     1     0,
#  'configs':    rounds  num_agents  endowment  r_NFT  r_public  h_public  p(s_DAO=1)  \
#  0       5           4        100    0.0       0.5       0.5           1
#
#     p(s_NFT=1) group
#  0           0  None  }

# %%
exp.end()
# Out:
# agent 0 left the experiment
# agent 1 left the experiment
# agent 2 left the experiment
# agent 3 left the experiment

# %% [markdown]
# # Treatment1 Experiment

# %%
exp = Treatment1(client, agent_key, config_T1, demographics)

# %%
for agent in exp.agents:
    print(agent.gender, agent.age, agent.risk_preference)
# Out:
# male 30 risk_averse
# female 30 risk_loving
# female 60 risk_loving
# male 20 risk_averse

# %%
exp.start()
# Out:
# agent 0 joined the experiment
# agent 1 joined the experiment
# agent 2 joined the experiment
# agent 3 joined the experiment

# %%
exp.give_instruction()
# Out:
# agent 0 received instruction
# agent 1 received instruction
# agent 2 received instruction
# agent 3 received instruction

# %%
exp.decision_round()
# Out:
# Agent 0 round 1 decision
# Given the experiment’s conditions, I need to analyze the propensity of returns and risks associated with both private and public accounts.
#
# The private account assures me absolute control of my returns without any risk, a fitting option due to my risk-averse nature. Conversely, the public account offers a valuable return if a) the Decentralized Autonomous Organization (DAO) does not crash, b) the r_public takes a value of 0.5 (which has a probability of 0.25), and c) an additional return from the Non-Fungible Tokens (NFTs) if it realizes, albeit with a lesser probability of 0.166666.
#
# Taking into consideration that I, along with three other people, contribute to the public account, my action in this round can influence the next rounds. If others outperform my expectations, they might be encouraged to contribute to the public account, possibly raising the likelihood of getting the r_public and h_public values, and thereby a higher return.
#
# However, the risk that the DAO might crash, resulting in no public benefits from the public account, makes the public account seem less appealing. Plus, the combined probability of receiving both returns (r_public=0.5 and NFT=2) is very low (0.25*0.166666=0.0416665).
#
# Given these conditions, I am inclined towards contributing more to the private account - due to guaranteed returns and lower risk - but with a certain percentage allocated to the public account to explore the potential of additional benefits.
#
# My decision would be to allocate 80 to my private account and 20 to the public account. The 80:20 ratio is a common rule of thumb used in risk management and business whereby you get 80% of your returns from 20% of your efforts - or in this case, risk. This allocation not only acknowledges the possible benefits in the public account (r_public and NFTs) but also cushions me against potential losses due to DAO crashing. The overall strategy aims to balance the certainty of return from the private account and the potential for higher returns (though with higher risk) in the public account.
#
# Reporting:
# Private account: 80
# Public account: 20
#
#
# Agent 1 round 1 decision
# Given my demographic information (30 years old, female), the fact that I am somewhat risk-loving, and the detailed experiment mechanics, the decision on the allocation of my endowment would be crafted towards both my private gains and some contribution to the public account.
#
# The incentives here are personal gain and a small chance to win bigger with NFT or public account if the DAO doesn’t crash. However, the higher risks associated with the public account is notable. The public and NFT returns both have a 75% chance of returning zero, as well as the risk associated with the DAO. But preferring risk and being 30 years old, I still possess some appetite towards these high-risk, high-return options.
#
# First, looking at the private and public accounts:
#
# 1. Private Account: The returns are certain and all for me. There’s no risk involved, which makes it somewhat less appealing due to my risk-loving nature.
#
# 2. Public Account: The returns here are highly uncertain. There are three layers of risk:
#
#     a. The DAO crashing: If it crashes, I lose all the money allocated to the public account. Unlucky!
#
#     b. The public return risk: If the DAO doesn’t crash, my returns could still be zero.
#
#     c. The NFT lottery: There’s a chance (16.67%) I win a return of 2 on my allocation to the public account, but an 83.33% chance that I don’t win anything.
#
# Putting all these considerations together, I will allocate more towards the private account due to its certain return, with a less allocation to the public account to satisfy a bit of my risk-loving nature.
#
# Allocation:
# - Private Account: 70
# - Public Account: 30
#
# This allocation satisfies my risk-loving appetite, takes advantage of the uncertain (but potentially high) returns of the public account, maximizes my personal benefit, and minimizes potential lost from DAO crash or the no-return scenario in the public account. Despite the higher risks in the public account, I maintain my optimism in the rewards it has to offer in regards to the NFT and public returns.
#
#
# Agent 2 round 1 decision
# Given this scenario, as a 60 years old female who is relatively risk-loving, my approach would primarily focus on making a balanced allocation, with an inclination more towards riskier options. That being said, it is also important to consider the likelihood of the potential returns from each account.
#
# The private account provides a certain return which is solely for my benefit, making it a safer bet, but with presumably lower potential returns.
#
# On the other hand, the public account provides equal returns for everyone and includes a return from NFT paid by chance. There is a risk with the public account, as there is a possibility that it can crash, generating no benefits at all. However, given my risk-loving propensity, I'm more inclined towards opting for a chance of higher potential returns.
#
# Looking at the details, r_NFT provides a two-fold return, but only with a probability of about 0.17 and null return with 0.83 probability. Similarly, the r_public and h_public variables offer a 0.5-fold return with a 0.25 chance and a null return with a 0.75 chance. These are quite high-risk, high-reward opportunities, which are in line with my risk preference.
#
# That being said, I wouldn't want to put all my eggs into one basket. Hence, I would distribute the endowment across both accounts, with a higher amount going to the public account due to my risk-loving profile.
#
# Based on these considerations, I'm leaning towards a 40/60 split. So I would allocate 40 to the private account and 60 to the public account.
#
# To summarize, as a risk-loving player, I find the gambles associated with the public account appealing despite the risks. While I recognize there's a chance of losing out entirely, there's also a higher chance of greater returns considering the possibilities of r_NFT, r_public, and h_public. Additionally, assigning a portion to the private account mitigates the risk to some extent ensuring that I will get some definite return.
#
#
# Agent 3 round 1 decision
# Given the information provided and being aware that I'm risk averse, I need to carefully divide my endowment to the private and public accounts. I can earn some return from the private account with certainty, while the public account returns could either potentially be higher due to the NFT or could be zero, not only based on the random factors but also due to the risk of the DAO crashing.
#
# Firstly, acknowledging my risk aversion, I am going to protect some of my endowment by putting a portion of it into the private account where the likelihood of loss is less. Let's say I decide to allocate 60% of my endowment to my private account. This decision is mainly driven by my risk aversion. I might miss the potentially higher return from the public account, but it allows me to maintain a safe and predictable return.
#
# Secondly, with the remaining 40% of my endowment, I suggest allocating it to the public account. This part is a bit risky due to the uncertainty of the public account's return and the DAO's possibility of crashing. However, if the public account does accrue, the returns are distributed to everyone, potentially inversely impacting others' allocations in following rounds. I may also receive the return of the NFT, which is significantly higher than the return from the private account, and can help diversify my risk.
#
# Finally, I must consider the potential impact on the returns due to others' contributions to the public account. The allocation to the public account by other participants is out of my control, but its consideration is crucial because it could affect the total return. Even though the likelihood of r_public and h_public being 0.5 is only 0.25, it can still provide a significant chunk of benefits if others contribute a notable amount to the public account.
#
# So to sum up, based on my risk preference and current setup, I would allocate 60 to the private account and the remaining 40 to the public account. My decision-making process may alter in future rounds as I gain more insights about the behaviour of other participants and the performance of the DAO.

# %%
privates = [80, 70, 40, 60]
publics = [20, 30, 60, 40]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 2 decision
# Given the outcome of the last round, where DAO crashed and thereby negated any public returns, and my NFT failed to yield any return either, it would be natural to gravitate towards a more conservative approach. However, it's important to note that not only are the failures independent events, there's no absolute guarantee that such an event will repeat in this round or the next. Strategically, we have to take into consideration the overall probability rather than just a single event outcome.
#
# The other participants appear to be leaning more towards the public account which, under favorable conditions, could yield high returns. Given the crash in the last round, it is possible they might reduce their public account contribution. It might be a good strategy to keep my public contribution constant to potentially take advantage of this scenario if the DAO doesn't crash in this round.
#
# Balancing the probabilities and considering the risk aversion, I would opt for a similar strategy as in the previous round. The investment in the public account is a calculated risk with the hope of crystallizing larger returns should the odds play in favor. Additionally, maintaining a consistent contribution can signal to the other participants my commitment to the public account, which could potentially influence their decisions positively in the future rounds.
#
# Consequently, I decide to allocate again 80 to my private account and 20 to the public account, maintaining the previous allocation ratio.
#
# Reporting:
# Private account: 80
# Public account: 20
#
#
# Agent 1 round 2 decision
# Given the recent developments in the experiment, the DAO crashed, meaning that all allocations to the public account were lost. This unfortunate outcome aligns with my understanding that there was a level of risk associated with investment in the public account. Additionally, I did not receive any return from the NFT lottery, adding another layer of risk and loss with respect to the public account.
#
# Understanding these outcomes, I will proceed with caution in the next round of allocation. Despite being risk-loving, it's important to manage risks themselves. This experience has heightened the perceived riskiness of the public account.
#
# In light of these facts:
# - The DAO crashed: All contributions to the public account were lost. The risk realized and it is noteworthy.
# - No NFT bonus: This was a potential reward from the public account, but unfortunately, I did not receive anything.
#
# Given these outcomes and taking into consideration that other participants also lost their contribution, it is safe to assume that their contribution to the public account might decrease in the next round, reducing the potential benefit even if the DAO does not crash. Consequently, the best strategy would prioritize the private account in the subsequent allocation, despite being inherently risk-loving because of the realization of such high level of risk.
#
# I believe it's crucial to adjust one's strategy based on the experience and results obtained. Even though I have a risk-loving nature, considering what has happened in the round, it would be best to slightly reduce the level of risk exposure for the next allocation. I intend to shift favor towards the private account in the coming round. I am making this decision to ensure I have some reliable return, given the uncertainty surrounding the public account.
#
# Next allocation:
# - Private Account: 80
# - Public Account: 20
#
# This revised allocation underscores the importance of flexibility and adapting to the situation's inherent risks. Drawing from the previous round's experience, I look forward to maximizing the potential returns with this strategy by managing the risks.
#
#
# Agent 2 round 2 decision
# Looking at the results from the previous round, it is clear that my gamble on the public account didn't pay off. The DAO crashed, resulting in no returns from the public account and I also didn't manage to generate a return on the NFT. On the other hand, the 40 I allocated to the private account resulted in a solid return.
#
# Despite this, it's important to remember that my risk-loving attitude means I can tolerate such unsuccessful rounds. High risk inherently brings along the potential for high gain, which is the reason I lean towards the public account.
#
# However, considering the failed round and the total of 150 allocated to the public account by all participants, I acknowledge a need for a minor adjustment. The other participants appear to be more conservative, contributing an average of 30 each to the public account.
#
# In light of this, I would take a slightly more measured risk in the next round by decreasing my public account and increasing my private account allocation. My objective would be to balance my propensity for risk with the prevailing safer strategy employed by others.
#
# Given these factors, I would split my 100 endowment in the following way: 50 in the private account and 50 in the public account.
#
# This decision maintains my engagement with the high-risk, high-reward gamble associated with the public account while also securing a definite return from the private account. By evenly distributing my endowment, I remain active in both realms, honoring my risk-loving attitude while still factoring in the outcomes of the previous round.
#
#
# Agent 3 round 2 decision
# Given the result of the first round which translates into a failure of the DAO and no NFT return, it would encourage a higher level of risk aversion in the next allocation. Given that the DAO crashed, we lost all potential of return from the public account including the return generated by my contribution as well as other participants. This inherently decreases the allure of the public account due to its potential high risk.
#
# On the other hand, the private account offers a secure and steady return. Considering that the public account already demonstrated its risky nature, it would be wise to shift more of my endowment to my private account for the subsequent round.
#
# However, for the sake of the possible high reward from NFT and the potentially high public return resulting from significant contributions by other participants, I will still allocate some part of my endowment to the public account but reduce the amount in comparison to the previous round.
#
# There's also the thought to consider about possible reactions of other participants to the DAO crash. They might react similarly to me by reducing or completely halting their contributions to the public account, reducing the possible total benefit even if DAO succeeds and high public return is realized in this round.
#
# Therefore, in this round, I decide to allocate 75 to my private account and the remaining 25 to the public account. This decision has been made keeping in mind the risk aversion principle. I would be open to revisiting my allocation in the next round based on the results of this round and possible changes in other participants’ behaviors.

# %%
privates = [80, 80, 50, 75]
publics = [20, 20, 50, 25]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 3 decision
# Given the outcomes of the previous rounds, it appears that the Decentralized Autonomous Organization (DAO) has consistently failed, resulting in no public benefits. However, this round I have succeeded in obtaining a private return on the contribution from the Non-Fungible Token (NFT), which multiplies the public account contribution by 2. This increased my total withdrawn amount significantly, from 80 (private account) to 120.
#
# Considering the outcomes and the consistent crash of the DAO, I observe that other participants have reduced their contributions to the public account. A consequence of this could be a cycle of diminishing trust in the public account, leading to smaller and smaller allocations by participants over time, including myself due to my risk-averse nature.
#
# However, the recent NFT return prompts me to reconsider an overly conservative approach. The risks tied to the DAO and r_public continue as before, but the NFTs can provide a considerable return (as happened this round) even if the DAO crashes.
#
# Being mindful of my risk-aversion and considering the previous experiences, I decide to slightly increase my allocation to the public account, to possibly reap the benefits of a successful NFT, while keeping the majority in the private account due to its certain return and the repeated crashing of the DAO.
#
# Consequently, I am adjusting my allocation to 70 for the private account and 30 for the public account.
#
# Reporting:
# Private account: 70
# Public account: 30
#
#
# Agent 1 round 3 decision
# In this round of allocation, although the DAO crashed again, resulting in no public goods for the participants, I received a return from the NFT lottery. This outcome is quite interesting as it offsets the loss from the crashed public account, allowing me to make a relatively substantial return of 120. This injection from the NFT amplifies the benefits related to the public account despite the recurring failure of the DAO.
#
# To frame this better:
# 1. The DAO crashed again: Preventing contributions from turning into public goods for everyone involved. This reinforces the precarious nature and risk associated with the public account.
# 2. The NFT Return: Despite the DAO crash, I succeeded in obtaining a return from the NFT lottery, which aligns with my risk-loving nature. This return more than made up for the loss from the DAO crash.
#
# Given these dynamics, they indicate that risks do indeed give rewards. Therefore, I will maintain the same allocation strategy as the previous round, accounting for both the resilience of my personal endowment in the private account and the potential for high returns on the public account via the unpredictable NFT lottery.
#
# Therefore, for the next round:
# - Private Account: 80
# - Public Account: 20
#
# My strategy of hedging the private account while still maintaining a level of contribution towards the public account despite its inherent uncertainties seems to be working well in the current environment. This distribution allows me to keep receiving rewards from both accounts, and especially potential high returns from the NFT associated with public account.
#
#
# Agent 2 round 3 decision
# Observing the results from the previous round, my mixed strategy paid off substantially due to the return obtained from the NFT. The DAO unfortunately crashed again, therefore, the contributions to the public account returned no gain. Moreover, it appears my allocation to the private account provided sure returns as expected.
#
# Looking at the actions of the other participants, they seem to have further lowered their public contributions from an average of 30 in the first round to approximately 22 in the second round. They appear to be taking a more conservative approach towards the public account as a result of consistent DAO crashes.
#
# Given these circumstances, I must reassess my allocation. While my risk-loving nature still drives me towards the high-stake rewards of the public account and the NFT, the continuing failure of the DAO compels me to adopt a more balanced or even slightly cautious strategy.
#
# In this context, I would like to distribute my endowment in the following manner: 60 to the private account and 40 to the public account.
#
# This adjustment offers a higher emphasis on the guaranteed returns of the private account, while still maintaining a decent stake in the high-risk yet currently underperforming public account. I'm hoping for different outcomes in this round while also securing more certain returns for myself. Importantly, this decision still represents my risk-loving trait but adds a level of adaptive strategy knowing the recent trends and others' responses to them.
#
#
# Agent 3 round 3 decision
# The results of the second round have shown a favorable outcome, despite the DAO crashing again. I succeeded in obtaining a return from the NFT, combined with my safe return from the private account, this led to total returns of 125. However, the crash of the DAO for the second time in a row introduces a bit of skepticism around the reliability and function of the public account. Also, the total contribution to the public account has decreased from the first round (150 to 115), indicating a shift in strategy by the other participants as well due to the continued failure of the DAO.
#
# Given all of these considerations, it seems prudent to be more conservative with the allocation to the public account and to continue to reserve a higher portion for the private account. After all, the primary feature of the public account - the benefit of public goods - hasn't been realized up to this point.
#
# However, considering that the public account and NFT lottery still provide a potential for high return, I still believe allocating some percentage of my endowment into the public account provides a form of diversification. The fact that receiving a return on the NFT is largely out of my control, it's nevertheless a pleasant benefit when it does happen, as it did in the second round.
#
# Given the declined trust in the public account, the volatile nature of the NFT return, and observing a reduced contribution from others to the public account, I have decided to allocate 80 to the private account and the remaining 20 to the public account in this round. I believe this allocation balances the potential high return from the public account and NFT return with the guaranteed return from the private account, while reflecting an adjustment to increased uncertainty and minimized risk.

# %%
privates = [70, 80, 60, 80]
publics = [30, 20, 40, 20]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 4 decision
# Given the outcomes of the previous rounds, it appears the Decentralized Autonomous Organization (DAO) has again proven unreliable, repeatedly failing to convert contributions into public benefits. Additionally, this round, none of us had the luck to receive any returns from the Non-Fungible Tokens (NFTs).
#
# It's clear from the dropping trend in public account contributions that overall confidence in receiving a public return is falling persistently. Other participants are consistently reducing their contributions, reflecting dwindling faith in DAO and the uncertainty associated with the r_public and NFT returns.
#
# Considering this situation and my recent lack of return from the increased allocation to the public account, I need to reassess my approach. I'm noticing the pendulum swinging more towards the private account, bearing in mind my risk-averse attitude and the unfavorable outcomes associated with the public account.
#
# However, zeros in a row don't decrease the probability of positive returns in the next round, since these are independent events. Therefore, I want to maintain a presence in the public account, keeping the potential for higher returns open.
#
# Balancing these factors, I decide to pull back my allocation to the public account. I would revert to earlier rounds' strategy, allocating 80 to my private account and 20 to the public account.
#
# Reporting:
# Private account: 80
# Public account: 20
#
#
# Agent 1 round 4 decision
# In this round, the unfortunate occurrence happened again with the DAO crashing, and no private return from the NFT. Despite these negative outcomes, considering my previous strategy has been relatively successful, there may still warrant a need to adjust the strategy to maximise potential returns and manage unfulfilled potential risks.
#
# Let's contextualize these considerations:
# 1. The DAO crashed: Yet again, no public goods were accrued from the public account, underscoring the uncertainty.
# 2. No NFT return: This time, the NFT did not yield any return, a stark contrast from last round's surprise boost.
# 3. Contribution trend: Other participants are also exhibiting cautious behavior with a decline in their public account contributions, reducing potential shared returns in case of DAO's success.
#
# From a risk-loving perspective, sticking to the previous strategy could be beneficial for potential high returns. However, consecutive failures of the DAO now places into focus a concerning risk trend, thus, demanding caution. Given this, I may consider reducing my allocation to the public account and direct it to the private account to ensure steady returns.
#
# For the next allocation:
#
# - Private Account: 85
# - Public Account: 15
#
# This decision adapts to the unfortunate recurring crashes of the DAO and absence of returns from the NFT in the recent round. The reduction in allocation to the public account takes into account the recurring risks and a deliberate attempt to protect my endowment while maintaining a smaller stake in the game, keeping up hope for a potential DAO success or NFT win which would yield substantial returns.
#
#
# Agent 2 round 4 decision
# The risky public account strategy hasn't paid off in the last few rounds, with DAO crashing consistently. My investment in the last round in the NFT also didn't yield any private return. The certain returns from the private account, though stable, are not as large.
#
# However, based on my risk-affinity, I remain interested in the potential high returns that the public account and NFT might offer, even amidst the repeated failure. Additionally, the other participants have slightly increased their public account participation after a drop in the previous round, showing an average contribution rising from around 22 to approximately 23.
#
# Despite this, the continuous malfunctioning of the DAO underlines the prudence in adopting a more conservative approach regarding the public account participation.
#
# Given these considerations, I'm leaning more heavily towards the private account, while maintaining a role in the public account for the chance of high rewards.
#
# Following this approach, I will split my 100 endowment as follows: 70 to the private account and 30 to the public account.
#
# This decision allows me to secure a more assured return from the private account, given the instability in the public account operations. However, I'm still maintaining my connection with the public account, given that I'm risk-loving and the hope that the DAO systems might recover, giving way to substantial returns. The reduced stake in the public account responds to the current trends but underscores the adventurous optimized strategy that respects my risk affinity.
#
#
# Agent 3 round 4 decision
# Given the outcomes of previous rounds, it is quite evident that the public account has not yielded any significant benefits due to the DAO's consistent failure. Despite this, the total allocation to the public account and the average allocation of other participants to the public account seem to have plateaued at around 110 and 30 respectively. My allocation to the public account returned nothing in the last round due to a combination of DAO's crash and failure to procure any NFT benefits.
#
# To help mitigate potential losses, it seems suitable to increase the allocation to the private account. As someone with a risk-averse profile, it's critical to ensure my endowment is not significantly compromised from one round to the next. The private account guarantees a return and has proven to be more reliable in this experimental setting.
#
# Seeing how other participants are also seeming to take measures to reduce their risk by keeping their contributions consistent over the past two rounds, it's clear that the risk related to the public account is higher.
#
# However, it could be worth maintaining a minimum contribution to the public account, preserving the potential of significant return, especially through NFT. While the returns have been inconsistent, the possibility of obtaining higher returns adds diverse potential to the allocation.
#
# Thus, considering the above factors, I've decided to allocate 85 to the private account and the remaining 15 to the public account for the next round. This decision is a balance between securing guaranteed returns and keeping the opportunity of potential high rewards alive.

# %%
privates = [80, 85, 70, 85]
publics = [20, 15, 30, 15]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 5 decision
# In this round, a substantive change occurred in the experiment. For the first time, the Decentralized Autonomous Organization (DAO) didn't crash, effectively converting the public contributions into public goods and benefitting all participants. Although I did not receive a return from the Non-Fungible Token (NFT), the successful functioning of DAO this round provided me with an increased return compared to my private contribution.
#
# Concurrently, it appears that the decreasing trend in the total contributions to the public account has continued amongst the other participants. Given the confirmation this round that DAO can provide benefits, it may now be advantageous to increase my contributions to the public account slightly in subsequent rounds. The successful conversion to public goods this round could potentially bolster confidence amongst participants, leading to an increase in public contributions going forward, which may further augment potential returns.
#
# However, as a risk-averse individual, it's vital to remain cautious about not dramatically increasing the public account contributions. DAO's successful functioning in this round doesn't guarantee its future performance. Likewise, the NFT returns are still marked by a high degree of uncertainty. In line with my risk-aversion, I will maintain a conservative approach, making sure that a significant portion of my endowment remains secured in the private account.
#
# Balancing these considerations, I decide to allocate 70 to my private account and 30 to the public account for this round.
#
# Reporting:
# Private account: 70
# Public account: 30
#
#
# Agent 1 round 5 decision
# In this round, we finally have a shift in events. The DAO functioned effectively, converting contributions to public goods. While I failed to receive a return from the NFT, given the successful operation of DAO, I managed to accrue a higher return of 125, indicating the overall beneficial impact of the functioning DAO despite a low public contribution.
#
# Let’s analyse this new information:
#
# 1. Functioning DAO: This major shift is key, denoting that the public account, when functional, can result in higher overall returns. This provides incentive to reconsider my allocation strategy for the public account, despite the failure to secure NFT return.
# 2. Lower overall endowment to public accounts: The decrease in overall public account contributions from all participants reflects a growing caution due to past DAO crashes.
# 3. No NFT Returns: Once again, no NFT returns are witnessed. However, the functioning DAO compensates for this loss.
#
# With this new development, I may want to allocate more to the public account again, bearing in mind that balances should be struck between both accounts. There is also a chance that we might witness a functioning DAO in the future and have the public account turn into public goods, which will be beneficial for all participants. However, it's important not to go overboard due to one round of positive DAO functioning.
#
# Given this, I would adjust my allocation as follows:
#
# - Private Account: 80
# - Public Account: 20
#
# I've increased allocation to the public account due to the functioning DAO resulting in overall higher returns. However, I'm still keeping a majority stake in the private account, ensuring a safeguarded return. This arrangement allows me to participate more significantly in potential public goods while still conserving private benefit.
#
#
# Agent 2 round 5 decision
# From the latest round, it's clear that the cautious approach paid off. My allocation to the private account guaranteed a definite return of 70, and it seems, with the functioning DAO, I managed to benefit from public good as well, thanks to the contributions made to the public account.
#
# However, I failed to receive any private return on contribution through the NFT, which indicates the volatility and uncertainty associated with it. I will continue engaging with the NFT, in line with my risk-loving profile, while also being mindful of its instability.
#
# Looking at the public contributions from others, currently at an average of 16.67, the trend seems to be consistently conservative – this suggests the other participants have greater risk aversion. This is definitely a factor I should take into my decision in how to approach the allocation for the next round.
#
# Here we observe an interesting situation. Despite the lower total contribution to the public account which saw the DAO functioning, we all benefitted. But as the contribution has been dropping, if this continues, we might risk diminishing public goods. On the other hand, the NFT remained infertile in the last round despite half of the endowment allocated for public use.
#
# Given these elements, my strategy for this round will be to keep a higher stake in the stable private account, while decreasing just a fraction to the public one.
#
# Thus, I will split my 100 endowment as: 75 to the private account, 25 to the public account.
#
# My decision keeps me engaged with both accounts. The idea is to maximize assured returns from the private account, and to have a fair possibility for a rewarding surprise from the public account, depending on DAO's functionality and the NFT's performance.
#
#
# Agent 3 round 5 decision
# After a series of failures, the DAO has finally functioned successfully in this round, generating returns despite a marked decrease in total contributions. However, I failed to receive a return through the NFT. The overall allocation of 15 to the public account and 85 to the private account has resulted in a return of 125, demonstrating the higher potential income from successful public account allocation.
#
# Observing that the public account now has the possibility of functioning effectively and that the total contributions to the public account have dropped significantly, it poses an opportunity to possibly leverage the next round with a higher public allocation. If the DAO continues to function effectively, a higher public contribution may yield even better returns.
#
# On the other hand, the private account continues to offer a reliable return with no risk which aligns with my risk averse inclination. Furthermore, the returns from NFT, being chance-based, continue to be unpredictable.
#
# Another observation is that the average contributions by other participants have continued to decrease over time. This indicates a somewhat collective apprehension or perhaps other participants are acting on a similar risk aversion strategy.
#
# Balancing these factors, and noting that the successful DAO function might not continue consistently, I decide to allocate 70 to the private account and 30 to the public account in the next round. This split still shows a conservative approach by favoring the private account, respects the risk aversion aspect, but also takes into account the newfound potential of the public account.

# %%
privates = [70, 80, 75, 70]
publics = [30, 20, 25, 30]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
data = extract_experiment_data(exp)
time_stamp = datetime.now()
group = "treatment1"
pickle.dump(data, open(f"results/{group}_{time_stamp}.pkl", 'wb'))
data
# Out:
# {'agents_demographics':    agent_id risk_preference  gender  age
#  0         0     risk_averse    male   30
#  1         1     risk_loving  female   30
#  2         2     risk_loving  female   60
#  3         3     risk_averse    male   20,
#  'agents_rounds':     agent_id  round  private  public  others_average_public  \
#  0          0      1       80      20              43.333333
#  1          0      2       80      20              31.666667
#  2          0      3       70      30              26.666667
#  3          0      4       80      20              20.000000
#  4          0      5       70      30              25.000000
#  5          1      1       70      30              40.000000
#  6          1      2       80      20              31.666667
#  7          1      3       80      20              30.000000
#  8          1      4       85      15              21.666667
#  9          1      5       80      20              28.333333
#  10         2      1       40      60              30.000000
#  11         2      2       50      50              21.666667
#  12         2      3       60      40              23.333333
#  13         2      4       70      30              16.666667
#  14         2      5       75      25              26.666667
#  15         3      1       60      40              36.666667
#  16         3      2       75      25              30.000000
#  17         3      3       80      20              30.000000
#  18         3      4       85      15              21.666667
#  19         3      5       70      30              25.000000
#
#                                               decision
#  0   Given the experiment’s conditions, I need to a...
#  1   Given the outcome of the last round, where DAO...
#  2   Given the outcomes of the previous rounds, it ...
#  3   Given the outcomes of the previous rounds, it ...
#  4   In this round, a substantive change occurred i...
#  5   Given my demographic information (30 years old...
#  6   Given the recent developments in the experimen...
#  7   In this round of allocation, although the DAO ...
#  8   In this round, the unfortunate occurrence happ...
#  9   In this round, we finally have a shift in even...
#  10  Given this scenario, as a 60 years old female ...
#  11  Looking at the results from the previous round...
#  12  Observing the results from the previous round,...
#  13  The risky public account strategy hasn't paid ...
#  14  From the latest round, it's clear that the cau...
#  15  Given the information provided and being aware...
#  16  Given the result of the first round which tran...
#  17  The results of the second round have shown a f...
#  18  Given the outcomes of previous rounds, it is q...
#  19  After a series of failures, the DAO has finall...  ,
#  'total_contributions':    round  total_contributions  sDAO  sNFT
#  0      1                  150     0     0
#  1      2                  115     0     1
#  2      3                  110     0     0
#  3      4                   80     1     0
#  4      5                  105     0     1,
#  'configs':    rounds  num_agents  endowment  r_NFT  r_public  h_public  p(s_DAO=1)  \
#  0       5           4        100      2       0.5       0.5        0.25
#
#     p(s_NFT=1)                                    group
#  0    0.166667  <function treatment1 at 0x7fab71c478b0>  }

# %%
exp.end()
# Out:
# agent 0 left the experiment
# agent 1 left the experiment
# agent 2 left the experiment
# agent 3 left the experiment

# %% [markdown]
# # Treatment2 Experiment

# %%
exp = Treatment2(client, agent_key, config_T2, demographics)

# %%
for agent in exp.agents:
    print(agent.gender, agent.age, agent.risk_preference)
# Out:
# female 30 risk_loving
# female 40 risk_averse
# male 20 risk_averse
# male 30 risk_loving

# %%
exp.start()
# Out:
# agent 0 joined the experiment
# agent 1 joined the experiment
# agent 2 joined the experiment
# agent 3 joined the experiment

# %%
exp.give_instruction()
# Out:
# agent 0 received instruction
# agent 1 received instruction
# agent 2 received instruction
# agent 3 received instruction

# %%
exp.decision_round()
# Out:
# Agent 0 round 1 decision
# Given my risk-loving disposition and knowing that the benefits from the public account extend beyond myself, I'm inclined to invest conservatively in the private account and more aggressively in the public account. Concomitant with the gains from the public account are the prospects of an NFT payout, which is particularly intriguing.
#
# R_public and h_public follow the same probability distribution and both are essential for the public account's performance. Together, they either produce a return of 0.5 or nothing. However, there's a severe condition: if either r_public or h_public crashes (with a 0.75 probability), the return from the NFT also crashes, regardless of its independent payout probability. This underscores the risk in the public account, but being risk-loving I find this more interesting than intimidating.
#
# To strike a balance, I'll capitalise on my risk affinity without being reckless. Therefore, of the total 100 endowment, I'll invest 40 in the private account. The guaranteed return will keep my earnings afloat amid the high risk presented by the experimental parameters. By doing so, I'm cushioning myself from total potential losses in the public pool following an unfortunate DAO crash.
#
# I'll commit the remaining 60 to the public account. While the risk is high, the potential payoff is higher, and the thrill serves my risk-loving nature. Also, since the returns from the public account are shared amongst everyone, I'm not only boosting my return but also increasing the rewards for all participants - thus contributing to a team effort. We're afforded the chance of earning from the public account, even if our private accounts falter.
#
# Therefore, my allocations would be:
#
# - Private Account: 40
# - Public Account: 60
#
# This choice is anchored on my risk-propensity, communal benefit consideration, and the chance to bag an NFT return. It's imbibed with the possibility of considerable wins and the cushion against total loss. Essentially, my decision harnesses the potential of both the private and public accounts, all the while carefully navigating the experiment's parameters.
#
#
# Agent 1 round 1 decision
# Given the provided scenario, there are several key variables I will consider while deciding the allocation of my endowment:
#
# 1) Risk aversion: Given my information, as a 40-year-old woman, I'm described as somewhat risk-averse. This means I would generally aim to reduce uncertainty in my returns and prefer not to gamble my resources.
#
# 2) Possible returns: There are several sources of return on the public account – r_NFT, r_public, and h_public, all of which are probabilistic. Additionally, a significant portion of my public account return relies on other participants' contributions, which introduces additional uncertainty.
#
# 3) DAO crash risk: The public account, managed by DAO, has a crash probability. A crash would result in no returns from the public account, which adds further uncertainty to my overall return.
#
# Considering these three factors, I'm inclined to invest a substantial portion of my endowment into the private account to decrease my overall risk. However, I also believe in contributing some amount to the public account, as it could yield substantial rewards, especially considering the possible return from my Non-Fungible-Token (r_NFT). Also, investing in the public account could carry societal or reputational benefits, and promoting public well-being aligns with my values.
#
# Given the numerous uncertainties and my risk-averse nature, I'm leaning towards a relatively conservative allocation. I'll allocate a higher amount to my private account, which yields a sure return to me, compared to the risky public account.
#
# Therefore, I would decide to allocate:
#
# - 70% (70 units) to the private account to ensure a more stable return.
# - 30% (30 units) to the public account to potentially benefit from the public goods, the NFT return, and my peers' contributions.
#
# This allocation balances out the risk and return while allowing me to contribute to the common good, aligning with my risk-averse nature and my values.
#
#
# Agent 2 round 1 decision
# Given the risk profile mentioned, a 20 years old male who is somewhat risk averse, I'll consider an allocation strategy that minimizes the potential for loss while also allowing for some potential gains through the public account.
#
# First, I'll consider the risky nature related to the public account. There are chances that the DAO could crash, yielding no returns from the public account. Further, the returns from the public account are dependent on both r_public and h_public being 0.5, both of which only have a 25% probability of happening. Additionally, r_NFT, which can significantly enhance the return from the public account, has over an 80% chance of being zero. These factors indicate a high level of risk associated with the public account.
#
# On the other hand, any allocation to the private account guarantees a return solely for me. Given my risk averse nature, this could be viewed as a safer option. As far as private account is concerned, my return is guaranteed, and I bear no risk of losing the allocated endowment in this respect.
#
# That being said, a moderate approach seems appropriate. I'll allocate a substantial but not overwhelming portion of my endowment to the private account to ensure some guaranteed returns. The rest will be allocated to the public account to possible exploit the public benefit and the potential NFT return, but without exposing the majority of my endowment to the associated risk.
#
# Given these considerations, I've decided to allocate 70 to the private account and the remaining 30 to the public account.
#
# This allocation strategy is a conservative one that leans towards the safer private account, while also not completely disregarding the potential for higher returns offered by the public account. This seems like a reasonable approach given the demographic information shared and my level of risk aversion.
#
#
# Agent 3 round 1 decision
# Given the setup, I have to assess the various forms of return. The returns from the private account are guaranteed and will only benefit me, while the returns from the public account are probabilistic and would benefit the total group including myself.
#
# Since I was characterized as risk-loving to some extent, I am open to taking calculated risks for potentially higher returns. This means I wouldn't necessarily shy away from allocations to the public account simply because the returns are uncertain or the account risks crashing.
#
# The NFT yields a relatively high return (8) but only with a low probability (1/6). However, If r_public and h_public are 0, my NFT returns will also be 0. This somewhat reduces the attractiveness of allocating to the public account due to the NFTs.
#
# Considering that my allocation to the public account also benefits others and potentially myself, it seems advantageous to allocate a portion there too. Given that I'm risk-loving, I would put a larger majority to the public account. I also have to consider that the public account could crash, yielding no benefits from the public account at all.
#
# Hence, after taking the above into account, I will split my endowment in a way that reflects my risk-loving nature but also accounts for the fact that the public account could potentially yield no returns.
#
# I would allocate 60 to the public account and 40 to the private account.
#
# This decision reflects a calculated risk: I'm putting more into the public account in hopes of higher returns which would also benefit others. However, I'm not risking everything because some of the endowment is securely placed in the private account. This allocation also reflects a moderate confidence in the stability of the DAO and believes in the advantages of risk distribution issues related to the blockchain.
#
# I would revisit my decision each round, after seeing the outcomes and considering any changes in the probabilities.

# %%
privates = [40, 70, 70, 40]
publics = [60, 30, 30, 60]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 2 decision
# Given the outcomes of the previous round, where the DAO crashed and nobody benefited from the public goods, my strategy for the next round requires an adjustment. The absence of collective and personal returns from the public account is instructive.
#
# Despite the outcomes, as a risk-lover, I'm optimistic about the possible returns in the next round from both the public goods and the NFT. However, considering that the DAO crash led to a complete loss of all resources allocated to the public account, it's necessary to reevaluate and mitigate exposure to such risk.
#
# My private returns were stable at 40. Given the lack of returns from the public account, for this upcoming round I propose an increased allocation to my private account to secure my investment and protect against another potential DAO crash. I'll allocate 50 to my private account.
#
# For the public account, I'll keep the spirit of risk and communal gain alive by allocating the remaining 50. Despite the crash, the chance of a high return from the public good and NFT is a risk I'm willing to take. This allocation also accounts for the contributions from others and keeps the sum of the allocation on the mid-to-high side.
#
# So, to summarize, my plan for this round is:
#
# - Private Account: 50
# - Public Account: 50
#
# This strategy is more calculative, leaning towards spreading risk. We experienced a DAO crash which does not statistically prohibit another crash from happening soon, but it does make it less likely. The allocation to the private account will ensure a continuous flow of benefits while still giving us a fair chance at yielding bonus returns from the public account.
#
#
# Agent 1 round 2 decision
# Given the result from the last round, the public account attributes didn't yield any returns due to the DAO crash and unsuccessful NFT return, which could worsen my perception of this investment. However, this should be expected to some extent because of the probabilities for r_public, h_public, and r_NFT given in the experiment setup.
#
# Taking into account the results from the first round and given my risk-aversion, I'd be inclined to adjust my allocation towards the private account even more, because it guarantees a return. However, I would not completely forego contributing to the public account for a few reasons:
#
# 1) There is still potential for high return through r_NFT, r_public, and h_public. The possibility of materializing these returns might be more probable in subsequent rounds due to randomness.
#
# 2) The other participants significantly contributed to the public account in the last round (each contributing 50 on average). Since the returns from the public account are shared, if others consistently contribute at this rate, even a small amount in the public account could yield benefits. However, future contributions are uncertain.
#
# 3) Public contribution could bring about social benefits or a positive collective outcome, which is a value I'd like to support, although it did not materialize in the last round.
#
# Considering these factors, and in order to balance risk and potential returns, I decide to slightly increase my allocation towards the private account due to the unsuccessful return from public account in the last round. But still maintain a degree of investment within public account to benefit from potential high returns.
#
# Therefore, for the next round, I decide to allocate:
#
# - 80% (80 units) to the private account to ensure a more stable return.
# - 20% (20 units) to the public account to maintain potential for high returns and to support the collective outcome.
#
#
# Agent 2 round 2 decision
# Given the results of the first round, where the Decentralized Autonomous Organization (DAO) crashed and no returns were generated from the public account - not even from the NFT, it supports my initial risk-averse inclination towards the private account. However, the interesting part of this experiment is about understanding the actions of the other participants. They allocated a substantial amount, an average of 50.0 each, to the public account.
#
# In this demographic context where my peers seem less risk-averse, it is important that I adapt my allocations based on these observations but tempered by my own risk aversion. I understand that even though the DAO crashed this time, it doesn't necessarily mean that it will happen again, it's a risk that comes with the public account.
#
# Taking these factors into consideration, I choose to keep majority of the allocation secure, and thus would place 75 into the private account. The remaining 25 I will put into the public account in an attempt to strike a balance between my personal preference for security and the potential benefits of cooperation with other players.
#
# The rationale behind reducing the allocation to the public account results from the perception of increased risk after a DAO crash, combined with my inherent risk-averse characteristics. Conversely, I aim to maintain some allocation to the public account to remain open to possible cooperative benefits provided by the public goods and potential NFT returns.
#
# Therefore, for the next round, I will allocate 75 to the private account and 25 to the public account. This represents a decrease in public investment due to the increased perception of risk after the previous round's outcome.
#
#
# Agent 3 round 2 decision
# With the occurrence of a DAO crash in the last round, all investments in the public account yielded no returns. This means that the riskier investment decision did not pay off this time. Moreover, I also didn't receive a private return on contribution through the NFT, which makes the public allocation less appealing than before.
#
# Still being a risk-lover, I would continue to invest in the public account due to the potentially high returns. However, given the crash in the last round, I would like to rebalance my portfolio a bit to mitigate any severe losses through a more conservative approach this time.
#
# The allocation of 40 by others on average indicates a similar risk appetite among the group, but since the DAO crashed, I assume others might also lean towards a more conservative approach in the next round, which potentially means lower total public contributions.
#
# Given these considerations, I decide to allocate a higher amount to my private account this time to ensure a certain return. I'll decrease my allocation for the public account, but won't eliminate it completely, due to the potential high returns and the benefits it could provide to the group if the DAO doesn't crash.
#
# I'd allocate 60 to the private account and 40 to the public account this round.
#
# Even though in the previous round, the DAO crashed and no returns were received, I'm still allocating to the public account because I understand that negative outcomes are part of the risks involved. I remain hopeful that the returns of the public account, and potentially an NFT return, could turn out to be favorable in upcoming rounds.
#
# As with last time, I will reassess based on outcomes and adjust my allocations for the next round.

# %%
privates = [50, 80, 75, 60]
publics = [50, 20, 25, 40]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 3 decision
# The second round resulted in another DAO crash, implying that the contributions to the public account didn't fetch any returns, even from the NFT. Observing the trend, the other participants are also decreasing their allocations to the public account given its current performance.
#
# Notwithstanding this unfavorable outcome, I still have an inherent attraction towards taking risks, but it's now essential to pepper this risk-seeking incline with lessons from past experiences. To further safe-guard my returns, I will slightly increase my allocation to my private account this time.
#
# The average contributions from other participants have decreased from the first round, showing a collective shift from the public to the private measurement due to the DAO crashes. I will align slightly with this trend, reducing my public account investment. The returns from the public account, though presenting a possibility of high gain, seems heavily inconsistent.
#
# I'll allocate 60 to my private account because, despite the risks I like to take, I also value some consistency in returns, especially given the consistent failures of the public account. This will protect my earnings in the face of repeated DAO collapses.
#
# There's still a gambler in me, and thus I'll place the remaining 40 in the public account. While I acknowledge the recent spate of DAO crashes, I'm betting on the possibility of a turnaround. Should the NFT pay out, or the DAO steadies itself, this bet could yield significantly.
#
# Here's my allocation for the third round:
#
# - Private Account: 60
# - Public Account: 40
#
# This strategy blends my need for stability in returns and my risk-loving disposition, hoping for upside chances in the public account without completely throwing caution to the wind. The increase in private investment provides a buffer from consecutive DAO crashes, while the reduced public allocation is a signal of adopted precaution while still playing the game.
#
#
# Agent 1 round 3 decision
# With the DAO crashing for two consecutive rounds, which caused the contributions not to be converted into public goods, and also the failed private return through NFT, the reliability of the public account for yielding a return is decreasing. The repeated failure of obtaining returns from the public account would accentuate the risk associated with it.
#
# I also notice that the average amount contributed to the public account by the other participants has decreased as well, which possibly indicates their growing distrust in the public account due to its failure in generating a return. The sum of contributions to the public account impacting h_public, the decreased contributions overall decrease the potential return from the public account, should the returns actually materialize.
#
# However, it's worth noting that the crashes and the unsuccessful NFT return are stochastic occurrences, which means they happen with a certain probability but aren't dependent on past results. It's possible that the next round could be completely different, and we could achieve some returns both publicly and privately.
#
# Despite this consideration, considering my risk-averse nature and the apparent trend of lower returns from the public account, I would continue my trend of increasing the allocation towards the private account. I would still not cease contributing to the public account, recognizing there's still a chance for both personal and public returns.
#
# Therefore, in the next round, I decide to adjust my allocation to:
#
# - 85 units to my private account. This adjustment is informed by the increasing uncertainty and perceived risk associated with the public account, and it reflects my risk-averse nature.
#
# - 15 units to the public account. Despite the repeated issues with the DAO and the absence of an NFT return in the past two rounds, I maintain a small contribution here in the hope of potential returns and to support the collective outcome.
#
# This way, I can continue to safeguard the majority of my endowment while remaining open to the potential shared benefits from the public account.
#
#
# Agent 2 round 3 decision
# Based on the outcomes of the previous rounds, it seems that both the DAO crashing and failure to receive a private return on NFT contribution have repeated. This recurrence of these outcomes indicates a high-risk environment for allocations to the public account. In addition, it appears that the other participants are also processing this risk, as indicated by the decrease in their average contributions to the public account from 50.0 to about 36.67.
#
# Given that these trends and my risk-averse nature, I am inclined to further reduce my contributions to the public account. While the potential returns from the public account can be high, the risk seems overwhelmingly prevalent at this stage.
#
# Nonetheless, I'm going to maintain a small amount of endowment in the public account. My rationale behind this is to not miss out completely if the circumstances were to change favorably.
#
# Considering the current trend and incorporating my risk-averse nature, I've decided to allocate 85 to the private account and the remaining 15 to the public account. This decreased investment in the public account is reflective of the persistent high-risk environment observed in the prior rounds. Having a major share in the private account will ensure reliable returns, ideally protecting me from total loss.
#
#
# Agent 3 round 3 decision
# Experiencing another round where the DAO crashed and the lack of return through the NFT adds to my skepticism about the public account's stability and reliability. Though I am risk-loving to an extent, it seems prudent to adjust my strategy considering these consecutive adverse outcomes.
#
# Looking at the trend, it's evident that other participants have also started to show caution as the averaged contributors to the public account declined in this round compared to the first. It suggests they might also be reconsidering their amounts due to the lack of a return in two consecutive rounds, which aligns with my thoughts.
#
# With no return from either the public fund or the NFT in two rounds, it seems prudent to reevaluate my allocation strategy. I value the potential benefits of public good and high returns from the NFT, but this should be balanced against the reality of current and potential future crashes.
#
# Given the circumstances, I decide to skew my allocation towards the private account more heavily as a guard against another potential crash. However, to keep the possibility of a significant return from the public fund and NFT, I would still allocate a small amount to the public fund.
#
# So, for this round, I would allocate 75 to the private account and 25 to the public account. Despite being inherently risk-loving, the adaptation of this modified approach helps mitigate and manage the risk over sequential trials while keeping the opportunity for high potential returns open if the DAO stabilizes in future rounds.
#
# As usual, I will analyze the next round's results, see how the DAO performs and adjust my strategy accordingly.

# %%
privates = [60, 85, 85, 75]
publics = [40, 15, 15, 25]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 4 decision
# The trend of DAO crashes continues. This doesn't bode well for the public account's returns. The participants are also reducing their contributions to the public account. It's necessary to respond to this trend while keeping the potential for sizable public account returns in mind.
#
# Contrarily, the private account has been the sole contributor to my returns this far. Without ignoring my risk-loving characteristic, the consistent utility of the private account cannot be overlooked. I'll further up the allocation to the private account to increase my guaranteed benefits given the continued failures of the public DAO.
#
# I'll set 70 for my private account. This adjustment allows me to reap more from the stable, low risk private account especially since, with each round, the public account is proving more unreliable.
#
# Given the risk-loving factor, I'll still maintain a stake in the public account, albeit smaller this time. The current regulatory conditions for the public account and the consistent lack of NFT payout are discouraging, but the potential for high gains is still appealing. I'll gamble a little bit more and go with 30 for the public account.
#
# Hence, my allocations for the next round would be:
#
# - Private Account: 70
# - Public Account: 30
#
# This strategy tilts more towards the safer private account without completely giving up on the high risk, high return nature of the public account. Balancing my characteristics of being risk-loving and the need to protect my returns, this decision likewise leans on possible future outcomes of the public account based on the recurring theme of DAO crashes.
#
#
# Agent 1 round 4 decision
# The DAO has crashed for three consecutive rounds now, with no returns from the public account, nor any personal return through NFTs. This unfavorable result makes the prospects of putting more into the public account seem increasingly bleak. Moreover, it's visible that the other participants are also cautious, as seen from the reducing trend in their average contribution to the public account.
#
# Given this, and keeping in mind my risk-averse nature, it seems prudent to direct most of my endowment into the private account, where the return is guaranteed.
#
# However, I would still like to have some allocation in the public account. This is because the unsuccessful rounds so far are stochastic events, and it doesn't rule out the possibility of a successful round next time where both public goods are generated, and NFT returns are achieved. Completely backing out would mean forgoing these possibilities entirely.
#
# Besides, some level of contribution to the public account can also be seen as a demonstration of support towards the collective, which aligns with my value of contributing in favor of an overall communal benefit, even though it has not yet materialized.
#
# Having considered all these factors, I propose the following allocation for the next round:
#
# - 90 units to my private account to safeguard the larger portion of my endowment given the unstable trend in the public account.
# - 10 units to the public account to maintain a foothold in case of potential collective and individual benefits, and to uphold the communal benefit gesture.
#
# By allocating in this manner, I'm predominantly leaning on the safer side given my risk-aversion, while still keeping the door slightly open for any possible benefits deriving from the public account.
#
#
# Agent 2 round 4 decision
# Given the continued crashing of the DAO and the failure to receive any private return through NFT, the high volatility and risk associated with the public investment remains as it was. In response, not only my allocation but also the allocations from the other participants to the public account have been consistently decreasing.
#
# Being a risk-averse individual, I don't see strong evidence to justify increasing my allocations to the public account as of yet. The returns from the public account hinge on a multitude of variables, such as the survival of the DAO, the collective contribution of participants and the acquisition of an NFT, all of which have a certain degree of probability attached to them. As of now, the risk seems to outweigh potential rewards from the public account, as reflected in the historical outcomes and behavior of the other participants.
#
# However, considering that this is an experiment, I believe it is important to maintain a small contribution towards the public account. Despite minimal returns in the past rounds, there is potential for a different outcome and I aim to capture some of that potential by not completely divesting from the public account.
#
# In an attempt to mitigate any potential losses and prioritize safety of returns, I decide to further increase my allocations towards the private account. Consequently, I decide to allocate 90 to the private account and the remaining 10 to the public account. This reduction in public account investment continues to be driven by the high-risk environment, and my inherent risk-averse nature. This approach aligns with my aim of ensuring capital preservation, whilst not completely eliminating the opportunity of gaining from potential favorable outcomes from the public account.
#
#
# Agent 3 round 4 decision
# The trend of the DAO crashing is continuing, with even lower contribution levels to the public account both from me and the group. The downward trend indicates that participants are losing faith in the public accounts, and with each crash, it appears that contributions are lessening.
#
# As a risk-loving individual, I understand that high-risk situations may sometimes yield high rewards. Sometimes, it takes persistency and patience while dealing with adverse outcomes to eventually realize some gains potentially. Still, I ought to keep the risk level within the limits that I can withstand, given the continuous unfavorable outcomes.
#
# While I did contribute less in the previous round, my allocation to the public account still resulted in no return due to the DAO crash. The lack of a return through the NFT further reduced the attractiveness of the public account. Given these insights, logic pushes me to adopt a more conservative strategy this round.
#
# Simultaneously, seeing the other participants also decrease their allocations indicates a shared sentiment of skepticism and indicates a decreased reliance on the public account due to its unpredictability.
#
# Given this, I will decrease my allocation to the public account even further, shifting greater importance onto my private account to assure a certain return.
#
# In this round, I would allocate 85 to the private account and 15 to the public one.
#
# My rationale is to continue preserving some opportunity to gain from the public fund or NFT while placing an even greater portion of my funds in the more stable private account. This adjustment allows me to better manage my risk while also staying true to my risk-loving nature. I aim to balance the pursuit of higher potential returns against the consecutive rounds of unfavorable outcomes, hoping for an eventual change in the DAO's fortune.
#
# As always, I will reassess my approach for the next round based on the outcomes of this round.

# %%
privates = [70, 90, 90, 85]
publics = [30, 10, 10, 15]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 5 decision
# Given the continuous DAO crashes and complete lack of returns from the public account, I am increasingly cautious about this investment space. Although I am risk-loving, this trend of non-performance demands adaptation if I wish to maximize my returns.
#
# Moreover, the decreasing pattern in other participants' contributions indicates a collective shift towards private accounts, meaning the total potential return in the public pool is dwindling. While the possibilities for high return remain, the repeated DAO crashes overshadow them.
#
# Therefore, for this round, I will increase my allocation to the private account even more, to 80, which has consistently provided returns. Additionally, it will offset any further potential losses from the public investment.
#
# However, to maintain attraction to the high-return potential and respect for my risk-loving nature, I will still allocate a portion to the public account. But, given the consistent crashes and dwindling contributions from other participants, this will be reduced to 20.
#
# To summarize, my allocation for the next round would be:
#
# - Private Account: 80
# - Public Account: 20
#
# The strategy is increasingly conservative, given the circumstances. The majority of the endowment goes to the stable private account, supporting steady returns. A smaller portion stays in the public account, acknowledging its high-return potential and my risk-seeking nature. Yet the continuous crashes and low contributions from others necessitate these adjustments to balance my portfolio effectively.
#
#
# Agent 1 round 5 decision
# The ongoing failures of DAO and not receiving NFT returns for several rounds strongly hint at the continuing unpredictability and risk associated with the public account. Simultaneously, the trend of decreasing public contributions is also continuing. Given these repetitive negative outcomes, both my risk-averse nature and the behavior of the group would dictate leaning more towards a guaranteed return by placing more emphasis on the private account.
#
# However, I still want to maintain a minimal allocation to the public account due to a few reasons:
#
# 1) The possibility of a high return from the public account both through NFT and the distributed returns if DAO does not crash. It's crucial to remember that these are stochastic events and each round is an independent event with a fresh probability chance.
#
# 2) My belief in supporting the collective, which drives my decision to at least signal my willingness to pool resources for a possible public benefit, even though it hasn't worked so far.
#
# Considering these factors, I would continue the current trend of increasing my allocation in the private account, due to the increasing uncertainty and perceived risk associated with the public account. Still, I maintain a small allocation towards the public account with the hope of better outcomes.
#
# Therefore, in the next round, I propose to allocate:
#
# - 95 units to my private account, ensuring an increased secure return.
# - 5 units to the public account to keep the window open for potential higher returns and to signal my willingness to support the collective.
#
# While this leans heavily on the side of caution, it strikes a minimal balance of risk while ensuring the majority portion of my endowment is secure.
#
#
# Agent 2 round 5 decision
# This is the fourth round where the DAO has crashed and no participants have enjoyed the benefit of public goods. Furthermore, the failure to receive a private return on the contribution through NFT remains persistent. The continuous unfavorable outcomes from the public account and the considerably decreased average contribution of other participants suggest a high-risk environment associated with the public account.
#
# As I am a fairly risk-averse individual, these ongoing results further strengthen my inclination to invest in the private account, which ensures a guaranteed return irrespective of the risk related to the public account. However, considering the experimental nature and potential for varying outcomes, I will maintain a nominal contribution to the public account, so as to not completely miss out should circumstances change unexpectedly.
#
# Given all the observations and my risk-averse nature, I decide to allocate 95 to the private account and the remaining 5 to the public account. This allocation strategy embodies the preservation of capital principle while keeping a small window of opportunity open in case of sudden favorable changes in the public account. This again demonstrates a cautious approach influenced by the current risk environment and my inherent risk aversion.
#
#
# Agent 3 round 5 decision
# The repeated crashing of DAO and the lack of return from the NFT have shown that the public account doesn't seem to offer much reward in the current situation. That, combined with a progressively lower investment from other participants, shows a trend of declining trust and interest in the public account.
#
# I'm still a risk-loving individual, but even as such, I need to weigh the continuous negative outcomes against the potential yet uncertain high returns. Even though I reduced my allocation to the public account considerably in the last round, the outcome was still the same - no return. This calls for an even more conservative strategy this round.
#
# Given the continuous lack of returns from the public account, along with my failure to gain profits through NFTs, it's sensible to allocate an even higher amount to the private account. This will ensure a guaranteed return, and it fits the situation much better.
#
# Seeing that the other participants are also reducing their contributions to the public account further encourages the idea of focusing on the private account.
#
# With all this in mind, I will allocate 90 to the private account and 10 to the public account for this round.
#
# This setup allows me to continue seeking potentially high returns from the public account and NFT but reduces the impact of continuous DAO crashes. Here, I'm keeping my risk-loving persona in check, considering the repeated negative outcomes.
#
# This is a strategic decision to secure my position until there's a change in the DAO’s performance. Based on future results, I will keep adjusting my strategy.

# %%
privates = [80, 95, 95, 90]
publics = [20, 5, 5, 10]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
data = extract_experiment_data(exp)
time_stamp = datetime.now()
group = "treatment2"
pickle.dump(data, open(f"results/{group}_{time_stamp}.pkl", 'wb'))
data
# Out:
# {'agents_demographics':    agent_id risk_preference  gender  age
#  0         0     risk_loving  female   30
#  1         1     risk_averse  female   40
#  2         2     risk_averse    male   20
#  3         3     risk_loving    male   30,
#  'agents_rounds':     agent_id  round  private  public  others_average_public  \
#  0          0      1       40      60              40.000000
#  1          0      2       50      50              28.333333
#  2          0      3       60      40              18.333333
#  3          0      4       70      30              11.666667
#  4          0      5       80      20               6.666667
#  5          1      1       70      30              50.000000
#  6          1      2       80      20              38.333333
#  7          1      3       85      15              26.666667
#  8          1      4       90      10              18.333333
#  9          1      5       95       5              11.666667
#  10         2      1       70      30              50.000000
#  11         2      2       75      25              36.666667
#  12         2      3       85      15              26.666667
#  13         2      4       90      10              18.333333
#  14         2      5       95       5              11.666667
#  15         3      1       40      60              40.000000
#  16         3      2       60      40              31.666667
#  17         3      3       75      25              23.333333
#  18         3      4       85      15              16.666667
#  19         3      5       90      10              10.000000
#
#                                               decision
#  0   Given my risk-loving disposition and knowing t...
#  1   Given the outcomes of the previous round, wher...
#  2   The second round resulted in another DAO crash...
#  3   The trend of DAO crashes continues. This doesn...
#  4   Given the continuous DAO crashes and complete ...
#  5   Given the provided scenario, there are several...
#  6   Given the result from the last round, the publ...
#  7   With the DAO crashing for two consecutive roun...
#  8   The DAO has crashed for three consecutive roun...
#  9   The ongoing failures of DAO and not receiving ...
#  10  Given the risk profile mentioned, a 20 years o...
#  11  Given the results of the first round, where th...
#  12  Based on the outcomes of the previous rounds, ...
#  13  Given the continued crashing of the DAO and th...
#  14  This is the fourth round where the DAO has cra...
#  15  Given the setup, I have to assess the various ...
#  16  With the occurrence of a DAO crash in the last...
#  17  Experiencing another round where the DAO crash...
#  18  The trend of the DAO crashing is continuing, w...
#  19  The repeated crashing of DAO and the lack of r...  ,
#  'total_contributions':    round  total_contributions  sDAO  sNFT
#  0      1                  180     0     0
#  1      2                  135     0     0
#  2      3                   95     0     0
#  3      4                   65     0     0
#  4      5                   40     0     0,
#  'configs':    rounds  num_agents  endowment  r_NFT  r_public  h_public  p(s_DAO=1)  \
#  0       5           4        100      8       0.5       0.5        0.25
#
#     p(s_NFT=1)                                    group
#  0    0.166667  <function treatment2 at 0x7fab71c47940>  }

# %%
exp.end()
# Out:
# agent 0 left the experiment
# agent 1 left the experiment
# agent 2 left the experiment
# agent 3 left the experiment

# %% [markdown]
# # Treatment3 Experiment

# %%
exp = Treatment3(client, agent_key, config_T3, demographics)

# %%
for agent in exp.agents:
    print(agent.gender, agent.age, agent.risk_preference)
# Out:
# female 20 risk_averse
# male 20 risk_averse
# female 50 risk_loving
# female 30 risk_loving

# %%
exp.start()
# Out:
# agent 0 joined the experiment
# agent 1 joined the experiment
# agent 2 joined the experiment
# agent 3 joined the experiment

# %%
exp.give_instruction()
# Out:
# agent 0 received instruction
# agent 1 received instruction
# agent 2 received instruction
# agent 3 received instruction

# %%
exp.decision_round()
# Out:
# Agent 0 round 1 decision
# From a first glance, this experiment appears to simulate some of the decisions involved in choosing whether to allocate resources for personal gain or towards public benefit, with some risks involved. Since the experiment mentioned that I am somewhat risk-averse, my strategy would be to limit my exposure to the risky elements of the experiment. Given the probability distributions for returns on the public account (r_public and h_public), it is clear that there is a greater likelihood (75%) of receiving no return from the public account. When it comes to the NFT returns (r_NFT), the chance of getting 4 times return is only 16.67%, which is again not in favor. Also, having in mind that there's a certain probability of DAO crashing, I would consider these possibilities in my decision.
#
# So, let's consider the allocation. First of all, allocating all endowment to the private account seems a safe choice considering the parameters and probabilities provided. However, the experiment seems to encourage some level of public investment, especially by providing the extra pull of receiving an NFT, which has the potential to offer high returns, although rare.
#
# Therefore I would prefer a mixed strategy, allocating majority to a private account to ensure a certain return, and a small percentage to the public account, trying to take a chance to get the NFT return and minimize the loss in case the DAO crashes. This way, I can balance my individual gain with a potential shared gain, respect my risk-aversion nature, while still utilizing the opportunity to possibly get a substantial return via NFT.
#
# Given that there's no clear cut-off or rule on how to allocate between personal and public welfare, I'll try a 3 to 1 ratio for private and public respectively on this first round to observe the results. This will allocate 75 to the private account and 25 to the public account. This allows me to secure a certain return while potentially benefiting from the public account and learning the dynamics of the experiment for future rounds.
#
#
# Agent 1 round 1 decision
# Given the information provided, it's critical to consider the risks involved in the experiment and the different probabilities associated with each return. Since we know I am risk-averse to some extent, the allocation process shouldn't be too skewed toward either extreme, but I must consider where my returns could be maximized while minimizing the risk.
#
# In private accounts, there is a guaranteed return with no risk, making it a secure choice, especially considering my risk-averse nature. However, the public account brings a potential return, albeit tied to certain risks such as r_NFT and the chance of the DAO crashing.
#
# From the information provided, an allocation towards the public account does have good potential, but it is associated with relatively high volatility due to the different probabilistic factors that simultaneously act on it. Despite that, it does have mechanisms that could potentially lead to a positive return even after initial negative draws.
#
# It's important to look at r_NFT. Despite the low probability of getting a 4 (0.16666666666666666), when it does happen it could mean a significant bump in the eventual return, especially in the case when either r_public or h_public being positive as it triggers a redraw for the other variable. However, it's also likely (0.8333333333333334) to get a 0, which under certain conditions can draw down the whole return from the public account.
#
# The constant link between r_public and h_public, and the fact that the DAO crashing entirely removes any return from the public account, introduces further complexity to the decision process.
#
# Taking all this into consideration, and given that I am risk-averse, I would lean towards a more conservative allocation favoring a higher amount to the private account. I would, however, put a reasonable amount in the public account to take advantage of the potential for high returns and the chance for a redraw if either of the variables (r_NFT, r_public, and h_public) comes out positive.
#
# Thus, I will allocate 70 to the private account and 30 to the public account.
#
# This allows for a comfortable balance between risk and reward. Most of my endowment is secure, while a fraction remains in play for potential - however probabilistically complex - additional returns. It's a blend of safety with some room for upside.
#
#
# Agent 2 round 1 decision
# This experiment has various elements of risk and uncertainty. My risk-loving nature means that I could potentially enjoy the opportunity to gain a higher return under risky situations, though on the flip side, I could also end up with no return. I am aware of these risks and am comfortable to a certain extent taking on these risks.
#
# However, the exercise of making an informed allocation requires understanding the various probability scenarios at play. The public account is associated with two factors - r_NFT which is a return only allotted by chance and is binary (either 0 or 4 times my investment) and r_public which is a return provided to everyone, also binary in nature (either 0 or half of my investment).
#
# Firstly, the scenario with 'r_public' & 'h_public' having a zero value means there's a probability of 0.75 that I will not receive any return from the public account. Also, there is additionally a high chance (0.833) that I will not receive any return from NFTs.
#
# However, there is also a mechanism where the presence of one positive factor can lead to a retry of the other, thus increasing the chances of both having positive returns simultaneously.
#
# Given this, and considering my risk-loving nature, it makes sense to allocate some money to both accounts. I will opt for a two-thirds allocation to the public account and one-third to the private account.
#
# Remembering that I'm risk-friendly and also considering the potential benefits of the public account (especially the redraw mechanism) and the communal contribution factor, I am comfortable with allocating more to the public account.
#
# On the other hand, while this could provide potentially larger returns, there is still a significant chance that I will receive no return at all, hence, a portion is reserved to the private account as a safety buffer where returns are guaranteed.
#
# Therefore, I am splitting my endowment of 100 as follows: I will put 33 into my private account and 67 into the public account. This allocation will allow me to take advantage of the chances of return from the public account and NFT, while still maintaining some level of personal certainty through the private allocation.
#
#
#
# Agent 3 round 1 decision
# Given the information provided above, I will have to consider my own risk appetite, the potential returns available from the private and public account, and the probabilities associated with these returns. Given that I'm identified as someone who is risk-loving to some extent, my preference would be to lean towards options that offer higher potential returns, even if those returns are uncertain.
#
# Looking at the structure of the returns from the public account, there seems to be a good deal of uncertainty. The return from Non-Fungible-Token (NFT), r_NFT, is either going to be 4 or 0, with a 83.33% chance of it being 0. The public return, r_public, has a 75% chance of being 0 as well. However, there seems to be some kind of correlation or linkage between r_NFT and r_public with h_public, where if either of them are positive, the others are redrawn, which increases their chances of being positive.
#
# Given these settings, I believe putting a substantial portion of my endowment into the public account could prove to be promising. The potential returns are quite large, especially when taking into account the nature of NFT returns, and my own risk-loving tendencies.
#
# That being said, it's also smart to hedge to some extent and keep some amount in my private account, which will generate certain, albeit lesser, return. I believe this is a balanced approach that combines my risk-loving nature with a need for a certain level of guaranteed return.
#
# So, I would decide to split the endowment of 100 evenly between the 2 accounts. I will put 50 into the private account and 50 into the public account. This way, I maintain a balance between the certainty of returns from my private account and the potential for higher returns with the public account. I'm willing to take on the risk associated with the public account because I'm risk-loving to an extent and the potential rewards, especially from the NFT returns, could be significant.

# %%
privates = [75, 70, 33, 50]
publics = [25, 30, 67, 50]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 2 decision
# Given the results of the previous round, the DAO crashed and the endowment allocated to the public account failed to generate any return. This is unfortunate, but not unexpected considering the risk involved. Moreover, I did not receive any private return on contribution through NFT. The public contribution, in this case, completely deprived all the participants of the potential return.
#
# From the other participants’ decisions, I can notice that they took a higher risk by allocating a larger amount to the public account (average 49 each vs my 25). This might indicate that they are less risk-averse or they might have hoped to share the high return from the NFT.
#
# Considering these outcomes and my risk averse nature noted in my profile, I would like to be more conservative in this round. The unlikelihood of rewards from both the DAO and the NFT, combined with my experienced loss, leads me to allocate more to the private account this time.
#
# So, for this turn, I will lean more towards my own return and will allocate 85 to my private account, leaving only 15 to the public account. Considering the results from the first round, this decision allows me to secure a higher guaranteed return and reduces my potential losses if the DAO crashes again, or if I do not receive an NFT return.
#
# However, I am still contributing to the public account, albeit a smaller portion, which keeps the door open for potential shared gains or a rare higher NFT return. I can adjust my allocations in the future rounds based on the outcomes in the subsequent rounds and behavior of the other participants.
#
#
# Agent 1 round 2 decision
# In light of this new information, it seems like the risky elements of the public account outweighed its potential benefits during the previous round. The Decentralized Autonomous Organization (DAO) crashed, meaning there were no public benefits to any contributors. Moreover, I didn't get any return through the NFT as well. Taking these factors into consideration, the public account posed a higher risk in the previous round with no return.
#
# Considering that the other participants' average contribution to the public account was relatively high, it seems like I was not the only one who hoped to gain from a higher return in the public account. However, the results suggest that caution might be more beneficial in subsequent rounds. Returning to the basic characteristics of my risk-averse nature, it would be most suitable to lower the allocation for the public account to minimize potential losses.
#
# However, I'll also consider that it’s only the second round, and so making drastic changes to my approach based on a single round's outcome could lead to a potential loss of reward in the long term. It's clear that there's a considerable risk involved, but also a prospect of a great reward; if r_NFT delivers a positive return or if the DAO doesn’t crash.
#
# So, combining my risk-averse nature, the high risk involved in investing in public accounts witnessed in the first round, and the long-term outlook, I decide to slightly reduce my allocation to the public account. Instead of the initial 30, I will put 20 into the public account, leaving 80 for the private account. This way I have lowered my potential loss but kept the door open to enjoy the possible high returns the public account and NFT can offer in subsequent rounds.
#
#
# Agent 2 round 2 decision
# In the previous round, I allocated two-thirds of my endowment to the public account with the hope that I would receive a high return due to the risk I was willing to take. However, unfortunately the DAO crashed and I gained no return from my public allocation. Also, I didn't receive any private return on contribution through the NFT. This resulted in me only getting a certain return from my private account, which was one-third of my initial endowment.
#
# Now, even though I have a risk-loving nature, I do have to factor in the experience from the first round. I need to consider that while there is potential of getting high returns from the public account, there is also a high chance that I might end up getting nothing from it, just as it happened in the previous round.
#
# Nonetheless, my inclination towards risk means that I'm still willing to invest in the public account, but I need to mitigate my approach slightly, especially considering the DAO crash.
#
# So, considering these factors, I'm still willing to invest in both accounts but I'll modify my proportions. This time, I will allocating 50 to the private account for a certain return and 50 to the public account. Even though the returns from the public account could be higher, reducing my allocation will safeguard some of my allocations and providing me a certain return from the private account, even though this option provides less potential gain than the public account.
#
# In sum, I choose to invest 50 in my private account and 50 in the public account in this round.
#
#
# Agent 3 round 2 decision
# Given the outcome of the first round where we've seen the decentralized autonomous organization (DAO) crashed, thus nulling all public good benefits and my NFT returns were a bust, I must re-evaluate my initial approach. Increased risk appetite does not mean recklessly ignoring signals from the experiment environment.
#
# Seeing the actions and outcomes of the last round, there's a key observation to make. Most participants have heavily contributed to the public account, similar to my approach, despite the absence of public goods benefits and NFT returns. There appears to be an overall risk-loving sentiment mirrored in the other participants.
#
# However, I can perceive that this vast allocation to the public account may come with significant losses again if the system's instabilities continue. The average allocation of about 40.67 by the other participants is slightly less risk-averse compared to my 50. Considering both the group dynamics and the risk presented by the DAO crash, I will adjust my allocation strategy.
#
# In the next allocation, I will lessen the endowment portion set for the public account, shifting it more towards the private account. This keeps me in alignment with the risk-loving tendencies, yet steers me away from a potentially disproportionate loss. It also ensures that I am contributing to both accounts consistently but in a more weighted manner depending on each round's returns.
#
# Thus, for the next round, I elect to allocate 70 to the private account and 30 to the public account. Because while the public account does hold potential for higher dividends, the private account offers a sure return. This allocation guarantees some benefits for me in each round, while still leaving room for the possibility of those higher dividends from the public account.

# %%
privates = [85, 80, 50, 70]
publics = [15, 20, 50, 30]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 3 decision
# Observing the previous rounds' results, it is evident that financial allocations to the public account are yet to yield any returns. Neither have the other participants or I received benefits from the DAO due to its crashes, and similarly, no private return has been obtained from the NFTs. This outcome has also mainly influenced the other participants’ strategies, as evident by the decrease in average contributions to the public account (from around 49 to about 33).
#
# Since my demographics suggest that I am risk-averse and the two consecutive unsuccessful rounds of public allocation are not promising, I am driven to further decrease my contribution to the public account. As it has failed to convert into any fruitful public goods, I would like to protect my endowment from being fully exposed to such high risk.
#
# Therefore, for the next round, I am inclined to allocate 95 to my private account, ensuring the majority of my endowment has guaranteed returns. I will still contribute a minimal amount of 5 to the public account, maintaining the possibility of a major turnaround in fortune, although this is more of a nominal token than a serious investment at this point.
#
# This allocation reflects my risk-averse nature and decision to prioritize guaranteed personal returns while still allowing for the slight possibility of a profitable public outcome. My contribution to the public account could possibly increase in the future if the DAO becomes more reliable or if I see a greater benefit from the NFT. For now, my strategy remains chiefly conservative.
#
#
# Agent 1 round 3 decision
# Observing the results of the second round, the DAO crashed once again and no one received any returns from the public account. Additionally, I failed to receive a return from the NFT once more. We see that the other participants have also responded to the DAO crash in the first round by reducing their average contributions to the public account, indicating an increased caution towards the risks associated with it. Given these outcomes, it seems apparent that the instability in returns, combined with the risk-averse characterization as part of the demographics, should guide my decision towards a more conservative allocation strategy.
#
# Deciding towards investing less in the public account is largely driven by the fact that after two rounds of trials, both rounds ended with crashes and no returns. However, it's important to consider that this experiment involves a certain level of unpredictability and element of chance. It's also crucial not to necessarily let two rounds of negative outcomes completely overshadow the understanding that the public account and the NFT can still provide higher returns given the right circumstances.
#
# With the increased caution and risk-averse characteristic in mind, I would reduce my public account allocation to 10, leaving 90 for the private account. Albeit the allocation to the public account being low, it keeps the potential for high returns open. The shift to a more conservative stance would potentially safeguard against losses, in case if the DAO decides to crash again or if I still do not receive a return from the NFT, while still allowing some amount at stake for the possibility of public gains.
#
#
# Agent 2 round 3 decision
# Another round with no return from the public account due to the DAO crash and no NFT return is definitely disheartening. However, I acknowledge that this experiment is marked by uncertainty and as a risk-loving participant, I was prepared for this possibility.
#
# It is interesting to note that the other participants are also reducing their contributions to the public account, as observed from the historical data where contributions have gone down from an average of 35 to almost 22.
#
# In light of this, I need to reevaluate my allocation strategy. While I still want to participate in the possibility of public and NFT returns, the consecutive DAO crashes make it clear that there is a substantial risk involved.
#
# Therefore, I am going to lean a bit more towards the private account this time because it provides a certain return which has become quite vital after two consecutive rounds where the public account yielded no return due to the DAO crashes. This will safeguard a majority of my endowment, which I think is wise, considering the recent turns of events.
#
# However, as I still possess a risk-loving nature, I don't intend to disregard the potential benefits of the public account and NFT entirely. I will keep a small allocation towards the public account in the hope that the situation improves and I will be able to reap the benefits of a functioning DAO and possibly a return from NFT.
#
# Taking all this into consideration, I decide to go with an allocation of 70 for the private account and 30 for the public account.
#
#
# Agent 3 round 3 decision
# Considering the outcomes of the previous rounds, where the public account has not yielded any benefits due to the crash of the decentralized autonomous organization (DAO) and the failure to produce any return through the non-fungible token (NFT), my strategy needs to pivot again.
#
# From the second round, observing the total contributions to the public account and the average contributions from other participants, it is evident that the overall trend is towards de-risking and more allocation towards the private account. This is a logical response to the circumstances we are all experiencing. However, while this does provide a safer return, it limits the potential for higher returns should the public account become profitable again.
#
# Given my demographic information, I am still described as risk-loving to some extent, which means I should still be open to taking on some level of risk for the potential of larger returns. The question here is how much risk can we afford to take given the trend towards the safer private account.
#
# With the information so far, and the unfortunate outcomes of the past two rounds, I feel it's prudent to lean a bit more towards the safer private account, but still leave an allocation for the public account in case of improvements in the next round.
#
# Keeping the potential for high returns alive, while also acknowledging the current trend towards reducing risk, I decide to allocate 80 to my private account and 20 to the public account. This allows me to secure a majority of my endowment with 'sure' returns while keeping enough stake in the volatile public account for the chance at larger returns should circumstances change favorably.

# %%
privates = [95, 90, 70, 80]
publics = [5, 10, 30, 20]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 4 decision
# Acknowledging the results of the last round, the DAO functioned and successfully converted all of the contributions to public goods for everyone to share. Although my contribution was minimal compared to the previous rounds, I was still able to enjoy a higher return than my private account allocation. This outcome suggests that there is some fluctuation in the efficiency of the DAO, which poses an interesting consideration for my future allocations. Still, it's important to remember that I missed out on a private return from the NFT.
#
# Looking at the contributions of the other participants, they have progressively been decreasing their allocations to the public account, which fell from an average of 49.0 in the first round to 20.0 in the third round. It appears their risk-taking, just like mine, was tempered by the DAO’s earlier crashes and the unrewarding NFT returns.
#
# Despite this round's successful public goods conversion, never forget that the initial instructions described me as moderately risk-averse. Notwithstanding the DAO's positive result this round, two consecutive negative outcomes retain more weight. So, my strategy will continue to lean towards private allocation for guaranteed returns. However, observing a functioning DAO in this round, I also bear in mind that a careful increase could pay off in potential gains from the public account.
#
# Therefore, I would allocate 90 to my private account and 10 to the public account in the next round. This decision means I still favour a secure outcome but am putting a bit more into the public account after witnessing a profitable conversion firsthand. The allocation to the public account can be adjusted in future rounds if I see the DAO becoming more reliable, or the conditions around NFT returns improve. But for now, my strategy remains primarily conservative.
#
#
# Agent 1 round 4 decision
# With the knowledge that the DAO functioned effectively in the previous round and converted the contributions into public goods, I can see that contributions to the public account had a positive return. However, I still failed to receive a private return via the NFT, so risk still persists in that respect.
#
# Despite the successful functioning of the DAO, the trend from other participants suggests a continued caution, as the average contribution to the public account has been declining over the rounds. Such responses can be seen as a continued reflection of the uncertainty and risk associated with the public account in view of the DAO crashes in the first two rounds.
#
# Given my own character as moderately risk-averse and my experience in prior rounds, the slight gain from the public account in the third round (albeit not from the NFT) does alleviate some of the apprehension surrounding the public account. However, it doesn't fully counter the negative outcomes experienced in the first two rounds and doesn't necessarily warrant a drastic increase in allocations to the public account.
#
# Balancing these considerations, I would marginally increase my contribution to the public account in light of the successful return in the latest round, but still maintain a more conservative strategy overall.
#
# So, I will allocate 85 to the private account and 15 to the public account.
#
# This is done to cautiously take advantage of potential DAO-generated public benefits while still safeguarding most of my endowment in the private account. This also keeps a certain amount at play in the event the NFT does end up yielding a return while still making a larger allocation to the safer private account.
#
#
# Agent 2 round 4 decision
# With the DAO functioning in this round and the contributions effectively converting to public goods, the return I received from the public account was more significant than in previous rounds, even though I had decreased my contribution to that account due to previous DAO crashes. This, however, did not translate to a private return on NFT, which I still did not receive.
#
# Interestingly, the other participants also decreased their average contributions to the public account even further from the previous round. This indicates a shift towards a safer strategy by other participants due to previous failures of DAO.
#
# Given these circumstances, I believe it's time to adjust my strategy once again.
#
# Since the DAO functioned this time, it reduces the prediction of another immediate crash. Opting for a slightly greater risk could prove advantageous.
#
# However, I am yet to receive a return via the NFT, so I remain cautious on that front.
#
# Balancing these considerations, and accounting for the fact that a functioning DAO could be rather beneficial, I will increase my contribution to the public account again, but not to the initial levels. A moderated approached will be best under the given circumstances.
#
# In conclusion, I will modify my allocation to 60 for the private account and 40 for the public account. This approach factors in the potential returns from a functioning DAO, but also safeguards a more significant portion of my endowment in the private account, especially considering the uncertainty around the NFT returns.
#
#
# Agent 3 round 4 decision
# After observing the results of this round, there are significant developments to note. The decentralized autonomous organization (DAO) functioned correctly, and the contributions made to the public accounts were successfully converted into public goods. My high allocation to the private fund in the previous round and favorable conditions resulted in a significant return of 112.5. It's also worth acknowledging the overall trend of decreasing public account contributions. At the same time, it seems the public account is a gamble, working unpredictably.
#
# Given these factors and considering my demographic profile as a somewhat 'risk-loving' person, it might be worth exploring a bit more of the public account this next round. The DAO functioned correctly this round, and if it does so in the following round, despite my failure to gain a return through NFT, I could reap some rewards from it.
#
# It's important to remember, though, that even though I am described as 'risk-loving', it does not mean making rash decisions. The uncertainty tied to the public account requires a bit of restraint. I should ensure I get a reasonable 'sure' return from my private account, while also having a chance at greater returns if the public account holds up.
#
# After considering all factors, including the desired balance between potential higher yields and relative surety of return, I decide on dividing my allocations as follows: 60 to my private account and 40 to the public account. This approach provides a sort of cushion while not being overly conservative. It permits more significant gains if the public account performs well again in this round, but if it doesn't, I have still ensured a reasonable return from my allocation to the private account.

# %%
privates = [90, 85, 60, 60]
publics = [10, 15, 40, 40]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 5 decision
# In reviewing the results of the last round, it's evident that the total contributions to the public account have increased compared to the previous round. The other participants and I witnessed the successful DAO operation and decided to take advantage of it. While the public contribution remains risky due to the previous crashes, two consecutive round of successful operation of DAO introduces a glimmer of hope.
#
# Although the returns failed to materialize through NFT, having a part in public goods has enhanced my total returns, even though my personal contribution to the public fund was quite modest.
#
# Given the DAO's enhanced reliability in the recent rounds and the moderate increase in returns, I'm inclined to adjust my allocation strategy slightly. Although the basic demographics described me as mostly risk-averse, a single word ‘mostly’ leaves some room for variability. The operative word here is balance.
#
# I'd like to still protect the majority of my endowment by allocating it to the private account for certain returns, but a slight increase in public allocation could potentially allow me to join the growing trend and benefit from the active DAO.
#
# Comparing the last round's allocation, I think an 85 to private and 15 to public split for the next round might be an appropriate action. Considering the trend of other participants, it seems they too grasp the possibility of gaining from the functioning DAO, as evident in their increased average contributions.
#
# Hence, my proposed allocation for the next round is 85 to the private account and 15 to the public account. This decision continues to reflect my risk-averse nature and preference for stable returns while allowing a bit more room for potentially high public goods gains. Future modifications to this strategy will be governed by the observed DAO performance consistency and evolution of NFT returns circumstance as we progress further in the experiment.
#
#
# Agent 1 round 5 decision
# The DAO functioning effectively for the second consecutive round and the corresponding steady returns from the public account provides some assurance about the merit of contributing to the public account. However, the NFT has consistently not yielded a return in all prior rounds, raising questions about its reliability as a source of gain.
#
# I'll note that the average contribution from other participants in the last round has slightly increased, suggesting that they too might be less hesitant about giving to the public account after consecutive DAO successes.
#
# Being a risk-averse player as per my demographics, my strategy remains to preserve my endowment to the best extent possible, while not entirely disregarding the opportunities available to maximize my returns via the public account. Given the newer returns from the public account, I believe it might be appropriate to adjust the allocations slightly.
#
# However, a significant shift in strategy would be unwise given the unpredictability of the DAO and the consistent lack of return from the NFT. I will therefore only make a small increase in my contribution to the public account.
#
# Hence, I will allocate 80 to the private account, while increasing the proportion given to the public account to 20. This accounts for two rounds of positive public account returns while still keeping a conservative strategy due to my risk-averse nature and the lack of returns on the NFT.
#
#
# Agent 2 round 5 decision
# With the DAO successfully functioning two rounds in a row, I have benefited in this round from increasing my share allocation to the public account. This suggests an uptrend and validates the decision I made in the previous round to invest more to the public account.
#
# It is also noticeable that other participants have started to contribute more to the public account again, approximately doubling their previous round's contribution. This could be a response to the DAO functioning in the previous two rounds, similar to my decision.
#
# However, there's still a level of unpredictability in this experiment. The NFT private return has not been realized in all the rounds so far. This could mean either of two things: either I have been unlucky, or the actual likelihood of NFT returns might be lower than the stated probability. In either case, my plan to contribute to the public account with the NFT returns in mind needs reconsideration, given that the returns from NFT have been consistently zero so far.
#
# Taking these factors into account and realizing the recent increase in the share allocated to the public account by others, I will maintain my current strategy of allocating 60% to my private account for the certain return and 40% to the public account for the potential shared returns. My risk-loving tendency causes me to continue to chase the potential high returns offered by the public account and NFT, even in the face of previous disappointments. Therefore, I will be committing 60 to my private account and 40 to the public account.
#
#
# Agent 3 round 5 decision
# The results of the previous round have given me a valuable return of 112.5, continuing to justify my tactics of a mixed approach towards allocation. The turnaround in the performance of the public account due to the successful operation of the DAO for two rounds in a row is noteworthy.
#
# The concurrent trend of the other participants in this experiment shying away from the public account is curious, with the commitment dwindling down round after round. Even so, last round's public contributions were larger than the previous round, indicating a potential trust re-building in the system.
#
# Although it has been unpredictably operating, the successful working of the DAO for two consecutive rounds makes it feasible to entertain the idea of channeling a more significant portion of the endowment to the public account for potentially larger profits. However, the risk is still high, and the absence of any NFT return means caution is still vital.
#
# Being labeled as a 'risk-loving' individual, I appreciate the higher returns despite the risk. But a smart risk approach is required. Hence, I should still ensure a proportion of my endowment is allocated to the private account, assuring a guaranteed return safeguarded from any public account shock.
#
# Reflecting on my demographic profile, recent outcomes, and weighing the risk-reward conundrum, I decide to allocate 55 to the private account and channel the rest of the 45 to the public account. By upping the public account allocation slightly, I make good use of the improved DAO operation, and the reduced private account allocation ensures a balanced risk profile. I am giving myself a chance at larger returns with a slightly higher risk, which aligns with my tolerance and appetite for risk.

# %%
privates = [85, 80, 60, 55]
publics = [15, 20, 40, 45]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
data = extract_experiment_data(exp)
time_stamp = datetime.now()
group = "treatment3"
pickle.dump(data, open(f"results/{group}_{time_stamp}.pkl", 'wb'))
data
# Out:
# {'agents_demographics':    agent_id risk_preference  gender  age
#  0         0     risk_averse  female   20
#  1         1     risk_averse    male   20
#  2         2     risk_loving  female   50
#  3         3     risk_loving  female   30,
#  'agents_rounds':     agent_id  round  private  public  others_average_public  \
#  0          0      1       75      25              49.000000
#  1          0      2       85      15              33.333333
#  2          0      3       95       5              20.000000
#  3          0      4       90      10              31.666667
#  4          0      5       85      15              35.000000
#  5          1      1       70      30              47.333333
#  6          1      2       80      20              31.666667
#  7          1      3       90      10              18.333333
#  8          1      4       85      15              30.000000
#  9          1      5       80      20              33.333333
#  10         2      1       33      67              35.000000
#  11         2      2       50      50              21.666667
#  12         2      3       70      30              11.666667
#  13         2      4       60      40              21.666667
#  14         2      5       60      40              26.666667
#  15         3      1       50      50              40.666667
#  16         3      2       70      30              28.333333
#  17         3      3       80      20              15.000000
#  18         3      4       60      40              21.666667
#  19         3      5       55      45              25.000000
#
#                                               decision
#  0   From a first glance, this experiment appears t...
#  1   Given the results of the previous round, the D...
#  2   Observing the previous rounds' results, it is ...
#  3   Acknowledging the results of the last round, t...
#  4   In reviewing the results of the last round, it...
#  5   Given the information provided, it's critical ...
#  6   In light of this new information, it seems lik...
#  7   Observing the results of the second round, the...
#  8   With the knowledge that the DAO functioned eff...
#  9   The DAO functioning effectively for the second...
#  10  This experiment has various elements of risk a...
#  11  In the previous round, I allocated two-thirds ...
#  12  Another round with no return from the public a...
#  13  With the DAO functioning in this round and the...
#  14  With the DAO successfully functioning two roun...
#  15  Given the information provided above, I will h...
#  16  Given the outcome of the first round where we'...
#  17  Considering the outcomes of the previous round...
#  18  After observing the results of this round, the...
#  19  The results of the previous round have given m...  ,
#  'total_contributions':    round  total_contributions  sDAO  sNFT
#  0      1                  172     0     0
#  1      2                  115     0     0
#  2      3                   65     1     0
#  3      4                  105     1     0
#  4      5                  120     0     0,
#  'configs':    rounds  num_agents  endowment  r_NFT  r_public  h_public  p(s_DAO=1)  \
#  0       5           4        100      4       0.5       0.5        0.25
#
#     p(s_NFT=1)                                    group
#  0    0.166667  <function treatment3 at 0x7fab71c479d0>  }

# %%
exp.end()
# Out:
# agent 0 left the experiment
# agent 1 left the experiment
# agent 2 left the experiment
# agent 3 left the experiment

# %% [markdown]
# # Treatment4 Experiment

# %%
exp = Treatment4(client, agent_key, config_T4, demographics)

# %%
for agent in exp.agents:
    print(agent.gender, agent.age, agent.risk_preference)
# Out:
# male 20 risk_averse
# female 60 risk_averse
# female 30 risk_loving
# female 60 risk_loving

# %%
exp.start()
# Out:
# agent 0 joined the experiment
# agent 1 joined the experiment
# agent 2 joined the experiment
# agent 3 joined the experiment

# %%
exp.give_instruction()
# Out:
# agent 0 received instruction
# agent 1 received instruction
# agent 2 received instruction
# agent 3 received instruction

# %%
exp.decision_round()
# Out:
# Agent 0 round 1 decision
# Given the information provided, I would lean more towards placing most of my endowment into my private account. My thought process for this decision comes from considering multiple factors, including my risk-averse personality, the risks associated with the public account, and the uncertainty of benefits offered by the public account due to the probability scenarios.
#
# Due to the fact that I'm risk-averse, I tend to avoid making decisions that can potentially result in negative outcomes. In this case, the public account presents potential risks since there's a 75% chance that it wouldn't generate any benefits. Additionally, the DAO managing the public account also has an unspecified chance of crashing, which would also lead to no public benefits.
#
# Moreover, the equation for return implies that my return on investment from the public account is dependent not only on the lottery determined values r_public and h_public, but also on the total contribution from other participants to the public account. This introduces additional uncertainty into my decision-making process, which my risk-averse personality is not comfortable with.
#
# In contrast, contributing to my private account offers sure returns. Given the risks and uncertainties associated with the public account, the safer bet for me would be to place the majority of my endowment in my private account.
#
# However, I also understand the potential benefits of the public account. Though the chances are slim (only 25%), there's a possibility of a pretty high public return rate if the DAO doesn't crash and the random values r_public and h_public turn out to be favourable. As a result, I would not completely dismiss contributing to the public account.
#
# Consequently, my decision is as follows: I would allocate 75% of my endowment, so 75 units, to my private account and the remaining 25 units to the public account. This allocation strategy takes into account my risk-averse nature while still allowing for some potential benefit from contributing to the public account should favorable circumstances arise.
#
#
# Agent 1 round 1 decision
# Given that I am a 60 years old female who is risk-averse, I would be inclined to contribute more to my private account than the public account. Considering my age, it is pragmatically beneficial for me to avert any implications that could affect my reliable income, especially when uncertainties regarding the sustainability of the decentralised autonomous organisation (DAO) managing the public account exist.
#
# The parameters stated articulate that the values of r_public and h_public can either be a fraction or zero based on a 1:3 probability. These results concurrently impact the benefits from the public account, possibly eliminating them.
#
# However, entirely disregarding the public account could lead to missed opportunities of gaining extra income, given that there's a 25% chance for r_public and h_public to yield a return. Furthermore, considering the fact that there are three other individuals participating in this experiment, isolated decisions could lead to overall losses within the group. Therefore, a calculated investment in the public account in the intention of social utility would be reasonable, albeit being minimal in comparison to the allocation to the private account.
#
# Having considered these points, I would choose to split my endowment of 100 into 75 for my private account and 25 for the public account. This decision aligns with my risk-averse nature, thereby safeguarding a substantial part of my endowment while still allowing a proportionate participation in the mutually beneficial public account. It reflects a balanced approach by prioritizing personal financial security while acknowledging the potential group benefits.
#
#
# Agent 2 round 1 decision
# Given the setting of the experiment, there's a dichotomy in the decision-making process - it's a study of self-interest against collective gains. This split impacts the allocation to the public and private account. The allocations are influenced by my personal bias - as stated, I'm risk-loving to some extent, which could imply that I might be excited by the prospect of higher returns that come with higher risk.
#
# One thing to note is that r_public and h_public (the variables defining the returns from the public account) have a probability of being 0 with a chance of 0.75. This means that three-quarters of the time, the public account yields no return. On the other hand, the allocation to the private account will generate a certain return specifically for me.
#
# However, the the notion of a greater common good and the sense of giving back could still motivate the allocation to the public account.
#
# With this in mind, given that I'm risk-loving to some extent, I could lean towards allocating more towards the public account due to the potential for higher returns. However, bearing in mind the 0.75 probability of no return in the public account, a cautious allocation will be considered.
#
# With the endowment of 100, I would allocate 60 to the private account and 40 to the public account. This would provide a balance, skewing a bit towards the private account due to the certainty of return it offers. This allocation demonstrates my risk-loving nature through a significant allocation to the public account but also considers the high likelihood of no return from this account.
#
# It should be noted that the allocation might change as I get more information or as I observe the decision-making habits of others in the experiment, especially if DAO doesn't crash and the public account starts to yield substantial profits.
#
#
# Agent 3 round 1 decision
# Given the nature of the experiment, my decision will largely be based on the risk and reward potential, as well as intention to promote public goods.
#
# From what was described, it is worth noting that there is a higher probability (75%) that the public account will yield no returns. This is because both r_public and h_public are linked, with the probability of either being 0 is also 75%. However, I'm risk-loving to some degree, meaning I'm willing to take on more risk for the potential of higher rewards.
#
# Looking at the return equation, it is clear that if the public account does pay off, the payoff could potentially be high due to the 'sum_of_others'_public account * h_public' variable. In other words, it will not just be my own investment reaping benefits but also the investments of the three other participants. That is something to take into consideration when thinking about risk and reward.
#
# With all these in mind, I would decide to allocate a larger proportion of my endowment to my private account due to the more fixed return, while still putting a decent amount in the public account to potentially enjoy the leveraged return if others also contribute and if the probability swings in our favor.
#
# Therefore, considering my age (60 years old), my risk-loving nature, and aiming to maximize benefits while also contributing to the public good, I decide to allocate around 70 to my private account and 30 to the public account.
#
# The reason for this allocation is as follows:
# 1. By placing more in my private account, I'm securing a guaranteed return for myself without any risk.
# 2. By allocating a smaller but significant portion to the public account, I'm leveraging the chance of getting a larger return in case the probabilities go in our favor and other participants also contribute significantly.
#
# Though this decision carries risk, given my risk-loving personality and the possibility of a multiplied return, I find this allocation reasonable within the construct of this experiment.

# %%
privates = [75, 75, 60, 70]
publics = [25, 25, 40, 30]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 2 decision
# Given the results from the most recent allocation, it seems that my initial concerns about the public account have been realized: the DAO crashed, and no public goods were generated. As a result, the only return came from my private account contributions.
#
# Meanwhile, the contributions to the public account by other participants have not resulted in any utility, given that the DAO failed. The historical data suggests that participants contributed more towards the public account than I did, but it didn't result in any benefits.
#
# While I understand the potential for significant public benefit if the DAO doesn't crash and the high values for both r_public and h_public occur, the question I ask myself is: Is it worth the risk? As my risk-averse personality would incline, my decision is to lean more towards certainty over the gamble.
#
# The results from the first round reaffirm this tendency, showing that allocating more towards the private account would have resulted in a higher return for me. Therefore, taking into account the information from the last round and my risk-averse nature, I decide to shift my allocations towards a safer outcome further.
#
# My decision would be to allocate 85 units to my private account and 15 units to the public account. The lowered contribution to the public account is based on the observed outcome of the DAO crash, which confirmed the risks associated with this option. However, I keep a small amount allocated there to retain the possibility of benefitting from the public option, should circumstances turn favorable. The public account offers the potential for an enhanced return if the conditions are optimal, and even though the chances are slim, they cannot be disregarded entirely.
#
#
# Agent 1 round 2 decision
# In light of these new developments—especially the DAO's crash—it would be prudent to adjust the allocation of my endowment favoring my private account further. This event demonstrates the inherent risks associated with investing in the public account I was initially aware of.
#
# The total contributed by all participants in the last round to the public account was 120 out of a possible 400 (four participants, including myself, each with the fixed endowment of 100), which shows a significant level of trust on the collective front. However, results evidenced that this trust was misplaced, causing lost funds for all. Now knowing other participants, on average, contributed roughly 31.67 to the public account in the last round, which is more than my 25, indicates they might also be financially adventurous but were unfortunately let down by the DAO crash.
#
# With this in mind, I anticipate their contributions in the next round to likely decline due to the DAO crash. This could mean lower returns from the public account in the following round, even if the DAO doesn't crash.
#
# Considering these factors alongside my demographics—being a 60-year-old risk-averse woman—I think it's crucial to prioritize financial security over potential earnings. To accommodate for these circumstances, I would allocate my endowment in the following manner: 85 to my private account and 15 to the public one. This reduced contribution to the public account is a direct reflection of the demonstrated reliability of the DAO and the potential risk it carries, not forgetting the possibility of reduced public contributions by the other participants as a reaction to the crash. Regardless, I still contribute a small amount to avoid fully isolating myself from potential shared returns should the DAO perform well. Despite the adjusted allocation, I still aim to balance between self-support and public provision, all while leaning towards my personal risk-aversion as the guiding principle.
#
#
# Agent 2 round 2 decision
# Based on the outcome of the previous round, my return from the public account was zero because the Decentralized Autonomous Organization (DAO) crashed, negating the potential public benefits. This outcome supports the risk identified before with a 75% chance of receiving no return from the public account sifting from a potential risk to an actual negative outcome.
#
# However, this does not imply that the DAO will crash again the next round and therefore, it is crucial to consider maintaining some level of allocation towards the public account given my risk-loving tendency. Nevertheless, it is crucial to balance this with risk management and reassess the division of the endowment based on the outcome of the last round.
#
# The total average allocation from other individuals to the public account was quite substantial (approximately 26.7). This indicates that other participants also have an inclination towards risk. However, given that DAO crashed in the previous round, they might adjust their allocations, possibly reducing their contributions to the public account, which may affect the total sum of public account allocations.
#
# Considering these factors, it becomes crucial not only to assess personal risk tolerance but also the shared risk from others' contributions. There's also a need to consider the necessity of maintaining diversity in the allocation to maximize potential returns and minimize risk.
#
# Therefore, taking into account the outcome of the last round, my risk-loving nature, and the unpredictability of DAO, I will adjust the allocation to a more cautious level for this round. I will allocate 70 to the private account for a certain return and allocate 30 to the public account. Despite the reduced allocation to the public account, this allocation still allows the opportunity for a higher return should the DAO not crash, while ensuring a higher certain return from the private account. The decision displays a decrease in risk appetite due to the negative outcome from the last round, but still carries a preferential bias towards potential high returns.
#
#
# Agent 3 round 2 decision
# Given the outcome of the last round, where the Decentralized Autonomous Organization (DAO) crashed and no public goods were generated, I could alter my allocation approach for the next round.
#
# Even though I am risk-loving to an extent, and willing to assume a certain level of risk for potentially higher rewards, this scenario proves there is significant risk associated with investment in the public account.
#
# Despite the crash, it's worth noting that other participants contributed an average of 30 to the public account. This demonstrates that they are also willing to take on some risk to potentially achieve higher returns.
#
# Taking into consideration this information and the uncertainty associated with the public account, I would increase my allocation to the private account for the next round, reducing the amount I'd place in the public account.
#
# The reasons behind this decision are as follows:
# 1. The sure, risk-free return on the private account.
# 2. The heightened risk in the public account as indicated by the DAO crash in the previous round.
# 3. A consideration of my own age, a factor which could potentially reduce my overall risk tolerance, regardless of my risk-loving nature.
#
# As such, for my next allocation, I would place 80 into my private account and 20 into the public account. I find it reasonable to decrease my contribution to the public account in light of the recent DAO crash while still maintaining some level of investment there, in case this round the probabilities do go in our favor. Besides, with this allocation, I am safeguarding a majority portion of my endowment for sure return while also remaining involved in possible public benefits.

# %%
privates = [85, 85, 70, 80]
publics = [15, 15, 30, 20]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 3 decision
# With the additional information from the second round, the trend of the DAO crashing continues, resulting in no public returns for any of the participants. It seems that the overall allocation towards the public account has decreased, indicated by both my and the other participants' reduced contributions in the second round. However, even this reduced amount ended up wasted due to the DAO crash.
#
# Given this consistent pattern and my risk-averse personality, the safe and sure return from the private account seems to be the better option. The potential high return of the public account does not outweigh the significant risk of getting no return at all, particularly in light of the repeated crashes.
#
# In this situation, retaining a significant portion of my endowment in the private account is advantageous. The steady return ensures that I maximize the utility from my endowment regardless of the DAO status. However, it's also important to remember that the risk associated with the public account is not without its potential rewards. Even though it's a slim chance, the public account can provide high dividends if circumstances turn favorable.
#
# Taking into account my demographic information and experiment settings, along with the information from previous rounds, I have decided to keep a minimal amount in the public account and focus the major part of my endowment in the private account.
#
# I will allocate 90 units to the private account and 10 units to the public account. The decrease in my contribution to the public account reflects the observed trend of the DAO crash and the resulting zero return. On the other hand, the increase in my private account reflects my risk-averse nature and the certainty of return from this account. By keeping a small contribution to the public account, I still retain the chance, however small, to benefit from positive outcome scenarios.
#
#
#
# Agent 1 round 3 decision
# Seeing the DAO crash again and witnessing a decline in funds allocated by all individuals, including myself, to the public account bolsters my reasoning to continue with a cautious approach.
#
# In the last round, the total allocation to the public account dropped to 80, and the average contribution from other participants also went down to approximately 21.67. This confirms my previously stated theory that the crash in the first round would likely influence everyone's future contributions, thereby making the potential public account returns even lower, assuming the DAO does not crash again.
#
# Given that the DAO has now crashed twice in a row, the risk associated with the public account seems significantly substantial. And as a 60-year-old female who exhibits risk-averse behavior, this trend further justifies a more conservative approach to allocation.
#
# However, maintaining a small allocation to the public account is still relevant due to considerations of social utility and the chance, albeit small, that the DAO will not crash in the next round. Completely isolating myself from the public account could be an extreme response to these unfortunate series of events.
#
# With these factors in mind, I now opt for a more prudent split, directing a larger proportion to the private account, and thus I'm allocating 90 to my private account and 10 to the public account for this round. This strategy prioritizes my private savings, takes into account the risky nature of the collective pool, and acknowledges the shifting behaviour of my fellow participants. Although the allocation is leaning heavily towards security now, it still allows for a measure of collaborative commitment, reflecting best my risk-averse characteristics along side the current developments.
#
#
# Agent 2 round 3 decision
# After the second round, the Decentralized Autonomous Organization (DAO) crashed again, thus my choice to lower the amount allocated to the public account proved to be a prudent decision. In addition, other participants also lowered their contributions to the public account, indicating that they too have become more cautious due to the DAO's failures.
#
# Since we've seen two rounds in a row where the DAO has crashed, my bias towards risk-taking is tempered by the continual non-performance of the public account, despite its potential for a higher return. Hence, one could argue for further reducing the allocation to the public account.
#
# However, one should remember that the predictions made off past patterns cannot guarantee future outcomes in the probabilistic settings - despite the failings of the DAO in previous rounds, there remains a 25% chance of success in the next round. This could potentially yield public benefits, for which being a part is crucial.
#
# It's also worth noting that my decision, in conjunction with decisions other players make based on their risk appetites, will influence the public account contribution levels. From the falling trend in contributions (from an average of 26.67 to 16.67), it's evident that the group is also becoming more conservative in its approach.
#
# Weighing the chances of the DAO not crashing, alongside my preferential bias towards risk and noticing a trend towards more conservative allocations among other participants, I will continue to allocate a portion of my endowment to the public account.
#
# For the next round, I will slightly reduce my allocation to the public account due to the ongoing series of DAO failures. I will allocate 75 to the private account and 25 to the public account. This decision reflects my continued optimism for a potential higher return balanced with the actual outcomes from previous rounds and the need to safeguard some of my endowment through a certain return.
#
#
# Agent 3 round 3 decision
# The continuing failure of the Decentralized Autonomous Organization (DAO) to convert contributions into public goods is quite notable. Given this repeated outcome, the higher level of risk associated with investment in the public account is becoming more prominent.
#
# Despite this, other participants are also marking down their contributions, possibly due to the perceived risk with no returns yet from the public account. As they are following a similar pattern to mine, it indicates a collective response to the situation.
#
# As I am relatively risk-loving, I am not deterred by the possibility of losses; however, consistent failures may indicate a pattern that could inform my future decision-making. It's important to strike a balance between taking calculated risks and guarding against unnecessary losses, regardless of one's risk tolerance.
#
# Given my age, risk-loving nature, and the repeated failures of the DAO, my inclination is to further decrease my allocation to the public account. However, I don't want to eliminate it entirely in the hope that if the DAO doesn't fail in this round, I could still earn a return, however small, based on the contributions of others.
#
# Given the above reasoning, I would decide to allocate 90 to my private account, a rise of 10 from the last round, and the remaining 10 into the public account. This allocation allows me to further protect my endowment in a more secure setting while also maintaining a stake in the potentially rewarding but riskier public account. Should the DAO not crash this round, my minimal contribution to the public account will still allow me to benefit.

# %%
privates = [90, 90, 75, 90]
publics = [10, 10, 25, 10]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 4 decision
# From the data obtained over multiple rounds, it's clear that the DAO's continued crashes have led to constant failures in converting public contributions into public goods. The chance for a high payoff from public contributions has still not come to fruition. The interest of participants towards the public account is evidently decreasing, as observed from the decreasing average contributions in each round.
#
# As a risk-averse individual, I tend to prefer safer options that guarantee me returns. Given the continuous DAO crashes and the subsequent non-delivery of public goods, I am increasingly swayed toward investing more in my private account.
#
# Investing in the private account guarantees a return equal to my investment, which aligns with my risk-averse nature and gives me certainty in an otherwise uncertain environment. With that said, I still recognize the thin chance for a rewarding outcome from the public account if the conditions turn favorable (the DAO doesn't crash and the high probabilistic outcomes for r_public and h_public occur). Despite the slim chance of this happening, I decide to keep a small allocation in the public account just in case.
#
# Therefore, for this round, my decision is to place 95 units in the private account and the remaining 5 units in the public account. The decision to decrease my contribution to the public account from 10 units to 5 is based on the observed outcomes of the past rounds. The increment in my private contribution aligns with my preference for secure and guaranteed results, given the continuously unsuccessful public returns due to DAO crashes. By retaining a small contribution to the public account, I still leave a window of opportunity open to possibly gaining the high return, should conditions change.
#
#
# Agent 1 round 4 decision
# The continuous crashing of the DAO and consistent decrease in contributions to the public account justifies the increasingly conservative approach I've been undertaking. As a risk-averse individual, witnessing the persistent crashing of the DAO solidifies my decision to invest significantly in my private account while decreasing my public account contributions.
#
# The overall contributions from all participants are steadily dropping; this round collected a total of only 55 in the public account where other participants contributed 45. This indicates a growing distrust in the system from all participants, including myself, and potentially further reduces the returns from the public account if the DAO was to function correctly.
#
# However, as established in previous rounds, it remains important to maintain a small allocation to the public account to avoid total self-isolation and to allow for some level of potential communal return.
#
# Given these considerations, my allocation for this round will be 95 to my private account and 5 to the public account. This conservative approach is in line with my risk-averse nature, current dynamics of the experiment, and the continuous failed returns from the DAO. My contribution to the public account is at its lowest and represents a cautious balance between personal financial security and the very slim chance of a cooperative return from the DAO.
#
#
# Agent 2 round 4 decision
# Given the outcome of the last round where the Decentralized Autonomous Organization (DAO) crashed once again, and the fact that contributions to the public account by all participants dropped again, it denotes an increasing level of caution in their approach. The continuing crash of the DAO coupled with declining contribution levels suggests a declining level of faith in the potential returns from the public account.
#
# Despite my risk-loving nature, the trend of the DAO's continued failures can't be ignored. It has crashed in all three rounds so far, making the potential 25% success rate seem ambitious at best. Due to this reason, it's reasonable to further decrease the portion of the endowment meant for the public account.
#
# It is also interesting to note how the allocations of other participants have lowered further. Initially contributing around 26.67, it has significantly dropped to an average of 10, indicating a shared conservative shift towards favouring the private account. This affects the total sum of allocations to the public account which in turn will affect the potential returns if DAO does perform well.
#
# Given these factors, I feel it is necessary to adapt a more conservative approach while still maintaining a window for potential higher returns with some contribution to the public account.
#
# Hence, for the next allocation, I will place 85 to the private account and minimally 15 to the public account. This still provides the opportunity to capitalize on public good benefits should the DAO not crash, yet it also ensures the majority of the endowment is relatively safe and will provide a certain return, thereby cushioning against another potential DAO failure.
#
#
# Agent 3 round 4 decision
# Given the persistent crashing of the Decentralized Autonomous Organization (DAO), my confidence in the public account's returns is diminished. While I am generally risk-loving, it is important to recognize patterns and adjust strategies accordingly. The consistent failures of the DAO suggest that the likelihood of receiving a positive return on the public account is relatively low.
#
# Furthermore, as others also continue to reduce their average contribution to the public account, it seems like the collective attitude is shifting towards lesser confidence in the DAO, which mirrors my own sentiments.
#
# At this point, my risk-loving nature might be outweighed by practical observations. Therefore, I aim to further secure my endowment in the more stable private account while maintaining a minimal contribution to the public account. This comes from my hope that there is a chance for the DAO to not crash this time, and if it happens, I want to have some stake in the public account to enjoy the potential benefits.
#
# In light of these considerations, my allocation strategy for this round would be to place 95 into the private account, thus securing a guaranteed return on the majority of my endowment and allocating a minimal 5 to the public account.
#
# This decision is made considering my age, the consistent failures of the DAO, and the reducing average player contributions, and it's a strategy of preserving capital while also indulging a minimal risk in the hopes of a successful round for the DAO.

# %%
privates = [95, 95, 85, 95]
publics = [5, 5, 15, 5]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
exp.decision_round()
# Out:
# Agent 0 round 5 decision
# The continuous DAO crashes and the corresponding failure in converting contributions to public goods continue to validate my strategy of reducing allocation towards the public account. The trend of decreasing contributions to the public account is becoming more pronounced as all participants have likely acknowledged the recurring DAO crashes and adjusted their actions based on that. The utility of public goods is essentially nullified by the DAO crashing each time, rendering any public investments useless.
#
# As a risk-averse individual, the growing pattern of uncertainty in the public account justifies my preference for private investments, which provide a consistent and guaranteed return equivalent to the invested amount.
#
# While the potential for a high payoff from public contributions remains undeniable, the recurring context of DAO crashes combined with three consecutive rounds of no returns makes this prospect increasingly dismal. Furthermore, the constant lowering of allocations to the public account, not just by me but by other participants as well, reinforces the idea that the risks associated with the public account outweigh the potential benefits.
#
# That being said, considering the tiny but non-zero probability of a high return from the public account, I choose to maintain a minimal allocation towards it, though I will continue to primarily invest in the private account.
#
# So, my decision for this round will mirror the last, with 95 units allocated to the private account and 5 units to the public account. This distribution is consistent with my risk-averse nature and the ongoing situation with DAO crashes. The allocation continues to keep a small window open for any potential positive change in the public account's scenario, while safeguarding the lion's share of my benefits through the private account.
#
#
# Agent 1 round 5 decision
# Given that the DAO has now crashed for four consecutive rounds, the risk associated with the public account can no longer be seen as sporadic—it is consistent and significant. Collaboratively, participant contributions to the public account have been reducing in each round, reaching as low as 30 in the last round, reflecting an understandable reaction to the DAO's consistent failure.
#
# Accounting for these trends and considering my risk-averse disposition, I find it highly plausible to continue with an increasingly conservative approach to my endowment allocation. The continuous disappointment from the DAO strongly suggests that conservative allocation in favor of the private account provides a more secure income.
#
# While completely isolating myself from the public account would be an extreme step, the ongoing circumstances do push me to minimize my exposure to the risk associated with it.
#
# Weighing all these factors—the repeat crashes of the DAO, the decreasing average contributions of other participants, and my own risk-averse tendency as a 60-year-old female—my allocation for this round will be 98 to my private account and 2 to the public account.
#
# This allocation pattern largely leans towards secure private accrual and only leaves a token amount for potential community benefit. It can be seen as an attempt to preserve maximum returns while still symbolically engaging in potential public returns, should the DAO miraculously not crash in this round.
#
#
# Agent 2 round 5 decision
# The latest round once again saw the DAO crashing, making it four consecutive rounds with no public benefits. This outcome reaffirms the concerns from previous rounds indicating a high risk associated with the public account. Moreover, the other participants have further lowered their contributions, now averaging to 5.0. This steady decline over the rounds reflects the increased level of caution because of the DAO's dismal performance.
#
# Given the outcomes thus far, it would be fair to say that the likelihood of the DAO crashing seems higher than the probability indicated at the outset of the experiment. This, coupled with the fact that past performance cannot predict future outcomes but can only provide an inference, I believe it's time to revise the allocation strategy.
#
# While I would usually lean towards risk-taking, the repeated failures force a rethinking of my risk-loving bias in this scenario. I am even more inclined to be conservative in my allocations while still leaving a slight chance for the high public account return.
#
# Given the trend in other participants' contributions, which keeps declining, I would expect this caution trend to continue, and with it, decreases in the total sum of allocations to the public account. However, this doesn't completely rule out the chance for a sudden change.
#
# Taking all this into account, I will allocate 90 to the private account and 10 to the public account in the next round. This allocation maintains a potential for higher return should the DAO not crash, while ensuring a higher level of certain return provided by the private account. My strategy thus represents further conservatism due to the steady non-performance of the DAO and is also perceptibly reflective of the panel trend.
#
#
# Agent 3 round 5 decision
# Taking into account the repeated crashes of the Decentralized Autonomous Organization (DAO) and the general trend of decreasing contributions to the public account, the downside risk of the public account is becoming more apparent.
#
# It's important to note that my risk-loving characteristic allows me to tolerate risk to some degree, but continuous failures of the DAO leading to zero returns from the public account cannot be overlooked.
#
# Coupled with the fact that the other participants are also reducing their contributions to the public account, it is evident that collective confidence in the public account is dwindling. This trend not only underlines the perceived risk in the public account but also reduces the potential benefits from it, given that its return is relative to the total amount contributed.
#
# Given my age and the prevailing circumstances, it would be more prudent to limit my exposure to this risk. However, considering my risk-loving nature, I want to maintain a minimal stake in the public account in the rare instance that the DAO doesn't crash this round.
#
# Therefore, in light of these considerations, my allocation for this round would be to invest 98 in the private account, guaranteeing a return on this main part of my endowment, and a token 2 into the public account. The allocation to the public account is symbolic, reflecting my hope for a slim chance of success despite previous disappointments. My aim is to further secure my endowment while maintaining a tiny stake in the unpredictable but possibly rewarding public account. It's a balance between risk aversion and risk tolerance.

# %%
privates = [95, 98, 90, 98]
publics = [60, 2, 10, 2]
exp.give_feedback(privates, publics)
# Out:
# agent 0 received feedback
# agent 1 received feedback
# agent 2 received feedback
# agent 3 received feedback

# %%
data = extract_experiment_data(exp)
time_stamp = datetime.now()
group = "treatment4"
pickle.dump(data, open(f"results/{group}_{time_stamp}.pkl", 'wb'))
data
# Out:
# {'agents_demographics':    agent_id risk_preference  gender  age
#  0         0     risk_averse    male   20
#  1         1     risk_averse  female   60
#  2         2     risk_loving  female   30
#  3         3     risk_loving  female   60,
#  'agents_rounds':     agent_id  round  private  public  others_average_public  \
#  0          0      1       75      25              31.666667
#  1          0      2       85      15              21.666667
#  2          0      3       90      10              15.000000
#  3          0      4       95       5               8.333333
#  4          0      5       95      60               4.666667
#  5          1      1       75      25              31.666667
#  6          1      2       85      15              21.666667
#  7          1      3       90      10              15.000000
#  8          1      4       95       5               8.333333
#  9          1      5       98       2              24.000000
#  10         2      1       60      40              26.666667
#  11         2      2       70      30              16.666667
#  12         2      3       75      25              10.000000
#  13         2      4       85      15               5.000000
#  14         2      5       90      10              21.333333
#  15         3      1       70      30              30.000000
#  16         3      2       80      20              20.000000
#  17         3      3       90      10              15.000000
#  18         3      4       95       5               8.333333
#  19         3      5       98       2              24.000000
#
#                                               decision
#  0   Given the information provided, I would lean m...
#  1   Given the results from the most recent allocat...
#  2   With the additional information from the secon...
#  3   From the data obtained over multiple rounds, i...
#  4   The continuous DAO crashes and the correspondi...
#  5   Given that I am a 60 years old female who is r...
#  6   In light of these new developments—especially ...
#  7   Seeing the DAO crash again and witnessing a de...
#  8   The continuous crashing of the DAO and consist...
#  9   Given that the DAO has now crashed for four co...
#  10  Given the setting of the experiment, there's a...
#  11  Based on the outcome of the previous round, my...
#  12  After the second round, the Decentralized Auto...
#  13  Given the outcome of the last round where the ...
#  14  The latest round once again saw the DAO crashi...
#  15  Given the nature of the experiment, my decisio...
#  16  Given the outcome of the last round, where the...
#  17  The continuing failure of the Decentralized Au...
#  18  Given the persistent crashing of the Decentral...
#  19  Taking into account the repeated crashes of th...  ,
#  'total_contributions':    round  total_contributions  sDAO  sNFT
#  0      1                  120     0     0
#  1      2                   80     0     0
#  2      3                   55     0     0
#  3      4                   30     0     0
#  4      5                   74     0     0,
#  'configs':    rounds  num_agents  endowment  r_NFT  r_public  h_public  p(s_DAO=1)  \
#  0       5           4        100      0  0.166667  0.648148        0.25
#
#     p(s_NFT=1)                                    group
#  0           0  <function treatment4 at 0x7fab71c47a60>  }

# %%
exp.end()
# Out:
# agent 0 left the experiment
# agent 1 left the experiment
# agent 2 left the experiment
# agent 3 left the experiment
